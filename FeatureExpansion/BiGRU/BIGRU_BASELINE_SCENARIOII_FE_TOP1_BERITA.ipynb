# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigram_Top1_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 28ms/step - loss: 0.6883 - accuracy: 0.5430 - val_loss: 0.6788 - val_accuracy: 0.5501
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6563 - accuracy: 0.6385 - val_loss: 0.6278 - val_accuracy: 0.7252
# Epoch 3/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.5859 - accuracy: 0.7878 - val_loss: 0.5475 - val_accuracy: 0.8110
# Epoch 4/10
# 351/351 [==============================] - 9s 24ms/step - loss: 0.4999 - accuracy: 0.8463 - val_loss: 0.4674 - val_accuracy: 0.8512
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4267 - accuracy: 0.8624 - val_loss: 0.4085 - val_accuracy: 0.8606
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3752 - accuracy: 0.8718 - val_loss: 0.3707 - val_accuracy: 0.8660
# Epoch 7/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3405 - accuracy: 0.8765 - val_loss: 0.3473 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3173 - accuracy: 0.8825 - val_loss: 0.3325 - val_accuracy: 0.8688
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3000 - accuracy: 0.8860 - val_loss: 0.3234 - val_accuracy: 0.8716
# Epoch 10/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2870 - accuracy: 0.8904 - val_loss: 0.3176 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.8716148734092712
# Validation Loss: 0.3175646960735321
#
# 156/156 [==============================] - 2s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8711    0.8427    0.8566      2269
#            1     0.8720    0.8958    0.8838      2716
#
#     accuracy                         0.8716      4985
#    macro avg     0.8716    0.8692    0.8702      4985
# weighted avg     0.8716    0.8716    0.8714      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 29ms/step - loss: 0.6870 - accuracy: 0.5685 - val_loss: 0.6749 - val_accuracy: 0.6433
# Epoch 2/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6485 - accuracy: 0.7254 - val_loss: 0.6178 - val_accuracy: 0.7914
# Epoch 3/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.5759 - accuracy: 0.8153 - val_loss: 0.5383 - val_accuracy: 0.8313
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4921 - accuracy: 0.8498 - val_loss: 0.4615 - val_accuracy: 0.8570
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4215 - accuracy: 0.8658 - val_loss: 0.4052 - val_accuracy: 0.8630
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3727 - accuracy: 0.8716 - val_loss: 0.3689 - val_accuracy: 0.8654
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3395 - accuracy: 0.8785 - val_loss: 0.3460 - val_accuracy: 0.8668
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3151 - accuracy: 0.8849 - val_loss: 0.3312 - val_accuracy: 0.8686
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2995 - accuracy: 0.8878 - val_loss: 0.3223 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2865 - accuracy: 0.8908 - val_loss: 0.3166 - val_accuracy: 0.8730
#
# Validation Accuracy: 0.8730190396308899
# Validation Loss: 0.3165569603443146
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8728    0.8440    0.8582      2269
#            1     0.8732    0.8973    0.8851      2716
#
#     accuracy                         0.8730      4985
#    macro avg     0.8730    0.8706    0.8716      4985
# weighted avg     0.8730    0.8730    0.8728      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 35ms/step - loss: 0.6882 - accuracy: 0.5785 - val_loss: 0.6781 - val_accuracy: 0.6463
# Epoch 2/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6561 - accuracy: 0.7451 - val_loss: 0.6290 - val_accuracy: 0.8034
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5889 - accuracy: 0.8298 - val_loss: 0.5498 - val_accuracy: 0.8425
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5033 - accuracy: 0.8536 - val_loss: 0.4690 - val_accuracy: 0.8604
# Epoch 5/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4285 - accuracy: 0.8639 - val_loss: 0.4093 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3766 - accuracy: 0.8707 - val_loss: 0.3711 - val_accuracy: 0.8630
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3415 - accuracy: 0.8773 - val_loss: 0.3474 - val_accuracy: 0.8654
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3167 - accuracy: 0.8831 - val_loss: 0.3321 - val_accuracy: 0.8698
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2993 - accuracy: 0.8860 - val_loss: 0.3226 - val_accuracy: 0.8708
# Epoch 10/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2867 - accuracy: 0.8899 - val_loss: 0.3164 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.3164375126361847
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8737    0.8418    0.8575      2269
#            1     0.8717    0.8984    0.8849      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8727    0.8701    0.8712      4985
# weighted avg     0.8727    0.8726    0.8724      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 39ms/step - loss: 0.6881 - accuracy: 0.5469 - val_loss: 0.6780 - val_accuracy: 0.5755
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6538 - accuracy: 0.6846 - val_loss: 0.6242 - val_accuracy: 0.7503
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5819 - accuracy: 0.8072 - val_loss: 0.5430 - val_accuracy: 0.8257
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4973 - accuracy: 0.8501 - val_loss: 0.4652 - val_accuracy: 0.8554
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4264 - accuracy: 0.8616 - val_loss: 0.4080 - val_accuracy: 0.8612
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3760 - accuracy: 0.8707 - val_loss: 0.3705 - val_accuracy: 0.8612
# Epoch 7/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3407 - accuracy: 0.8785 - val_loss: 0.3468 - val_accuracy: 0.8648
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3178 - accuracy: 0.8827 - val_loss: 0.3323 - val_accuracy: 0.8674
# Epoch 9/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3010 - accuracy: 0.8859 - val_loss: 0.3232 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2875 - accuracy: 0.8909 - val_loss: 0.3170 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.3169710040092468
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8689    0.8440    0.8562      2269
#            1     0.8727    0.8936    0.8830      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8708    0.8688    0.8696      4985
# weighted avg     0.8710    0.8710    0.8708      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 35ms/step - loss: 0.6894 - accuracy: 0.5583 - val_loss: 0.6815 - val_accuracy: 0.6321
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6597 - accuracy: 0.7523 - val_loss: 0.6313 - val_accuracy: 0.8158
# Epoch 3/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.5895 - accuracy: 0.8401 - val_loss: 0.5500 - val_accuracy: 0.8514
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5026 - accuracy: 0.8568 - val_loss: 0.4687 - val_accuracy: 0.8574
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4287 - accuracy: 0.8646 - val_loss: 0.4101 - val_accuracy: 0.8620
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3784 - accuracy: 0.8700 - val_loss: 0.3728 - val_accuracy: 0.8620
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3452 - accuracy: 0.8752 - val_loss: 0.3494 - val_accuracy: 0.8666
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3202 - accuracy: 0.8804 - val_loss: 0.3343 - val_accuracy: 0.8684
# Epoch 9/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3038 - accuracy: 0.8853 - val_loss: 0.3245 - val_accuracy: 0.8690
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2904 - accuracy: 0.8884 - val_loss: 0.3188 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.3187881410121918
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8796    0.8308    0.8545      2269
#            1     0.8649    0.9050    0.8845      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8722    0.8679    0.8695      4985
# weighted avg     0.8716    0.8712    0.8708      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5_FE_BERITA_TOP1 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_5_FE_BERITA_TOP1_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8718956870611836
# Average Precision : 0.8709076404321767
# Average Recall : 0.8980117820324006
# Average F1 Score : 0.871658590505243
