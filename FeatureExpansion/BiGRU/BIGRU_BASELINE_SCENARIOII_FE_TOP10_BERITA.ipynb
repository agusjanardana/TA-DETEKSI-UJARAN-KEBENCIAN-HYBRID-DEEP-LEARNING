# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigram_Top10_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 23s 28ms/step - loss: 0.6767 - accuracy: 0.5913 - val_loss: 0.6421 - val_accuracy: 0.6975
# Epoch 2/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.5740 - accuracy: 0.7982 - val_loss: 0.5035 - val_accuracy: 0.8435
# Epoch 3/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.4389 - accuracy: 0.8601 - val_loss: 0.3964 - val_accuracy: 0.8620
# Epoch 4/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.3582 - accuracy: 0.8726 - val_loss: 0.3473 - val_accuracy: 0.8688
# Epoch 5/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.3167 - accuracy: 0.8810 - val_loss: 0.3251 - val_accuracy: 0.8718
# Epoch 6/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.2935 - accuracy: 0.8877 - val_loss: 0.3144 - val_accuracy: 0.8728
# Epoch 7/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.2787 - accuracy: 0.8916 - val_loss: 0.3094 - val_accuracy: 0.8738
# Epoch 8/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.2676 - accuracy: 0.8959 - val_loss: 0.3077 - val_accuracy: 0.8770
# Epoch 9/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.2569 - accuracy: 0.9003 - val_loss: 0.3075 - val_accuracy: 0.8748
# Epoch 10/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2490 - accuracy: 0.9035 - val_loss: 0.3089 - val_accuracy: 0.8740
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.308935284614563
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8721    0.8475    0.8596      2269
#            1     0.8755    0.8962    0.8857      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8738    0.8718    0.8727      4985
# weighted avg     0.8740    0.8740    0.8739      4985
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_5 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_10 (Dense)            (44856, 32)               2080
#
#  dropout_5 (Dropout)         (44856, 32)               0
#
#  dense_11 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 22s 26ms/step - loss: 0.6724 - accuracy: 0.5740 - val_loss: 0.6326 - val_accuracy: 0.6680
# Epoch 2/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.5689 - accuracy: 0.7661 - val_loss: 0.5082 - val_accuracy: 0.8279
# Epoch 3/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.4494 - accuracy: 0.8540 - val_loss: 0.4100 - val_accuracy: 0.8626
# Epoch 4/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.3684 - accuracy: 0.8733 - val_loss: 0.3542 - val_accuracy: 0.8708
# Epoch 5/10
# 701/701 [==============================] - 16s 24ms/step - loss: 0.3233 - accuracy: 0.8816 - val_loss: 0.3287 - val_accuracy: 0.8724
# Epoch 6/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2979 - accuracy: 0.8882 - val_loss: 0.3166 - val_accuracy: 0.8740
# Epoch 7/10
# 701/701 [==============================] - 18s 26ms/step - loss: 0.2817 - accuracy: 0.8927 - val_loss: 0.3117 - val_accuracy: 0.8760
# Epoch 8/10
# 701/701 [==============================] - 18s 26ms/step - loss: 0.2685 - accuracy: 0.8976 - val_loss: 0.3103 - val_accuracy: 0.8758
# Epoch 9/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2588 - accuracy: 0.9004 - val_loss: 0.3107 - val_accuracy: 0.8762
# Epoch 10/10
# 701/701 [==============================] - 18s 26ms/step - loss: 0.2510 - accuracy: 0.9028 - val_loss: 0.3121 - val_accuracy: 0.8748
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.3120628297328949
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8703    0.8519    0.8610      2269
#            1     0.8784    0.8940    0.8861      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8744    0.8729    0.8736      4985
# weighted avg     0.8747    0.8748    0.8747      4985
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_6 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_12 (Dense)            (44856, 32)               2080
#
#  dropout_6 (Dropout)         (44856, 32)               0
#
#  dense_13 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 26s 31ms/step - loss: 0.6771 - accuracy: 0.5631 - val_loss: 0.6437 - val_accuracy: 0.6375
# Epoch 2/10
# 701/701 [==============================] - 19s 26ms/step - loss: 0.5832 - accuracy: 0.7418 - val_loss: 0.5229 - val_accuracy: 0.8048
# Epoch 3/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.4628 - accuracy: 0.8493 - val_loss: 0.4206 - val_accuracy: 0.8596
# Epoch 4/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.3787 - accuracy: 0.8735 - val_loss: 0.3613 - val_accuracy: 0.8688
# Epoch 5/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.3308 - accuracy: 0.8821 - val_loss: 0.3323 - val_accuracy: 0.8726
# Epoch 6/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.3028 - accuracy: 0.8877 - val_loss: 0.3183 - val_accuracy: 0.8736
# Epoch 7/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2864 - accuracy: 0.8914 - val_loss: 0.3124 - val_accuracy: 0.8742
# Epoch 8/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2742 - accuracy: 0.8952 - val_loss: 0.3101 - val_accuracy: 0.8762
# Epoch 9/10
# 701/701 [==============================] - 18s 25ms/step - loss: 0.2645 - accuracy: 0.8998 - val_loss: 0.3101 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 18s 25ms/step - loss: 0.2561 - accuracy: 0.9018 - val_loss: 0.3127 - val_accuracy: 0.8754
#
# Validation Accuracy: 0.8754262924194336
# Validation Loss: 0.3127174377441406
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8801    0.8409    0.8600      2269
#            1     0.8718    0.9043    0.8878      2716
#
#     accuracy                         0.8754      4985
#    macro avg     0.8760    0.8726    0.8739      4985
# weighted avg     0.8756    0.8754    0.8751      4985
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_7 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_14 (Dense)            (44856, 32)               2080
#
#  dropout_7 (Dropout)         (44856, 32)               0
#
#  dense_15 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 24s 29ms/step - loss: 0.6740 - accuracy: 0.6021 - val_loss: 0.6347 - val_accuracy: 0.7406
# Epoch 2/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.5652 - accuracy: 0.8062 - val_loss: 0.4968 - val_accuracy: 0.8473
# Epoch 3/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.4359 - accuracy: 0.8600 - val_loss: 0.3964 - val_accuracy: 0.8638
# Epoch 4/10
# 701/701 [==============================] - 19s 26ms/step - loss: 0.3602 - accuracy: 0.8723 - val_loss: 0.3488 - val_accuracy: 0.8692
# Epoch 5/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3193 - accuracy: 0.8807 - val_loss: 0.3264 - val_accuracy: 0.8734
# Epoch 6/10
# 701/701 [==============================] - 18s 25ms/step - loss: 0.2965 - accuracy: 0.8880 - val_loss: 0.3150 - val_accuracy: 0.8738
# Epoch 7/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2801 - accuracy: 0.8919 - val_loss: 0.3110 - val_accuracy: 0.8760
# Epoch 8/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2686 - accuracy: 0.8956 - val_loss: 0.3086 - val_accuracy: 0.8768
# Epoch 9/10
# 701/701 [==============================] - 18s 25ms/step - loss: 0.2580 - accuracy: 0.9003 - val_loss: 0.3087 - val_accuracy: 0.8774
# Epoch 10/10
# 701/701 [==============================] - 18s 26ms/step - loss: 0.2515 - accuracy: 0.9033 - val_loss: 0.3101 - val_accuracy: 0.8756
#
# Validation Accuracy: 0.8756268620491028
# Validation Loss: 0.31006431579589844
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8696    0.8550    0.8622      2269
#            1     0.8805    0.8929    0.8867      2716
#
#     accuracy                         0.8756      4985
#    macro avg     0.8751    0.8739    0.8744      4985
# weighted avg     0.8755    0.8756    0.8755      4985
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_8 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_16 (Dense)            (44856, 32)               2080
#
#  dropout_8 (Dropout)         (44856, 32)               0
#
#  dense_17 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 22s 26ms/step - loss: 0.6785 - accuracy: 0.6446 - val_loss: 0.6426 - val_accuracy: 0.8100
# Epoch 2/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.5670 - accuracy: 0.8426 - val_loss: 0.4929 - val_accuracy: 0.8588
# Epoch 3/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.4293 - accuracy: 0.8639 - val_loss: 0.3912 - val_accuracy: 0.8616
# Epoch 4/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.3551 - accuracy: 0.8727 - val_loss: 0.3460 - val_accuracy: 0.8672
# Epoch 5/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3155 - accuracy: 0.8817 - val_loss: 0.3248 - val_accuracy: 0.8732
# Epoch 6/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2921 - accuracy: 0.8890 - val_loss: 0.3148 - val_accuracy: 0.8724
# Epoch 7/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2768 - accuracy: 0.8937 - val_loss: 0.3102 - val_accuracy: 0.8744
# Epoch 8/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2644 - accuracy: 0.8987 - val_loss: 0.3081 - val_accuracy: 0.8738
# Epoch 9/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2563 - accuracy: 0.9016 - val_loss: 0.3085 - val_accuracy: 0.8746
# Epoch 10/10
# 701/701 [==============================] - 17s 25ms/step - loss: 0.2490 - accuracy: 0.9037 - val_loss: 0.3097 - val_accuracy: 0.8732
#
# Validation Accuracy: 0.8732196688652039
# Validation Loss: 0.30971789360046387
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8699    0.8484    0.8590      2269
#            1     0.8759    0.8940    0.8848      2716
#
#     accuracy                         0.8732      4985
#    macro avg     0.8729    0.8712    0.8719      4985
# weighted avg     0.8732    0.8732    0.8731      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_BERITA_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_BERITA_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8746238716148446
# Average Precision : 0.8764530754834666
# Average Recall : 0.8962444771723123
# Average F1 Score : 0.8744623539425135
