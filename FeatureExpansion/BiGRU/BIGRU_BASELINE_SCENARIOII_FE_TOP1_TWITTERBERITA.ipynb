# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigram_Top1_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 20s 31ms/step - loss: 0.6874 - accuracy: 0.5664 - val_loss: 0.6761 - val_accuracy: 0.6205
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6495 - accuracy: 0.7293 - val_loss: 0.6173 - val_accuracy: 0.7948
# Epoch 3/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.5727 - accuracy: 0.8261 - val_loss: 0.5321 - val_accuracy: 0.8427
# Epoch 4/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4850 - accuracy: 0.8540 - val_loss: 0.4536 - val_accuracy: 0.8570
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4144 - accuracy: 0.8649 - val_loss: 0.3984 - val_accuracy: 0.8600
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3666 - accuracy: 0.8718 - val_loss: 0.3639 - val_accuracy: 0.8638
# Epoch 7/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3345 - accuracy: 0.8794 - val_loss: 0.3427 - val_accuracy: 0.8668
# Epoch 8/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3120 - accuracy: 0.8842 - val_loss: 0.3292 - val_accuracy: 0.8680
# Epoch 9/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.2962 - accuracy: 0.8886 - val_loss: 0.3210 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2844 - accuracy: 0.8914 - val_loss: 0.3162 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3161660432815552
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8757    0.8387    0.8568      2269
#            1     0.8698    0.9006    0.8849      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8728    0.8696    0.8709      4985
# weighted avg     0.8725    0.8724    0.8721      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 34ms/step - loss: 0.6875 - accuracy: 0.5451 - val_loss: 0.6765 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6513 - accuracy: 0.6125 - val_loss: 0.6204 - val_accuracy: 0.6979
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5803 - accuracy: 0.7589 - val_loss: 0.5447 - val_accuracy: 0.7996
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5022 - accuracy: 0.8330 - val_loss: 0.4739 - val_accuracy: 0.8411
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4350 - accuracy: 0.8596 - val_loss: 0.4174 - val_accuracy: 0.8612
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3834 - accuracy: 0.8731 - val_loss: 0.3779 - val_accuracy: 0.8642
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3477 - accuracy: 0.8789 - val_loss: 0.3518 - val_accuracy: 0.8678
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3221 - accuracy: 0.8845 - val_loss: 0.3358 - val_accuracy: 0.8692
# Epoch 9/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3039 - accuracy: 0.8873 - val_loss: 0.3251 - val_accuracy: 0.8726
# Epoch 10/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.2915 - accuracy: 0.8904 - val_loss: 0.3193 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.3192853629589081
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8778    0.8330    0.8548      2269
#            1     0.8662    0.9032    0.8843      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8720    0.8681    0.8695      4985
# weighted avg     0.8715    0.8712    0.8709      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 33ms/step - loss: 0.6885 - accuracy: 0.5666 - val_loss: 0.6787 - val_accuracy: 0.6124
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6526 - accuracy: 0.7289 - val_loss: 0.6206 - val_accuracy: 0.7990
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5753 - accuracy: 0.8280 - val_loss: 0.5341 - val_accuracy: 0.8439
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4870 - accuracy: 0.8531 - val_loss: 0.4543 - val_accuracy: 0.8560
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4143 - accuracy: 0.8654 - val_loss: 0.3985 - val_accuracy: 0.8612
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3669 - accuracy: 0.8723 - val_loss: 0.3642 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3342 - accuracy: 0.8779 - val_loss: 0.3427 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3123 - accuracy: 0.8826 - val_loss: 0.3290 - val_accuracy: 0.8678
# Epoch 9/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.2974 - accuracy: 0.8879 - val_loss: 0.3211 - val_accuracy: 0.8712
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2845 - accuracy: 0.8916 - val_loss: 0.3157 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.31570738554000854
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8716    0.8440    0.8576      2269
#            1     0.8730    0.8962    0.8844      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8723    0.8701    0.8710      4985
# weighted avg     0.8724    0.8724    0.8722      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 35ms/step - loss: 0.6876 - accuracy: 0.5593 - val_loss: 0.6766 - val_accuracy: 0.6229
# Epoch 2/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6487 - accuracy: 0.7450 - val_loss: 0.6151 - val_accuracy: 0.8090
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5693 - accuracy: 0.8362 - val_loss: 0.5285 - val_accuracy: 0.8475
# Epoch 4/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4822 - accuracy: 0.8559 - val_loss: 0.4512 - val_accuracy: 0.8606
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4132 - accuracy: 0.8653 - val_loss: 0.3978 - val_accuracy: 0.8598
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3665 - accuracy: 0.8727 - val_loss: 0.3645 - val_accuracy: 0.8636
# Epoch 7/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3363 - accuracy: 0.8760 - val_loss: 0.3438 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3145 - accuracy: 0.8823 - val_loss: 0.3304 - val_accuracy: 0.8678
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2976 - accuracy: 0.8866 - val_loss: 0.3217 - val_accuracy: 0.8708
# Epoch 10/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.2862 - accuracy: 0.8902 - val_loss: 0.3165 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.31650203466415405
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8733    0.8387    0.8557      2269
#            1     0.8696    0.8984    0.8837      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8715    0.8685    0.8697      4985
# weighted avg     0.8713    0.8712    0.8710      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 21s 39ms/step - loss: 0.6862 - accuracy: 0.5468 - val_loss: 0.6740 - val_accuracy: 0.5627
# Epoch 2/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6484 - accuracy: 0.6653 - val_loss: 0.6189 - val_accuracy: 0.7290
# Epoch 3/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5784 - accuracy: 0.7863 - val_loss: 0.5426 - val_accuracy: 0.8088
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4985 - accuracy: 0.8431 - val_loss: 0.4693 - val_accuracy: 0.8497
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4300 - accuracy: 0.8633 - val_loss: 0.4128 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3795 - accuracy: 0.8705 - val_loss: 0.3747 - val_accuracy: 0.8670
# Epoch 7/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3437 - accuracy: 0.8776 - val_loss: 0.3494 - val_accuracy: 0.8694
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3188 - accuracy: 0.8825 - val_loss: 0.3336 - val_accuracy: 0.8710
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3012 - accuracy: 0.8880 - val_loss: 0.3242 - val_accuracy: 0.8718
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2878 - accuracy: 0.8907 - val_loss: 0.3180 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.31802135705947876
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8688    0.8462    0.8573      2269
#            1     0.8742    0.8932    0.8836      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8715    0.8697    0.8705      4985
# weighted avg     0.8718    0.8718    0.8717      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_FE_TWITTERBERITA_TOP1_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_FE_TWITTERBERITA_TOP1_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8718154463390171
# Average Precision : 0.870568511086469
# Average Recall : 0.8983063328424153
# Average F1 Score : 0.8715721191734461
