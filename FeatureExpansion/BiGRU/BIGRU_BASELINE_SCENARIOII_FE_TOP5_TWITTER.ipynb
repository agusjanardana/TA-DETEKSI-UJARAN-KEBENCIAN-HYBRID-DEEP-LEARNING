# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigram_Top5_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 33ms/step - loss: 0.6863 - accuracy: 0.5835 - val_loss: 0.6729 - val_accuracy: 0.6524
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6440 - accuracy: 0.7543 - val_loss: 0.6112 - val_accuracy: 0.8058
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5682 - accuracy: 0.8307 - val_loss: 0.5305 - val_accuracy: 0.8441
# Epoch 4/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4871 - accuracy: 0.8540 - val_loss: 0.4577 - val_accuracy: 0.8570
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4209 - accuracy: 0.8642 - val_loss: 0.4048 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3749 - accuracy: 0.8687 - val_loss: 0.3699 - val_accuracy: 0.8620
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3426 - accuracy: 0.8748 - val_loss: 0.3477 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3194 - accuracy: 0.8822 - val_loss: 0.3333 - val_accuracy: 0.8694
# Epoch 9/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3024 - accuracy: 0.8849 - val_loss: 0.3241 - val_accuracy: 0.8700
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2903 - accuracy: 0.8884 - val_loss: 0.3178 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.317758709192276
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8715    0.8431    0.8571      2269
#            1     0.8724    0.8962    0.8841      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8720    0.8696    0.8706      4985
# weighted avg     0.8720    0.8720    0.8718      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 41ms/step - loss: 0.6848 - accuracy: 0.5712 - val_loss: 0.6698 - val_accuracy: 0.6281
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6405 - accuracy: 0.7319 - val_loss: 0.6071 - val_accuracy: 0.7924
# Epoch 3/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.5641 - accuracy: 0.8240 - val_loss: 0.5248 - val_accuracy: 0.8343
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4803 - accuracy: 0.8512 - val_loss: 0.4506 - val_accuracy: 0.8590
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4144 - accuracy: 0.8641 - val_loss: 0.3979 - val_accuracy: 0.8616
# Epoch 6/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.3674 - accuracy: 0.8711 - val_loss: 0.3645 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3360 - accuracy: 0.8775 - val_loss: 0.3432 - val_accuracy: 0.8660
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3135 - accuracy: 0.8820 - val_loss: 0.3297 - val_accuracy: 0.8666
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.2984 - accuracy: 0.8868 - val_loss: 0.3214 - val_accuracy: 0.8714
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2860 - accuracy: 0.8908 - val_loss: 0.3161 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3160687983036041
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8768    0.8374    0.8566      2269
#            1     0.8691    0.9017    0.8851      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8729    0.8695    0.8709      4985
# weighted avg     0.8726    0.8724    0.8721      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 31ms/step - loss: 0.6880 - accuracy: 0.5577 - val_loss: 0.6778 - val_accuracy: 0.6319
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6547 - accuracy: 0.7365 - val_loss: 0.6271 - val_accuracy: 0.7900
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5887 - accuracy: 0.8254 - val_loss: 0.5525 - val_accuracy: 0.8381
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5102 - accuracy: 0.8521 - val_loss: 0.4781 - val_accuracy: 0.8590
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4410 - accuracy: 0.8610 - val_loss: 0.4202 - val_accuracy: 0.8606
# Epoch 6/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3904 - accuracy: 0.8685 - val_loss: 0.3813 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3548 - accuracy: 0.8733 - val_loss: 0.3560 - val_accuracy: 0.8650
# Epoch 8/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3306 - accuracy: 0.8767 - val_loss: 0.3392 - val_accuracy: 0.8672
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3115 - accuracy: 0.8842 - val_loss: 0.3280 - val_accuracy: 0.8684
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2983 - accuracy: 0.8867 - val_loss: 0.3205 - val_accuracy: 0.8702
#
# Validation Accuracy: 0.8702106475830078
# Validation Loss: 0.32054516673088074
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8710    0.8391    0.8548      2269
#            1     0.8696    0.8962    0.8827      2716
#
#     accuracy                         0.8702      4985
#    macro avg     0.8703    0.8677    0.8687      4985
# weighted avg     0.8702    0.8702    0.8700      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 35ms/step - loss: 0.6863 - accuracy: 0.5544 - val_loss: 0.6739 - val_accuracy: 0.5834
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6465 - accuracy: 0.6964 - val_loss: 0.6133 - val_accuracy: 0.7755
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5690 - accuracy: 0.8144 - val_loss: 0.5297 - val_accuracy: 0.8247
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4848 - accuracy: 0.8480 - val_loss: 0.4539 - val_accuracy: 0.8562
# Epoch 5/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4161 - accuracy: 0.8648 - val_loss: 0.3998 - val_accuracy: 0.8616
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3686 - accuracy: 0.8705 - val_loss: 0.3654 - val_accuracy: 0.8656
# Epoch 7/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3366 - accuracy: 0.8779 - val_loss: 0.3436 - val_accuracy: 0.8656
# Epoch 8/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3147 - accuracy: 0.8828 - val_loss: 0.3303 - val_accuracy: 0.8690
# Epoch 9/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.2978 - accuracy: 0.8868 - val_loss: 0.3215 - val_accuracy: 0.8708
# Epoch 10/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.2847 - accuracy: 0.8909 - val_loss: 0.3165 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.3165246546268463
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8741    0.8418    0.8577      2269
#            1     0.8718    0.8987    0.8851      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8730    0.8703    0.8714      4985
# weighted avg     0.8729    0.8728    0.8726      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 23s 54ms/step - loss: 0.6874 - accuracy: 0.6284 - val_loss: 0.6753 - val_accuracy: 0.7496
# Epoch 2/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6464 - accuracy: 0.8087 - val_loss: 0.6119 - val_accuracy: 0.8379
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5641 - accuracy: 0.8501 - val_loss: 0.5225 - val_accuracy: 0.8538
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4754 - accuracy: 0.8592 - val_loss: 0.4449 - val_accuracy: 0.8570
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4064 - accuracy: 0.8673 - val_loss: 0.3928 - val_accuracy: 0.8600
# Epoch 6/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3602 - accuracy: 0.8736 - val_loss: 0.3607 - val_accuracy: 0.8622
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3306 - accuracy: 0.8794 - val_loss: 0.3406 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3094 - accuracy: 0.8835 - val_loss: 0.3282 - val_accuracy: 0.8680
# Epoch 9/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.2936 - accuracy: 0.8879 - val_loss: 0.3202 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2812 - accuracy: 0.8915 - val_loss: 0.3153 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.315250426530838
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8730    0.8453    0.8589      2269
#            1     0.8741    0.8973    0.8855      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8736    0.8713    0.8722      4985
# weighted avg     0.8736    0.8736    0.8734      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TOP5_TWITTER-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TOP5_TWITTER.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8722166499498496
# Average Precision : 0.8713885600709416
# Average Recall : 0.8980117820324006
# Average F1 Score : 0.8719872130968301
