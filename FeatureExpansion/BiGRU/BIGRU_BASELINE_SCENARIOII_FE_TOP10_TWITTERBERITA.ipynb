# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigram_Top10_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")

  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 28ms/step - loss: 0.6880 - accuracy: 0.6451 - val_loss: 0.6777 - val_accuracy: 0.7484
# Epoch 2/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.6542 - accuracy: 0.8061 - val_loss: 0.6259 - val_accuracy: 0.8485
# Epoch 3/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.5862 - accuracy: 0.8463 - val_loss: 0.5498 - val_accuracy: 0.8574
# Epoch 4/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.5071 - accuracy: 0.8544 - val_loss: 0.4752 - val_accuracy: 0.8590
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4386 - accuracy: 0.8622 - val_loss: 0.4186 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3898 - accuracy: 0.8673 - val_loss: 0.3806 - val_accuracy: 0.8650
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3545 - accuracy: 0.8750 - val_loss: 0.3556 - val_accuracy: 0.8684
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3309 - accuracy: 0.8791 - val_loss: 0.3391 - val_accuracy: 0.8682
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3125 - accuracy: 0.8835 - val_loss: 0.3279 - val_accuracy: 0.8700
# Epoch 10/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.2984 - accuracy: 0.8885 - val_loss: 0.3205 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.3204880654811859
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8725    0.8418    0.8569      2269
#            1     0.8716    0.8973    0.8843      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8721    0.8695    0.8706      4985
# weighted avg     0.8720    0.8720    0.8718      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 33ms/step - loss: 0.6855 - accuracy: 0.5475 - val_loss: 0.6717 - val_accuracy: 0.5613
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6442 - accuracy: 0.6577 - val_loss: 0.6125 - val_accuracy: 0.7288
# Epoch 3/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.5706 - accuracy: 0.7875 - val_loss: 0.5342 - val_accuracy: 0.8144
# Epoch 4/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4900 - accuracy: 0.8453 - val_loss: 0.4595 - val_accuracy: 0.8473
# Epoch 5/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4212 - accuracy: 0.8622 - val_loss: 0.4047 - val_accuracy: 0.8602
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3724 - accuracy: 0.8728 - val_loss: 0.3687 - val_accuracy: 0.8648
# Epoch 7/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.3384 - accuracy: 0.8795 - val_loss: 0.3458 - val_accuracy: 0.8664
# Epoch 8/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3156 - accuracy: 0.8829 - val_loss: 0.3320 - val_accuracy: 0.8692
# Epoch 9/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2992 - accuracy: 0.8878 - val_loss: 0.3229 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2871 - accuracy: 0.8902 - val_loss: 0.3179 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.31786346435546875
#
# 156/156 [==============================] - 2s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8756    0.8374    0.8560      2269
#            1     0.8689    0.9006    0.8845      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8722    0.8690    0.8703      4985
# weighted avg     0.8719    0.8718    0.8715      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 20s 35ms/step - loss: 0.6873 - accuracy: 0.5487 - val_loss: 0.6764 - val_accuracy: 0.5599
# Epoch 2/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.6521 - accuracy: 0.6595 - val_loss: 0.6222 - val_accuracy: 0.7322
# Epoch 3/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.5794 - accuracy: 0.7960 - val_loss: 0.5409 - val_accuracy: 0.8150
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4946 - accuracy: 0.8453 - val_loss: 0.4630 - val_accuracy: 0.8560
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4223 - accuracy: 0.8648 - val_loss: 0.4052 - val_accuracy: 0.8614
# Epoch 6/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.3723 - accuracy: 0.8721 - val_loss: 0.3679 - val_accuracy: 0.8638
# Epoch 7/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3379 - accuracy: 0.8782 - val_loss: 0.3449 - val_accuracy: 0.8660
# Epoch 8/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3149 - accuracy: 0.8834 - val_loss: 0.3306 - val_accuracy: 0.8676
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.2979 - accuracy: 0.8877 - val_loss: 0.3219 - val_accuracy: 0.8708
# Epoch 10/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.2851 - accuracy: 0.8921 - val_loss: 0.3166 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.31663358211517334
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8709    0.8413    0.8559      2269
#            1     0.8711    0.8958    0.8833      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8710    0.8686    0.8696      4985
# weighted avg     0.8710    0.8710    0.8708      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 40ms/step - loss: 0.6883 - accuracy: 0.5882 - val_loss: 0.6780 - val_accuracy: 0.7029
# Epoch 2/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6521 - accuracy: 0.7845 - val_loss: 0.6198 - val_accuracy: 0.8307
# Epoch 3/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5748 - accuracy: 0.8424 - val_loss: 0.5327 - val_accuracy: 0.8542
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4843 - accuracy: 0.8575 - val_loss: 0.4516 - val_accuracy: 0.8604
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4133 - accuracy: 0.8644 - val_loss: 0.3972 - val_accuracy: 0.8616
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3669 - accuracy: 0.8714 - val_loss: 0.3639 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3359 - accuracy: 0.8776 - val_loss: 0.3432 - val_accuracy: 0.8668
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3127 - accuracy: 0.8835 - val_loss: 0.3299 - val_accuracy: 0.8686
# Epoch 9/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.2968 - accuracy: 0.8888 - val_loss: 0.3213 - val_accuracy: 0.8700
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2847 - accuracy: 0.8901 - val_loss: 0.3159 - val_accuracy: 0.8708
#
# Validation Accuracy: 0.8708124160766602
# Validation Loss: 0.31586530804634094
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8671    0.8457    0.8563      2269
#            1     0.8737    0.8918    0.8827      2716
#
#     accuracy                         0.8708      4985
#    macro avg     0.8704    0.8687    0.8695      4985
# weighted avg     0.8707    0.8708    0.8707      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 34ms/step - loss: 0.6865 - accuracy: 0.5980 - val_loss: 0.6731 - val_accuracy: 0.6973
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6440 - accuracy: 0.7870 - val_loss: 0.6102 - val_accuracy: 0.8293
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5651 - accuracy: 0.8407 - val_loss: 0.5254 - val_accuracy: 0.8544
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4807 - accuracy: 0.8561 - val_loss: 0.4506 - val_accuracy: 0.8612
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4135 - accuracy: 0.8653 - val_loss: 0.3984 - val_accuracy: 0.8606
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3691 - accuracy: 0.8707 - val_loss: 0.3654 - val_accuracy: 0.8658
# Epoch 7/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3374 - accuracy: 0.8773 - val_loss: 0.3443 - val_accuracy: 0.8676
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3152 - accuracy: 0.8822 - val_loss: 0.3309 - val_accuracy: 0.8688
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2997 - accuracy: 0.8859 - val_loss: 0.3219 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2869 - accuracy: 0.8910 - val_loss: 0.3166 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.3166293203830719
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8753    0.8383    0.8564      2269
#            1     0.8695    0.9002    0.8846      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8724    0.8692    0.8705      4985
# weighted avg     0.8721    0.8720    0.8717      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8715346038114344
# Average Precision : 0.8709700855210138
# Average Recall : 0.8971281296023564
# Average F1 Score : 0.8713079630998195
