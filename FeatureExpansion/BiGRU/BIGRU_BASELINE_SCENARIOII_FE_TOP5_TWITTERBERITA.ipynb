# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigram_Top5_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 26ms/step - loss: 0.6892 - accuracy: 0.6015 - val_loss: 0.6802 - val_accuracy: 0.7035
# Epoch 2/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.6577 - accuracy: 0.7805 - val_loss: 0.6300 - val_accuracy: 0.8355
# Epoch 3/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.5907 - accuracy: 0.8419 - val_loss: 0.5535 - val_accuracy: 0.8520
# Epoch 4/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.5080 - accuracy: 0.8560 - val_loss: 0.4757 - val_accuracy: 0.8580
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4357 - accuracy: 0.8638 - val_loss: 0.4162 - val_accuracy: 0.8618
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3832 - accuracy: 0.8692 - val_loss: 0.3769 - val_accuracy: 0.8628
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3468 - accuracy: 0.8769 - val_loss: 0.3515 - val_accuracy: 0.8654
# Epoch 8/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3223 - accuracy: 0.8805 - val_loss: 0.3353 - val_accuracy: 0.8684
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3051 - accuracy: 0.8854 - val_loss: 0.3251 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2899 - accuracy: 0.8898 - val_loss: 0.3183 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.3183031380176544
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8698    0.8449    0.8571      2269
#            1     0.8734    0.8943    0.8838      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8716    0.8696    0.8704      4985
# weighted avg     0.8718    0.8718    0.8716      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 31ms/step - loss: 0.6875 - accuracy: 0.5473 - val_loss: 0.6770 - val_accuracy: 0.5521
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6525 - accuracy: 0.6484 - val_loss: 0.6226 - val_accuracy: 0.7350
# Epoch 3/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.5807 - accuracy: 0.7869 - val_loss: 0.5430 - val_accuracy: 0.8195
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4987 - accuracy: 0.8412 - val_loss: 0.4673 - val_accuracy: 0.8499
# Epoch 5/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.4296 - accuracy: 0.8601 - val_loss: 0.4107 - val_accuracy: 0.8598
# Epoch 6/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3788 - accuracy: 0.8701 - val_loss: 0.3729 - val_accuracy: 0.8634
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3440 - accuracy: 0.8777 - val_loss: 0.3490 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3200 - accuracy: 0.8816 - val_loss: 0.3338 - val_accuracy: 0.8670
# Epoch 9/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.3030 - accuracy: 0.8853 - val_loss: 0.3246 - val_accuracy: 0.8706
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2897 - accuracy: 0.8906 - val_loss: 0.3183 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.31826701760292053
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8709    0.8413    0.8559      2269
#            1     0.8711    0.8958    0.8833      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8710    0.8686    0.8696      4985
# weighted avg     0.8710    0.8710    0.8708      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 37ms/step - loss: 0.6877 - accuracy: 0.5470 - val_loss: 0.6777 - val_accuracy: 0.5587
# Epoch 2/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.6530 - accuracy: 0.6707 - val_loss: 0.6230 - val_accuracy: 0.7414
# Epoch 3/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.5812 - accuracy: 0.7972 - val_loss: 0.5433 - val_accuracy: 0.8193
# Epoch 4/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4986 - accuracy: 0.8421 - val_loss: 0.4669 - val_accuracy: 0.8489
# Epoch 5/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.4298 - accuracy: 0.8600 - val_loss: 0.4108 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.3792 - accuracy: 0.8696 - val_loss: 0.3735 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.3445 - accuracy: 0.8756 - val_loss: 0.3495 - val_accuracy: 0.8660
# Epoch 8/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.3228 - accuracy: 0.8801 - val_loss: 0.3352 - val_accuracy: 0.8684
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3047 - accuracy: 0.8854 - val_loss: 0.3247 - val_accuracy: 0.8696
# Epoch 10/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.2914 - accuracy: 0.8876 - val_loss: 0.3186 - val_accuracy: 0.8704
#
# Validation Accuracy: 0.870411217212677
# Validation Loss: 0.31864693760871887
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8717    0.8387    0.8549      2269
#            1     0.8694    0.8969    0.8829      2716
#
#     accuracy                         0.8704      4985
#    macro avg     0.8706    0.8678    0.8689      4985
# weighted avg     0.8705    0.8704    0.8702      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 37ms/step - loss: 0.6862 - accuracy: 0.5496 - val_loss: 0.6732 - val_accuracy: 0.5866
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6413 - accuracy: 0.7045 - val_loss: 0.6055 - val_accuracy: 0.7737
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5586 - accuracy: 0.8172 - val_loss: 0.5186 - val_accuracy: 0.8353
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4722 - accuracy: 0.8534 - val_loss: 0.4428 - val_accuracy: 0.8592
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4046 - accuracy: 0.8645 - val_loss: 0.3912 - val_accuracy: 0.8628
# Epoch 6/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3589 - accuracy: 0.8728 - val_loss: 0.3597 - val_accuracy: 0.8652
# Epoch 7/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3292 - accuracy: 0.8784 - val_loss: 0.3399 - val_accuracy: 0.8684
# Epoch 8/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3077 - accuracy: 0.8851 - val_loss: 0.3275 - val_accuracy: 0.8696
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2930 - accuracy: 0.8882 - val_loss: 0.3197 - val_accuracy: 0.8710
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2802 - accuracy: 0.8923 - val_loss: 0.3151 - val_accuracy: 0.8722
#
# Validation Accuracy: 0.8722166419029236
# Validation Loss: 0.3150542080402374
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8716    0.8435    0.8573      2269
#            1     0.8727    0.8962    0.8843      2716
#
#     accuracy                         0.8722      4985
#    macro avg     0.8721    0.8699    0.8708      4985
# weighted avg     0.8722    0.8722    0.8720      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 24s 45ms/step - loss: 0.6893 - accuracy: 0.6199 - val_loss: 0.6805 - val_accuracy: 0.7378
# Epoch 2/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6574 - accuracy: 0.8073 - val_loss: 0.6288 - val_accuracy: 0.8502
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5856 - accuracy: 0.8501 - val_loss: 0.5451 - val_accuracy: 0.8542
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4968 - accuracy: 0.8598 - val_loss: 0.4632 - val_accuracy: 0.8564
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4221 - accuracy: 0.8650 - val_loss: 0.4049 - val_accuracy: 0.8602
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3719 - accuracy: 0.8716 - val_loss: 0.3683 - val_accuracy: 0.8634
# Epoch 7/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3379 - accuracy: 0.8771 - val_loss: 0.3457 - val_accuracy: 0.8664
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3140 - accuracy: 0.8832 - val_loss: 0.3317 - val_accuracy: 0.8682
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2979 - accuracy: 0.8871 - val_loss: 0.3224 - val_accuracy: 0.8706
# Epoch 10/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.2843 - accuracy: 0.8919 - val_loss: 0.3169 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.3168603181838989
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8724    0.8405    0.8561      2269
#            1     0.8707    0.8973    0.8838      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8715    0.8689    0.8699      4985
# weighted avg     0.8714    0.8714    0.8712      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8713741223671013
# Average Precision : 0.8714589014770622
# Average Recall : 0.8960972017673049
# Average F1 Score : 0.8711631952310421
