# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigram_Top1_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 31ms/step - loss: 0.6843 - accuracy: 0.5483 - val_loss: 0.6688 - val_accuracy: 0.5751
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6386 - accuracy: 0.6733 - val_loss: 0.6045 - val_accuracy: 0.7436
# Epoch 3/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.5602 - accuracy: 0.7986 - val_loss: 0.5228 - val_accuracy: 0.8213
# Epoch 4/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.4781 - accuracy: 0.8472 - val_loss: 0.4500 - val_accuracy: 0.8493
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4118 - accuracy: 0.8644 - val_loss: 0.3975 - val_accuracy: 0.8614
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3658 - accuracy: 0.8722 - val_loss: 0.3641 - val_accuracy: 0.8630
# Epoch 7/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3345 - accuracy: 0.8785 - val_loss: 0.3432 - val_accuracy: 0.8670
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3121 - accuracy: 0.8843 - val_loss: 0.3301 - val_accuracy: 0.8712
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2958 - accuracy: 0.8877 - val_loss: 0.3221 - val_accuracy: 0.8720
# Epoch 10/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2838 - accuracy: 0.8928 - val_loss: 0.3170 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.316990464925766
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8723    0.8400    0.8559      2269
#            1     0.8704    0.8973    0.8836      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8713    0.8686    0.8697      4985
# weighted avg     0.8712    0.8712    0.8710      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 30ms/step - loss: 0.6880 - accuracy: 0.5632 - val_loss: 0.6780 - val_accuracy: 0.6349
# Epoch 2/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.6562 - accuracy: 0.7236 - val_loss: 0.6301 - val_accuracy: 0.7884
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5917 - accuracy: 0.8169 - val_loss: 0.5548 - val_accuracy: 0.8283
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5099 - accuracy: 0.8464 - val_loss: 0.4768 - val_accuracy: 0.8576
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4377 - accuracy: 0.8603 - val_loss: 0.4166 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3839 - accuracy: 0.8676 - val_loss: 0.3765 - val_accuracy: 0.8616
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3485 - accuracy: 0.8745 - val_loss: 0.3516 - val_accuracy: 0.8634
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3232 - accuracy: 0.8795 - val_loss: 0.3358 - val_accuracy: 0.8656
# Epoch 9/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3064 - accuracy: 0.8836 - val_loss: 0.3256 - val_accuracy: 0.8680
# Epoch 10/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.2923 - accuracy: 0.8871 - val_loss: 0.3188 - val_accuracy: 0.8696
#
# Validation Accuracy: 0.8696088194847107
# Validation Loss: 0.3188461661338806
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8661    0.8440    0.8549      2269
#            1     0.8724    0.8910    0.8816      2716
#
#     accuracy                         0.8696      4985
#    macro avg     0.8693    0.8675    0.8683      4985
# weighted avg     0.8695    0.8696    0.8695      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 28ms/step - loss: 0.6872 - accuracy: 0.5642 - val_loss: 0.6744 - val_accuracy: 0.6429
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6458 - accuracy: 0.7409 - val_loss: 0.6130 - val_accuracy: 0.7900
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5699 - accuracy: 0.8194 - val_loss: 0.5320 - val_accuracy: 0.8357
# Epoch 4/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4886 - accuracy: 0.8492 - val_loss: 0.4596 - val_accuracy: 0.8556
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4226 - accuracy: 0.8617 - val_loss: 0.4068 - val_accuracy: 0.8594
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3755 - accuracy: 0.8702 - val_loss: 0.3713 - val_accuracy: 0.8626
# Epoch 7/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3431 - accuracy: 0.8770 - val_loss: 0.3488 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3211 - accuracy: 0.8804 - val_loss: 0.3343 - val_accuracy: 0.8668
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3039 - accuracy: 0.8857 - val_loss: 0.3249 - val_accuracy: 0.8672
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2906 - accuracy: 0.8903 - val_loss: 0.3192 - val_accuracy: 0.8700
#
# Validation Accuracy: 0.8700100183486938
# Validation Loss: 0.3192412555217743
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8744    0.8343    0.8539      2269
#            1     0.8667    0.8999    0.8829      2716
#
#     accuracy                         0.8700      4985
#    macro avg     0.8705    0.8671    0.8684      4985
# weighted avg     0.8702    0.8700    0.8697      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 29ms/step - loss: 0.6882 - accuracy: 0.5437 - val_loss: 0.6784 - val_accuracy: 0.5553
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6521 - accuracy: 0.6808 - val_loss: 0.6199 - val_accuracy: 0.7613
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5744 - accuracy: 0.8175 - val_loss: 0.5334 - val_accuracy: 0.8341
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4857 - accuracy: 0.8530 - val_loss: 0.4540 - val_accuracy: 0.8582
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4146 - accuracy: 0.8640 - val_loss: 0.3991 - val_accuracy: 0.8598
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3672 - accuracy: 0.8709 - val_loss: 0.3651 - val_accuracy: 0.8624
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3362 - accuracy: 0.8777 - val_loss: 0.3438 - val_accuracy: 0.8664
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3129 - accuracy: 0.8828 - val_loss: 0.3306 - val_accuracy: 0.8688
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2973 - accuracy: 0.8863 - val_loss: 0.3220 - val_accuracy: 0.8718
# Epoch 10/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2843 - accuracy: 0.8912 - val_loss: 0.3168 - val_accuracy: 0.8732
#
# Validation Accuracy: 0.8732196688652039
# Validation Loss: 0.31676167249679565
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8692    0.8493    0.8591      2269
#            1     0.8764    0.8932    0.8848      2716
#
#     accuracy                         0.8732      4985
#    macro avg     0.8728    0.8712    0.8719      4985
# weighted avg     0.8731    0.8732    0.8731      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 30ms/step - loss: 0.6844 - accuracy: 0.5749 - val_loss: 0.6686 - val_accuracy: 0.6277
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6358 - accuracy: 0.7242 - val_loss: 0.5988 - val_accuracy: 0.7823
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5514 - accuracy: 0.8229 - val_loss: 0.5117 - val_accuracy: 0.8323
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4663 - accuracy: 0.8523 - val_loss: 0.4391 - val_accuracy: 0.8572
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4034 - accuracy: 0.8655 - val_loss: 0.3904 - val_accuracy: 0.8618
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3596 - accuracy: 0.8726 - val_loss: 0.3595 - val_accuracy: 0.8622
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3297 - accuracy: 0.8804 - val_loss: 0.3403 - val_accuracy: 0.8678
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3095 - accuracy: 0.8838 - val_loss: 0.3285 - val_accuracy: 0.8682
# Epoch 9/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2937 - accuracy: 0.8880 - val_loss: 0.3211 - val_accuracy: 0.8714
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2832 - accuracy: 0.8910 - val_loss: 0.3161 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.31606754660606384
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8669    0.8466    0.8566      2269
#            1     0.8743    0.8914    0.8828      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8706    0.8690    0.8697      4985
# weighted avg     0.8709    0.8710    0.8709      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_FE_TWITTERTOP1_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_FE_TWITTER_TOP1_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8710130391173522
# Average Precision : 0.8720356404066669
# Average Recall : 0.8945508100147276
# Average F1 Score : 0.8708199943330616
