# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigram_Top10_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 35ms/step - loss: 0.6860 - accuracy: 0.5673 - val_loss: 0.6721 - val_accuracy: 0.6419
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6417 - accuracy: 0.7355 - val_loss: 0.6070 - val_accuracy: 0.7815
# Epoch 3/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5624 - accuracy: 0.8160 - val_loss: 0.5239 - val_accuracy: 0.8323
# Epoch 4/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4791 - accuracy: 0.8502 - val_loss: 0.4508 - val_accuracy: 0.8516
# Epoch 5/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4132 - accuracy: 0.8642 - val_loss: 0.3987 - val_accuracy: 0.8626
# Epoch 6/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3676 - accuracy: 0.8724 - val_loss: 0.3654 - val_accuracy: 0.8650
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3362 - accuracy: 0.8791 - val_loss: 0.3442 - val_accuracy: 0.8686
# Epoch 8/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3146 - accuracy: 0.8828 - val_loss: 0.3308 - val_accuracy: 0.8690
# Epoch 9/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.2997 - accuracy: 0.8868 - val_loss: 0.3223 - val_accuracy: 0.8694
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2847 - accuracy: 0.8917 - val_loss: 0.3172 - val_accuracy: 0.8698
#
# Validation Accuracy: 0.8698094487190247
# Validation Loss: 0.3172023892402649
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8695    0.8400    0.8545      2269
#            1     0.8700    0.8947    0.8822      2716
#
#     accuracy                         0.8698      4985
#    macro avg     0.8698    0.8674    0.8684      4985
# weighted avg     0.8698    0.8698    0.8696      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 33ms/step - loss: 0.6867 - accuracy: 0.5503 - val_loss: 0.6747 - val_accuracy: 0.5856
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6473 - accuracy: 0.6752 - val_loss: 0.6138 - val_accuracy: 0.7507
# Epoch 3/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5707 - accuracy: 0.7919 - val_loss: 0.5332 - val_accuracy: 0.8171
# Epoch 4/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4900 - accuracy: 0.8420 - val_loss: 0.4620 - val_accuracy: 0.8435
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4246 - accuracy: 0.8597 - val_loss: 0.4084 - val_accuracy: 0.8622
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3768 - accuracy: 0.8717 - val_loss: 0.3726 - val_accuracy: 0.8646
# Epoch 7/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3449 - accuracy: 0.8779 - val_loss: 0.3495 - val_accuracy: 0.8682
# Epoch 8/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3205 - accuracy: 0.8827 - val_loss: 0.3345 - val_accuracy: 0.8706
# Epoch 9/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3030 - accuracy: 0.8872 - val_loss: 0.3253 - val_accuracy: 0.8720
# Epoch 10/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.2914 - accuracy: 0.8920 - val_loss: 0.3192 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.3191588222980499
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8724    0.8440    0.8580      2269
#            1     0.8731    0.8969    0.8849      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8728    0.8704    0.8714      4985
# weighted avg     0.8728    0.8728    0.8726      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 30ms/step - loss: 0.6859 - accuracy: 0.5537 - val_loss: 0.6726 - val_accuracy: 0.5968
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6437 - accuracy: 0.7042 - val_loss: 0.6097 - val_accuracy: 0.7691
# Epoch 3/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.5658 - accuracy: 0.8128 - val_loss: 0.5275 - val_accuracy: 0.8315
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4835 - accuracy: 0.8501 - val_loss: 0.4545 - val_accuracy: 0.8572
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4171 - accuracy: 0.8641 - val_loss: 0.4016 - val_accuracy: 0.8616
# Epoch 6/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.3694 - accuracy: 0.8728 - val_loss: 0.3665 - val_accuracy: 0.8650
# Epoch 7/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3371 - accuracy: 0.8776 - val_loss: 0.3443 - val_accuracy: 0.8676
# Epoch 8/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3150 - accuracy: 0.8839 - val_loss: 0.3309 - val_accuracy: 0.8696
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2987 - accuracy: 0.8865 - val_loss: 0.3219 - val_accuracy: 0.8714
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2857 - accuracy: 0.8900 - val_loss: 0.3165 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.3164801001548767
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8727    0.8431    0.8577      2269
#            1     0.8725    0.8973    0.8847      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8726    0.8702    0.8712      4985
# weighted avg     0.8726    0.8726    0.8724      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 32ms/step - loss: 0.6864 - accuracy: 0.5451 - val_loss: 0.6746 - val_accuracy: 0.5486
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6504 - accuracy: 0.6359 - val_loss: 0.6212 - val_accuracy: 0.7127
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5825 - accuracy: 0.7704 - val_loss: 0.5470 - val_accuracy: 0.8026
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5044 - accuracy: 0.8352 - val_loss: 0.4757 - val_accuracy: 0.8451
# Epoch 5/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.4380 - accuracy: 0.8594 - val_loss: 0.4198 - val_accuracy: 0.8580
# Epoch 6/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3872 - accuracy: 0.8696 - val_loss: 0.3810 - val_accuracy: 0.8620
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3531 - accuracy: 0.8771 - val_loss: 0.3552 - val_accuracy: 0.8664
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3277 - accuracy: 0.8812 - val_loss: 0.3382 - val_accuracy: 0.8684
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3085 - accuracy: 0.8864 - val_loss: 0.3272 - val_accuracy: 0.8718
# Epoch 10/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.2941 - accuracy: 0.8900 - val_loss: 0.3203 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.8716148734092712
# Validation Loss: 0.3203066885471344
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8707    0.8431    0.8567      2269
#            1     0.8723    0.8954    0.8837      2716
#
#     accuracy                         0.8716      4985
#    macro avg     0.8715    0.8693    0.8702      4985
# weighted avg     0.8716    0.8716    0.8714      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 36ms/step - loss: 0.6870 - accuracy: 0.5626 - val_loss: 0.6750 - val_accuracy: 0.6273
# Epoch 2/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6463 - accuracy: 0.7564 - val_loss: 0.6120 - val_accuracy: 0.8074
# Epoch 3/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5659 - accuracy: 0.8371 - val_loss: 0.5249 - val_accuracy: 0.8451
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4780 - accuracy: 0.8557 - val_loss: 0.4484 - val_accuracy: 0.8606
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4109 - accuracy: 0.8657 - val_loss: 0.3960 - val_accuracy: 0.8622
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3644 - accuracy: 0.8722 - val_loss: 0.3630 - val_accuracy: 0.8652
# Epoch 7/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3337 - accuracy: 0.8779 - val_loss: 0.3424 - val_accuracy: 0.8676
# Epoch 8/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3120 - accuracy: 0.8831 - val_loss: 0.3292 - val_accuracy: 0.8690
# Epoch 9/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.2958 - accuracy: 0.8884 - val_loss: 0.3210 - val_accuracy: 0.8714
# Epoch 10/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.2843 - accuracy: 0.8905 - val_loss: 0.3157 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.31567639112472534
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8707    0.8457    0.8580      2269
#            1     0.8741    0.8951    0.8845      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8724    0.8704    0.8713      4985
# weighted avg     0.8726    0.8726    0.8724      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTER_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTER_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8718956870611836
# Average Precision : 0.8724289764571692
# Average Recall : 0.8958762886597939
# Average F1 Score : 0.8716976952281975
