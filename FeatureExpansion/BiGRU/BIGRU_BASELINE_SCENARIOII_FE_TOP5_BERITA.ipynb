# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigram_Top5_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 35ms/step - loss: 0.6850 - accuracy: 0.5610 - val_loss: 0.6700 - val_accuracy: 0.6164
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6400 - accuracy: 0.7055 - val_loss: 0.6059 - val_accuracy: 0.7707
# Epoch 3/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.5617 - accuracy: 0.8097 - val_loss: 0.5219 - val_accuracy: 0.8327
# Epoch 4/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4769 - accuracy: 0.8506 - val_loss: 0.4468 - val_accuracy: 0.8548
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4094 - accuracy: 0.8656 - val_loss: 0.3942 - val_accuracy: 0.8620
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3635 - accuracy: 0.8741 - val_loss: 0.3613 - val_accuracy: 0.8658
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3315 - accuracy: 0.8801 - val_loss: 0.3406 - val_accuracy: 0.8664
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3118 - accuracy: 0.8837 - val_loss: 0.3283 - val_accuracy: 0.8698
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2952 - accuracy: 0.8881 - val_loss: 0.3202 - val_accuracy: 0.8716
# Epoch 10/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2832 - accuracy: 0.8933 - val_loss: 0.3155 - val_accuracy: 0.8722
#
# Validation Accuracy: 0.8722166419029236
# Validation Loss: 0.31553617119789124
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8723    0.8427    0.8572      2269
#            1     0.8722    0.8969    0.8844      2716
#
#     accuracy                         0.8722      4985
#    macro avg     0.8722    0.8698    0.8708      4985
# weighted avg     0.8722    0.8722    0.8720      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 30ms/step - loss: 0.6868 - accuracy: 0.5796 - val_loss: 0.6748 - val_accuracy: 0.6516
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6477 - accuracy: 0.7410 - val_loss: 0.6165 - val_accuracy: 0.7982
# Epoch 3/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.5731 - accuracy: 0.8278 - val_loss: 0.5345 - val_accuracy: 0.8429
# Epoch 4/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4883 - accuracy: 0.8534 - val_loss: 0.4575 - val_accuracy: 0.8586
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4188 - accuracy: 0.8637 - val_loss: 0.4028 - val_accuracy: 0.8618
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3709 - accuracy: 0.8713 - val_loss: 0.3673 - val_accuracy: 0.8632
# Epoch 7/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3389 - accuracy: 0.8779 - val_loss: 0.3454 - val_accuracy: 0.8680
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3165 - accuracy: 0.8820 - val_loss: 0.3314 - val_accuracy: 0.8678
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2983 - accuracy: 0.8867 - val_loss: 0.3225 - val_accuracy: 0.8688
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2861 - accuracy: 0.8907 - val_loss: 0.3169 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.8716148734092712
# Validation Loss: 0.3169403374195099
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8752    0.8374    0.8559      2269
#            1     0.8689    0.9002    0.8843      2716
#
#     accuracy                         0.8716      4985
#    macro avg     0.8720    0.8688    0.8701      4985
# weighted avg     0.8717    0.8716    0.8713      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 33ms/step - loss: 0.6852 - accuracy: 0.5469 - val_loss: 0.6712 - val_accuracy: 0.5643
# Epoch 2/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6411 - accuracy: 0.6753 - val_loss: 0.6085 - val_accuracy: 0.7460
# Epoch 3/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5659 - accuracy: 0.7999 - val_loss: 0.5290 - val_accuracy: 0.8215
# Epoch 4/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4854 - accuracy: 0.8458 - val_loss: 0.4573 - val_accuracy: 0.8463
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4208 - accuracy: 0.8625 - val_loss: 0.4047 - val_accuracy: 0.8594
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3733 - accuracy: 0.8718 - val_loss: 0.3696 - val_accuracy: 0.8630
# Epoch 7/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.3401 - accuracy: 0.8778 - val_loss: 0.3470 - val_accuracy: 0.8658
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3168 - accuracy: 0.8829 - val_loss: 0.3325 - val_accuracy: 0.8698
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2999 - accuracy: 0.8875 - val_loss: 0.3231 - val_accuracy: 0.8700
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2870 - accuracy: 0.8921 - val_loss: 0.3175 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.3174508810043335
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8669    0.8471    0.8569      2269
#            1     0.8746    0.8914    0.8829      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8708    0.8692    0.8699      4985
# weighted avg     0.8711    0.8712    0.8711      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 33ms/step - loss: 0.6866 - accuracy: 0.5612 - val_loss: 0.6736 - val_accuracy: 0.6177
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6425 - accuracy: 0.7288 - val_loss: 0.6067 - val_accuracy: 0.7821
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5598 - accuracy: 0.8224 - val_loss: 0.5205 - val_accuracy: 0.8331
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4749 - accuracy: 0.8518 - val_loss: 0.4458 - val_accuracy: 0.8588
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4082 - accuracy: 0.8647 - val_loss: 0.3940 - val_accuracy: 0.8614
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3625 - accuracy: 0.8720 - val_loss: 0.3612 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.3306 - accuracy: 0.8793 - val_loss: 0.3409 - val_accuracy: 0.8670
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3090 - accuracy: 0.8850 - val_loss: 0.3282 - val_accuracy: 0.8694
# Epoch 9/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.2938 - accuracy: 0.8898 - val_loss: 0.3202 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.2820 - accuracy: 0.8912 - val_loss: 0.3152 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.8716148734092712
# Validation Loss: 0.31521618366241455
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8654    0.8502    0.8577      2269
#            1     0.8766    0.8895    0.8830      2716
#
#     accuracy                         0.8716      4985
#    macro avg     0.8710    0.8698    0.8704      4985
# weighted avg     0.8715    0.8716    0.8715      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 34ms/step - loss: 0.6873 - accuracy: 0.5538 - val_loss: 0.6754 - val_accuracy: 0.6243
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6448 - accuracy: 0.7478 - val_loss: 0.6071 - val_accuracy: 0.8110
# Epoch 3/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.5581 - accuracy: 0.8381 - val_loss: 0.5156 - val_accuracy: 0.8447
# Epoch 4/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4688 - accuracy: 0.8556 - val_loss: 0.4396 - val_accuracy: 0.8588
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4029 - accuracy: 0.8651 - val_loss: 0.3895 - val_accuracy: 0.8624
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3589 - accuracy: 0.8729 - val_loss: 0.3589 - val_accuracy: 0.8652
# Epoch 7/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3297 - accuracy: 0.8790 - val_loss: 0.3397 - val_accuracy: 0.8672
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3096 - accuracy: 0.8832 - val_loss: 0.3276 - val_accuracy: 0.8712
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2940 - accuracy: 0.8884 - val_loss: 0.3199 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.2810 - accuracy: 0.8921 - val_loss: 0.3154 - val_accuracy: 0.8734
#
# Validation Accuracy: 0.873420238494873
# Validation Loss: 0.3154429793357849
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8767    0.8400    0.8580      2269
#            1     0.8709    0.9013    0.8858      2716
#
#     accuracy                         0.8734      4985
#    macro avg     0.8738    0.8707    0.8719      4985
# weighted avg     0.8735    0.8734    0.8732      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TOP5_BERITA-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TOP5_BERITA.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8720160481444333
# Average Precision : 0.8726372755385257
# Average Recall : 0.8958762886597939
# Average F1 Score : 0.871817662962561
