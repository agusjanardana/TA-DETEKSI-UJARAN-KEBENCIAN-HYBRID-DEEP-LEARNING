# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigram_Top5_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.6129 - accuracy: 0.7274 - val_loss: 0.5275 - val_accuracy: 0.8325
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4756 - accuracy: 0.8237 - val_loss: 0.4175 - val_accuracy: 0.8564
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3993 - accuracy: 0.8468 - val_loss: 0.3677 - val_accuracy: 0.8602
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3616 - accuracy: 0.8596 - val_loss: 0.3418 - val_accuracy: 0.8652
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3380 - accuracy: 0.8683 - val_loss: 0.3293 - val_accuracy: 0.8680
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3221 - accuracy: 0.8743 - val_loss: 0.3201 - val_accuracy: 0.8690
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3084 - accuracy: 0.8804 - val_loss: 0.3148 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2988 - accuracy: 0.8833 - val_loss: 0.3107 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2897 - accuracy: 0.8862 - val_loss: 0.3081 - val_accuracy: 0.8770
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2831 - accuracy: 0.8894 - val_loss: 0.3063 - val_accuracy: 0.8752
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8752256631851196
# Validation Loss: 0.3062731921672821
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8769    0.8444    0.8604      2269
#            1     0.8739    0.9010    0.8872      2716
#
#     accuracy                         0.8752      4985
#    macro avg     0.8754    0.8727    0.8738      4985
# weighted avg     0.8753    0.8752    0.8750      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6096 - accuracy: 0.7261 - val_loss: 0.5201 - val_accuracy: 0.8433
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4663 - accuracy: 0.8318 - val_loss: 0.4091 - val_accuracy: 0.8560
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3899 - accuracy: 0.8523 - val_loss: 0.3599 - val_accuracy: 0.8610
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3492 - accuracy: 0.8640 - val_loss: 0.3363 - val_accuracy: 0.8664
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3273 - accuracy: 0.8742 - val_loss: 0.3253 - val_accuracy: 0.8690
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3130 - accuracy: 0.8779 - val_loss: 0.3173 - val_accuracy: 0.8718
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3000 - accuracy: 0.8825 - val_loss: 0.3125 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2894 - accuracy: 0.8864 - val_loss: 0.3102 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2813 - accuracy: 0.8902 - val_loss: 0.3066 - val_accuracy: 0.8726
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2730 - accuracy: 0.8923 - val_loss: 0.3040 - val_accuracy: 0.8750
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8750250935554504
# Validation Loss: 0.3040132224559784
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8821    0.8374    0.8591      2269
#            1     0.8697    0.9065    0.8877      2716
#
#     accuracy                         0.8750      4985
#    macro avg     0.8759    0.8719    0.8734      4985
# weighted avg     0.8753    0.8750    0.8747      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6327 - accuracy: 0.6903 - val_loss: 0.5586 - val_accuracy: 0.8130
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4987 - accuracy: 0.8213 - val_loss: 0.4383 - val_accuracy: 0.8544
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4113 - accuracy: 0.8468 - val_loss: 0.3794 - val_accuracy: 0.8586
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3667 - accuracy: 0.8596 - val_loss: 0.3472 - val_accuracy: 0.8644
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3414 - accuracy: 0.8662 - val_loss: 0.3300 - val_accuracy: 0.8686
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3234 - accuracy: 0.8745 - val_loss: 0.3205 - val_accuracy: 0.8686
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3102 - accuracy: 0.8789 - val_loss: 0.3170 - val_accuracy: 0.8706
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3002 - accuracy: 0.8823 - val_loss: 0.3110 - val_accuracy: 0.8708
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2907 - accuracy: 0.8860 - val_loss: 0.3073 - val_accuracy: 0.8734
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2821 - accuracy: 0.8893 - val_loss: 0.3048 - val_accuracy: 0.8746
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8746238946914673
# Validation Loss: 0.3048160970211029
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8726    0.8484    0.8603      2269
#            1     0.8762    0.8965    0.8863      2716
#
#     accuracy                         0.8746      4985
#    macro avg     0.8744    0.8725    0.8733      4985
# weighted avg     0.8746    0.8746    0.8745      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 8s 10ms/step - loss: 0.6194 - accuracy: 0.7081 - val_loss: 0.5369 - val_accuracy: 0.8365
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4803 - accuracy: 0.8280 - val_loss: 0.4228 - val_accuracy: 0.8556
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3992 - accuracy: 0.8512 - val_loss: 0.3684 - val_accuracy: 0.8574
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3576 - accuracy: 0.8620 - val_loss: 0.3419 - val_accuracy: 0.8634
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3330 - accuracy: 0.8706 - val_loss: 0.3267 - val_accuracy: 0.8662
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3170 - accuracy: 0.8773 - val_loss: 0.3189 - val_accuracy: 0.8684
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3043 - accuracy: 0.8809 - val_loss: 0.3143 - val_accuracy: 0.8692
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2935 - accuracy: 0.8852 - val_loss: 0.3090 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2850 - accuracy: 0.8887 - val_loss: 0.3065 - val_accuracy: 0.8740
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2770 - accuracy: 0.8913 - val_loss: 0.3046 - val_accuracy: 0.8754
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8754262924194336
# Validation Loss: 0.30464762449264526
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8712    0.8524    0.8617      2269
#            1     0.8788    0.8947    0.8867      2716
#
#     accuracy                         0.8754      4985
#    macro avg     0.8750    0.8735    0.8742      4985
# weighted avg     0.8754    0.8754    0.8753      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6128 - accuracy: 0.7231 - val_loss: 0.5266 - val_accuracy: 0.8321
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4725 - accuracy: 0.8298 - val_loss: 0.4174 - val_accuracy: 0.8588
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3974 - accuracy: 0.8499 - val_loss: 0.3667 - val_accuracy: 0.8620
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3566 - accuracy: 0.8628 - val_loss: 0.3436 - val_accuracy: 0.8634
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3338 - accuracy: 0.8689 - val_loss: 0.3259 - val_accuracy: 0.8698
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3173 - accuracy: 0.8751 - val_loss: 0.3186 - val_accuracy: 0.8706
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3046 - accuracy: 0.8815 - val_loss: 0.3131 - val_accuracy: 0.8738
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2955 - accuracy: 0.8839 - val_loss: 0.3105 - val_accuracy: 0.8738
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2862 - accuracy: 0.8879 - val_loss: 0.3065 - val_accuracy: 0.8766
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2781 - accuracy: 0.8902 - val_loss: 0.3043 - val_accuracy: 0.8764
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8764292597770691
# Validation Loss: 0.30425870418548584
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8738    0.8515    0.8625      2269
#            1     0.8785    0.8973    0.8878      2716
#
#     accuracy                         0.8764      4985
#    macro avg     0.8762    0.8744    0.8751      4985
# weighted avg     0.8764    0.8764    0.8763      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.875346038114343
# Average Precision : 0.8754315716728784
# Average Recall : 0.8991899852724595
# Average F1 Score : 0.8871359806148711
