# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM-TRIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigram_Top1_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 9ms/step - loss: 0.6107 - accuracy: 0.7302 - val_loss: 0.5220 - val_accuracy: 0.8307
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4666 - accuracy: 0.8324 - val_loss: 0.4114 - val_accuracy: 0.8556
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3906 - accuracy: 0.8525 - val_loss: 0.3599 - val_accuracy: 0.8622
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3517 - accuracy: 0.8641 - val_loss: 0.3353 - val_accuracy: 0.8696
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3295 - accuracy: 0.8720 - val_loss: 0.3247 - val_accuracy: 0.8698
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3135 - accuracy: 0.8779 - val_loss: 0.3198 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3015 - accuracy: 0.8816 - val_loss: 0.3114 - val_accuracy: 0.8736
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2922 - accuracy: 0.8863 - val_loss: 0.3070 - val_accuracy: 0.8754
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2818 - accuracy: 0.8888 - val_loss: 0.3046 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2741 - accuracy: 0.8917 - val_loss: 0.3044 - val_accuracy: 0.8752
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8752256631851196
# Validation Loss: 0.3043672442436218
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8814    0.8387    0.8595      2269
#            1     0.8705    0.9057    0.8878      2716
#
#     accuracy                         0.8752      4985
#    macro avg     0.8760    0.8722    0.8736      4985
# weighted avg     0.8755    0.8752    0.8749      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6302 - accuracy: 0.6956 - val_loss: 0.5550 - val_accuracy: 0.8130
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4970 - accuracy: 0.8216 - val_loss: 0.4387 - val_accuracy: 0.8550
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4139 - accuracy: 0.8459 - val_loss: 0.3824 - val_accuracy: 0.8602
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3669 - accuracy: 0.8593 - val_loss: 0.3479 - val_accuracy: 0.8640
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3424 - accuracy: 0.8666 - val_loss: 0.3327 - val_accuracy: 0.8666
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3242 - accuracy: 0.8731 - val_loss: 0.3230 - val_accuracy: 0.8678
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3126 - accuracy: 0.8786 - val_loss: 0.3152 - val_accuracy: 0.8708
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3006 - accuracy: 0.8833 - val_loss: 0.3112 - val_accuracy: 0.8720
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2912 - accuracy: 0.8858 - val_loss: 0.3076 - val_accuracy: 0.8736
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2831 - accuracy: 0.8891 - val_loss: 0.3051 - val_accuracy: 0.8754
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8754262924194336
# Validation Loss: 0.3050505518913269
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8669    0.8581    0.8625      2269
#            1     0.8824    0.8899    0.8862      2716
#
#     accuracy                         0.8754      4985
#    macro avg     0.8747    0.8740    0.8743      4985
# weighted avg     0.8754    0.8754    0.8754      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6262 - accuracy: 0.7070 - val_loss: 0.5496 - val_accuracy: 0.8249
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4936 - accuracy: 0.8216 - val_loss: 0.4353 - val_accuracy: 0.8576
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4126 - accuracy: 0.8445 - val_loss: 0.3784 - val_accuracy: 0.8610
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3668 - accuracy: 0.8601 - val_loss: 0.3463 - val_accuracy: 0.8656
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3416 - accuracy: 0.8671 - val_loss: 0.3323 - val_accuracy: 0.8674
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3223 - accuracy: 0.8754 - val_loss: 0.3236 - val_accuracy: 0.8690
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3091 - accuracy: 0.8797 - val_loss: 0.3151 - val_accuracy: 0.8712
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2996 - accuracy: 0.8836 - val_loss: 0.3104 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2911 - accuracy: 0.8876 - val_loss: 0.3078 - val_accuracy: 0.8734
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2812 - accuracy: 0.8902 - val_loss: 0.3051 - val_accuracy: 0.8750
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8750250935554504
# Validation Loss: 0.3050658702850342
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8796    0.8405    0.8596      2269
#            1     0.8715    0.9039    0.8874      2716
#
#     accuracy                         0.8750      4985
#    macro avg     0.8756    0.8722    0.8735      4985
# weighted avg     0.8752    0.8750    0.8747      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6165 - accuracy: 0.7174 - val_loss: 0.5315 - val_accuracy: 0.8299
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4756 - accuracy: 0.8284 - val_loss: 0.4189 - val_accuracy: 0.8554
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3968 - accuracy: 0.8492 - val_loss: 0.3659 - val_accuracy: 0.8590
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3564 - accuracy: 0.8618 - val_loss: 0.3401 - val_accuracy: 0.8642
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3327 - accuracy: 0.8695 - val_loss: 0.3256 - val_accuracy: 0.8682
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3182 - accuracy: 0.8769 - val_loss: 0.3194 - val_accuracy: 0.8706
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3043 - accuracy: 0.8804 - val_loss: 0.3141 - val_accuracy: 0.8714
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2953 - accuracy: 0.8835 - val_loss: 0.3100 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2861 - accuracy: 0.8873 - val_loss: 0.3085 - val_accuracy: 0.8726
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2772 - accuracy: 0.8900 - val_loss: 0.3050 - val_accuracy: 0.8746
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8746238946914673
# Validation Loss: 0.3049969971179962
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8764    0.8435    0.8596      2269
#            1     0.8733    0.9006    0.8867      2716
#
#     accuracy                         0.8746      4985
#    macro avg     0.8748    0.8721    0.8732      4985
# weighted avg     0.8747    0.8746    0.8744      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6105 - accuracy: 0.7231 - val_loss: 0.5227 - val_accuracy: 0.8479
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4680 - accuracy: 0.8297 - val_loss: 0.4132 - val_accuracy: 0.8578
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3925 - accuracy: 0.8497 - val_loss: 0.3634 - val_accuracy: 0.8608
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3531 - accuracy: 0.8625 - val_loss: 0.3401 - val_accuracy: 0.8654
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3315 - accuracy: 0.8712 - val_loss: 0.3265 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3155 - accuracy: 0.8768 - val_loss: 0.3186 - val_accuracy: 0.8684
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3019 - accuracy: 0.8810 - val_loss: 0.3130 - val_accuracy: 0.8706
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2923 - accuracy: 0.8856 - val_loss: 0.3090 - val_accuracy: 0.8728
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2847 - accuracy: 0.8876 - val_loss: 0.3062 - val_accuracy: 0.8744
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2753 - accuracy: 0.8911 - val_loss: 0.3049 - val_accuracy: 0.8748
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.30487948656082153
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8810    0.8383    0.8591      2269
#            1     0.8701    0.9054    0.8874      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8755    0.8718    0.8732      4985
# weighted avg     0.8751    0.8748    0.8745      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.875025075225677
# Average Precision : 0.873563136508199
# Average Recall : 0.9011045655375552
# Average F1 Score : 0.8870895108584366
