# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigram_Top5_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.6279 - accuracy: 0.6866 - val_loss: 0.5539 - val_accuracy: 0.8449
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4963 - accuracy: 0.8187 - val_loss: 0.4394 - val_accuracy: 0.8566
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4131 - accuracy: 0.8475 - val_loss: 0.3785 - val_accuracy: 0.8608
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3701 - accuracy: 0.8578 - val_loss: 0.3506 - val_accuracy: 0.8646
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3437 - accuracy: 0.8667 - val_loss: 0.3337 - val_accuracy: 0.8676
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3281 - accuracy: 0.8730 - val_loss: 0.3244 - val_accuracy: 0.8690
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3148 - accuracy: 0.8773 - val_loss: 0.3175 - val_accuracy: 0.8694
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3055 - accuracy: 0.8820 - val_loss: 0.3129 - val_accuracy: 0.8728
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2953 - accuracy: 0.8857 - val_loss: 0.3093 - val_accuracy: 0.8744
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2864 - accuracy: 0.8892 - val_loss: 0.3065 - val_accuracy: 0.8748
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.3065008521080017
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8651    0.8590    0.8620      2269
#            1     0.8829    0.8881    0.8855      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8740    0.8735    0.8737      4985
# weighted avg     0.8748    0.8748    0.8748      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6118 - accuracy: 0.7218 - val_loss: 0.5244 - val_accuracy: 0.8481
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4689 - accuracy: 0.8289 - val_loss: 0.4122 - val_accuracy: 0.8574
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3915 - accuracy: 0.8526 - val_loss: 0.3616 - val_accuracy: 0.8596
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3525 - accuracy: 0.8629 - val_loss: 0.3402 - val_accuracy: 0.8642
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3287 - accuracy: 0.8713 - val_loss: 0.3248 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3135 - accuracy: 0.8781 - val_loss: 0.3170 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3021 - accuracy: 0.8827 - val_loss: 0.3115 - val_accuracy: 0.8716
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2919 - accuracy: 0.8856 - val_loss: 0.3077 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2825 - accuracy: 0.8889 - val_loss: 0.3049 - val_accuracy: 0.8756
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2751 - accuracy: 0.8915 - val_loss: 0.3043 - val_accuracy: 0.8748
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.3042938709259033
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8849    0.8334    0.8584      2269
#            1     0.8673    0.9094    0.8879      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8761    0.8714    0.8731      4985
# weighted avg     0.8753    0.8748    0.8744      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6217 - accuracy: 0.7055 - val_loss: 0.5406 - val_accuracy: 0.8203
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4817 - accuracy: 0.8279 - val_loss: 0.4255 - val_accuracy: 0.8558
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4003 - accuracy: 0.8493 - val_loss: 0.3687 - val_accuracy: 0.8610
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3590 - accuracy: 0.8620 - val_loss: 0.3420 - val_accuracy: 0.8638
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3336 - accuracy: 0.8686 - val_loss: 0.3307 - val_accuracy: 0.8678
# Epoch 6/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3163 - accuracy: 0.8767 - val_loss: 0.3200 - val_accuracy: 0.8696
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3052 - accuracy: 0.8797 - val_loss: 0.3138 - val_accuracy: 0.8724
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2947 - accuracy: 0.8851 - val_loss: 0.3092 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2851 - accuracy: 0.8881 - val_loss: 0.3089 - val_accuracy: 0.8730
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2758 - accuracy: 0.8901 - val_loss: 0.3047 - val_accuracy: 0.8740
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.3046700954437256
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8603    0.8634    0.8619      2269
#            1     0.8855    0.8829    0.8842      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8729    0.8731    0.8730      4985
# weighted avg     0.8741    0.8740    0.8740      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 8s 10ms/step - loss: 0.6299 - accuracy: 0.6915 - val_loss: 0.5561 - val_accuracy: 0.8092
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4994 - accuracy: 0.8188 - val_loss: 0.4401 - val_accuracy: 0.8552
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4161 - accuracy: 0.8434 - val_loss: 0.3794 - val_accuracy: 0.8596
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3724 - accuracy: 0.8566 - val_loss: 0.3526 - val_accuracy: 0.8626
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3469 - accuracy: 0.8650 - val_loss: 0.3332 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3272 - accuracy: 0.8709 - val_loss: 0.3235 - val_accuracy: 0.8680
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3136 - accuracy: 0.8777 - val_loss: 0.3173 - val_accuracy: 0.8714
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3040 - accuracy: 0.8810 - val_loss: 0.3123 - val_accuracy: 0.8734
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2934 - accuracy: 0.8865 - val_loss: 0.3095 - val_accuracy: 0.8742
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2874 - accuracy: 0.8876 - val_loss: 0.3068 - val_accuracy: 0.8730
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8730190396308899
# Validation Loss: 0.30679160356521606
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8745    0.8418    0.8578      2269
#            1     0.8718    0.8991    0.8853      2716
#
#     accuracy                         0.8730      4985
#    macro avg     0.8732    0.8704    0.8716      4985
# weighted avg     0.8731    0.8730    0.8728      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5995 - accuracy: 0.7396 - val_loss: 0.5059 - val_accuracy: 0.8497
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4546 - accuracy: 0.8353 - val_loss: 0.4027 - val_accuracy: 0.8586
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3833 - accuracy: 0.8542 - val_loss: 0.3554 - val_accuracy: 0.8632
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3475 - accuracy: 0.8649 - val_loss: 0.3336 - val_accuracy: 0.8666
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3251 - accuracy: 0.8731 - val_loss: 0.3224 - val_accuracy: 0.8698
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3106 - accuracy: 0.8801 - val_loss: 0.3161 - val_accuracy: 0.8718
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2996 - accuracy: 0.8837 - val_loss: 0.3110 - val_accuracy: 0.8724
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2878 - accuracy: 0.8875 - val_loss: 0.3103 - val_accuracy: 0.8736
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2788 - accuracy: 0.8915 - val_loss: 0.3050 - val_accuracy: 0.8768
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2702 - accuracy: 0.8927 - val_loss: 0.3030 - val_accuracy: 0.8758
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8758274912834167
# Validation Loss: 0.3029695153236389
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8743    0.8493    0.8616      2269
#            1     0.8770    0.8980    0.8874      2716
#
#     accuracy                         0.8758      4985
#    macro avg     0.8757    0.8736    0.8745      4985
# weighted avg     0.8758    0.8758    0.8757      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTER_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTER_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8745035105315948
# Average Precision : 0.8769046976275895
# Average Recall : 0.8955081001472754
# Average F1 Score : 0.886037633050293
