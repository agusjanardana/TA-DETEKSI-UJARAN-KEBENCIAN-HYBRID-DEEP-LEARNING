# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM-TRIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigram_Top1_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.6191 - accuracy: 0.7091 - val_loss: 0.5363 - val_accuracy: 0.8321
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4813 - accuracy: 0.8258 - val_loss: 0.4246 - val_accuracy: 0.8560
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4037 - accuracy: 0.8496 - val_loss: 0.3683 - val_accuracy: 0.8608
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3583 - accuracy: 0.8622 - val_loss: 0.3437 - val_accuracy: 0.8638
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3338 - accuracy: 0.8690 - val_loss: 0.3277 - val_accuracy: 0.8666
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3165 - accuracy: 0.8762 - val_loss: 0.3190 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3053 - accuracy: 0.8817 - val_loss: 0.3136 - val_accuracy: 0.8708
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2953 - accuracy: 0.8848 - val_loss: 0.3109 - val_accuracy: 0.8728
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2865 - accuracy: 0.8894 - val_loss: 0.3064 - val_accuracy: 0.8740
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2764 - accuracy: 0.8915 - val_loss: 0.3056 - val_accuracy: 0.8732
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8732196688652039
# Validation Loss: 0.3055998384952545
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8809    0.8343    0.8569      2269
#            1     0.8674    0.9057    0.8862      2716
#
#     accuracy                         0.8732      4985
#    macro avg     0.8741    0.8700    0.8716      4985
# weighted avg     0.8735    0.8732    0.8729      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6193 - accuracy: 0.7120 - val_loss: 0.5377 - val_accuracy: 0.8271
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4799 - accuracy: 0.8261 - val_loss: 0.4233 - val_accuracy: 0.8554
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3996 - accuracy: 0.8487 - val_loss: 0.3674 - val_accuracy: 0.8604
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3595 - accuracy: 0.8609 - val_loss: 0.3465 - val_accuracy: 0.8642
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3354 - accuracy: 0.8677 - val_loss: 0.3377 - val_accuracy: 0.8650
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3203 - accuracy: 0.8733 - val_loss: 0.3223 - val_accuracy: 0.8692
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3068 - accuracy: 0.8801 - val_loss: 0.3138 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2964 - accuracy: 0.8835 - val_loss: 0.3097 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2856 - accuracy: 0.8887 - val_loss: 0.3065 - val_accuracy: 0.8760
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2796 - accuracy: 0.8905 - val_loss: 0.3042 - val_accuracy: 0.8744
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8744232654571533
# Validation Loss: 0.3042105734348297
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8749    0.8449    0.8596      2269
#            1     0.8740    0.8991    0.8864      2716
#
#     accuracy                         0.8744      4985
#    macro avg     0.8745    0.8720    0.8730      4985
# weighted avg     0.8744    0.8744    0.8742      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6084 - accuracy: 0.7249 - val_loss: 0.5181 - val_accuracy: 0.8341
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4640 - accuracy: 0.8313 - val_loss: 0.4107 - val_accuracy: 0.8558
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3913 - accuracy: 0.8520 - val_loss: 0.3616 - val_accuracy: 0.8606
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3508 - accuracy: 0.8646 - val_loss: 0.3402 - val_accuracy: 0.8652
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3297 - accuracy: 0.8706 - val_loss: 0.3250 - val_accuracy: 0.8690
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3126 - accuracy: 0.8772 - val_loss: 0.3168 - val_accuracy: 0.8714
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3018 - accuracy: 0.8815 - val_loss: 0.3124 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2921 - accuracy: 0.8857 - val_loss: 0.3088 - val_accuracy: 0.8736
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2825 - accuracy: 0.8893 - val_loss: 0.3055 - val_accuracy: 0.8738
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2749 - accuracy: 0.8929 - val_loss: 0.3038 - val_accuracy: 0.8756
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8756268620491028
# Validation Loss: 0.30378180742263794
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8716    0.8524    0.8619      2269
#            1     0.8789    0.8951    0.8869      2716
#
#     accuracy                         0.8756      4985
#    macro avg     0.8752    0.8737    0.8744      4985
# weighted avg     0.8756    0.8756    0.8755      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6201 - accuracy: 0.7047 - val_loss: 0.5386 - val_accuracy: 0.8421
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4805 - accuracy: 0.8274 - val_loss: 0.4251 - val_accuracy: 0.8584
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4023 - accuracy: 0.8499 - val_loss: 0.3701 - val_accuracy: 0.8612
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3580 - accuracy: 0.8612 - val_loss: 0.3403 - val_accuracy: 0.8656
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3349 - accuracy: 0.8693 - val_loss: 0.3268 - val_accuracy: 0.8696
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3180 - accuracy: 0.8767 - val_loss: 0.3186 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3050 - accuracy: 0.8814 - val_loss: 0.3127 - val_accuracy: 0.8750
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2961 - accuracy: 0.8851 - val_loss: 0.3093 - val_accuracy: 0.8754
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2861 - accuracy: 0.8884 - val_loss: 0.3061 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2773 - accuracy: 0.8924 - val_loss: 0.3047 - val_accuracy: 0.8766
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8766298890113831
# Validation Loss: 0.30469247698783875
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8715    0.8550    0.8632      2269
#            1     0.8808    0.8947    0.8877      2716
#
#     accuracy                         0.8766      4985
#    macro avg     0.8761    0.8749    0.8754      4985
# weighted avg     0.8766    0.8766    0.8765      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6227 - accuracy: 0.7080 - val_loss: 0.5453 - val_accuracy: 0.8177
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4902 - accuracy: 0.8255 - val_loss: 0.4338 - val_accuracy: 0.8548
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4102 - accuracy: 0.8449 - val_loss: 0.3758 - val_accuracy: 0.8598
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3653 - accuracy: 0.8602 - val_loss: 0.3461 - val_accuracy: 0.8656
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3399 - accuracy: 0.8672 - val_loss: 0.3296 - val_accuracy: 0.8680
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3226 - accuracy: 0.8746 - val_loss: 0.3225 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3093 - accuracy: 0.8798 - val_loss: 0.3145 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2995 - accuracy: 0.8839 - val_loss: 0.3103 - val_accuracy: 0.8746
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2883 - accuracy: 0.8875 - val_loss: 0.3077 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2804 - accuracy: 0.8911 - val_loss: 0.3057 - val_accuracy: 0.8758
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8758274912834167
# Validation Loss: 0.3057384192943573
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8819    0.8396    0.8602      2269
#            1     0.8712    0.9061    0.8883      2716
#
#     accuracy                         0.8758      4985
#    macro avg     0.8765    0.8728    0.8743      4985
# weighted avg     0.8761    0.8758    0.8755      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8751454363089268
# Average Precision : 0.8744450930754282
# Average Recall : 0.9001472754050074
# Average F1 Score : 0.8870833335321417
