# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM-TRIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigram_Top5_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.5972 - accuracy: 0.7264 - val_loss: 0.5037 - val_accuracy: 0.8285
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4529 - accuracy: 0.8334 - val_loss: 0.4007 - val_accuracy: 0.8590
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3827 - accuracy: 0.8546 - val_loss: 0.3536 - val_accuracy: 0.8620
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3473 - accuracy: 0.8651 - val_loss: 0.3335 - val_accuracy: 0.8672
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3262 - accuracy: 0.8734 - val_loss: 0.3227 - val_accuracy: 0.8712
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3125 - accuracy: 0.8791 - val_loss: 0.3168 - val_accuracy: 0.8750
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3018 - accuracy: 0.8834 - val_loss: 0.3127 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2897 - accuracy: 0.8882 - val_loss: 0.3093 - val_accuracy: 0.8752
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2823 - accuracy: 0.8907 - val_loss: 0.3072 - val_accuracy: 0.8728
# Epoch 10/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2740 - accuracy: 0.8943 - val_loss: 0.3052 - val_accuracy: 0.8738
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8738214373588562
# Validation Loss: 0.30517271161079407
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8697    0.8502    0.8598      2269
#            1     0.8771    0.8936    0.8853      2716
#
#     accuracy                         0.8738      4985
#    macro avg     0.8734    0.8719    0.8725      4985
# weighted avg     0.8737    0.8738    0.8737      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6355 - accuracy: 0.6926 - val_loss: 0.5685 - val_accuracy: 0.8223
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.5144 - accuracy: 0.8142 - val_loss: 0.4551 - val_accuracy: 0.8566
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4297 - accuracy: 0.8408 - val_loss: 0.3937 - val_accuracy: 0.8614
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3812 - accuracy: 0.8553 - val_loss: 0.3562 - val_accuracy: 0.8636
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3526 - accuracy: 0.8640 - val_loss: 0.3362 - val_accuracy: 0.8686
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3322 - accuracy: 0.8719 - val_loss: 0.3250 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3182 - accuracy: 0.8766 - val_loss: 0.3173 - val_accuracy: 0.8718
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3071 - accuracy: 0.8809 - val_loss: 0.3137 - val_accuracy: 0.8738
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2993 - accuracy: 0.8847 - val_loss: 0.3092 - val_accuracy: 0.8730
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2880 - accuracy: 0.8879 - val_loss: 0.3067 - val_accuracy: 0.8748
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.30671438574790955
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8813    0.8378    0.8590      2269
#            1     0.8699    0.9057    0.8874      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8756    0.8718    0.8732      4985
# weighted avg     0.8751    0.8748    0.8745      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6311 - accuracy: 0.6906 - val_loss: 0.5595 - val_accuracy: 0.8142
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.5022 - accuracy: 0.8186 - val_loss: 0.4431 - val_accuracy: 0.8530
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4180 - accuracy: 0.8433 - val_loss: 0.3832 - val_accuracy: 0.8588
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3710 - accuracy: 0.8585 - val_loss: 0.3526 - val_accuracy: 0.8636
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3425 - accuracy: 0.8672 - val_loss: 0.3324 - val_accuracy: 0.8676
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3248 - accuracy: 0.8723 - val_loss: 0.3239 - val_accuracy: 0.8686
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3122 - accuracy: 0.8772 - val_loss: 0.3174 - val_accuracy: 0.8700
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3015 - accuracy: 0.8824 - val_loss: 0.3129 - val_accuracy: 0.8716
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2932 - accuracy: 0.8851 - val_loss: 0.3090 - val_accuracy: 0.8722
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2841 - accuracy: 0.8900 - val_loss: 0.3061 - val_accuracy: 0.8734
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873420238494873
# Validation Loss: 0.30609211325645447
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8740    0.8435    0.8585      2269
#            1     0.8730    0.8984    0.8855      2716
#
#     accuracy                         0.8734      4985
#    macro avg     0.8735    0.8710    0.8720      4985
# weighted avg     0.8734    0.8734    0.8732      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 8s 10ms/step - loss: 0.6122 - accuracy: 0.7191 - val_loss: 0.5261 - val_accuracy: 0.8405
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4707 - accuracy: 0.8293 - val_loss: 0.4158 - val_accuracy: 0.8560
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3951 - accuracy: 0.8511 - val_loss: 0.3686 - val_accuracy: 0.8622
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3565 - accuracy: 0.8621 - val_loss: 0.3407 - val_accuracy: 0.8630
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3336 - accuracy: 0.8693 - val_loss: 0.3262 - val_accuracy: 0.8696
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3169 - accuracy: 0.8764 - val_loss: 0.3186 - val_accuracy: 0.8720
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3047 - accuracy: 0.8813 - val_loss: 0.3132 - val_accuracy: 0.8732
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2959 - accuracy: 0.8844 - val_loss: 0.3110 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2879 - accuracy: 0.8870 - val_loss: 0.3072 - val_accuracy: 0.8726
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2781 - accuracy: 0.8916 - val_loss: 0.3051 - val_accuracy: 0.8740
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.30508527159690857
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8797    0.8378    0.8582      2269
#            1     0.8697    0.9043    0.8866      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8747    0.8710    0.8724      4985
# weighted avg     0.8742    0.8740    0.8737      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6185 - accuracy: 0.7145 - val_loss: 0.5364 - val_accuracy: 0.8504
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4827 - accuracy: 0.8252 - val_loss: 0.4266 - val_accuracy: 0.8564
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4031 - accuracy: 0.8480 - val_loss: 0.3699 - val_accuracy: 0.8588
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3626 - accuracy: 0.8605 - val_loss: 0.3429 - val_accuracy: 0.8662
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3366 - accuracy: 0.8703 - val_loss: 0.3280 - val_accuracy: 0.8676
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3200 - accuracy: 0.8743 - val_loss: 0.3186 - val_accuracy: 0.8696
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3060 - accuracy: 0.8802 - val_loss: 0.3137 - val_accuracy: 0.8702
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2966 - accuracy: 0.8847 - val_loss: 0.3094 - val_accuracy: 0.8734
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2877 - accuracy: 0.8872 - val_loss: 0.3059 - val_accuracy: 0.8762
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2791 - accuracy: 0.8919 - val_loss: 0.3051 - val_accuracy: 0.8744
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8744232654571533
# Validation Loss: 0.30514609813690186
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8812    0.8369    0.8585      2269
#            1     0.8693    0.9057    0.8871      2716
#
#     accuracy                         0.8744      4985
#    macro avg     0.8752    0.8713    0.8728      4985
# weighted avg     0.8747    0.8744    0.8741      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_BERITA_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_BERITA_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8741023069207623
# Average Precision : 0.8717859506315488
# Average Recall : 0.9015463917525773
# Average F1 Score : 0.8863995694138993
