# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigram_Top10_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.6206 - accuracy: 0.7161 - val_loss: 0.5395 - val_accuracy: 0.8351
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4835 - accuracy: 0.8274 - val_loss: 0.4283 - val_accuracy: 0.8576
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4025 - accuracy: 0.8496 - val_loss: 0.3715 - val_accuracy: 0.8592
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3604 - accuracy: 0.8600 - val_loss: 0.3445 - val_accuracy: 0.8648
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3355 - accuracy: 0.8699 - val_loss: 0.3288 - val_accuracy: 0.8700
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3178 - accuracy: 0.8742 - val_loss: 0.3197 - val_accuracy: 0.8714
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3057 - accuracy: 0.8804 - val_loss: 0.3169 - val_accuracy: 0.8732
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2953 - accuracy: 0.8849 - val_loss: 0.3104 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2859 - accuracy: 0.8884 - val_loss: 0.3071 - val_accuracy: 0.8750
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2775 - accuracy: 0.8911 - val_loss: 0.3078 - val_accuracy: 0.8736
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3077958822250366
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8889    0.8255    0.8560      2269
#            1     0.8624    0.9138    0.8874      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8757    0.8697    0.8717      4985
# weighted avg     0.8745    0.8736    0.8731      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6076 - accuracy: 0.7214 - val_loss: 0.5174 - val_accuracy: 0.8317
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4634 - accuracy: 0.8324 - val_loss: 0.4106 - val_accuracy: 0.8568
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3863 - accuracy: 0.8536 - val_loss: 0.3584 - val_accuracy: 0.8608
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3509 - accuracy: 0.8631 - val_loss: 0.3362 - val_accuracy: 0.8668
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3278 - accuracy: 0.8714 - val_loss: 0.3257 - val_accuracy: 0.8688
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3136 - accuracy: 0.8784 - val_loss: 0.3167 - val_accuracy: 0.8720
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3003 - accuracy: 0.8830 - val_loss: 0.3152 - val_accuracy: 0.8716
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2920 - accuracy: 0.8861 - val_loss: 0.3091 - val_accuracy: 0.8746
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2827 - accuracy: 0.8887 - val_loss: 0.3057 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2740 - accuracy: 0.8921 - val_loss: 0.3045 - val_accuracy: 0.8736
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3044873774051666
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8761    0.8413    0.8584      2269
#            1     0.8717    0.9006    0.8859      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8739    0.8710    0.8721      4985
# weighted avg     0.8737    0.8736    0.8734      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6184 - accuracy: 0.7136 - val_loss: 0.5337 - val_accuracy: 0.8229
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4750 - accuracy: 0.8294 - val_loss: 0.4174 - val_accuracy: 0.8570
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3952 - accuracy: 0.8520 - val_loss: 0.3646 - val_accuracy: 0.8612
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3544 - accuracy: 0.8625 - val_loss: 0.3386 - val_accuracy: 0.8658
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3312 - accuracy: 0.8707 - val_loss: 0.3253 - val_accuracy: 0.8686
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3161 - accuracy: 0.8774 - val_loss: 0.3181 - val_accuracy: 0.8706
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3018 - accuracy: 0.8820 - val_loss: 0.3117 - val_accuracy: 0.8732
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2931 - accuracy: 0.8846 - val_loss: 0.3092 - val_accuracy: 0.8738
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2833 - accuracy: 0.8890 - val_loss: 0.3064 - val_accuracy: 0.8750
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2762 - accuracy: 0.8915 - val_loss: 0.3029 - val_accuracy: 0.8768
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.876830518245697
# Validation Loss: 0.3029238283634186
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8712    0.8559    0.8635      2269
#            1     0.8813    0.8943    0.8878      2716
#
#     accuracy                         0.8768      4985
#    macro avg     0.8763    0.8751    0.8756      4985
# weighted avg     0.8767    0.8768    0.8767      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 8s 10ms/step - loss: 0.6095 - accuracy: 0.7292 - val_loss: 0.5193 - val_accuracy: 0.8524
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4643 - accuracy: 0.8313 - val_loss: 0.4106 - val_accuracy: 0.8568
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3888 - accuracy: 0.8510 - val_loss: 0.3623 - val_accuracy: 0.8620
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3519 - accuracy: 0.8623 - val_loss: 0.3388 - val_accuracy: 0.8638
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3295 - accuracy: 0.8700 - val_loss: 0.3252 - val_accuracy: 0.8694
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3151 - accuracy: 0.8759 - val_loss: 0.3175 - val_accuracy: 0.8714
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3032 - accuracy: 0.8802 - val_loss: 0.3128 - val_accuracy: 0.8742
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2927 - accuracy: 0.8837 - val_loss: 0.3093 - val_accuracy: 0.8742
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2840 - accuracy: 0.8883 - val_loss: 0.3066 - val_accuracy: 0.8740
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2769 - accuracy: 0.8907 - val_loss: 0.3047 - val_accuracy: 0.8734
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873420238494873
# Validation Loss: 0.304747998714447
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8788    0.8374    0.8576      2269
#            1     0.8693    0.9035    0.8861      2716
#
#     accuracy                         0.8734      4985
#    macro avg     0.8741    0.8705    0.8718      4985
# weighted avg     0.8736    0.8734    0.8731      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6191 - accuracy: 0.7100 - val_loss: 0.5381 - val_accuracy: 0.8361
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4829 - accuracy: 0.8277 - val_loss: 0.4256 - val_accuracy: 0.8574
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4043 - accuracy: 0.8488 - val_loss: 0.3723 - val_accuracy: 0.8602
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3627 - accuracy: 0.8598 - val_loss: 0.3456 - val_accuracy: 0.8638
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3374 - accuracy: 0.8688 - val_loss: 0.3288 - val_accuracy: 0.8682
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3213 - accuracy: 0.8746 - val_loss: 0.3206 - val_accuracy: 0.8692
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3091 - accuracy: 0.8808 - val_loss: 0.3177 - val_accuracy: 0.8708
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2986 - accuracy: 0.8831 - val_loss: 0.3109 - val_accuracy: 0.8750
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2901 - accuracy: 0.8872 - val_loss: 0.3088 - val_accuracy: 0.8730
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2826 - accuracy: 0.8896 - val_loss: 0.3091 - val_accuracy: 0.8736
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3091159164905548
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8882    0.8264    0.8562      2269
#            1     0.8629    0.9131    0.8873      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8756    0.8697    0.8717      4985
# weighted avg     0.8744    0.8736    0.8731      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTER_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_TWITTER_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.874222668004012
# Average Precision : 0.8695309103394552
# Average Recall : 0.905081001472754
# Average F1 Score : 0.8868923804446153
