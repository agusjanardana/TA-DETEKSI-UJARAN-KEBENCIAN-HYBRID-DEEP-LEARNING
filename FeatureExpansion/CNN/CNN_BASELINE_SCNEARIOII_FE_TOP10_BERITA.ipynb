# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigram_Top10_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.6278 - accuracy: 0.7075 - val_loss: 0.5518 - val_accuracy: 0.8243
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4957 - accuracy: 0.8204 - val_loss: 0.4369 - val_accuracy: 0.8572
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4148 - accuracy: 0.8449 - val_loss: 0.3788 - val_accuracy: 0.8602
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3674 - accuracy: 0.8577 - val_loss: 0.3480 - val_accuracy: 0.8634
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3436 - accuracy: 0.8674 - val_loss: 0.3328 - val_accuracy: 0.8652
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3254 - accuracy: 0.8726 - val_loss: 0.3233 - val_accuracy: 0.8704
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3131 - accuracy: 0.8778 - val_loss: 0.3161 - val_accuracy: 0.8706
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3028 - accuracy: 0.8828 - val_loss: 0.3114 - val_accuracy: 0.8728
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2922 - accuracy: 0.8856 - val_loss: 0.3089 - val_accuracy: 0.8718
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2846 - accuracy: 0.8896 - val_loss: 0.3055 - val_accuracy: 0.8756
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8756268620491028
# Validation Loss: 0.30551251769065857
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8763    0.8462    0.8610      2269
#            1     0.8751    0.9002    0.8875      2716
#
#     accuracy                         0.8756      4985
#    macro avg     0.8757    0.8732    0.8742      4985
# weighted avg     0.8756    0.8756    0.8754      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6267 - accuracy: 0.7022 - val_loss: 0.5485 - val_accuracy: 0.8375
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4896 - accuracy: 0.8246 - val_loss: 0.4327 - val_accuracy: 0.8538
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4070 - accuracy: 0.8463 - val_loss: 0.3732 - val_accuracy: 0.8610
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3637 - accuracy: 0.8598 - val_loss: 0.3441 - val_accuracy: 0.8640
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3397 - accuracy: 0.8686 - val_loss: 0.3308 - val_accuracy: 0.8694
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3220 - accuracy: 0.8744 - val_loss: 0.3208 - val_accuracy: 0.8710
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3088 - accuracy: 0.8806 - val_loss: 0.3148 - val_accuracy: 0.8724
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2993 - accuracy: 0.8830 - val_loss: 0.3104 - val_accuracy: 0.8746
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2889 - accuracy: 0.8869 - val_loss: 0.3073 - val_accuracy: 0.8762
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2811 - accuracy: 0.8900 - val_loss: 0.3055 - val_accuracy: 0.8760
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8760280609130859
# Validation Loss: 0.3055207133293152
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8802    0.8422    0.8608      2269
#            1     0.8728    0.9043    0.8882      2716
#
#     accuracy                         0.8760      4985
#    macro avg     0.8765    0.8732    0.8745      4985
# weighted avg     0.8762    0.8760    0.8758      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6145 - accuracy: 0.7120 - val_loss: 0.5295 - val_accuracy: 0.8504
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4724 - accuracy: 0.8297 - val_loss: 0.4147 - val_accuracy: 0.8548
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3931 - accuracy: 0.8518 - val_loss: 0.3637 - val_accuracy: 0.8618
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3546 - accuracy: 0.8620 - val_loss: 0.3384 - val_accuracy: 0.8678
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3313 - accuracy: 0.8716 - val_loss: 0.3270 - val_accuracy: 0.8692
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3152 - accuracy: 0.8771 - val_loss: 0.3191 - val_accuracy: 0.8706
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3035 - accuracy: 0.8818 - val_loss: 0.3131 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2932 - accuracy: 0.8851 - val_loss: 0.3096 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2838 - accuracy: 0.8878 - val_loss: 0.3062 - val_accuracy: 0.8732
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2770 - accuracy: 0.8911 - val_loss: 0.3039 - val_accuracy: 0.8764
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8764292597770691
# Validation Loss: 0.3038850724697113
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8742    0.8510    0.8624      2269
#            1     0.8782    0.8976    0.8878      2716
#
#     accuracy                         0.8764      4985
#    macro avg     0.8762    0.8743    0.8751      4985
# weighted avg     0.8764    0.8764    0.8763      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6198 - accuracy: 0.7086 - val_loss: 0.5366 - val_accuracy: 0.8325
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4799 - accuracy: 0.8261 - val_loss: 0.4221 - val_accuracy: 0.8552
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4000 - accuracy: 0.8493 - val_loss: 0.3688 - val_accuracy: 0.8592
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3584 - accuracy: 0.8607 - val_loss: 0.3419 - val_accuracy: 0.8650
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3359 - accuracy: 0.8701 - val_loss: 0.3271 - val_accuracy: 0.8690
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3186 - accuracy: 0.8754 - val_loss: 0.3199 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3073 - accuracy: 0.8792 - val_loss: 0.3156 - val_accuracy: 0.8708
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2958 - accuracy: 0.8843 - val_loss: 0.3095 - val_accuracy: 0.8752
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2869 - accuracy: 0.8874 - val_loss: 0.3075 - val_accuracy: 0.8738
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2786 - accuracy: 0.8908 - val_loss: 0.3049 - val_accuracy: 0.8762
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8762286901473999
# Validation Loss: 0.3048616051673889
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8779    0.8457    0.8615      2269
#            1     0.8750    0.9017    0.8881      2716
#
#     accuracy                         0.8762      4985
#    macro avg     0.8764    0.8737    0.8748      4985
# weighted avg     0.8763    0.8762    0.8760      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6148 - accuracy: 0.7172 - val_loss: 0.5306 - val_accuracy: 0.8514
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4737 - accuracy: 0.8278 - val_loss: 0.4189 - val_accuracy: 0.8566
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3951 - accuracy: 0.8492 - val_loss: 0.3670 - val_accuracy: 0.8600
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3567 - accuracy: 0.8603 - val_loss: 0.3394 - val_accuracy: 0.8652
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3326 - accuracy: 0.8687 - val_loss: 0.3254 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3162 - accuracy: 0.8755 - val_loss: 0.3177 - val_accuracy: 0.8726
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3032 - accuracy: 0.8815 - val_loss: 0.3123 - val_accuracy: 0.8738
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2928 - accuracy: 0.8845 - val_loss: 0.3090 - val_accuracy: 0.8750
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2849 - accuracy: 0.8897 - val_loss: 0.3077 - val_accuracy: 0.8748
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2754 - accuracy: 0.8913 - val_loss: 0.3044 - val_accuracy: 0.8776
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8776329159736633
# Validation Loss: 0.30436238646507263
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8731    0.8554    0.8642      2269
#            1     0.8812    0.8962    0.8886      2716
#
#     accuracy                         0.8776      4985
#    macro avg     0.8772    0.8758    0.8764      4985
# weighted avg     0.8776    0.8776    0.8775      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_BERITA_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_DROPOUT0.5_FE_BERITA_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8763891675025075
# Average Precision : 0.8764622660396221
# Average Recall : 0.9
# Average F1 Score : 0.8880657780019066
