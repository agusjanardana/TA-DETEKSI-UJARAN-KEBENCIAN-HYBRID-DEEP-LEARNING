# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM-TRIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigram_Top1_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 14s 10ms/step - loss: 0.6117 - accuracy: 0.7255 - val_loss: 0.5263 - val_accuracy: 0.8321
# Epoch 2/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4722 - accuracy: 0.8278 - val_loss: 0.4160 - val_accuracy: 0.8552
# Epoch 3/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3950 - accuracy: 0.8505 - val_loss: 0.3653 - val_accuracy: 0.8592
# Epoch 4/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3564 - accuracy: 0.8597 - val_loss: 0.3408 - val_accuracy: 0.8648
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3343 - accuracy: 0.8700 - val_loss: 0.3283 - val_accuracy: 0.8692
# Epoch 6/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.3166 - accuracy: 0.8758 - val_loss: 0.3186 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3067 - accuracy: 0.8801 - val_loss: 0.3138 - val_accuracy: 0.8712
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2947 - accuracy: 0.8847 - val_loss: 0.3100 - val_accuracy: 0.8742
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2867 - accuracy: 0.8864 - val_loss: 0.3074 - val_accuracy: 0.8746
# Epoch 10/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.2781 - accuracy: 0.8898 - val_loss: 0.3049 - val_accuracy: 0.8756
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8756268620491028
# Validation Loss: 0.30493074655532837
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8760    0.8466    0.8610      2269
#            1     0.8754    0.8999    0.8874      2716
#
#     accuracy                         0.8756      4985
#    macro avg     0.8757    0.8732    0.8742      4985
# weighted avg     0.8756    0.8756    0.8754      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6098 - accuracy: 0.7153 - val_loss: 0.5228 - val_accuracy: 0.8405
# Epoch 2/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4687 - accuracy: 0.8304 - val_loss: 0.4144 - val_accuracy: 0.8544
# Epoch 3/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3940 - accuracy: 0.8530 - val_loss: 0.3631 - val_accuracy: 0.8598
# Epoch 4/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3554 - accuracy: 0.8641 - val_loss: 0.3415 - val_accuracy: 0.8644
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3316 - accuracy: 0.8701 - val_loss: 0.3273 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3164 - accuracy: 0.8755 - val_loss: 0.3188 - val_accuracy: 0.8702
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3052 - accuracy: 0.8821 - val_loss: 0.3139 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2940 - accuracy: 0.8847 - val_loss: 0.3097 - val_accuracy: 0.8758
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2872 - accuracy: 0.8880 - val_loss: 0.3070 - val_accuracy: 0.8754
# Epoch 10/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2790 - accuracy: 0.8913 - val_loss: 0.3046 - val_accuracy: 0.8742
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8742226958274841
# Validation Loss: 0.3046342730522156
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8752    0.8440    0.8593      2269
#            1     0.8734    0.8995    0.8863      2716
#
#     accuracy                         0.8742      4985
#    macro avg     0.8743    0.8717    0.8728      4985
# weighted avg     0.8743    0.8742    0.8740      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6325 - accuracy: 0.6903 - val_loss: 0.5595 - val_accuracy: 0.8191
# Epoch 2/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4984 - accuracy: 0.8212 - val_loss: 0.4378 - val_accuracy: 0.8570
# Epoch 3/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4122 - accuracy: 0.8479 - val_loss: 0.3806 - val_accuracy: 0.8610
# Epoch 4/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3644 - accuracy: 0.8612 - val_loss: 0.3467 - val_accuracy: 0.8660
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3392 - accuracy: 0.8686 - val_loss: 0.3306 - val_accuracy: 0.8688
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3225 - accuracy: 0.8736 - val_loss: 0.3222 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3087 - accuracy: 0.8789 - val_loss: 0.3154 - val_accuracy: 0.8714
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2989 - accuracy: 0.8836 - val_loss: 0.3108 - val_accuracy: 0.8722
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2888 - accuracy: 0.8867 - val_loss: 0.3076 - val_accuracy: 0.8748
# Epoch 10/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.2813 - accuracy: 0.8907 - val_loss: 0.3049 - val_accuracy: 0.8738
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8738214373588562
# Validation Loss: 0.30494406819343567
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8721    0.8471    0.8594      2269
#            1     0.8752    0.8962    0.8856      2716
#
#     accuracy                         0.8738      4985
#    macro avg     0.8736    0.8716    0.8725      4985
# weighted avg     0.8738    0.8738    0.8737      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6120 - accuracy: 0.7263 - val_loss: 0.5259 - val_accuracy: 0.8497
# Epoch 2/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4716 - accuracy: 0.8264 - val_loss: 0.4157 - val_accuracy: 0.8566
# Epoch 3/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.3965 - accuracy: 0.8507 - val_loss: 0.3653 - val_accuracy: 0.8618
# Epoch 4/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.3564 - accuracy: 0.8613 - val_loss: 0.3406 - val_accuracy: 0.8692
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3339 - accuracy: 0.8700 - val_loss: 0.3258 - val_accuracy: 0.8704
# Epoch 6/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.3166 - accuracy: 0.8763 - val_loss: 0.3182 - val_accuracy: 0.8720
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3047 - accuracy: 0.8809 - val_loss: 0.3120 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2935 - accuracy: 0.8852 - val_loss: 0.3092 - val_accuracy: 0.8726
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.2854 - accuracy: 0.8892 - val_loss: 0.3060 - val_accuracy: 0.8754
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2766 - accuracy: 0.8912 - val_loss: 0.3037 - val_accuracy: 0.8752
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8752256631851196
# Validation Loss: 0.3037426769733429
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8762    0.8453    0.8605      2269
#            1     0.8745    0.9002    0.8872      2716
#
#     accuracy                         0.8752      4985
#    macro avg     0.8753    0.8728    0.8738      4985
# weighted avg     0.8753    0.8752    0.8750      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6132 - accuracy: 0.7166 - val_loss: 0.5281 - val_accuracy: 0.8223
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4720 - accuracy: 0.8294 - val_loss: 0.4164 - val_accuracy: 0.8560
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3962 - accuracy: 0.8512 - val_loss: 0.3662 - val_accuracy: 0.8610
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3554 - accuracy: 0.8644 - val_loss: 0.3403 - val_accuracy: 0.8666
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3326 - accuracy: 0.8695 - val_loss: 0.3266 - val_accuracy: 0.8676
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3154 - accuracy: 0.8762 - val_loss: 0.3196 - val_accuracy: 0.8708
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3057 - accuracy: 0.8805 - val_loss: 0.3140 - val_accuracy: 0.8716
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2943 - accuracy: 0.8854 - val_loss: 0.3091 - val_accuracy: 0.8732
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2849 - accuracy: 0.8893 - val_loss: 0.3061 - val_accuracy: 0.8734
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2777 - accuracy: 0.8911 - val_loss: 0.3047 - val_accuracy: 0.8742
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8742226958274841
# Validation Loss: 0.30469581484794617
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8766    0.8422    0.8591      2269
#            1     0.8724    0.9010    0.8864      2716
#
#     accuracy                         0.8742      4985
#    macro avg     0.8745    0.8716    0.8728      4985
# weighted avg     0.8743    0.8742    0.8740      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8746238716148446
# Average Precision : 0.8741706030780974
# Average Recall : 0.8993372606774669
# Average F1 Score : 0.88657362785532
