# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM-TRIGRAM DROPOUT 0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigram_Top10_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.6406 - accuracy: 0.6771 - val_loss: 0.5756 - val_accuracy: 0.8179
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.5162 - accuracy: 0.8149 - val_loss: 0.4541 - val_accuracy: 0.8536
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4249 - accuracy: 0.8421 - val_loss: 0.3863 - val_accuracy: 0.8578
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3746 - accuracy: 0.8578 - val_loss: 0.3535 - val_accuracy: 0.8618
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3466 - accuracy: 0.8650 - val_loss: 0.3355 - val_accuracy: 0.8676
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3275 - accuracy: 0.8718 - val_loss: 0.3242 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3135 - accuracy: 0.8774 - val_loss: 0.3192 - val_accuracy: 0.8706
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3040 - accuracy: 0.8804 - val_loss: 0.3133 - val_accuracy: 0.8718
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2953 - accuracy: 0.8833 - val_loss: 0.3090 - val_accuracy: 0.8750
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2858 - accuracy: 0.8877 - val_loss: 0.3065 - val_accuracy: 0.8742
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8742226958274841
# Validation Loss: 0.30650776624679565
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8739    0.8457    0.8596      2269
#            1     0.8745    0.8980    0.8861      2716
#
#     accuracy                         0.8742      4985
#    macro avg     0.8742    0.8719    0.8728      4985
# weighted avg     0.8742    0.8742    0.8740      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6059 - accuracy: 0.7308 - val_loss: 0.5152 - val_accuracy: 0.8325
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4615 - accuracy: 0.8306 - val_loss: 0.4074 - val_accuracy: 0.8566
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3887 - accuracy: 0.8517 - val_loss: 0.3609 - val_accuracy: 0.8618
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3501 - accuracy: 0.8647 - val_loss: 0.3363 - val_accuracy: 0.8656
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3288 - accuracy: 0.8708 - val_loss: 0.3236 - val_accuracy: 0.8696
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3124 - accuracy: 0.8773 - val_loss: 0.3174 - val_accuracy: 0.8718
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3024 - accuracy: 0.8822 - val_loss: 0.3115 - val_accuracy: 0.8718
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2913 - accuracy: 0.8858 - val_loss: 0.3088 - val_accuracy: 0.8718
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2819 - accuracy: 0.8896 - val_loss: 0.3056 - val_accuracy: 0.8738
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2734 - accuracy: 0.8915 - val_loss: 0.3035 - val_accuracy: 0.8754
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8754262924194336
# Validation Loss: 0.30353277921676636
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8745    0.8480    0.8610      2269
#            1     0.8761    0.8984    0.8871      2716
#
#     accuracy                         0.8754      4985
#    macro avg     0.8753    0.8732    0.8741      4985
# weighted avg     0.8754    0.8754    0.8752      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6146 - accuracy: 0.7056 - val_loss: 0.5305 - val_accuracy: 0.8215
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4760 - accuracy: 0.8261 - val_loss: 0.4208 - val_accuracy: 0.8552
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3975 - accuracy: 0.8504 - val_loss: 0.3650 - val_accuracy: 0.8606
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3589 - accuracy: 0.8616 - val_loss: 0.3451 - val_accuracy: 0.8634
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3345 - accuracy: 0.8710 - val_loss: 0.3316 - val_accuracy: 0.8694
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3183 - accuracy: 0.8756 - val_loss: 0.3211 - val_accuracy: 0.8704
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3056 - accuracy: 0.8822 - val_loss: 0.3143 - val_accuracy: 0.8740
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2954 - accuracy: 0.8852 - val_loss: 0.3135 - val_accuracy: 0.8714
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2879 - accuracy: 0.8885 - val_loss: 0.3109 - val_accuracy: 0.8730
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2782 - accuracy: 0.8906 - val_loss: 0.3053 - val_accuracy: 0.8746
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8746238946914673
# Validation Loss: 0.30534881353378296
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8663    0.8568    0.8615      2269
#            1     0.8814    0.8895    0.8855      2716
#
#     accuracy                         0.8746      4985
#    macro avg     0.8739    0.8732    0.8735      4985
# weighted avg     0.8745    0.8746    0.8746      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 8s 10ms/step - loss: 0.6331 - accuracy: 0.6860 - val_loss: 0.5618 - val_accuracy: 0.8289
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.5057 - accuracy: 0.8190 - val_loss: 0.4477 - val_accuracy: 0.8532
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4185 - accuracy: 0.8441 - val_loss: 0.3825 - val_accuracy: 0.8602
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3739 - accuracy: 0.8564 - val_loss: 0.3527 - val_accuracy: 0.8628
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3472 - accuracy: 0.8640 - val_loss: 0.3370 - val_accuracy: 0.8662
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3295 - accuracy: 0.8709 - val_loss: 0.3251 - val_accuracy: 0.8684
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3171 - accuracy: 0.8763 - val_loss: 0.3192 - val_accuracy: 0.8700
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3068 - accuracy: 0.8801 - val_loss: 0.3163 - val_accuracy: 0.8706
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2980 - accuracy: 0.8837 - val_loss: 0.3110 - val_accuracy: 0.8736
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2894 - accuracy: 0.8866 - val_loss: 0.3076 - val_accuracy: 0.8752
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8752256631851196
# Validation Loss: 0.30758675932884216
#
# 156/156 [==============================] - 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8701    0.8532    0.8616      2269
#            1     0.8793    0.8936    0.8864      2716
#
#     accuracy                         0.8752      4985
#    macro avg     0.8747    0.8734    0.8740      4985
# weighted avg     0.8751    0.8752    0.8751      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6292 - accuracy: 0.7006 - val_loss: 0.5573 - val_accuracy: 0.8477
# Epoch 2/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4979 - accuracy: 0.8190 - val_loss: 0.4380 - val_accuracy: 0.8548
# Epoch 3/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.4128 - accuracy: 0.8456 - val_loss: 0.3793 - val_accuracy: 0.8600
# Epoch 4/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3685 - accuracy: 0.8579 - val_loss: 0.3511 - val_accuracy: 0.8628
# Epoch 5/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3415 - accuracy: 0.8664 - val_loss: 0.3343 - val_accuracy: 0.8668
# Epoch 6/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3239 - accuracy: 0.8734 - val_loss: 0.3228 - val_accuracy: 0.8686
# Epoch 7/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.3106 - accuracy: 0.8777 - val_loss: 0.3163 - val_accuracy: 0.8696
# Epoch 8/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2993 - accuracy: 0.8822 - val_loss: 0.3130 - val_accuracy: 0.8720
# Epoch 9/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2907 - accuracy: 0.8859 - val_loss: 0.3088 - val_accuracy: 0.8726
# Epoch 10/10
# 701/701 [==============================] - 5s 7ms/step - loss: 0.2826 - accuracy: 0.8893 - val_loss: 0.3076 - val_accuracy: 0.8736
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3076048493385315
#
# 156/156 [==============================] - 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8799    0.8365    0.8577      2269
#            1     0.8688    0.9046    0.8864      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8744    0.8706    0.8720      4985
# weighted avg     0.8739    0.8736    0.8733      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM Dropout 0.5')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTERBERITA_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8746238716148446
# Average Precision : 0.8760437833201802
# Average Recall : 0.8968335787923417
# Average F1 Score : 0.8862920518648234
