# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigramTrigram_Top5_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 10s 15ms/step - loss: 0.6890 - accuracy: 0.5463 - val_loss: 0.6796 - val_accuracy: 0.5531
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6491 - accuracy: 0.6636 - val_loss: 0.6068 - val_accuracy: 0.7569
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5486 - accuracy: 0.8075 - val_loss: 0.4925 - val_accuracy: 0.8431
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4409 - accuracy: 0.8604 - val_loss: 0.4001 - val_accuracy: 0.8652
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3677 - accuracy: 0.8739 - val_loss: 0.3499 - val_accuracy: 0.8696
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3267 - accuracy: 0.8845 - val_loss: 0.3270 - val_accuracy: 0.8716
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3018 - accuracy: 0.8902 - val_loss: 0.3179 - val_accuracy: 0.8738
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2857 - accuracy: 0.8963 - val_loss: 0.3156 - val_accuracy: 0.8740
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2749 - accuracy: 0.8991 - val_loss: 0.3150 - val_accuracy: 0.8730
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2641 - accuracy: 0.9033 - val_loss: 0.3168 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.31682050228118896
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8697    0.8471    0.8582      2269
#            1     0.8750    0.8940    0.8844      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8723    0.8705    0.8713      4985
# weighted avg     0.8726    0.8726    0.8725      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6879 - accuracy: 0.5476 - val_loss: 0.6756 - val_accuracy: 0.5486
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6408 - accuracy: 0.6747 - val_loss: 0.5944 - val_accuracy: 0.7703
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5344 - accuracy: 0.8240 - val_loss: 0.4775 - val_accuracy: 0.8439
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4269 - accuracy: 0.8664 - val_loss: 0.3886 - val_accuracy: 0.8654
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3562 - accuracy: 0.8785 - val_loss: 0.3429 - val_accuracy: 0.8702
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3196 - accuracy: 0.8868 - val_loss: 0.3236 - val_accuracy: 0.8716
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2959 - accuracy: 0.8919 - val_loss: 0.3165 - val_accuracy: 0.8726
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2812 - accuracy: 0.8967 - val_loss: 0.3133 - val_accuracy: 0.8726
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2671 - accuracy: 0.9012 - val_loss: 0.3147 - val_accuracy: 0.8736
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2584 - accuracy: 0.9068 - val_loss: 0.3157 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.3157452344894409
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8601    0.8559    0.8580      2269
#            1     0.8801    0.8837    0.8819      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8701    0.8698    0.8699      4985
# weighted avg     0.8710    0.8710    0.8710      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6883 - accuracy: 0.6183 - val_loss: 0.6764 - val_accuracy: 0.7739
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6419 - accuracy: 0.8118 - val_loss: 0.5934 - val_accuracy: 0.8530
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5257 - accuracy: 0.8533 - val_loss: 0.4592 - val_accuracy: 0.8602
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4102 - accuracy: 0.8673 - val_loss: 0.3719 - val_accuracy: 0.8660
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3473 - accuracy: 0.8778 - val_loss: 0.3347 - val_accuracy: 0.8710
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3133 - accuracy: 0.8863 - val_loss: 0.3184 - val_accuracy: 0.8718
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2913 - accuracy: 0.8923 - val_loss: 0.3121 - val_accuracy: 0.8736
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2767 - accuracy: 0.8986 - val_loss: 0.3103 - val_accuracy: 0.8734
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2659 - accuracy: 0.9021 - val_loss: 0.3113 - val_accuracy: 0.8726
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2560 - accuracy: 0.9058 - val_loss: 0.3137 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.3137475550174713
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8695    0.8457    0.8575      2269
#            1     0.8740    0.8940    0.8839      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8718    0.8699    0.8707      4985
# weighted avg     0.8720    0.8720    0.8719      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6901 - accuracy: 0.5559 - val_loss: 0.6819 - val_accuracy: 0.6385
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6496 - accuracy: 0.7574 - val_loss: 0.6006 - val_accuracy: 0.8315
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5301 - accuracy: 0.8450 - val_loss: 0.4628 - val_accuracy: 0.8580
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4113 - accuracy: 0.8632 - val_loss: 0.3743 - val_accuracy: 0.8644
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3469 - accuracy: 0.8754 - val_loss: 0.3373 - val_accuracy: 0.8682
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3162 - accuracy: 0.8836 - val_loss: 0.3214 - val_accuracy: 0.8706
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2945 - accuracy: 0.8896 - val_loss: 0.3145 - val_accuracy: 0.8714
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2800 - accuracy: 0.8963 - val_loss: 0.3123 - val_accuracy: 0.8722
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2683 - accuracy: 0.9017 - val_loss: 0.3128 - val_accuracy: 0.8720
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2601 - accuracy: 0.9043 - val_loss: 0.3144 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.31437575817108154
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8654    0.8497    0.8575      2269
#            1     0.8763    0.8895    0.8829      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8708    0.8696    0.8702      4985
# weighted avg     0.8713    0.8714    0.8713      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6879 - accuracy: 0.5457 - val_loss: 0.6753 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6335 - accuracy: 0.6656 - val_loss: 0.5799 - val_accuracy: 0.7669
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5162 - accuracy: 0.8245 - val_loss: 0.4604 - val_accuracy: 0.8497
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4132 - accuracy: 0.8648 - val_loss: 0.3802 - val_accuracy: 0.8662
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3497 - accuracy: 0.8783 - val_loss: 0.3402 - val_accuracy: 0.8702
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3149 - accuracy: 0.8860 - val_loss: 0.3222 - val_accuracy: 0.8732
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2938 - accuracy: 0.8926 - val_loss: 0.3160 - val_accuracy: 0.8746
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2801 - accuracy: 0.8956 - val_loss: 0.3132 - val_accuracy: 0.8760
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2690 - accuracy: 0.9006 - val_loss: 0.3141 - val_accuracy: 0.8750
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2587 - accuracy: 0.9044 - val_loss: 0.3159 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.3158916234970093
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8674    0.8506    0.8589      2269
#            1     0.8772    0.8914    0.8842      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8723    0.8710    0.8716      4985
# weighted avg     0.8727    0.8728    0.8727      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.87197592778335
# Average Precision : 0.8765083581917041
# Average Recall : 0.8905007363770251
# Average F1 Score : 0.8718636432582223
