# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigramTrigram_Top1_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 10s 16ms/step - loss: 0.6889 - accuracy: 0.5508 - val_loss: 0.6794 - val_accuracy: 0.5539
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6483 - accuracy: 0.6904 - val_loss: 0.6053 - val_accuracy: 0.7527
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5455 - accuracy: 0.8131 - val_loss: 0.4857 - val_accuracy: 0.8485
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4375 - accuracy: 0.8555 - val_loss: 0.3956 - val_accuracy: 0.8630
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3704 - accuracy: 0.8697 - val_loss: 0.3496 - val_accuracy: 0.8686
# Epoch 6/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3315 - accuracy: 0.8788 - val_loss: 0.3290 - val_accuracy: 0.8702
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3109 - accuracy: 0.8853 - val_loss: 0.3199 - val_accuracy: 0.8720
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2933 - accuracy: 0.8919 - val_loss: 0.3158 - val_accuracy: 0.8742
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2820 - accuracy: 0.8948 - val_loss: 0.3136 - val_accuracy: 0.8724
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2702 - accuracy: 0.8996 - val_loss: 0.3150 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3150007128715515
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8747    0.8400    0.8570      2269
#            1     0.8706    0.8995    0.8848      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8727    0.8698    0.8709      4985
# weighted avg     0.8725    0.8724    0.8722      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6889 - accuracy: 0.5756 - val_loss: 0.6778 - val_accuracy: 0.7005
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6419 - accuracy: 0.7805 - val_loss: 0.5917 - val_accuracy: 0.8385
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5227 - accuracy: 0.8440 - val_loss: 0.4567 - val_accuracy: 0.8620
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4101 - accuracy: 0.8651 - val_loss: 0.3725 - val_accuracy: 0.8654
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3498 - accuracy: 0.8748 - val_loss: 0.3368 - val_accuracy: 0.8690
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3187 - accuracy: 0.8822 - val_loss: 0.3209 - val_accuracy: 0.8732
# Epoch 7/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2990 - accuracy: 0.8901 - val_loss: 0.3138 - val_accuracy: 0.8722
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2847 - accuracy: 0.8951 - val_loss: 0.3109 - val_accuracy: 0.8752
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2730 - accuracy: 0.8999 - val_loss: 0.3104 - val_accuracy: 0.8742
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2638 - accuracy: 0.9025 - val_loss: 0.3119 - val_accuracy: 0.8722
#
# Validation Accuracy: 0.8722166419029236
# Validation Loss: 0.3119383156299591
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8679    0.8484    0.8580      2269
#            1     0.8757    0.8921    0.8838      2716
#
#     accuracy                         0.8722      4985
#    macro avg     0.8718    0.8703    0.8709      4985
# weighted avg     0.8721    0.8722    0.8721      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6891 - accuracy: 0.5482 - val_loss: 0.6793 - val_accuracy: 0.5565
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6484 - accuracy: 0.6742 - val_loss: 0.6059 - val_accuracy: 0.7591
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5478 - accuracy: 0.8161 - val_loss: 0.4904 - val_accuracy: 0.8443
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4402 - accuracy: 0.8608 - val_loss: 0.3960 - val_accuracy: 0.8652
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3635 - accuracy: 0.8728 - val_loss: 0.3457 - val_accuracy: 0.8696
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3239 - accuracy: 0.8822 - val_loss: 0.3248 - val_accuracy: 0.8714
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3011 - accuracy: 0.8881 - val_loss: 0.3158 - val_accuracy: 0.8706
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2843 - accuracy: 0.8937 - val_loss: 0.3126 - val_accuracy: 0.8738
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2721 - accuracy: 0.8993 - val_loss: 0.3133 - val_accuracy: 0.8732
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2648 - accuracy: 0.9026 - val_loss: 0.3137 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.31366750597953796
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8647    0.8537    0.8592      2269
#            1     0.8791    0.8884    0.8837      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8719    0.8711    0.8714      4985
# weighted avg     0.8725    0.8726    0.8725      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6884 - accuracy: 0.5479 - val_loss: 0.6761 - val_accuracy: 0.5607
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6350 - accuracy: 0.7102 - val_loss: 0.5795 - val_accuracy: 0.8062
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5158 - accuracy: 0.8353 - val_loss: 0.4541 - val_accuracy: 0.8540
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4092 - accuracy: 0.8626 - val_loss: 0.3740 - val_accuracy: 0.8644
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3513 - accuracy: 0.8733 - val_loss: 0.3381 - val_accuracy: 0.8706
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3165 - accuracy: 0.8858 - val_loss: 0.3222 - val_accuracy: 0.8742
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2966 - accuracy: 0.8911 - val_loss: 0.3151 - val_accuracy: 0.8740
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2820 - accuracy: 0.8964 - val_loss: 0.3134 - val_accuracy: 0.8746
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2714 - accuracy: 0.8993 - val_loss: 0.3121 - val_accuracy: 0.8724
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2605 - accuracy: 0.9037 - val_loss: 0.3135 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3135371804237366
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8660    0.8515    0.8587      2269
#            1     0.8776    0.8899    0.8837      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8718    0.8707    0.8712      4985
# weighted avg     0.8723    0.8724    0.8723      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6885 - accuracy: 0.5461 - val_loss: 0.6780 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6454 - accuracy: 0.6711 - val_loss: 0.5999 - val_accuracy: 0.7695
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5421 - accuracy: 0.8209 - val_loss: 0.4847 - val_accuracy: 0.8495
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4372 - accuracy: 0.8632 - val_loss: 0.3953 - val_accuracy: 0.8676
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3675 - accuracy: 0.8742 - val_loss: 0.3468 - val_accuracy: 0.8672
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3259 - accuracy: 0.8837 - val_loss: 0.3261 - val_accuracy: 0.8718
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3031 - accuracy: 0.8889 - val_loss: 0.3162 - val_accuracy: 0.8726
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2874 - accuracy: 0.8948 - val_loss: 0.3131 - val_accuracy: 0.8734
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2744 - accuracy: 0.8987 - val_loss: 0.3121 - val_accuracy: 0.8740
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2656 - accuracy: 0.9022 - val_loss: 0.3142 - val_accuracy: 0.8722
#
# Validation Accuracy: 0.8722166419029236
# Validation Loss: 0.31415021419525146
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8712    0.8440    0.8574      2269
#            1     0.8730    0.8958    0.8842      2716
#
#     accuracy                         0.8722      4985
#    macro avg     0.8721    0.8699    0.8708      4985
# weighted avg     0.8722    0.8722    0.8720      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8723771313941825
# Average Precision : 0.8751958085437735
# Average Recall : 0.8931516936671576
# Average F1 Score : 0.872228916058222
