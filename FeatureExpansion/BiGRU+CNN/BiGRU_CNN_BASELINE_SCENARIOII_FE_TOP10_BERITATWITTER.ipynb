# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigramTrigram_Top10_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 10s 15ms/step - loss: 0.6892 - accuracy: 0.5701 - val_loss: 0.6783 - val_accuracy: 0.6810
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6401 - accuracy: 0.7915 - val_loss: 0.5863 - val_accuracy: 0.8532
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5141 - accuracy: 0.8541 - val_loss: 0.4470 - val_accuracy: 0.8622
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4016 - accuracy: 0.8665 - val_loss: 0.3665 - val_accuracy: 0.8662
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3441 - accuracy: 0.8763 - val_loss: 0.3326 - val_accuracy: 0.8692
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3137 - accuracy: 0.8852 - val_loss: 0.3186 - val_accuracy: 0.8726
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2947 - accuracy: 0.8915 - val_loss: 0.3131 - val_accuracy: 0.8742
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2789 - accuracy: 0.8972 - val_loss: 0.3111 - val_accuracy: 0.8738
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2706 - accuracy: 0.9007 - val_loss: 0.3111 - val_accuracy: 0.8730
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2589 - accuracy: 0.9056 - val_loss: 0.3134 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.313410222530365
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8626    0.8550    0.8588      2269
#            1     0.8798    0.8862    0.8830      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8712    0.8706    0.8709      4985
# weighted avg     0.8719    0.8720    0.8720      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6884 - accuracy: 0.5683 - val_loss: 0.6767 - val_accuracy: 0.6824
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6430 - accuracy: 0.7652 - val_loss: 0.5965 - val_accuracy: 0.8273
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5310 - accuracy: 0.8429 - val_loss: 0.4688 - val_accuracy: 0.8606
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4221 - accuracy: 0.8616 - val_loss: 0.3823 - val_accuracy: 0.8638
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3560 - accuracy: 0.8732 - val_loss: 0.3419 - val_accuracy: 0.8680
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3213 - accuracy: 0.8821 - val_loss: 0.3242 - val_accuracy: 0.8718
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2992 - accuracy: 0.8887 - val_loss: 0.3155 - val_accuracy: 0.8728
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2862 - accuracy: 0.8936 - val_loss: 0.3126 - val_accuracy: 0.8726
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2742 - accuracy: 0.8981 - val_loss: 0.3129 - val_accuracy: 0.8738
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2622 - accuracy: 0.9035 - val_loss: 0.3134 - val_accuracy: 0.8748
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.3134025037288666
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8720    0.8497    0.8607      2269
#            1     0.8771    0.8958    0.8863      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8745    0.8728    0.8735      4985
# weighted avg     0.8748    0.8748    0.8747      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6894 - accuracy: 0.5912 - val_loss: 0.6787 - val_accuracy: 0.7400
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6369 - accuracy: 0.8203 - val_loss: 0.5768 - val_accuracy: 0.8586
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5016 - accuracy: 0.8559 - val_loss: 0.4353 - val_accuracy: 0.8626
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3910 - accuracy: 0.8693 - val_loss: 0.3600 - val_accuracy: 0.8636
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3357 - accuracy: 0.8792 - val_loss: 0.3294 - val_accuracy: 0.8706
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3056 - accuracy: 0.8863 - val_loss: 0.3168 - val_accuracy: 0.8714
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2866 - accuracy: 0.8941 - val_loss: 0.3119 - val_accuracy: 0.8738
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2735 - accuracy: 0.8987 - val_loss: 0.3109 - val_accuracy: 0.8740
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2631 - accuracy: 0.9028 - val_loss: 0.3127 - val_accuracy: 0.8736
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2538 - accuracy: 0.9060 - val_loss: 0.3143 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.3142980635166168
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8704    0.8462    0.8581      2269
#            1     0.8744    0.8947    0.8844      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8724    0.8704    0.8713      4985
# weighted avg     0.8726    0.8726    0.8725      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6875 - accuracy: 0.5712 - val_loss: 0.6742 - val_accuracy: 0.6814
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6317 - accuracy: 0.7816 - val_loss: 0.5722 - val_accuracy: 0.8385
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4981 - accuracy: 0.8517 - val_loss: 0.4319 - val_accuracy: 0.8624
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3878 - accuracy: 0.8693 - val_loss: 0.3569 - val_accuracy: 0.8648
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3337 - accuracy: 0.8783 - val_loss: 0.3278 - val_accuracy: 0.8712
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3032 - accuracy: 0.8871 - val_loss: 0.3154 - val_accuracy: 0.8718
# Epoch 7/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2862 - accuracy: 0.8941 - val_loss: 0.3109 - val_accuracy: 0.8726
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2722 - accuracy: 0.8993 - val_loss: 0.3102 - val_accuracy: 0.8722
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2611 - accuracy: 0.9039 - val_loss: 0.3114 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2526 - accuracy: 0.9069 - val_loss: 0.3142 - val_accuracy: 0.8722
#
# Validation Accuracy: 0.8722166419029236
# Validation Loss: 0.31419333815574646
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8643    0.8532    0.8587      2269
#            1     0.8787    0.8881    0.8834      2716
#
#     accuracy                         0.8722      4985
#    macro avg     0.8715    0.8707    0.8710      4985
# weighted avg     0.8721    0.8722    0.8721      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6877 - accuracy: 0.5597 - val_loss: 0.6745 - val_accuracy: 0.6138
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6300 - accuracy: 0.7451 - val_loss: 0.5692 - val_accuracy: 0.8239
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4954 - accuracy: 0.8437 - val_loss: 0.4312 - val_accuracy: 0.8612
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3876 - accuracy: 0.8666 - val_loss: 0.3583 - val_accuracy: 0.8662
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3326 - accuracy: 0.8801 - val_loss: 0.3289 - val_accuracy: 0.8708
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3039 - accuracy: 0.8865 - val_loss: 0.3180 - val_accuracy: 0.8716
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2853 - accuracy: 0.8925 - val_loss: 0.3137 - val_accuracy: 0.8720
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2723 - accuracy: 0.8990 - val_loss: 0.3130 - val_accuracy: 0.8712
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2613 - accuracy: 0.9032 - val_loss: 0.3142 - val_accuracy: 0.8706
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2523 - accuracy: 0.9068 - val_loss: 0.3170 - val_accuracy: 0.8696
#
# Validation Accuracy: 0.8696088194847107
# Validation Loss: 0.3169647455215454
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8678    0.8418    0.8546      2269
#            1     0.8710    0.8929    0.8818      2716
#
#     accuracy                         0.8696      4985
#    macro avg     0.8694    0.8673    0.8682      4985
# weighted avg     0.8696    0.8696    0.8694      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8722567703109328
# Average Precision : 0.8761953826947722
# Average Recall : 0.8915316642120766
# Average F1 Score : 0.872132488510592
