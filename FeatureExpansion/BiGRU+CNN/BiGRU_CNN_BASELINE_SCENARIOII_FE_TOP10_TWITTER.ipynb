# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigramTrigram_Top10_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 10s 15ms/step - loss: 0.6860 - accuracy: 0.5472 - val_loss: 0.6703 - val_accuracy: 0.5486
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6307 - accuracy: 0.6624 - val_loss: 0.5819 - val_accuracy: 0.7581
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5261 - accuracy: 0.8136 - val_loss: 0.4790 - val_accuracy: 0.8379
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4321 - accuracy: 0.8653 - val_loss: 0.4014 - val_accuracy: 0.8658
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3659 - accuracy: 0.8803 - val_loss: 0.3545 - val_accuracy: 0.8706
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3258 - accuracy: 0.8886 - val_loss: 0.3313 - val_accuracy: 0.8730
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3007 - accuracy: 0.8943 - val_loss: 0.3212 - val_accuracy: 0.8754
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2866 - accuracy: 0.8968 - val_loss: 0.3191 - val_accuracy: 0.8766
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2744 - accuracy: 0.9010 - val_loss: 0.3185 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2627 - accuracy: 0.9049 - val_loss: 0.3218 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.32183218002319336
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8713    0.8475    0.8592      2269
#            1     0.8754    0.8954    0.8853      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8734    0.8715    0.8723      4985
# weighted avg     0.8736    0.8736    0.8735      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 16ms/step - loss: 0.6903 - accuracy: 0.5442 - val_loss: 0.6835 - val_accuracy: 0.5452
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6603 - accuracy: 0.6536 - val_loss: 0.6258 - val_accuracy: 0.7334
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5728 - accuracy: 0.7967 - val_loss: 0.5153 - val_accuracy: 0.8387
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4622 - accuracy: 0.8550 - val_loss: 0.4144 - val_accuracy: 0.8626
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3818 - accuracy: 0.8727 - val_loss: 0.3572 - val_accuracy: 0.8686
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3357 - accuracy: 0.8800 - val_loss: 0.3306 - val_accuracy: 0.8708
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3112 - accuracy: 0.8860 - val_loss: 0.3195 - val_accuracy: 0.8724
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2921 - accuracy: 0.8923 - val_loss: 0.3135 - val_accuracy: 0.8762
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2814 - accuracy: 0.8960 - val_loss: 0.3119 - val_accuracy: 0.8748
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2687 - accuracy: 0.9003 - val_loss: 0.3143 - val_accuracy: 0.8730
#
# Validation Accuracy: 0.8730190396308899
# Validation Loss: 0.31430384516716003
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8766    0.8391    0.8575      2269
#            1     0.8702    0.9013    0.8855      2716
#
#     accuracy                         0.8730      4985
#    macro avg     0.8734    0.8702    0.8715      4985
# weighted avg     0.8731    0.8730    0.8727      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6862 - accuracy: 0.5458 - val_loss: 0.6704 - val_accuracy: 0.5464
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6282 - accuracy: 0.6652 - val_loss: 0.5782 - val_accuracy: 0.7629
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5263 - accuracy: 0.8118 - val_loss: 0.4828 - val_accuracy: 0.8399
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4425 - accuracy: 0.8621 - val_loss: 0.4143 - val_accuracy: 0.8662
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3815 - accuracy: 0.8803 - val_loss: 0.3682 - val_accuracy: 0.8688
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3396 - accuracy: 0.8884 - val_loss: 0.3418 - val_accuracy: 0.8720
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3133 - accuracy: 0.8932 - val_loss: 0.3278 - val_accuracy: 0.8726
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2959 - accuracy: 0.8967 - val_loss: 0.3215 - val_accuracy: 0.8748
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2817 - accuracy: 0.9010 - val_loss: 0.3199 - val_accuracy: 0.8718
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2703 - accuracy: 0.9050 - val_loss: 0.3214 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.3213777244091034
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8677    0.8502    0.8589      2269
#            1     0.8769    0.8918    0.8843      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8723    0.8710    0.8716      4985
# weighted avg     0.8727    0.8728    0.8727      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6884 - accuracy: 0.5461 - val_loss: 0.6780 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6452 - accuracy: 0.6403 - val_loss: 0.6004 - val_accuracy: 0.7410
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5436 - accuracy: 0.8010 - val_loss: 0.4878 - val_accuracy: 0.8391
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4406 - accuracy: 0.8555 - val_loss: 0.4008 - val_accuracy: 0.8628
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3705 - accuracy: 0.8723 - val_loss: 0.3517 - val_accuracy: 0.8704
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3318 - accuracy: 0.8802 - val_loss: 0.3283 - val_accuracy: 0.8710
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3076 - accuracy: 0.8861 - val_loss: 0.3181 - val_accuracy: 0.8734
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2895 - accuracy: 0.8928 - val_loss: 0.3149 - val_accuracy: 0.8760
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2790 - accuracy: 0.8966 - val_loss: 0.3128 - val_accuracy: 0.8748
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2667 - accuracy: 0.9020 - val_loss: 0.3132 - val_accuracy: 0.8730
#
# Validation Accuracy: 0.8730190396308899
# Validation Loss: 0.3132382035255432
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8649    0.8546    0.8597      2269
#            1     0.8797    0.8884    0.8840      2716
#
#     accuracy                         0.8730      4985
#    macro avg     0.8723    0.8715    0.8719      4985
# weighted avg     0.8729    0.8730    0.8730      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6869 - accuracy: 0.5764 - val_loss: 0.6703 - val_accuracy: 0.7017
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6221 - accuracy: 0.7881 - val_loss: 0.5617 - val_accuracy: 0.8383
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4927 - accuracy: 0.8479 - val_loss: 0.4320 - val_accuracy: 0.8632
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3896 - accuracy: 0.8668 - val_loss: 0.3590 - val_accuracy: 0.8658
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3362 - accuracy: 0.8768 - val_loss: 0.3292 - val_accuracy: 0.8706
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3069 - accuracy: 0.8849 - val_loss: 0.3168 - val_accuracy: 0.8726
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2886 - accuracy: 0.8921 - val_loss: 0.3124 - val_accuracy: 0.8730
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2749 - accuracy: 0.8972 - val_loss: 0.3112 - val_accuracy: 0.8732
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2648 - accuracy: 0.9020 - val_loss: 0.3116 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2546 - accuracy: 0.9055 - val_loss: 0.3140 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.31402745842933655
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8667    0.8480    0.8572      2269
#            1     0.8752    0.8910    0.8831      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8709    0.8695    0.8701      4985
# weighted avg     0.8713    0.8714    0.8713      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8727783350050149
# Average Precision : 0.8755031711972201
# Average Recall : 0.8935935198821797
# Average F1 Score : 0.872629277077593
