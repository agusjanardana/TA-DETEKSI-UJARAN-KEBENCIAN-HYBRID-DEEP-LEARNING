# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigramTrigram_Top5_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 10s 15ms/step - loss: 0.6875 - accuracy: 0.5794 - val_loss: 0.6745 - val_accuracy: 0.6710
# Epoch 2/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.6375 - accuracy: 0.7692 - val_loss: 0.5893 - val_accuracy: 0.8251
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5256 - accuracy: 0.8401 - val_loss: 0.4646 - val_accuracy: 0.8578
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4187 - accuracy: 0.8627 - val_loss: 0.3810 - val_accuracy: 0.8672
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3567 - accuracy: 0.8748 - val_loss: 0.3411 - val_accuracy: 0.8704
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3237 - accuracy: 0.8825 - val_loss: 0.3227 - val_accuracy: 0.8708
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3024 - accuracy: 0.8888 - val_loss: 0.3154 - val_accuracy: 0.8724
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2864 - accuracy: 0.8936 - val_loss: 0.3123 - val_accuracy: 0.8750
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2766 - accuracy: 0.8976 - val_loss: 0.3121 - val_accuracy: 0.8736
# Epoch 10/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2658 - accuracy: 0.9025 - val_loss: 0.3147 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.3146657347679138
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8753    0.8383    0.8564      2269
#            1     0.8695    0.9002    0.8846      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8724    0.8692    0.8705      4985
# weighted avg     0.8721    0.8720    0.8717      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6863 - accuracy: 0.5533 - val_loss: 0.6709 - val_accuracy: 0.5767
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6285 - accuracy: 0.6977 - val_loss: 0.5739 - val_accuracy: 0.7821
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5113 - accuracy: 0.8303 - val_loss: 0.4550 - val_accuracy: 0.8508
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4113 - accuracy: 0.8646 - val_loss: 0.3781 - val_accuracy: 0.8650
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3519 - accuracy: 0.8760 - val_loss: 0.3404 - val_accuracy: 0.8698
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3185 - accuracy: 0.8845 - val_loss: 0.3245 - val_accuracy: 0.8742
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2963 - accuracy: 0.8908 - val_loss: 0.3170 - val_accuracy: 0.8764
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2827 - accuracy: 0.8961 - val_loss: 0.3145 - val_accuracy: 0.8754
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2709 - accuracy: 0.9001 - val_loss: 0.3140 - val_accuracy: 0.8748
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2612 - accuracy: 0.9030 - val_loss: 0.3157 - val_accuracy: 0.8740
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.3156810402870178
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8691    0.8515    0.8602      2269
#            1     0.8780    0.8929    0.8854      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8735    0.8722    0.8728      4985
# weighted avg     0.8739    0.8740    0.8739      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 16ms/step - loss: 0.6890 - accuracy: 0.5455 - val_loss: 0.6791 - val_accuracy: 0.5464
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6427 - accuracy: 0.6977 - val_loss: 0.5892 - val_accuracy: 0.8006
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5173 - accuracy: 0.8370 - val_loss: 0.4503 - val_accuracy: 0.8576
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4032 - accuracy: 0.8662 - val_loss: 0.3679 - val_accuracy: 0.8666
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3440 - accuracy: 0.8751 - val_loss: 0.3336 - val_accuracy: 0.8694
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3103 - accuracy: 0.8844 - val_loss: 0.3199 - val_accuracy: 0.8724
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2907 - accuracy: 0.8915 - val_loss: 0.3139 - val_accuracy: 0.8724
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2773 - accuracy: 0.8972 - val_loss: 0.3118 - val_accuracy: 0.8732
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2684 - accuracy: 0.9010 - val_loss: 0.3129 - val_accuracy: 0.8732
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2585 - accuracy: 0.9055 - val_loss: 0.3142 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.3142251670360565
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8654    0.8497    0.8575      2269
#            1     0.8763    0.8895    0.8829      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8708    0.8696    0.8702      4985
# weighted avg     0.8713    0.8714    0.8713      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 16ms/step - loss: 0.6890 - accuracy: 0.5677 - val_loss: 0.6778 - val_accuracy: 0.6879
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6376 - accuracy: 0.7886 - val_loss: 0.5825 - val_accuracy: 0.8415
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5087 - accuracy: 0.8505 - val_loss: 0.4426 - val_accuracy: 0.8626
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3980 - accuracy: 0.8641 - val_loss: 0.3645 - val_accuracy: 0.8656
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3399 - accuracy: 0.8757 - val_loss: 0.3314 - val_accuracy: 0.8706
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3109 - accuracy: 0.8861 - val_loss: 0.3179 - val_accuracy: 0.8716
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2910 - accuracy: 0.8924 - val_loss: 0.3120 - val_accuracy: 0.8726
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2764 - accuracy: 0.8962 - val_loss: 0.3107 - val_accuracy: 0.8732
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2662 - accuracy: 0.9009 - val_loss: 0.3112 - val_accuracy: 0.8738
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2565 - accuracy: 0.9053 - val_loss: 0.3134 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3134377896785736
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8666    0.8506    0.8585      2269
#            1     0.8771    0.8906    0.8838      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8719    0.8706    0.8712      4985
# weighted avg     0.8723    0.8724    0.8723      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 16ms/step - loss: 0.6888 - accuracy: 0.5763 - val_loss: 0.6780 - val_accuracy: 0.7011
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6407 - accuracy: 0.7970 - val_loss: 0.5888 - val_accuracy: 0.8491
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5180 - accuracy: 0.8494 - val_loss: 0.4512 - val_accuracy: 0.8630
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4050 - accuracy: 0.8639 - val_loss: 0.3696 - val_accuracy: 0.8660
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3465 - accuracy: 0.8743 - val_loss: 0.3352 - val_accuracy: 0.8704
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3146 - accuracy: 0.8836 - val_loss: 0.3200 - val_accuracy: 0.8714
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2955 - accuracy: 0.8898 - val_loss: 0.3137 - val_accuracy: 0.8692
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2826 - accuracy: 0.8945 - val_loss: 0.3123 - val_accuracy: 0.8736
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2696 - accuracy: 0.9007 - val_loss: 0.3124 - val_accuracy: 0.8734
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2598 - accuracy: 0.9042 - val_loss: 0.3145 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.3144862949848175
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8668    0.8493    0.8580      2269
#            1     0.8762    0.8910    0.8835      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8715    0.8701    0.8708      4985
# weighted avg     0.8719    0.8720    0.8719      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8723771313941826
# Average Precision : 0.8754102475092764
# Average Recall : 0.8928571428571429
# Average F1 Score : 0.8722337823466276
