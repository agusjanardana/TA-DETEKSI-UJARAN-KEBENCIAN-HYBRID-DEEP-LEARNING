# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigramTrigram_Top1_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 9s 15ms/step - loss: 0.6900 - accuracy: 0.5502 - val_loss: 0.6825 - val_accuracy: 0.5583
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6551 - accuracy: 0.6906 - val_loss: 0.6142 - val_accuracy: 0.7693
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5536 - accuracy: 0.8121 - val_loss: 0.4893 - val_accuracy: 0.8463
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4391 - accuracy: 0.8516 - val_loss: 0.3940 - val_accuracy: 0.8642
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3733 - accuracy: 0.8664 - val_loss: 0.3480 - val_accuracy: 0.8698
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3359 - accuracy: 0.8756 - val_loss: 0.3271 - val_accuracy: 0.8720
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3128 - accuracy: 0.8832 - val_loss: 0.3170 - val_accuracy: 0.8730
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2955 - accuracy: 0.8925 - val_loss: 0.3129 - val_accuracy: 0.8734
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2850 - accuracy: 0.8955 - val_loss: 0.3124 - val_accuracy: 0.8738
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2734 - accuracy: 0.9006 - val_loss: 0.3121 - val_accuracy: 0.8754
#
# Validation Accuracy: 0.8754262924194336
# Validation Loss: 0.3120802640914917
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8752    0.8471    0.8609      2269
#            1     0.8756    0.8991    0.8872      2716
#
#     accuracy                         0.8754      4985
#    macro avg     0.8754    0.8731    0.8741      4985
# weighted avg     0.8754    0.8754    0.8752      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6866 - accuracy: 0.5442 - val_loss: 0.6713 - val_accuracy: 0.5452
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6284 - accuracy: 0.6705 - val_loss: 0.5762 - val_accuracy: 0.7761
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5183 - accuracy: 0.8219 - val_loss: 0.4688 - val_accuracy: 0.8451
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4211 - accuracy: 0.8659 - val_loss: 0.3896 - val_accuracy: 0.8664
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3557 - accuracy: 0.8793 - val_loss: 0.3456 - val_accuracy: 0.8708
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3192 - accuracy: 0.8865 - val_loss: 0.3261 - val_accuracy: 0.8732
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2956 - accuracy: 0.8917 - val_loss: 0.3189 - val_accuracy: 0.8738
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2813 - accuracy: 0.8963 - val_loss: 0.3167 - val_accuracy: 0.8742
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2696 - accuracy: 0.9008 - val_loss: 0.3171 - val_accuracy: 0.8744
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2588 - accuracy: 0.9050 - val_loss: 0.3191 - val_accuracy: 0.8734
#
# Validation Accuracy: 0.873420238494873
# Validation Loss: 0.31909775733947754
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8673    0.8524    0.8597      2269
#            1     0.8784    0.8910    0.8847      2716
#
#     accuracy                         0.8734      4985
#    macro avg     0.8728    0.8717    0.8722      4985
# weighted avg     0.8733    0.8734    0.8733      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6873 - accuracy: 0.5659 - val_loss: 0.6741 - val_accuracy: 0.6201
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6333 - accuracy: 0.7423 - val_loss: 0.5793 - val_accuracy: 0.8171
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5139 - accuracy: 0.8398 - val_loss: 0.4514 - val_accuracy: 0.8592
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4054 - accuracy: 0.8645 - val_loss: 0.3705 - val_accuracy: 0.8674
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3447 - accuracy: 0.8753 - val_loss: 0.3341 - val_accuracy: 0.8706
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3124 - accuracy: 0.8831 - val_loss: 0.3184 - val_accuracy: 0.8712
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2913 - accuracy: 0.8911 - val_loss: 0.3123 - val_accuracy: 0.8742
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2772 - accuracy: 0.8970 - val_loss: 0.3111 - val_accuracy: 0.8766
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2639 - accuracy: 0.9012 - val_loss: 0.3117 - val_accuracy: 0.8742
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2570 - accuracy: 0.9053 - val_loss: 0.3140 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.31398913264274597
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8699    0.8431    0.8563      2269
#            1     0.8722    0.8947    0.8833      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8711    0.8689    0.8698      4985
# weighted avg     0.8712    0.8712    0.8710      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6876 - accuracy: 0.5522 - val_loss: 0.6749 - val_accuracy: 0.5852
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6347 - accuracy: 0.7263 - val_loss: 0.5773 - val_accuracy: 0.8197
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5072 - accuracy: 0.8408 - val_loss: 0.4409 - val_accuracy: 0.8586
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3978 - accuracy: 0.8631 - val_loss: 0.3631 - val_accuracy: 0.8656
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3416 - accuracy: 0.8740 - val_loss: 0.3314 - val_accuracy: 0.8704
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3101 - accuracy: 0.8845 - val_loss: 0.3176 - val_accuracy: 0.8742
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2907 - accuracy: 0.8909 - val_loss: 0.3122 - val_accuracy: 0.8750
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2782 - accuracy: 0.8962 - val_loss: 0.3115 - val_accuracy: 0.8732
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2674 - accuracy: 0.9013 - val_loss: 0.3126 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2586 - accuracy: 0.9037 - val_loss: 0.3141 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.31406962871551514
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8647    0.8532    0.8589      2269
#            1     0.8787    0.8884    0.8836      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8717    0.8708    0.8712      4985
# weighted avg     0.8723    0.8724    0.8723      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6882 - accuracy: 0.6195 - val_loss: 0.6749 - val_accuracy: 0.7747
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6337 - accuracy: 0.8237 - val_loss: 0.5786 - val_accuracy: 0.8562
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5113 - accuracy: 0.8507 - val_loss: 0.4483 - val_accuracy: 0.8606
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4057 - accuracy: 0.8641 - val_loss: 0.3715 - val_accuracy: 0.8656
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3495 - accuracy: 0.8734 - val_loss: 0.3374 - val_accuracy: 0.8700
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3180 - accuracy: 0.8836 - val_loss: 0.3216 - val_accuracy: 0.8724
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2981 - accuracy: 0.8911 - val_loss: 0.3149 - val_accuracy: 0.8696
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2832 - accuracy: 0.8953 - val_loss: 0.3124 - val_accuracy: 0.8730
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2705 - accuracy: 0.9010 - val_loss: 0.3133 - val_accuracy: 0.8724
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2620 - accuracy: 0.9054 - val_loss: 0.3149 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.3148748278617859
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8696    0.8435    0.8564      2269
#            1     0.8725    0.8943    0.8833      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8710    0.8689    0.8698      4985
# weighted avg     0.8712    0.8712    0.8710      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8727382146439318
# Average Precision : 0.8754844236488639
# Average Recall : 0.893519882179676
# Average F1 Score : 0.8725908047686527
