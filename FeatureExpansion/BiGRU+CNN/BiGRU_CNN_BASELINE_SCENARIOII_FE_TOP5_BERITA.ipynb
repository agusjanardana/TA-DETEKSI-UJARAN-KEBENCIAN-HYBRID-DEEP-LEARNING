# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigramTrigram_Top5_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 9s 14ms/step - loss: 0.6889 - accuracy: 0.6236 - val_loss: 0.6784 - val_accuracy: 0.8022
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6464 - accuracy: 0.8215 - val_loss: 0.6022 - val_accuracy: 0.8554
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5385 - accuracy: 0.8501 - val_loss: 0.4762 - val_accuracy: 0.8578
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4273 - accuracy: 0.8642 - val_loss: 0.3858 - val_accuracy: 0.8620
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3626 - accuracy: 0.8730 - val_loss: 0.3428 - val_accuracy: 0.8676
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3280 - accuracy: 0.8828 - val_loss: 0.3229 - val_accuracy: 0.8712
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3052 - accuracy: 0.8892 - val_loss: 0.3140 - val_accuracy: 0.8718
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2888 - accuracy: 0.8953 - val_loss: 0.3104 - val_accuracy: 0.8738
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2779 - accuracy: 0.8997 - val_loss: 0.3096 - val_accuracy: 0.8714
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2681 - accuracy: 0.9034 - val_loss: 0.3108 - val_accuracy: 0.8732
#
# Validation Accuracy: 0.8732196688652039
# Validation Loss: 0.31077125668525696
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8726    0.8449    0.8585      2269
#            1     0.8737    0.8969    0.8852      2716
#
#     accuracy                         0.8732      4985
#    macro avg     0.8731    0.8709    0.8718      4985
# weighted avg     0.8732    0.8732    0.8730      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6870 - accuracy: 0.5506 - val_loss: 0.6729 - val_accuracy: 0.5827
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6307 - accuracy: 0.7170 - val_loss: 0.5734 - val_accuracy: 0.8110
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5037 - accuracy: 0.8392 - val_loss: 0.4390 - val_accuracy: 0.8596
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3948 - accuracy: 0.8659 - val_loss: 0.3615 - val_accuracy: 0.8670
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3361 - accuracy: 0.8779 - val_loss: 0.3295 - val_accuracy: 0.8716
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3084 - accuracy: 0.8872 - val_loss: 0.3170 - val_accuracy: 0.8738
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2881 - accuracy: 0.8919 - val_loss: 0.3115 - val_accuracy: 0.8752
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2742 - accuracy: 0.8982 - val_loss: 0.3105 - val_accuracy: 0.8748
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2625 - accuracy: 0.9034 - val_loss: 0.3121 - val_accuracy: 0.8738
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2551 - accuracy: 0.9059 - val_loss: 0.3144 - val_accuracy: 0.8732
#
# Validation Accuracy: 0.8732196688652039
# Validation Loss: 0.3143649697303772
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8662    0.8532    0.8597      2269
#            1     0.8789    0.8899    0.8844      2716
#
#     accuracy                         0.8732      4985
#    macro avg     0.8726    0.8716    0.8720      4985
# weighted avg     0.8731    0.8732    0.8731      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6879 - accuracy: 0.5471 - val_loss: 0.6756 - val_accuracy: 0.5563
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6357 - accuracy: 0.6736 - val_loss: 0.5841 - val_accuracy: 0.7597
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5249 - accuracy: 0.8138 - val_loss: 0.4735 - val_accuracy: 0.8435
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4301 - accuracy: 0.8614 - val_loss: 0.3975 - val_accuracy: 0.8644
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3680 - accuracy: 0.8758 - val_loss: 0.3532 - val_accuracy: 0.8700
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3322 - accuracy: 0.8834 - val_loss: 0.3317 - val_accuracy: 0.8738
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3070 - accuracy: 0.8910 - val_loss: 0.3219 - val_accuracy: 0.8752
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2915 - accuracy: 0.8945 - val_loss: 0.3177 - val_accuracy: 0.8760
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2800 - accuracy: 0.9009 - val_loss: 0.3175 - val_accuracy: 0.8746
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2700 - accuracy: 0.9034 - val_loss: 0.3198 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3197901248931885
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8768    0.8405    0.8582      2269
#            1     0.8712    0.9013    0.8860      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8740    0.8709    0.8721      4985
# weighted avg     0.8737    0.8736    0.8734      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6889 - accuracy: 0.5477 - val_loss: 0.6785 - val_accuracy: 0.5962
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6440 - accuracy: 0.7313 - val_loss: 0.5941 - val_accuracy: 0.8231
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5288 - accuracy: 0.8388 - val_loss: 0.4634 - val_accuracy: 0.8598
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4189 - accuracy: 0.8608 - val_loss: 0.3766 - val_accuracy: 0.8656
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3542 - accuracy: 0.8727 - val_loss: 0.3378 - val_accuracy: 0.8688
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3191 - accuracy: 0.8814 - val_loss: 0.3209 - val_accuracy: 0.8706
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2989 - accuracy: 0.8887 - val_loss: 0.3135 - val_accuracy: 0.8724
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2849 - accuracy: 0.8951 - val_loss: 0.3110 - val_accuracy: 0.8742
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2713 - accuracy: 0.8997 - val_loss: 0.3110 - val_accuracy: 0.8746
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2615 - accuracy: 0.9045 - val_loss: 0.3126 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.31257763504981995
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8700    0.8493    0.8595      2269
#            1     0.8765    0.8940    0.8852      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8733    0.8716    0.8723      4985
# weighted avg     0.8735    0.8736    0.8735      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6880 - accuracy: 0.5478 - val_loss: 0.6760 - val_accuracy: 0.5545
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6388 - accuracy: 0.6854 - val_loss: 0.5900 - val_accuracy: 0.7699
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5291 - accuracy: 0.8191 - val_loss: 0.4715 - val_accuracy: 0.8481
# Epoch 4/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4242 - accuracy: 0.8624 - val_loss: 0.3861 - val_accuracy: 0.8680
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3592 - accuracy: 0.8774 - val_loss: 0.3442 - val_accuracy: 0.8714
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3236 - accuracy: 0.8843 - val_loss: 0.3252 - val_accuracy: 0.8716
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3016 - accuracy: 0.8907 - val_loss: 0.3188 - val_accuracy: 0.8738
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2873 - accuracy: 0.8962 - val_loss: 0.3145 - val_accuracy: 0.8744
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2726 - accuracy: 0.9017 - val_loss: 0.3165 - val_accuracy: 0.8738
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2641 - accuracy: 0.9040 - val_loss: 0.3173 - val_accuracy: 0.8734
#
# Validation Accuracy: 0.873420238494873
# Validation Loss: 0.31731894612312317
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8673    0.8524    0.8597      2269
#            1     0.8784    0.8910    0.8847      2716
#
#     accuracy                         0.8734      4985
#    macro avg     0.8728    0.8717    0.8722      4985
# weighted avg     0.8733    0.8734    0.8733      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8734202607823469
# Average Precision : 0.8757530575545125
# Average Recall : 0.8946244477172313
# Average F1 Score : 0.8732652365337714
