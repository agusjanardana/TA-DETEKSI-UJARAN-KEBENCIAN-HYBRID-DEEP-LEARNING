# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigramTrigram_Top10_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 9s 14ms/step - loss: 0.6882 - accuracy: 0.5619 - val_loss: 0.6767 - val_accuracy: 0.6277
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6393 - accuracy: 0.7589 - val_loss: 0.5861 - val_accuracy: 0.8275
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5150 - accuracy: 0.8427 - val_loss: 0.4474 - val_accuracy: 0.8636
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4038 - accuracy: 0.8634 - val_loss: 0.3670 - val_accuracy: 0.8660
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3456 - accuracy: 0.8732 - val_loss: 0.3336 - val_accuracy: 0.8722
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3137 - accuracy: 0.8846 - val_loss: 0.3196 - val_accuracy: 0.8742
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2931 - accuracy: 0.8907 - val_loss: 0.3141 - val_accuracy: 0.8750
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2790 - accuracy: 0.8966 - val_loss: 0.3115 - val_accuracy: 0.8760
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2701 - accuracy: 0.8989 - val_loss: 0.3117 - val_accuracy: 0.8732
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2607 - accuracy: 0.9045 - val_loss: 0.3143 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.3143085539340973
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8710    0.8422    0.8564      2269
#            1     0.8717    0.8958    0.8836      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8714    0.8690    0.8700      4985
# weighted avg     0.8714    0.8714    0.8712      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6888 - accuracy: 0.5518 - val_loss: 0.6783 - val_accuracy: 0.6044
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6419 - accuracy: 0.7344 - val_loss: 0.5879 - val_accuracy: 0.8124
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5159 - accuracy: 0.8432 - val_loss: 0.4479 - val_accuracy: 0.8614
# Epoch 4/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4014 - accuracy: 0.8658 - val_loss: 0.3658 - val_accuracy: 0.8694
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3411 - accuracy: 0.8774 - val_loss: 0.3317 - val_accuracy: 0.8726
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3101 - accuracy: 0.8847 - val_loss: 0.3177 - val_accuracy: 0.8734
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2905 - accuracy: 0.8917 - val_loss: 0.3123 - val_accuracy: 0.8740
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2780 - accuracy: 0.8965 - val_loss: 0.3103 - val_accuracy: 0.8730
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2663 - accuracy: 0.9009 - val_loss: 0.3118 - val_accuracy: 0.8728
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2569 - accuracy: 0.9050 - val_loss: 0.3129 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.8716148734092712
# Validation Loss: 0.3128831386566162
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8648    0.8510    0.8578      2269
#            1     0.8772    0.8888    0.8830      2716
#
#     accuracy                         0.8716      4985
#    macro avg     0.8710    0.8699    0.8704      4985
# weighted avg     0.8715    0.8716    0.8715      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6892 - accuracy: 0.5638 - val_loss: 0.6787 - val_accuracy: 0.6403
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6432 - accuracy: 0.7497 - val_loss: 0.5931 - val_accuracy: 0.8203
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5251 - accuracy: 0.8394 - val_loss: 0.4600 - val_accuracy: 0.8594
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4111 - accuracy: 0.8633 - val_loss: 0.3743 - val_accuracy: 0.8648
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3483 - accuracy: 0.8752 - val_loss: 0.3364 - val_accuracy: 0.8692
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3135 - accuracy: 0.8839 - val_loss: 0.3215 - val_accuracy: 0.8718
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2941 - accuracy: 0.8920 - val_loss: 0.3144 - val_accuracy: 0.8732
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2805 - accuracy: 0.8958 - val_loss: 0.3133 - val_accuracy: 0.8732
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2696 - accuracy: 0.8995 - val_loss: 0.3125 - val_accuracy: 0.8736
# Epoch 10/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2600 - accuracy: 0.9036 - val_loss: 0.3149 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.31494978070259094
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8689    0.8444    0.8565      2269
#            1     0.8730    0.8936    0.8832      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8710    0.8690    0.8698      4985
# weighted avg     0.8712    0.8712    0.8710      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6883 - accuracy: 0.5467 - val_loss: 0.6770 - val_accuracy: 0.5480
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6413 - accuracy: 0.6753 - val_loss: 0.5920 - val_accuracy: 0.7715
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5284 - accuracy: 0.8245 - val_loss: 0.4660 - val_accuracy: 0.8572
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4174 - accuracy: 0.8639 - val_loss: 0.3820 - val_accuracy: 0.8642
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3548 - accuracy: 0.8762 - val_loss: 0.3412 - val_accuracy: 0.8708
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3189 - accuracy: 0.8847 - val_loss: 0.3250 - val_accuracy: 0.8728
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2997 - accuracy: 0.8907 - val_loss: 0.3162 - val_accuracy: 0.8750
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2836 - accuracy: 0.8958 - val_loss: 0.3140 - val_accuracy: 0.8750
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2726 - accuracy: 0.9002 - val_loss: 0.3138 - val_accuracy: 0.8762
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2650 - accuracy: 0.9038 - val_loss: 0.3154 - val_accuracy: 0.8756
#
# Validation Accuracy: 0.8756268620491028
# Validation Loss: 0.31535452604293823
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8722    0.8515    0.8617      2269
#            1     0.8783    0.8958    0.8870      2716
#
#     accuracy                         0.8756      4985
#    macro avg     0.8753    0.8736    0.8744      4985
# weighted avg     0.8756    0.8756    0.8755      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6899 - accuracy: 0.6002 - val_loss: 0.6819 - val_accuracy: 0.7492
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6527 - accuracy: 0.8045 - val_loss: 0.6098 - val_accuracy: 0.8568
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5466 - accuracy: 0.8457 - val_loss: 0.4841 - val_accuracy: 0.8598
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4327 - accuracy: 0.8622 - val_loss: 0.3919 - val_accuracy: 0.8640
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3650 - accuracy: 0.8733 - val_loss: 0.3468 - val_accuracy: 0.8698
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3262 - accuracy: 0.8820 - val_loss: 0.3253 - val_accuracy: 0.8714
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3036 - accuracy: 0.8886 - val_loss: 0.3157 - val_accuracy: 0.8722
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2867 - accuracy: 0.8962 - val_loss: 0.3115 - val_accuracy: 0.8752
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2736 - accuracy: 0.8997 - val_loss: 0.3102 - val_accuracy: 0.8766
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2652 - accuracy: 0.9044 - val_loss: 0.3114 - val_accuracy: 0.8748
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.3113641142845154
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8723    0.8493    0.8607      2269
#            1     0.8768    0.8962    0.8864      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8746    0.8727    0.8735      4985
# weighted avg     0.8748    0.8748    0.8747      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.872938816449348
# Average Precision : 0.8754145761465206
# Average Recall : 0.8940353460972018
# Average F1 Score : 0.8727871334825548
