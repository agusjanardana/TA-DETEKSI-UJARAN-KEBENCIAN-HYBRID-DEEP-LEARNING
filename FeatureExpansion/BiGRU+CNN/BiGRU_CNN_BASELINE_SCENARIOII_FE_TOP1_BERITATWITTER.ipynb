# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigramTrigram_Top1_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 10s 15ms/step - loss: 0.6894 - accuracy: 0.5594 - val_loss: 0.6799 - val_accuracy: 0.6510
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6429 - accuracy: 0.7681 - val_loss: 0.5886 - val_accuracy: 0.8475
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5159 - accuracy: 0.8456 - val_loss: 0.4483 - val_accuracy: 0.8612
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4049 - accuracy: 0.8636 - val_loss: 0.3680 - val_accuracy: 0.8660
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3459 - accuracy: 0.8750 - val_loss: 0.3337 - val_accuracy: 0.8692
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3152 - accuracy: 0.8841 - val_loss: 0.3190 - val_accuracy: 0.8724
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2940 - accuracy: 0.8912 - val_loss: 0.3127 - val_accuracy: 0.8724
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2814 - accuracy: 0.8945 - val_loss: 0.3107 - val_accuracy: 0.8760
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2688 - accuracy: 0.8998 - val_loss: 0.3112 - val_accuracy: 0.8734
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2595 - accuracy: 0.9046 - val_loss: 0.3126 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.31261110305786133
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8704    0.8462    0.8581      2269
#            1     0.8744    0.8947    0.8844      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8724    0.8704    0.8713      4985
# weighted avg     0.8726    0.8726    0.8725      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6868 - accuracy: 0.5829 - val_loss: 0.6710 - val_accuracy: 0.7071
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6248 - accuracy: 0.7856 - val_loss: 0.5635 - val_accuracy: 0.8349
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4882 - accuracy: 0.8506 - val_loss: 0.4254 - val_accuracy: 0.8630
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3804 - accuracy: 0.8703 - val_loss: 0.3546 - val_accuracy: 0.8672
# Epoch 5/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3270 - accuracy: 0.8805 - val_loss: 0.3284 - val_accuracy: 0.8686
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3001 - accuracy: 0.8879 - val_loss: 0.3167 - val_accuracy: 0.8700
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2832 - accuracy: 0.8939 - val_loss: 0.3128 - val_accuracy: 0.8718
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2687 - accuracy: 0.8990 - val_loss: 0.3122 - val_accuracy: 0.8730
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2587 - accuracy: 0.9034 - val_loss: 0.3140 - val_accuracy: 0.8726
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2505 - accuracy: 0.9070 - val_loss: 0.3170 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.31696397066116333
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8648    0.8515    0.8581      2269
#            1     0.8775    0.8888    0.8831      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8712    0.8701    0.8706      4985
# weighted avg     0.8717    0.8718    0.8717      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6891 - accuracy: 0.5614 - val_loss: 0.6795 - val_accuracy: 0.6223
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6494 - accuracy: 0.7438 - val_loss: 0.6075 - val_accuracy: 0.8116
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5456 - accuracy: 0.8378 - val_loss: 0.4849 - val_accuracy: 0.8562
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4345 - accuracy: 0.8604 - val_loss: 0.3909 - val_accuracy: 0.8652
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3635 - accuracy: 0.8727 - val_loss: 0.3452 - val_accuracy: 0.8682
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3268 - accuracy: 0.8810 - val_loss: 0.3257 - val_accuracy: 0.8708
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3054 - accuracy: 0.8878 - val_loss: 0.3169 - val_accuracy: 0.8722
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2908 - accuracy: 0.8941 - val_loss: 0.3135 - val_accuracy: 0.8726
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2771 - accuracy: 0.8990 - val_loss: 0.3127 - val_accuracy: 0.8732
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2685 - accuracy: 0.9014 - val_loss: 0.3132 - val_accuracy: 0.8730
#
# Validation Accuracy: 0.8730190396308899
# Validation Loss: 0.3131977319717407
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8662    0.8528    0.8594      2269
#            1     0.8786    0.8899    0.8842      2716
#
#     accuracy                         0.8730      4985
#    macro avg     0.8724    0.8714    0.8718      4985
# weighted avg     0.8729    0.8730    0.8729      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6853 - accuracy: 0.5469 - val_loss: 0.6679 - val_accuracy: 0.5623
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6227 - accuracy: 0.6816 - val_loss: 0.5694 - val_accuracy: 0.7611
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5127 - accuracy: 0.8241 - val_loss: 0.4631 - val_accuracy: 0.8483
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4185 - accuracy: 0.8664 - val_loss: 0.3859 - val_accuracy: 0.8670
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3543 - accuracy: 0.8795 - val_loss: 0.3440 - val_accuracy: 0.8714
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3182 - accuracy: 0.8877 - val_loss: 0.3247 - val_accuracy: 0.8728
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2957 - accuracy: 0.8931 - val_loss: 0.3177 - val_accuracy: 0.8746
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2819 - accuracy: 0.8964 - val_loss: 0.3161 - val_accuracy: 0.8754
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2709 - accuracy: 0.9016 - val_loss: 0.3172 - val_accuracy: 0.8728
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2616 - accuracy: 0.9056 - val_loss: 0.3189 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.3189205229282379
#
# 156/156 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8629    0.8519    0.8574      2269
#            1     0.8776    0.8870    0.8823      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8703    0.8694    0.8698      4985
# weighted avg     0.8709    0.8710    0.8709      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6864 - accuracy: 0.5643 - val_loss: 0.6708 - val_accuracy: 0.6389
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6240 - accuracy: 0.7609 - val_loss: 0.5629 - val_accuracy: 0.8253
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4910 - accuracy: 0.8494 - val_loss: 0.4288 - val_accuracy: 0.8592
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3870 - accuracy: 0.8685 - val_loss: 0.3579 - val_accuracy: 0.8658
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3337 - accuracy: 0.8792 - val_loss: 0.3281 - val_accuracy: 0.8706
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3051 - accuracy: 0.8878 - val_loss: 0.3180 - val_accuracy: 0.8728
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2880 - accuracy: 0.8921 - val_loss: 0.3127 - val_accuracy: 0.8726
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2745 - accuracy: 0.8978 - val_loss: 0.3114 - val_accuracy: 0.8756
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2644 - accuracy: 0.9019 - val_loss: 0.3130 - val_accuracy: 0.8714
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2567 - accuracy: 0.9060 - val_loss: 0.3164 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.31635019183158875
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8683    0.8457    0.8569      2269
#            1     0.8739    0.8929    0.8833      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8711    0.8693    0.8701      4985
# weighted avg     0.8713    0.8714    0.8713      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.87197592778335
# Average Precision : 0.8763946909191922
# Average Recall : 0.8906480117820325
# Average F1 Score : 0.8718619889547939
