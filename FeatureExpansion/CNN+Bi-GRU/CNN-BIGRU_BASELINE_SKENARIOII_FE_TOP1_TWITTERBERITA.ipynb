# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigramTrigram_Top1_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test= process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 30s 30ms/step - loss: 0.6734 - accuracy: 0.6657 - val_loss: 0.6161 - val_accuracy: 0.8453
# Epoch 2/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.4976 - accuracy: 0.8511 - val_loss: 0.3919 - val_accuracy: 0.8650
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3520 - accuracy: 0.8727 - val_loss: 0.3258 - val_accuracy: 0.8718
# Epoch 4/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3050 - accuracy: 0.8865 - val_loss: 0.3112 - val_accuracy: 0.8740
# Epoch 5/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2830 - accuracy: 0.8942 - val_loss: 0.3078 - val_accuracy: 0.8746
# Epoch 6/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2674 - accuracy: 0.9016 - val_loss: 0.3104 - val_accuracy: 0.8736
# Epoch 7/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.2552 - accuracy: 0.9064 - val_loss: 0.3144 - val_accuracy: 0.8718
# Epoch 8/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2462 - accuracy: 0.9108 - val_loss: 0.3204 - val_accuracy: 0.8700
# Epoch 9/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2356 - accuracy: 0.9150 - val_loss: 0.3267 - val_accuracy: 0.8680
# Epoch 10/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2278 - accuracy: 0.9194 - val_loss: 0.3345 - val_accuracy: 0.8656
#
# Validation Accuracy: 0.8655967712402344
# Validation Loss: 0.3345397412776947
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8520    0.8528    0.8524      2269
#            1     0.8769    0.8763    0.8766      2716
#
#     accuracy                         0.8656      4985
#    macro avg     0.8645    0.8645    0.8645      4985
# weighted avg     0.8656    0.8656    0.8656      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 26s 31ms/step - loss: 0.6723 - accuracy: 0.6827 - val_loss: 0.6151 - val_accuracy: 0.8327
# Epoch 2/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.4962 - accuracy: 0.8547 - val_loss: 0.3901 - val_accuracy: 0.8672
# Epoch 3/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3477 - accuracy: 0.8751 - val_loss: 0.3244 - val_accuracy: 0.8712
# Epoch 4/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3019 - accuracy: 0.8867 - val_loss: 0.3105 - val_accuracy: 0.8718
# Epoch 5/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2789 - accuracy: 0.8960 - val_loss: 0.3087 - val_accuracy: 0.8744
# Epoch 6/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2658 - accuracy: 0.9029 - val_loss: 0.3102 - val_accuracy: 0.8732
# Epoch 7/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2534 - accuracy: 0.9081 - val_loss: 0.3141 - val_accuracy: 0.8710
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2442 - accuracy: 0.9110 - val_loss: 0.3198 - val_accuracy: 0.8688
# Epoch 9/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2356 - accuracy: 0.9157 - val_loss: 0.3259 - val_accuracy: 0.8670
# Epoch 10/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2282 - accuracy: 0.9191 - val_loss: 0.3336 - val_accuracy: 0.8660
#
# Validation Accuracy: 0.8659979701042175
# Validation Loss: 0.33362939953804016
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8607    0.8418    0.8512      2269
#            1     0.8702    0.8862    0.8781      2716
#
#     accuracy                         0.8660      4985
#    macro avg     0.8655    0.8640    0.8647      4985
# weighted avg     0.8659    0.8660    0.8659      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 30ms/step - loss: 0.6677 - accuracy: 0.6701 - val_loss: 0.6031 - val_accuracy: 0.8223
# Epoch 2/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.4860 - accuracy: 0.8521 - val_loss: 0.3860 - val_accuracy: 0.8682
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3454 - accuracy: 0.8770 - val_loss: 0.3231 - val_accuracy: 0.8728
# Epoch 4/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3000 - accuracy: 0.8884 - val_loss: 0.3105 - val_accuracy: 0.8752
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2769 - accuracy: 0.8952 - val_loss: 0.3083 - val_accuracy: 0.8758
# Epoch 6/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2630 - accuracy: 0.9021 - val_loss: 0.3107 - val_accuracy: 0.8754
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2515 - accuracy: 0.9068 - val_loss: 0.3152 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2414 - accuracy: 0.9117 - val_loss: 0.3215 - val_accuracy: 0.8696
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2357 - accuracy: 0.9146 - val_loss: 0.3282 - val_accuracy: 0.8672
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2272 - accuracy: 0.9191 - val_loss: 0.3361 - val_accuracy: 0.8632
#
# Validation Accuracy: 0.8631895780563354
# Validation Loss: 0.3360685408115387
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8506    0.8484    0.8495      2269
#            1     0.8736    0.8756    0.8746      2716
#
#     accuracy                         0.8632      4985
#    macro avg     0.8621    0.8620    0.8621      4985
# weighted avg     0.8632    0.8632    0.8632      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 32s 39ms/step - loss: 0.6756 - accuracy: 0.6216 - val_loss: 0.6286 - val_accuracy: 0.7591
# Epoch 2/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.5214 - accuracy: 0.8344 - val_loss: 0.4182 - val_accuracy: 0.8650
# Epoch 3/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3675 - accuracy: 0.8731 - val_loss: 0.3331 - val_accuracy: 0.8698
# Epoch 4/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3111 - accuracy: 0.8855 - val_loss: 0.3135 - val_accuracy: 0.8736
# Epoch 5/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2892 - accuracy: 0.8926 - val_loss: 0.3096 - val_accuracy: 0.8744
# Epoch 6/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2703 - accuracy: 0.9007 - val_loss: 0.3117 - val_accuracy: 0.8756
# Epoch 7/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2575 - accuracy: 0.9057 - val_loss: 0.3152 - val_accuracy: 0.8744
# Epoch 8/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2491 - accuracy: 0.9101 - val_loss: 0.3213 - val_accuracy: 0.8712
# Epoch 9/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2417 - accuracy: 0.9132 - val_loss: 0.3265 - val_accuracy: 0.8694
# Epoch 10/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2338 - accuracy: 0.9168 - val_loss: 0.3323 - val_accuracy: 0.8656
#
# Validation Accuracy: 0.8655967712402344
# Validation Loss: 0.33231475949287415
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8524    0.8524    0.8524      2269
#            1     0.8767    0.8767    0.8767      2716
#
#     accuracy                         0.8656      4985
#    macro avg     0.8645    0.8645    0.8645      4985
# weighted avg     0.8656    0.8656    0.8656      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 33ms/step - loss: 0.6716 - accuracy: 0.6491 - val_loss: 0.6126 - val_accuracy: 0.8251
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.4951 - accuracy: 0.8502 - val_loss: 0.3922 - val_accuracy: 0.8670
# Epoch 3/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3478 - accuracy: 0.8739 - val_loss: 0.3254 - val_accuracy: 0.8726
# Epoch 4/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3019 - accuracy: 0.8873 - val_loss: 0.3114 - val_accuracy: 0.8752
# Epoch 5/10
# 701/701 [==============================] - 25s 35ms/step - loss: 0.2791 - accuracy: 0.8956 - val_loss: 0.3102 - val_accuracy: 0.8772
# Epoch 6/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2680 - accuracy: 0.8999 - val_loss: 0.3124 - val_accuracy: 0.8748
# Epoch 7/10
# 701/701 [==============================] - 25s 35ms/step - loss: 0.2532 - accuracy: 0.9072 - val_loss: 0.3169 - val_accuracy: 0.8712
# Epoch 8/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2449 - accuracy: 0.9099 - val_loss: 0.3223 - val_accuracy: 0.8706
# Epoch 9/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2378 - accuracy: 0.9138 - val_loss: 0.3285 - val_accuracy: 0.8684
# Epoch 10/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2282 - accuracy: 0.9188 - val_loss: 0.3359 - val_accuracy: 0.8668
#
# Validation Accuracy: 0.8668004274368286
# Validation Loss: 0.3358602523803711
#
# 156/156 [==============================] - 2s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8620    0.8422    0.8520      2269
#            1     0.8707    0.8873    0.8789      2716
#
#     accuracy                         0.8668      4985
#    macro avg     0.8663    0.8648    0.8655      4985
# weighted avg     0.8667    0.8668    0.8667      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8654363089267804
# Average Precision : 0.8736176055877113
# Average Recall : 0.8804123711340207
# Average F1 Score : 0.8653790941969085
