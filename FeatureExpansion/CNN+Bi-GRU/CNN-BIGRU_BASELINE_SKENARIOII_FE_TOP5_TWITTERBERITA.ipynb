# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigramTrigram_Top5_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test= process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 32s 31ms/step - loss: 0.6872 - accuracy: 0.6270 - val_loss: 0.6716 - val_accuracy: 0.7922
# Epoch 2/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.6244 - accuracy: 0.8264 - val_loss: 0.5615 - val_accuracy: 0.8600
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4879 - accuracy: 0.8560 - val_loss: 0.4244 - val_accuracy: 0.8636
# Epoch 4/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3858 - accuracy: 0.8672 - val_loss: 0.3559 - val_accuracy: 0.8658
# Epoch 5/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3349 - accuracy: 0.8770 - val_loss: 0.3278 - val_accuracy: 0.8708
# Epoch 6/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3095 - accuracy: 0.8842 - val_loss: 0.3160 - val_accuracy: 0.8728
# Epoch 7/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2909 - accuracy: 0.8897 - val_loss: 0.3109 - val_accuracy: 0.8746
# Epoch 8/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2802 - accuracy: 0.8941 - val_loss: 0.3094 - val_accuracy: 0.8744
# Epoch 9/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.2693 - accuracy: 0.8995 - val_loss: 0.3096 - val_accuracy: 0.8744
# Epoch 10/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2614 - accuracy: 0.9031 - val_loss: 0.3115 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.31145215034484863
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8680    0.8462    0.8570      2269
#            1     0.8741    0.8925    0.8832      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8711    0.8693    0.8701      4985
# weighted avg     0.8713    0.8714    0.8713      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 25s 30ms/step - loss: 0.6896 - accuracy: 0.5592 - val_loss: 0.6793 - val_accuracy: 0.6461
# Epoch 2/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.6440 - accuracy: 0.7765 - val_loss: 0.5955 - val_accuracy: 0.8371
# Epoch 3/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.5282 - accuracy: 0.8484 - val_loss: 0.4628 - val_accuracy: 0.8658
# Epoch 4/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.4150 - accuracy: 0.8626 - val_loss: 0.3757 - val_accuracy: 0.8686
# Epoch 5/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3535 - accuracy: 0.8735 - val_loss: 0.3371 - val_accuracy: 0.8712
# Epoch 6/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3211 - accuracy: 0.8811 - val_loss: 0.3200 - val_accuracy: 0.8736
# Epoch 7/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3019 - accuracy: 0.8883 - val_loss: 0.3115 - val_accuracy: 0.8758
# Epoch 8/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2896 - accuracy: 0.8927 - val_loss: 0.3082 - val_accuracy: 0.8766
# Epoch 9/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2763 - accuracy: 0.8956 - val_loss: 0.3069 - val_accuracy: 0.8738
# Epoch 10/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2693 - accuracy: 0.9006 - val_loss: 0.3074 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3074415326118469
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8696    0.8497    0.8596      2269
#            1     0.8768    0.8936    0.8851      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8732    0.8717    0.8723      4985
# weighted avg     0.8735    0.8736    0.8735      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 31ms/step - loss: 0.6863 - accuracy: 0.5616 - val_loss: 0.6693 - val_accuracy: 0.6632
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.6189 - accuracy: 0.7672 - val_loss: 0.5563 - val_accuracy: 0.8255
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4832 - accuracy: 0.8546 - val_loss: 0.4220 - val_accuracy: 0.8644
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3798 - accuracy: 0.8723 - val_loss: 0.3525 - val_accuracy: 0.8704
# Epoch 5/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.3280 - accuracy: 0.8817 - val_loss: 0.3261 - val_accuracy: 0.8728
# Epoch 6/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.3018 - accuracy: 0.8888 - val_loss: 0.3153 - val_accuracy: 0.8738
# Epoch 7/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2866 - accuracy: 0.8930 - val_loss: 0.3111 - val_accuracy: 0.8736
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2736 - accuracy: 0.8972 - val_loss: 0.3101 - val_accuracy: 0.8726
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2650 - accuracy: 0.9023 - val_loss: 0.3117 - val_accuracy: 0.8740
# Epoch 10/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2569 - accuracy: 0.9046 - val_loss: 0.3146 - val_accuracy: 0.8738
#
# Validation Accuracy: 0.8738214373588562
# Validation Loss: 0.31464359164237976
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8751    0.8431    0.8588      2269
#            1     0.8728    0.8995    0.8859      2716
#
#     accuracy                         0.8738      4985
#    macro avg     0.8740    0.8713    0.8724      4985
# weighted avg     0.8739    0.8738    0.8736      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 25s 30ms/step - loss: 0.6864 - accuracy: 0.5561 - val_loss: 0.6708 - val_accuracy: 0.6044
# Epoch 2/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.6252 - accuracy: 0.7317 - val_loss: 0.5644 - val_accuracy: 0.8225
# Epoch 3/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.4944 - accuracy: 0.8470 - val_loss: 0.4315 - val_accuracy: 0.8652
# Epoch 4/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3891 - accuracy: 0.8704 - val_loss: 0.3579 - val_accuracy: 0.8688
# Epoch 5/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3351 - accuracy: 0.8804 - val_loss: 0.3271 - val_accuracy: 0.8720
# Epoch 6/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3060 - accuracy: 0.8862 - val_loss: 0.3144 - val_accuracy: 0.8750
# Epoch 7/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2898 - accuracy: 0.8908 - val_loss: 0.3098 - val_accuracy: 0.8754
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2765 - accuracy: 0.8962 - val_loss: 0.3080 - val_accuracy: 0.8758
# Epoch 9/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2666 - accuracy: 0.9013 - val_loss: 0.3091 - val_accuracy: 0.8756
# Epoch 10/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2581 - accuracy: 0.9034 - val_loss: 0.3105 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.31049585342407227
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8710    0.8480    0.8593      2269
#            1     0.8757    0.8951    0.8853      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8734    0.8715    0.8723      4985
# weighted avg     0.8736    0.8736    0.8735      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 32ms/step - loss: 0.6894 - accuracy: 0.6010 - val_loss: 0.6793 - val_accuracy: 0.7294
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.6436 - accuracy: 0.8127 - val_loss: 0.5925 - val_accuracy: 0.8576
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.5210 - accuracy: 0.8521 - val_loss: 0.4563 - val_accuracy: 0.8618
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4072 - accuracy: 0.8672 - val_loss: 0.3717 - val_accuracy: 0.8668
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3463 - accuracy: 0.8771 - val_loss: 0.3351 - val_accuracy: 0.8696
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3142 - accuracy: 0.8833 - val_loss: 0.3191 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2953 - accuracy: 0.8903 - val_loss: 0.3124 - val_accuracy: 0.8742
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2823 - accuracy: 0.8942 - val_loss: 0.3098 - val_accuracy: 0.8734
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2702 - accuracy: 0.8979 - val_loss: 0.3101 - val_accuracy: 0.8744
# Epoch 10/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2624 - accuracy: 0.9026 - val_loss: 0.3112 - val_accuracy: 0.8750
#
# Validation Accuracy: 0.8750250935554504
# Validation Loss: 0.31123512983322144
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8748    0.8466    0.8605      2269
#            1     0.8752    0.8987    0.8868      2716
#
#     accuracy                         0.8750      4985
#    macro avg     0.8750    0.8727    0.8737      4985
# weighted avg     0.8750    0.8750    0.8748      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8735005015045136
# Average Precision : 0.8749412318942559
# Average Recall : 0.8958762886597939
# Average F1 Score : 0.8733287560608431
