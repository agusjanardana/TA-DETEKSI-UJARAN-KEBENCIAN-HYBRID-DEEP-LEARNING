# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigramTrigram_Top5_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test= process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 35s 34ms/step - loss: 0.6902 - accuracy: 0.5451 - val_loss: 0.6832 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.6548 - accuracy: 0.6533 - val_loss: 0.6119 - val_accuracy: 0.7450
# Epoch 3/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.5500 - accuracy: 0.8098 - val_loss: 0.4882 - val_accuracy: 0.8415
# Epoch 4/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.4363 - accuracy: 0.8585 - val_loss: 0.3922 - val_accuracy: 0.8666
# Epoch 5/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.3639 - accuracy: 0.8742 - val_loss: 0.3443 - val_accuracy: 0.8718
# Epoch 6/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3251 - accuracy: 0.8797 - val_loss: 0.3235 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3040 - accuracy: 0.8866 - val_loss: 0.3143 - val_accuracy: 0.8742
# Epoch 8/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2904 - accuracy: 0.8919 - val_loss: 0.3104 - val_accuracy: 0.8748
# Epoch 9/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2781 - accuracy: 0.8961 - val_loss: 0.3089 - val_accuracy: 0.8754
# Epoch 10/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2680 - accuracy: 0.9000 - val_loss: 0.3094 - val_accuracy: 0.8758
#
# Validation Accuracy: 0.8758274912834167
# Validation Loss: 0.30943334102630615
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8726    0.8515    0.8619      2269
#            1     0.8784    0.8962    0.8872      2716
#
#     accuracy                         0.8758      4985
#    macro avg     0.8755    0.8738    0.8746      4985
# weighted avg     0.8758    0.8758    0.8757      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 30s 36ms/step - loss: 0.6874 - accuracy: 0.6205 - val_loss: 0.6715 - val_accuracy: 0.7852
# Epoch 2/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.6219 - accuracy: 0.8318 - val_loss: 0.5576 - val_accuracy: 0.8602
# Epoch 3/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.4831 - accuracy: 0.8598 - val_loss: 0.4207 - val_accuracy: 0.8634
# Epoch 4/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3796 - accuracy: 0.8716 - val_loss: 0.3532 - val_accuracy: 0.8670
# Epoch 5/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3287 - accuracy: 0.8796 - val_loss: 0.3259 - val_accuracy: 0.8698
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3035 - accuracy: 0.8863 - val_loss: 0.3153 - val_accuracy: 0.8720
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2861 - accuracy: 0.8922 - val_loss: 0.3107 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2735 - accuracy: 0.8973 - val_loss: 0.3094 - val_accuracy: 0.8714
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2643 - accuracy: 0.9020 - val_loss: 0.3102 - val_accuracy: 0.8720
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2559 - accuracy: 0.9050 - val_loss: 0.3124 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.31243571639060974
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8691    0.8484    0.8586      2269
#            1     0.8758    0.8932    0.8844      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8724    0.8708    0.8715      4985
# weighted avg     0.8727    0.8728    0.8727      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 30s 33ms/step - loss: 0.6883 - accuracy: 0.5496 - val_loss: 0.6767 - val_accuracy: 0.5886
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.6388 - accuracy: 0.7203 - val_loss: 0.5865 - val_accuracy: 0.8066
# Epoch 3/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.5184 - accuracy: 0.8407 - val_loss: 0.4524 - val_accuracy: 0.8640
# Epoch 4/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.4051 - accuracy: 0.8666 - val_loss: 0.3681 - val_accuracy: 0.8676
# Epoch 5/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3447 - accuracy: 0.8758 - val_loss: 0.3318 - val_accuracy: 0.8716
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3146 - accuracy: 0.8842 - val_loss: 0.3173 - val_accuracy: 0.8740
# Epoch 7/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2945 - accuracy: 0.8889 - val_loss: 0.3108 - val_accuracy: 0.8756
# Epoch 8/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2825 - accuracy: 0.8930 - val_loss: 0.3084 - val_accuracy: 0.8746
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2714 - accuracy: 0.8988 - val_loss: 0.3084 - val_accuracy: 0.8746
# Epoch 10/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2638 - accuracy: 0.9009 - val_loss: 0.3103 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3102657198905945
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8733    0.8449    0.8589      2269
#            1     0.8738    0.8976    0.8856      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8736    0.8713    0.8722      4985
# weighted avg     0.8736    0.8736    0.8734      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 32ms/step - loss: 0.6888 - accuracy: 0.5990 - val_loss: 0.6779 - val_accuracy: 0.7525
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.6426 - accuracy: 0.8111 - val_loss: 0.5932 - val_accuracy: 0.8586
# Epoch 3/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.5239 - accuracy: 0.8531 - val_loss: 0.4585 - val_accuracy: 0.8656
# Epoch 4/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.4125 - accuracy: 0.8641 - val_loss: 0.3736 - val_accuracy: 0.8688
# Epoch 5/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.3508 - accuracy: 0.8737 - val_loss: 0.3359 - val_accuracy: 0.8730
# Epoch 6/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3186 - accuracy: 0.8837 - val_loss: 0.3192 - val_accuracy: 0.8758
# Epoch 7/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2996 - accuracy: 0.8878 - val_loss: 0.3111 - val_accuracy: 0.8770
# Epoch 8/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2857 - accuracy: 0.8930 - val_loss: 0.3082 - val_accuracy: 0.8772
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2768 - accuracy: 0.8980 - val_loss: 0.3076 - val_accuracy: 0.8770
# Epoch 10/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2672 - accuracy: 0.9013 - val_loss: 0.3087 - val_accuracy: 0.8760
#
# Validation Accuracy: 0.8760280609130859
# Validation Loss: 0.3087098300457001
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8740    0.8502    0.8619      2269
#            1     0.8776    0.8976    0.8875      2716
#
#     accuracy                         0.8760      4985
#    macro avg     0.8758    0.8739    0.8747      4985
# weighted avg     0.8760    0.8760    0.8759      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 29s 33ms/step - loss: 0.6860 - accuracy: 0.5674 - val_loss: 0.6687 - val_accuracy: 0.6716
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.6208 - accuracy: 0.7626 - val_loss: 0.5607 - val_accuracy: 0.8156
# Epoch 3/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.4922 - accuracy: 0.8445 - val_loss: 0.4320 - val_accuracy: 0.8624
# Epoch 4/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.3901 - accuracy: 0.8684 - val_loss: 0.3604 - val_accuracy: 0.8704
# Epoch 5/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3387 - accuracy: 0.8793 - val_loss: 0.3302 - val_accuracy: 0.8726
# Epoch 6/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.3100 - accuracy: 0.8870 - val_loss: 0.3175 - val_accuracy: 0.8714
# Epoch 7/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.2926 - accuracy: 0.8921 - val_loss: 0.3121 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2800 - accuracy: 0.8959 - val_loss: 0.3106 - val_accuracy: 0.8748
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2702 - accuracy: 0.8999 - val_loss: 0.3112 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2609 - accuracy: 0.9036 - val_loss: 0.3132 - val_accuracy: 0.8740
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.31317996978759766
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8714    0.8484    0.8598      2269
#            1     0.8761    0.8954    0.8857      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8738    0.8719    0.8727      4985
# weighted avg     0.8740    0.8740    0.8739      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8744633901705117
# Average Precision : 0.8763442275636324
# Average Recall : 0.8960235640648012
# Average F1 Score : 0.8743049090077296
