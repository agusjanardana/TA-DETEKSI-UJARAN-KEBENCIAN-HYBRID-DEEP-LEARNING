# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigramTrigram_Top10_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 30ms/step - loss: 0.6885 - accuracy: 0.5824 - val_loss: 0.6755 - val_accuracy: 0.7061
# Epoch 2/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.6334 - accuracy: 0.8003 - val_loss: 0.5775 - val_accuracy: 0.8499
# Epoch 3/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.5064 - accuracy: 0.8533 - val_loss: 0.4436 - val_accuracy: 0.8658
# Epoch 4/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.3996 - accuracy: 0.8657 - val_loss: 0.3656 - val_accuracy: 0.8682
# Epoch 5/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.3433 - accuracy: 0.8756 - val_loss: 0.3320 - val_accuracy: 0.8714
# Epoch 6/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.3163 - accuracy: 0.8827 - val_loss: 0.3178 - val_accuracy: 0.8738
# Epoch 7/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.2974 - accuracy: 0.8896 - val_loss: 0.3121 - val_accuracy: 0.8744
# Epoch 8/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2831 - accuracy: 0.8946 - val_loss: 0.3086 - val_accuracy: 0.8744
# Epoch 9/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2737 - accuracy: 0.8979 - val_loss: 0.3082 - val_accuracy: 0.8744
# Epoch 10/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2655 - accuracy: 0.9020 - val_loss: 0.3090 - val_accuracy: 0.8740
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.30903735756874084
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8684    0.8524    0.8603      2269
#            1     0.8785    0.8921    0.8853      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8735    0.8722    0.8728      4985
# weighted avg     0.8739    0.8740    0.8739      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 33ms/step - loss: 0.6878 - accuracy: 0.5505 - val_loss: 0.6743 - val_accuracy: 0.5878
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.6339 - accuracy: 0.7172 - val_loss: 0.5799 - val_accuracy: 0.7900
# Epoch 3/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.5158 - accuracy: 0.8354 - val_loss: 0.4542 - val_accuracy: 0.8574
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4086 - accuracy: 0.8652 - val_loss: 0.3728 - val_accuracy: 0.8710
# Epoch 5/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3489 - accuracy: 0.8767 - val_loss: 0.3354 - val_accuracy: 0.8732
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3177 - accuracy: 0.8828 - val_loss: 0.3185 - val_accuracy: 0.8770
# Epoch 7/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2987 - accuracy: 0.8900 - val_loss: 0.3114 - val_accuracy: 0.8758
# Epoch 8/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2856 - accuracy: 0.8944 - val_loss: 0.3101 - val_accuracy: 0.8750
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2737 - accuracy: 0.8987 - val_loss: 0.3082 - val_accuracy: 0.8764
# Epoch 10/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2648 - accuracy: 0.9024 - val_loss: 0.3098 - val_accuracy: 0.8758
#
# Validation Accuracy: 0.8758274912834167
# Validation Loss: 0.30983760952949524
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8740    0.8497    0.8617      2269
#            1     0.8773    0.8976    0.8874      2716
#
#     accuracy                         0.8758      4985
#    macro avg     0.8756    0.8737    0.8745      4985
# weighted avg     0.8758    0.8758    0.8757      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 31ms/step - loss: 0.6891 - accuracy: 0.5647 - val_loss: 0.6778 - val_accuracy: 0.6798
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.6390 - accuracy: 0.7745 - val_loss: 0.5852 - val_accuracy: 0.8265
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.5155 - accuracy: 0.8495 - val_loss: 0.4498 - val_accuracy: 0.8638
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4034 - accuracy: 0.8690 - val_loss: 0.3669 - val_accuracy: 0.8686
# Epoch 5/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.3424 - accuracy: 0.8771 - val_loss: 0.3311 - val_accuracy: 0.8720
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3136 - accuracy: 0.8846 - val_loss: 0.3166 - val_accuracy: 0.8740
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2924 - accuracy: 0.8913 - val_loss: 0.3105 - val_accuracy: 0.8740
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2812 - accuracy: 0.8944 - val_loss: 0.3079 - val_accuracy: 0.8750
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2708 - accuracy: 0.8989 - val_loss: 0.3073 - val_accuracy: 0.8758
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2619 - accuracy: 0.9022 - val_loss: 0.3085 - val_accuracy: 0.8768
#
# Validation Accuracy: 0.876830518245697
# Validation Loss: 0.30849751830101013
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8709    0.8563    0.8636      2269
#            1     0.8816    0.8940    0.8878      2716
#
#     accuracy                         0.8768      4985
#    macro avg     0.8763    0.8751    0.8757      4985
# weighted avg     0.8767    0.8768    0.8767      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 29s 34ms/step - loss: 0.6857 - accuracy: 0.5991 - val_loss: 0.6679 - val_accuracy: 0.7200
# Epoch 2/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.6225 - accuracy: 0.8011 - val_loss: 0.5671 - val_accuracy: 0.8311
# Epoch 3/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.4987 - accuracy: 0.8548 - val_loss: 0.4383 - val_accuracy: 0.8646
# Epoch 4/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3962 - accuracy: 0.8690 - val_loss: 0.3627 - val_accuracy: 0.8672
# Epoch 5/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3396 - accuracy: 0.8780 - val_loss: 0.3307 - val_accuracy: 0.8710
# Epoch 6/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3110 - accuracy: 0.8855 - val_loss: 0.3172 - val_accuracy: 0.8730
# Epoch 7/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2935 - accuracy: 0.8904 - val_loss: 0.3126 - val_accuracy: 0.8730
# Epoch 8/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2809 - accuracy: 0.8948 - val_loss: 0.3102 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2712 - accuracy: 0.8993 - val_loss: 0.3105 - val_accuracy: 0.8756
# Epoch 10/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2624 - accuracy: 0.9034 - val_loss: 0.3123 - val_accuracy: 0.8732
#
# Validation Accuracy: 0.8732196688652039
# Validation Loss: 0.31228551268577576
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8672    0.8519    0.8595      2269
#            1     0.8781    0.8910    0.8845      2716
#
#     accuracy                         0.8732      4985
#    macro avg     0.8726    0.8715    0.8720      4985
# weighted avg     0.8731    0.8732    0.8731      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 29s 35ms/step - loss: 0.6869 - accuracy: 0.5574 - val_loss: 0.6715 - val_accuracy: 0.6267
# Epoch 2/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.6254 - accuracy: 0.7405 - val_loss: 0.5657 - val_accuracy: 0.8249
# Epoch 3/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.4945 - accuracy: 0.8451 - val_loss: 0.4329 - val_accuracy: 0.8614
# Epoch 4/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3908 - accuracy: 0.8678 - val_loss: 0.3593 - val_accuracy: 0.8700
# Epoch 5/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3369 - accuracy: 0.8764 - val_loss: 0.3285 - val_accuracy: 0.8708
# Epoch 6/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.3101 - accuracy: 0.8855 - val_loss: 0.3161 - val_accuracy: 0.8734
# Epoch 7/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2935 - accuracy: 0.8894 - val_loss: 0.3110 - val_accuracy: 0.8736
# Epoch 8/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2812 - accuracy: 0.8954 - val_loss: 0.3089 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 27s 39ms/step - loss: 0.2705 - accuracy: 0.8994 - val_loss: 0.3096 - val_accuracy: 0.8736
# Epoch 10/10
# 701/701 [==============================] - 25s 36ms/step - loss: 0.2636 - accuracy: 0.9034 - val_loss: 0.3106 - val_accuracy: 0.8736
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3105967342853546
#
# 156/156 [==============================] - 2s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8673    0.8528    0.8600      2269
#            1     0.8787    0.8910    0.8848      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8730    0.8719    0.8724      4985
# weighted avg     0.8735    0.8736    0.8735      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.874704112337011
# Average Precision : 0.8788523849812856
# Average Recall : 0.8931516936671576
# Average F1 Score : 0.8745932002841386
