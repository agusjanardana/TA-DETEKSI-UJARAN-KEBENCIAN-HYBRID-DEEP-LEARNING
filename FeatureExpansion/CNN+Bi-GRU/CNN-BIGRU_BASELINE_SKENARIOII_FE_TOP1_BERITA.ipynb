# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigramTrigram_Top1_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 34s 34ms/step - loss: 0.6740 - accuracy: 0.6619 - val_loss: 0.6194 - val_accuracy: 0.8363
# Epoch 2/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.5023 - accuracy: 0.8508 - val_loss: 0.3987 - val_accuracy: 0.8638
# Epoch 3/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3540 - accuracy: 0.8746 - val_loss: 0.3287 - val_accuracy: 0.8708
# Epoch 4/10
# 701/701 [==============================] - 25s 35ms/step - loss: 0.3055 - accuracy: 0.8858 - val_loss: 0.3125 - val_accuracy: 0.8734
# Epoch 5/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2836 - accuracy: 0.8939 - val_loss: 0.3091 - val_accuracy: 0.8736
# Epoch 6/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.2671 - accuracy: 0.9013 - val_loss: 0.3110 - val_accuracy: 0.8732
# Epoch 7/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2555 - accuracy: 0.9053 - val_loss: 0.3147 - val_accuracy: 0.8708
# Epoch 8/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2453 - accuracy: 0.9107 - val_loss: 0.3206 - val_accuracy: 0.8702
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2368 - accuracy: 0.9144 - val_loss: 0.3269 - val_accuracy: 0.8680
# Epoch 10/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2310 - accuracy: 0.9175 - val_loss: 0.3340 - val_accuracy: 0.8648
#
# Validation Accuracy: 0.8647943735122681
# Validation Loss: 0.3339898884296417
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8562    0.8449    0.8505      2269
#            1     0.8718    0.8814    0.8766      2716
#
#     accuracy                         0.8648      4985
#    macro avg     0.8640    0.8632    0.8635      4985
# weighted avg     0.8647    0.8648    0.8647      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 33ms/step - loss: 0.6676 - accuracy: 0.6288 - val_loss: 0.6005 - val_accuracy: 0.7888
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4849 - accuracy: 0.8476 - val_loss: 0.3873 - val_accuracy: 0.8658
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3417 - accuracy: 0.8783 - val_loss: 0.3241 - val_accuracy: 0.8726
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2982 - accuracy: 0.8886 - val_loss: 0.3125 - val_accuracy: 0.8750
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2773 - accuracy: 0.8960 - val_loss: 0.3108 - val_accuracy: 0.8762
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2630 - accuracy: 0.9025 - val_loss: 0.3149 - val_accuracy: 0.8736
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2516 - accuracy: 0.9072 - val_loss: 0.3190 - val_accuracy: 0.8702
# Epoch 8/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2425 - accuracy: 0.9117 - val_loss: 0.3246 - val_accuracy: 0.8676
# Epoch 9/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2344 - accuracy: 0.9155 - val_loss: 0.3314 - val_accuracy: 0.8650
# Epoch 10/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2273 - accuracy: 0.9173 - val_loss: 0.3390 - val_accuracy: 0.8616
#
# Validation Accuracy: 0.8615847826004028
# Validation Loss: 0.3390180170536041
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8492    0.8462    0.8477      2269
#            1     0.8719    0.8744    0.8732      2716
#
#     accuracy                         0.8616      4985
#    macro avg     0.8605    0.8603    0.8604      4985
# weighted avg     0.8615    0.8616    0.8616      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 30s 35ms/step - loss: 0.6711 - accuracy: 0.5902 - val_loss: 0.6132 - val_accuracy: 0.7306
# Epoch 2/10
# 701/701 [==============================] - 25s 35ms/step - loss: 0.5108 - accuracy: 0.8231 - val_loss: 0.4141 - val_accuracy: 0.8646
# Epoch 3/10
# 701/701 [==============================] - 25s 35ms/step - loss: 0.3645 - accuracy: 0.8735 - val_loss: 0.3328 - val_accuracy: 0.8702
# Epoch 4/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3101 - accuracy: 0.8851 - val_loss: 0.3132 - val_accuracy: 0.8744
# Epoch 5/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2876 - accuracy: 0.8934 - val_loss: 0.3105 - val_accuracy: 0.8756
# Epoch 6/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2698 - accuracy: 0.9008 - val_loss: 0.3109 - val_accuracy: 0.8742
# Epoch 7/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2601 - accuracy: 0.9053 - val_loss: 0.3147 - val_accuracy: 0.8718
# Epoch 8/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2487 - accuracy: 0.9098 - val_loss: 0.3189 - val_accuracy: 0.8720
# Epoch 9/10
# 701/701 [==============================] - 25s 35ms/step - loss: 0.2408 - accuracy: 0.9145 - val_loss: 0.3247 - val_accuracy: 0.8700
# Epoch 10/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2334 - accuracy: 0.9168 - val_loss: 0.3315 - val_accuracy: 0.8678
#
# Validation Accuracy: 0.8678033947944641
# Validation Loss: 0.3314542770385742
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8607    0.8466    0.8536      2269
#            1     0.8736    0.8855    0.8795      2716
#
#     accuracy                         0.8678      4985
#    macro avg     0.8671    0.8661    0.8665      4985
# weighted avg     0.8677    0.8678    0.8677      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 32ms/step - loss: 0.6709 - accuracy: 0.5910 - val_loss: 0.6112 - val_accuracy: 0.7236
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.5073 - accuracy: 0.8247 - val_loss: 0.4132 - val_accuracy: 0.8636
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3627 - accuracy: 0.8750 - val_loss: 0.3325 - val_accuracy: 0.8752
# Epoch 4/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3099 - accuracy: 0.8872 - val_loss: 0.3158 - val_accuracy: 0.8760
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2848 - accuracy: 0.8952 - val_loss: 0.3111 - val_accuracy: 0.8754
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2669 - accuracy: 0.9004 - val_loss: 0.3128 - val_accuracy: 0.8728
# Epoch 7/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2558 - accuracy: 0.9063 - val_loss: 0.3193 - val_accuracy: 0.8714
# Epoch 8/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2451 - accuracy: 0.9101 - val_loss: 0.3225 - val_accuracy: 0.8686
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2390 - accuracy: 0.9134 - val_loss: 0.3291 - val_accuracy: 0.8640
# Epoch 10/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2327 - accuracy: 0.9180 - val_loss: 0.3367 - val_accuracy: 0.8658
#
# Validation Accuracy: 0.8657974004745483
# Validation Loss: 0.33665019273757935
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8610    0.8409    0.8508      2269
#            1     0.8696    0.8866    0.8780      2716
#
#     accuracy                         0.8658      4985
#    macro avg     0.8653    0.8637    0.8644      4985
# weighted avg     0.8657    0.8658    0.8657      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 32ms/step - loss: 0.6740 - accuracy: 0.6330 - val_loss: 0.6221 - val_accuracy: 0.8098
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.5089 - accuracy: 0.8410 - val_loss: 0.4032 - val_accuracy: 0.8664
# Epoch 3/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3600 - accuracy: 0.8696 - val_loss: 0.3292 - val_accuracy: 0.8724
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3110 - accuracy: 0.8831 - val_loss: 0.3117 - val_accuracy: 0.8768
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2863 - accuracy: 0.8929 - val_loss: 0.3083 - val_accuracy: 0.8778
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2714 - accuracy: 0.8997 - val_loss: 0.3093 - val_accuracy: 0.8758
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2593 - accuracy: 0.9048 - val_loss: 0.3143 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2503 - accuracy: 0.9085 - val_loss: 0.3182 - val_accuracy: 0.8720
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2426 - accuracy: 0.9129 - val_loss: 0.3236 - val_accuracy: 0.8710
# Epoch 10/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2332 - accuracy: 0.9174 - val_loss: 0.3302 - val_accuracy: 0.8656
#
# Validation Accuracy: 0.8655967712402344
# Validation Loss: 0.33023858070373535
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8508    0.8546    0.8527      2269
#            1     0.8780    0.8748    0.8764      2716
#
#     accuracy                         0.8656      4985
#    macro avg     0.8644    0.8647    0.8646      4985
# weighted avg     0.8657    0.8656    0.8656      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8651153460381144
# Average Precision : 0.872992477093731
# Average Recall : 0.8805596465390281
# Average F1 Score : 0.8650521573882528
