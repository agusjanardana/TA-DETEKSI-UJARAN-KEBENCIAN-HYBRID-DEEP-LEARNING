# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitterberita/DatasetHatespeech_UnigramBigramTrigram_Top10_ExpandedBeritaTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 30ms/step - loss: 0.6879 - accuracy: 0.5582 - val_loss: 0.6755 - val_accuracy: 0.5966
# Epoch 2/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.6396 - accuracy: 0.7012 - val_loss: 0.5903 - val_accuracy: 0.7785
# Epoch 3/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.5318 - accuracy: 0.8221 - val_loss: 0.4720 - val_accuracy: 0.8497
# Epoch 4/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.4255 - accuracy: 0.8621 - val_loss: 0.3833 - val_accuracy: 0.8682
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3595 - accuracy: 0.8750 - val_loss: 0.3405 - val_accuracy: 0.8702
# Epoch 6/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3235 - accuracy: 0.8827 - val_loss: 0.3216 - val_accuracy: 0.8740
# Epoch 7/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.3053 - accuracy: 0.8880 - val_loss: 0.3133 - val_accuracy: 0.8744
# Epoch 8/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2925 - accuracy: 0.8928 - val_loss: 0.3103 - val_accuracy: 0.8748
# Epoch 9/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.2805 - accuracy: 0.8970 - val_loss: 0.3096 - val_accuracy: 0.8750
# Epoch 10/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.2719 - accuracy: 0.9002 - val_loss: 0.3109 - val_accuracy: 0.8742
#
# Validation Accuracy: 0.8742226958274841
# Validation Loss: 0.31093281507492065
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8776    0.8409    0.8589      2269
#            1     0.8716    0.9021    0.8866      2716
#
#     accuracy                         0.8742      4985
#    macro avg     0.8746    0.8715    0.8727      4985
# weighted avg     0.8743    0.8742    0.8740      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 25s 31ms/step - loss: 0.6878 - accuracy: 0.5854 - val_loss: 0.6741 - val_accuracy: 0.7081
# Epoch 2/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.6320 - accuracy: 0.7997 - val_loss: 0.5757 - val_accuracy: 0.8465
# Epoch 3/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.5046 - accuracy: 0.8560 - val_loss: 0.4398 - val_accuracy: 0.8634
# Epoch 4/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3956 - accuracy: 0.8691 - val_loss: 0.3621 - val_accuracy: 0.8688
# Epoch 5/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.3422 - accuracy: 0.8770 - val_loss: 0.3301 - val_accuracy: 0.8714
# Epoch 6/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.3137 - accuracy: 0.8841 - val_loss: 0.3172 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2960 - accuracy: 0.8903 - val_loss: 0.3109 - val_accuracy: 0.8738
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2814 - accuracy: 0.8958 - val_loss: 0.3096 - val_accuracy: 0.8756
# Epoch 9/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2721 - accuracy: 0.8984 - val_loss: 0.3086 - val_accuracy: 0.8744
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2639 - accuracy: 0.9019 - val_loss: 0.3101 - val_accuracy: 0.8740
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.3100718855857849
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8668    0.8546    0.8606      2269
#            1     0.8799    0.8903    0.8851      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8733    0.8724    0.8728      4985
# weighted avg     0.8739    0.8740    0.8739      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 30ms/step - loss: 0.6893 - accuracy: 0.5751 - val_loss: 0.6787 - val_accuracy: 0.7031
# Epoch 2/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.6430 - accuracy: 0.7932 - val_loss: 0.5935 - val_accuracy: 0.8437
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.5254 - accuracy: 0.8479 - val_loss: 0.4601 - val_accuracy: 0.8634
# Epoch 4/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.4113 - accuracy: 0.8661 - val_loss: 0.3727 - val_accuracy: 0.8674
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3511 - accuracy: 0.8749 - val_loss: 0.3346 - val_accuracy: 0.8712
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3196 - accuracy: 0.8814 - val_loss: 0.3183 - val_accuracy: 0.8730
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3004 - accuracy: 0.8900 - val_loss: 0.3108 - val_accuracy: 0.8742
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2861 - accuracy: 0.8942 - val_loss: 0.3082 - val_accuracy: 0.8764
# Epoch 9/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2766 - accuracy: 0.8982 - val_loss: 0.3073 - val_accuracy: 0.8758
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2672 - accuracy: 0.9018 - val_loss: 0.3086 - val_accuracy: 0.8744
#
# Validation Accuracy: 0.8744232654571533
# Validation Loss: 0.30855461955070496
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8739    0.8462    0.8598      2269
#            1     0.8748    0.8980    0.8863      2716
#
#     accuracy                         0.8744      4985
#    macro avg     0.8744    0.8721    0.8730      4985
# weighted avg     0.8744    0.8744    0.8742      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 26s 32ms/step - loss: 0.6868 - accuracy: 0.5620 - val_loss: 0.6704 - val_accuracy: 0.6431
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.6250 - accuracy: 0.7389 - val_loss: 0.5688 - val_accuracy: 0.7972
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.5023 - accuracy: 0.8419 - val_loss: 0.4451 - val_accuracy: 0.8592
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4014 - accuracy: 0.8702 - val_loss: 0.3675 - val_accuracy: 0.8694
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3427 - accuracy: 0.8795 - val_loss: 0.3333 - val_accuracy: 0.8710
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3134 - accuracy: 0.8864 - val_loss: 0.3190 - val_accuracy: 0.8722
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2935 - accuracy: 0.8931 - val_loss: 0.3128 - val_accuracy: 0.8738
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2823 - accuracy: 0.8966 - val_loss: 0.3111 - val_accuracy: 0.8766
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2727 - accuracy: 0.9004 - val_loss: 0.3116 - val_accuracy: 0.8762
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2628 - accuracy: 0.9042 - val_loss: 0.3126 - val_accuracy: 0.8742
#
# Validation Accuracy: 0.8742226958274841
# Validation Loss: 0.31264016032218933
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8668    0.8550    0.8609      2269
#            1     0.8802    0.8903    0.8852      2716
#
#     accuracy                         0.8742      4985
#    macro avg     0.8735    0.8726    0.8731      4985
# weighted avg     0.8741    0.8742    0.8741      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 32ms/step - loss: 0.6857 - accuracy: 0.5451 - val_loss: 0.6698 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.6337 - accuracy: 0.6042 - val_loss: 0.5908 - val_accuracy: 0.7043
# Epoch 3/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.5480 - accuracy: 0.7668 - val_loss: 0.5112 - val_accuracy: 0.8084
# Epoch 4/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.4777 - accuracy: 0.8484 - val_loss: 0.4546 - val_accuracy: 0.8504
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4266 - accuracy: 0.8738 - val_loss: 0.4106 - val_accuracy: 0.8682
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3834 - accuracy: 0.8857 - val_loss: 0.3759 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3504 - accuracy: 0.8911 - val_loss: 0.3507 - val_accuracy: 0.8732
# Epoch 8/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.3241 - accuracy: 0.8945 - val_loss: 0.3356 - val_accuracy: 0.8744
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3073 - accuracy: 0.8967 - val_loss: 0.3295 - val_accuracy: 0.8744
# Epoch 10/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2944 - accuracy: 0.8993 - val_loss: 0.3250 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.32498088479042053
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8622    0.8550    0.8586      2269
#            1     0.8797    0.8859    0.8828      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8710    0.8704    0.8707      4985
# weighted avg     0.8717    0.8718    0.8718      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITATWITTER_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8737412236710131
# Average Precision : 0.8772499504418626
# Average Recall : 0.8932989690721648
# Average F1 Score : 0.8736102572755844
