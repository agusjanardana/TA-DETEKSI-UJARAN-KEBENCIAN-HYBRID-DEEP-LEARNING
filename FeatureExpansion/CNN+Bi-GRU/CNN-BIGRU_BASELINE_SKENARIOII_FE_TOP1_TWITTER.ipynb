# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigramTrigram_Top1_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test= process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 30s 29ms/step - loss: 0.6748 - accuracy: 0.6269 - val_loss: 0.6205 - val_accuracy: 0.8052
# Epoch 2/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.5011 - accuracy: 0.8418 - val_loss: 0.3936 - val_accuracy: 0.8666
# Epoch 3/10
# 701/701 [==============================] - 19s 26ms/step - loss: 0.3519 - accuracy: 0.8725 - val_loss: 0.3253 - val_accuracy: 0.8720
# Epoch 4/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3044 - accuracy: 0.8853 - val_loss: 0.3137 - val_accuracy: 0.8760
# Epoch 5/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2821 - accuracy: 0.8942 - val_loss: 0.3099 - val_accuracy: 0.8768
# Epoch 6/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2679 - accuracy: 0.9014 - val_loss: 0.3111 - val_accuracy: 0.8756
# Epoch 7/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2548 - accuracy: 0.9059 - val_loss: 0.3151 - val_accuracy: 0.8740
# Epoch 8/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2466 - accuracy: 0.9096 - val_loss: 0.3204 - val_accuracy: 0.8708
# Epoch 9/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2387 - accuracy: 0.9145 - val_loss: 0.3265 - val_accuracy: 0.8668
# Epoch 10/10
# 701/701 [==============================] - 19s 26ms/step - loss: 0.2317 - accuracy: 0.9179 - val_loss: 0.3342 - val_accuracy: 0.8670
#
# Validation Accuracy: 0.8670009970664978
# Validation Loss: 0.33419516682624817
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8637    0.8405    0.8519      2269
#            1     0.8696    0.8892    0.8793      2716
#
#     accuracy                         0.8670      4985
#    macro avg     0.8667    0.8648    0.8656      4985
# weighted avg     0.8669    0.8670    0.8668      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 25s 30ms/step - loss: 0.6742 - accuracy: 0.6431 - val_loss: 0.6199 - val_accuracy: 0.8140
# Epoch 2/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.4988 - accuracy: 0.8479 - val_loss: 0.3927 - val_accuracy: 0.8640
# Epoch 3/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3489 - accuracy: 0.8738 - val_loss: 0.3257 - val_accuracy: 0.8718
# Epoch 4/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3015 - accuracy: 0.8862 - val_loss: 0.3119 - val_accuracy: 0.8732
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2800 - accuracy: 0.8949 - val_loss: 0.3109 - val_accuracy: 0.8764
# Epoch 6/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2645 - accuracy: 0.9003 - val_loss: 0.3127 - val_accuracy: 0.8752
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2531 - accuracy: 0.9077 - val_loss: 0.3163 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2430 - accuracy: 0.9110 - val_loss: 0.3220 - val_accuracy: 0.8716
# Epoch 9/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2353 - accuracy: 0.9158 - val_loss: 0.3288 - val_accuracy: 0.8680
# Epoch 10/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.2270 - accuracy: 0.9184 - val_loss: 0.3358 - val_accuracy: 0.8654
#
# Validation Accuracy: 0.8653962016105652
# Validation Loss: 0.33580952882766724
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8577    0.8444    0.8510      2269
#            1     0.8717    0.8829    0.8773      2716
#
#     accuracy                         0.8654      4985
#    macro avg     0.8647    0.8637    0.8641      4985
# weighted avg     0.8653    0.8654    0.8653      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 30s 33ms/step - loss: 0.6752 - accuracy: 0.6363 - val_loss: 0.6273 - val_accuracy: 0.7906
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.5205 - accuracy: 0.8358 - val_loss: 0.4163 - val_accuracy: 0.8658
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3684 - accuracy: 0.8687 - val_loss: 0.3341 - val_accuracy: 0.8706
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3153 - accuracy: 0.8821 - val_loss: 0.3148 - val_accuracy: 0.8720
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2907 - accuracy: 0.8922 - val_loss: 0.3099 - val_accuracy: 0.8724
# Epoch 6/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2746 - accuracy: 0.8990 - val_loss: 0.3112 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2616 - accuracy: 0.9047 - val_loss: 0.3139 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2515 - accuracy: 0.9092 - val_loss: 0.3187 - val_accuracy: 0.8700
# Epoch 9/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2433 - accuracy: 0.9132 - val_loss: 0.3247 - val_accuracy: 0.8682
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2373 - accuracy: 0.9165 - val_loss: 0.3313 - val_accuracy: 0.8656
#
# Validation Accuracy: 0.8655967712402344
# Validation Loss: 0.3313414454460144
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8613    0.8400    0.8505      2269
#            1     0.8690    0.8870    0.8779      2716
#
#     accuracy                         0.8656      4985
#    macro avg     0.8652    0.8635    0.8642      4985
# weighted avg     0.8655    0.8656    0.8654      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 32ms/step - loss: 0.6769 - accuracy: 0.7026 - val_loss: 0.6285 - val_accuracy: 0.8578
# Epoch 2/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.5177 - accuracy: 0.8524 - val_loss: 0.4134 - val_accuracy: 0.8678
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3618 - accuracy: 0.8736 - val_loss: 0.3325 - val_accuracy: 0.8720
# Epoch 4/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3105 - accuracy: 0.8847 - val_loss: 0.3133 - val_accuracy: 0.8724
# Epoch 5/10
# 701/701 [==============================] - 31s 44ms/step - loss: 0.2846 - accuracy: 0.8957 - val_loss: 0.3097 - val_accuracy: 0.8738
# Epoch 6/10
# 701/701 [==============================] - 30s 42ms/step - loss: 0.2697 - accuracy: 0.9028 - val_loss: 0.3109 - val_accuracy: 0.8752
# Epoch 7/10
# 701/701 [==============================] - 29s 41ms/step - loss: 0.2562 - accuracy: 0.9075 - val_loss: 0.3155 - val_accuracy: 0.8724
# Epoch 8/10
# 701/701 [==============================] - 29s 41ms/step - loss: 0.2476 - accuracy: 0.9112 - val_loss: 0.3207 - val_accuracy: 0.8686
# Epoch 9/10
# 701/701 [==============================] - 31s 44ms/step - loss: 0.2386 - accuracy: 0.9157 - val_loss: 0.3277 - val_accuracy: 0.8650
# Epoch 10/10
# 701/701 [==============================] - 30s 42ms/step - loss: 0.2295 - accuracy: 0.9184 - val_loss: 0.3349 - val_accuracy: 0.8648
#
# Validation Accuracy: 0.8647943735122681
# Validation Loss: 0.33490946888923645
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8630    0.8356    0.8491      2269
#            1     0.8662    0.8892    0.8775      2716
#
#     accuracy                         0.8648      4985
#    macro avg     0.8646    0.8624    0.8633      4985
# weighted avg     0.8647    0.8648    0.8646      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 37s 42ms/step - loss: 0.6736 - accuracy: 0.6261 - val_loss: 0.6211 - val_accuracy: 0.7934
# Epoch 2/10
# 701/701 [==============================] - 30s 43ms/step - loss: 0.5063 - accuracy: 0.8429 - val_loss: 0.3979 - val_accuracy: 0.8690
# Epoch 3/10
# 701/701 [==============================] - 29s 41ms/step - loss: 0.3546 - accuracy: 0.8721 - val_loss: 0.3254 - val_accuracy: 0.8752
# Epoch 4/10
# 701/701 [==============================] - 28s 41ms/step - loss: 0.3020 - accuracy: 0.8856 - val_loss: 0.3108 - val_accuracy: 0.8762
# Epoch 5/10
# 701/701 [==============================] - 29s 41ms/step - loss: 0.2814 - accuracy: 0.8953 - val_loss: 0.3082 - val_accuracy: 0.8756
# Epoch 6/10
# 701/701 [==============================] - 30s 43ms/step - loss: 0.2661 - accuracy: 0.9012 - val_loss: 0.3099 - val_accuracy: 0.8738
# Epoch 7/10
# 701/701 [==============================] - 29s 41ms/step - loss: 0.2555 - accuracy: 0.9061 - val_loss: 0.3149 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 33s 48ms/step - loss: 0.2458 - accuracy: 0.9107 - val_loss: 0.3192 - val_accuracy: 0.8710
# Epoch 9/10
# 701/701 [==============================] - 28s 39ms/step - loss: 0.2366 - accuracy: 0.9143 - val_loss: 0.3256 - val_accuracy: 0.8678
# Epoch 10/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2280 - accuracy: 0.9174 - val_loss: 0.3330 - val_accuracy: 0.8642
#
# Validation Accuracy: 0.8641926050186157
# Validation Loss: 0.3329542875289917
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8482    0.8546    0.8514      2269
#            1     0.8777    0.8722    0.8750      2716
#
#     accuracy                         0.8642      4985
#    macro avg     0.8630    0.8634    0.8632      4985
# weighted avg     0.8643    0.8642    0.8642      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP1-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP1.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8653961885656972
# Average Precision : 0.8708637951385082
# Average Recall : 0.8840942562592048
# Average F1 Score : 0.8652803814634682
