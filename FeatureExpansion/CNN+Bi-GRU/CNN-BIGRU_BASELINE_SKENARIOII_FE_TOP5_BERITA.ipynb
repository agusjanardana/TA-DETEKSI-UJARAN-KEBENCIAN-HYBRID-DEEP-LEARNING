# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/berita/DatasetHatespeech_UnigramBigramTrigram_Top5_ExpandedBerita.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 34s 32ms/step - loss: 0.6738 - accuracy: 0.6486 - val_loss: 0.6199 - val_accuracy: 0.8175
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.5016 - accuracy: 0.8479 - val_loss: 0.3953 - val_accuracy: 0.8670
# Epoch 3/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.3529 - accuracy: 0.8721 - val_loss: 0.3273 - val_accuracy: 0.8720
# Epoch 4/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.3052 - accuracy: 0.8852 - val_loss: 0.3124 - val_accuracy: 0.8762
# Epoch 5/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.2807 - accuracy: 0.8946 - val_loss: 0.3102 - val_accuracy: 0.8764
# Epoch 6/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.2672 - accuracy: 0.9011 - val_loss: 0.3112 - val_accuracy: 0.8744
# Epoch 7/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2545 - accuracy: 0.9065 - val_loss: 0.3146 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2442 - accuracy: 0.9100 - val_loss: 0.3199 - val_accuracy: 0.8686
# Epoch 9/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2386 - accuracy: 0.9147 - val_loss: 0.3261 - val_accuracy: 0.8662
# Epoch 10/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.2305 - accuracy: 0.9178 - val_loss: 0.3339 - val_accuracy: 0.8622
#
# Validation Accuracy: 0.8621865510940552
# Validation Loss: 0.33385589718818665
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8445    0.8546    0.8495      2269
#            1     0.8773    0.8686    0.8729      2716
#
#     accuracy                         0.8622      4985
#    macro avg     0.8609    0.8616    0.8612      4985
# weighted avg     0.8624    0.8622    0.8622      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 31s 37ms/step - loss: 0.6728 - accuracy: 0.6066 - val_loss: 0.6178 - val_accuracy: 0.7649
# Epoch 2/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.5080 - accuracy: 0.8367 - val_loss: 0.4067 - val_accuracy: 0.8638
# Epoch 3/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.3594 - accuracy: 0.8749 - val_loss: 0.3302 - val_accuracy: 0.8706
# Epoch 4/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3075 - accuracy: 0.8862 - val_loss: 0.3136 - val_accuracy: 0.8726
# Epoch 5/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.2833 - accuracy: 0.8947 - val_loss: 0.3110 - val_accuracy: 0.8764
# Epoch 6/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2664 - accuracy: 0.8993 - val_loss: 0.3128 - val_accuracy: 0.8722
# Epoch 7/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2561 - accuracy: 0.9057 - val_loss: 0.3167 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2464 - accuracy: 0.9106 - val_loss: 0.3222 - val_accuracy: 0.8718
# Epoch 9/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2382 - accuracy: 0.9138 - val_loss: 0.3288 - val_accuracy: 0.8680
# Epoch 10/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2302 - accuracy: 0.9180 - val_loss: 0.3362 - val_accuracy: 0.8628
#
# Validation Accuracy: 0.8627883791923523
# Validation Loss: 0.33616915345191956
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8456    0.8546    0.8501      2269
#            1     0.8774    0.8697    0.8735      2716
#
#     accuracy                         0.8628      4985
#    macro avg     0.8615    0.8621    0.8618      4985
# weighted avg     0.8629    0.8628    0.8628      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 33s 36ms/step - loss: 0.6731 - accuracy: 0.6133 - val_loss: 0.6177 - val_accuracy: 0.7470
# Epoch 2/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.5099 - accuracy: 0.8311 - val_loss: 0.4068 - val_accuracy: 0.8644
# Epoch 3/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.3642 - accuracy: 0.8712 - val_loss: 0.3301 - val_accuracy: 0.8688
# Epoch 4/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3102 - accuracy: 0.8848 - val_loss: 0.3132 - val_accuracy: 0.8722
# Epoch 5/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2879 - accuracy: 0.8934 - val_loss: 0.3096 - val_accuracy: 0.8756
# Epoch 6/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2713 - accuracy: 0.8999 - val_loss: 0.3100 - val_accuracy: 0.8740
# Epoch 7/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2592 - accuracy: 0.9052 - val_loss: 0.3153 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2492 - accuracy: 0.9093 - val_loss: 0.3187 - val_accuracy: 0.8724
# Epoch 9/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2403 - accuracy: 0.9138 - val_loss: 0.3254 - val_accuracy: 0.8694
# Epoch 10/10
# 701/701 [==============================] - 25s 36ms/step - loss: 0.2341 - accuracy: 0.9166 - val_loss: 0.3317 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.3317389488220215
#
# 156/156 [==============================] - 2s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8547    0.8506    0.8527      2269
#            1     0.8757    0.8792    0.8775      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8652    0.8649    0.8651      4985
# weighted avg     0.8662    0.8662    0.8662      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 30s 36ms/step - loss: 0.6722 - accuracy: 0.5877 - val_loss: 0.6173 - val_accuracy: 0.7065
# Epoch 2/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.5250 - accuracy: 0.8096 - val_loss: 0.4369 - val_accuracy: 0.8610
# Epoch 3/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3860 - accuracy: 0.8709 - val_loss: 0.3444 - val_accuracy: 0.8720
# Epoch 4/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3239 - accuracy: 0.8831 - val_loss: 0.3178 - val_accuracy: 0.8758
# Epoch 5/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2950 - accuracy: 0.8927 - val_loss: 0.3117 - val_accuracy: 0.8780
# Epoch 6/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2783 - accuracy: 0.8999 - val_loss: 0.3121 - val_accuracy: 0.8748
# Epoch 7/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2648 - accuracy: 0.9033 - val_loss: 0.3148 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2571 - accuracy: 0.9086 - val_loss: 0.3187 - val_accuracy: 0.8692
# Epoch 9/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2477 - accuracy: 0.9123 - val_loss: 0.3246 - val_accuracy: 0.8698
# Epoch 10/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2376 - accuracy: 0.9163 - val_loss: 0.3307 - val_accuracy: 0.8650
#
# Validation Accuracy: 0.864995002746582
# Validation Loss: 0.3307499289512634
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8443    0.8625    0.8533      2269
#            1     0.8830    0.8671    0.8750      2716
#
#     accuracy                         0.8650      4985
#    macro avg     0.8636    0.8648    0.8641      4985
# weighted avg     0.8654    0.8650    0.8651      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 32s 36ms/step - loss: 0.6746 - accuracy: 0.5998 - val_loss: 0.6230 - val_accuracy: 0.7436
# Epoch 2/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.5171 - accuracy: 0.8237 - val_loss: 0.4144 - val_accuracy: 0.8670
# Epoch 3/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3666 - accuracy: 0.8703 - val_loss: 0.3329 - val_accuracy: 0.8712
# Epoch 4/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.3130 - accuracy: 0.8844 - val_loss: 0.3130 - val_accuracy: 0.8736
# Epoch 5/10
# 701/701 [==============================] - 25s 35ms/step - loss: 0.2903 - accuracy: 0.8923 - val_loss: 0.3083 - val_accuracy: 0.8772
# Epoch 6/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2752 - accuracy: 0.8988 - val_loss: 0.3095 - val_accuracy: 0.8746
# Epoch 7/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2621 - accuracy: 0.9044 - val_loss: 0.3123 - val_accuracy: 0.8724
# Epoch 8/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2496 - accuracy: 0.9095 - val_loss: 0.3164 - val_accuracy: 0.8710
# Epoch 9/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.2431 - accuracy: 0.9131 - val_loss: 0.3223 - val_accuracy: 0.8708
# Epoch 10/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2375 - accuracy: 0.9164 - val_loss: 0.3285 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.32851630449295044
#
# 156/156 [==============================] - 2s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8557    0.8493    0.8525      2269
#            1     0.8749    0.8803    0.8776      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8653    0.8648    0.8650      4985
# weighted avg     0.8661    0.8662    0.8662      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_BERITA_TOP5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8644734202607823
# Average Precision : 0.8776514680352292
# Average Recall : 0.8729749631811486
# Average F1 Score : 0.8645046661055277
