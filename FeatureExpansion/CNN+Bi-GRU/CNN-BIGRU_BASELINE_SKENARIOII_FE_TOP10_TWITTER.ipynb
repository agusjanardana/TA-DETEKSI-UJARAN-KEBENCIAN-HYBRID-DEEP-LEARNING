# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data():
  dataset = pd.read_csv('../../../data/data_preprocessed/hasil_ekspansi/twitter/DatasetHatespeech_UnigramBigramTrigram_Top10_ExpandedTwitter.csv')
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label final'] = dataset['label final'].apply(lambda x: 1 if x == 'HS' else 0)

  # to_pd
  y_final = dataset['label final']
  x_final = dataset.drop('label final', axis=1)

  # split
  print("proses splitting....")
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=0.1, random_state=0)
  print("done splitting")
  
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_data()
# Out:
# proses splitting....
# done splitting

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(X_train, X_test, y_train, y_test):
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call(X_train, X_test, y_train, y_test))
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            960032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 29ms/step - loss: 0.6857 - accuracy: 0.5681 - val_loss: 0.6680 - val_accuracy: 0.6574
# Epoch 2/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.6173 - accuracy: 0.7669 - val_loss: 0.5532 - val_accuracy: 0.8355
# Epoch 3/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.4856 - accuracy: 0.8533 - val_loss: 0.4259 - val_accuracy: 0.8638
# Epoch 4/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3865 - accuracy: 0.8694 - val_loss: 0.3578 - val_accuracy: 0.8692
# Epoch 5/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3360 - accuracy: 0.8776 - val_loss: 0.3300 - val_accuracy: 0.8714
# Epoch 6/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.3095 - accuracy: 0.8862 - val_loss: 0.3174 - val_accuracy: 0.8742
# Epoch 7/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2931 - accuracy: 0.8895 - val_loss: 0.3115 - val_accuracy: 0.8734
# Epoch 8/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.2814 - accuracy: 0.8957 - val_loss: 0.3100 - val_accuracy: 0.8734
# Epoch 9/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2709 - accuracy: 0.8994 - val_loss: 0.3101 - val_accuracy: 0.8732
# Epoch 10/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.2621 - accuracy: 0.9024 - val_loss: 0.3118 - val_accuracy: 0.8740
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.3117561340332031
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8681    0.8528    0.8604      2269
#            1     0.8788    0.8918    0.8852      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8735    0.8723    0.8728      4985
# weighted avg     0.8739    0.8740    0.8739      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 26s 31ms/step - loss: 0.6875 - accuracy: 0.5788 - val_loss: 0.6735 - val_accuracy: 0.6887
# Epoch 2/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.6306 - accuracy: 0.7818 - val_loss: 0.5738 - val_accuracy: 0.8335
# Epoch 3/10
# 701/701 [==============================] - 19s 27ms/step - loss: 0.5013 - accuracy: 0.8523 - val_loss: 0.4370 - val_accuracy: 0.8630
# Epoch 4/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3922 - accuracy: 0.8682 - val_loss: 0.3603 - val_accuracy: 0.8684
# Epoch 5/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3375 - accuracy: 0.8789 - val_loss: 0.3291 - val_accuracy: 0.8720
# Epoch 6/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.3084 - accuracy: 0.8857 - val_loss: 0.3162 - val_accuracy: 0.8744
# Epoch 7/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.2912 - accuracy: 0.8896 - val_loss: 0.3112 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.2785 - accuracy: 0.8965 - val_loss: 0.3095 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2689 - accuracy: 0.8997 - val_loss: 0.3101 - val_accuracy: 0.8740
# Epoch 10/10
# 701/701 [==============================] - 19s 28ms/step - loss: 0.2595 - accuracy: 0.9038 - val_loss: 0.3115 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.31145450472831726
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8648    0.8541    0.8594      2269
#            1     0.8794    0.8884    0.8839      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8721    0.8713    0.8717      4985
# weighted avg     0.8727    0.8728    0.8727      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 27s 30ms/step - loss: 0.6894 - accuracy: 0.5798 - val_loss: 0.6792 - val_accuracy: 0.7021
# Epoch 2/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.6432 - accuracy: 0.8008 - val_loss: 0.5917 - val_accuracy: 0.8554
# Epoch 3/10
# 701/701 [==============================] - 20s 28ms/step - loss: 0.5209 - accuracy: 0.8532 - val_loss: 0.4563 - val_accuracy: 0.8614
# Epoch 4/10
# 701/701 [==============================] - 20s 29ms/step - loss: 0.4091 - accuracy: 0.8648 - val_loss: 0.3727 - val_accuracy: 0.8642
# Epoch 5/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.3478 - accuracy: 0.8751 - val_loss: 0.3359 - val_accuracy: 0.8676
# Epoch 6/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3184 - accuracy: 0.8823 - val_loss: 0.3201 - val_accuracy: 0.8730
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2984 - accuracy: 0.8899 - val_loss: 0.3129 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2844 - accuracy: 0.8949 - val_loss: 0.3098 - val_accuracy: 0.8732
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2717 - accuracy: 0.8994 - val_loss: 0.3094 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.2645 - accuracy: 0.9018 - val_loss: 0.3106 - val_accuracy: 0.8748
#
# Validation Accuracy: 0.8748244643211365
# Validation Loss: 0.3105842173099518
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8713    0.8506    0.8608      2269
#            1     0.8776    0.8951    0.8863      2716
#
#     accuracy                         0.8748      4985
#    macro avg     0.8745    0.8728    0.8735      4985
# weighted avg     0.8748    0.8748    0.8747      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 26s 31ms/step - loss: 0.6872 - accuracy: 0.6153 - val_loss: 0.6713 - val_accuracy: 0.7753
# Epoch 2/10
# 701/701 [==============================] - 21s 29ms/step - loss: 0.6254 - accuracy: 0.8217 - val_loss: 0.5656 - val_accuracy: 0.8576
# Epoch 3/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.4959 - accuracy: 0.8564 - val_loss: 0.4319 - val_accuracy: 0.8656
# Epoch 4/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3920 - accuracy: 0.8676 - val_loss: 0.3583 - val_accuracy: 0.8678
# Epoch 5/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.3404 - accuracy: 0.8766 - val_loss: 0.3282 - val_accuracy: 0.8734
# Epoch 6/10
# 701/701 [==============================] - 24s 34ms/step - loss: 0.3118 - accuracy: 0.8852 - val_loss: 0.3152 - val_accuracy: 0.8758
# Epoch 7/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2946 - accuracy: 0.8910 - val_loss: 0.3095 - val_accuracy: 0.8750
# Epoch 8/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.2810 - accuracy: 0.8952 - val_loss: 0.3080 - val_accuracy: 0.8744
# Epoch 9/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2717 - accuracy: 0.9003 - val_loss: 0.3076 - val_accuracy: 0.8764
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2632 - accuracy: 0.9022 - val_loss: 0.3092 - val_accuracy: 0.8756
#
# Validation Accuracy: 0.8756268620491028
# Validation Loss: 0.3092109262943268
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8760    0.8466    0.8610      2269
#            1     0.8754    0.8999    0.8874      2716
#
#     accuracy                         0.8756      4985
#    macro avg     0.8757    0.8732    0.8742      4985
# weighted avg     0.8756    0.8756    0.8754      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            960032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 28s 33ms/step - loss: 0.6890 - accuracy: 0.6073 - val_loss: 0.6775 - val_accuracy: 0.7569
# Epoch 2/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.6389 - accuracy: 0.8273 - val_loss: 0.5873 - val_accuracy: 0.8592
# Epoch 3/10
# 701/701 [==============================] - 21s 31ms/step - loss: 0.5172 - accuracy: 0.8559 - val_loss: 0.4537 - val_accuracy: 0.8642
# Epoch 4/10
# 701/701 [==============================] - 22s 31ms/step - loss: 0.4055 - accuracy: 0.8691 - val_loss: 0.3722 - val_accuracy: 0.8682
# Epoch 5/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.3461 - accuracy: 0.8785 - val_loss: 0.3361 - val_accuracy: 0.8706
# Epoch 6/10
# 701/701 [==============================] - 23s 32ms/step - loss: 0.3145 - accuracy: 0.8844 - val_loss: 0.3204 - val_accuracy: 0.8738
# Epoch 7/10
# 701/701 [==============================] - 24s 35ms/step - loss: 0.2952 - accuracy: 0.8913 - val_loss: 0.3135 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 23s 33ms/step - loss: 0.2807 - accuracy: 0.8947 - val_loss: 0.3109 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 22s 32ms/step - loss: 0.2718 - accuracy: 0.8990 - val_loss: 0.3106 - val_accuracy: 0.8732
# Epoch 10/10
# 701/701 [==============================] - 21s 30ms/step - loss: 0.2617 - accuracy: 0.9031 - val_loss: 0.3120 - val_accuracy: 0.8742
#
# Validation Accuracy: 0.8742226958274841
# Validation Loss: 0.31200212240219116
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8712    0.8493    0.8601      2269
#            1     0.8767    0.8951    0.8858      2716
#
#     accuracy                         0.8742      4985
#    macro avg     0.8739    0.8722    0.8729      4985
# weighted avg     0.8742    0.8742    0.8741      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP10-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5_FE_TWITTER_TOP10.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8743029087261786
# Average Precision : 0.8775652821323325
# Average Recall : 0.8940353460972018
# Average F1 Score : 0.8741720848474215
