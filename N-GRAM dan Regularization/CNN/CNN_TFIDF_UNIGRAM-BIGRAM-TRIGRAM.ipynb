# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM-TRIGRAM MODEL
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 19s 21ms/step - loss: 0.5919 - accuracy: 0.7439 - val_loss: 0.4957 - val_accuracy: 0.8461
# Epoch 2/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.4320 - accuracy: 0.8522 - val_loss: 0.3920 - val_accuracy: 0.8580
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3601 - accuracy: 0.8639 - val_loss: 0.3503 - val_accuracy: 0.8616
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3268 - accuracy: 0.8720 - val_loss: 0.3311 - val_accuracy: 0.8678
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3076 - accuracy: 0.8791 - val_loss: 0.3222 - val_accuracy: 0.8696
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2954 - accuracy: 0.8829 - val_loss: 0.3165 - val_accuracy: 0.8724
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2860 - accuracy: 0.8861 - val_loss: 0.3146 - val_accuracy: 0.8714
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2788 - accuracy: 0.8885 - val_loss: 0.3145 - val_accuracy: 0.8720
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2727 - accuracy: 0.8907 - val_loss: 0.3140 - val_accuracy: 0.8732
# Epoch 10/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2676 - accuracy: 0.8927 - val_loss: 0.3177 - val_accuracy: 0.8690
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8690069913864136
# Validation Loss: 0.31765255331993103
#
# 156/156 [==============================] - 2s 9ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8389    0.8814    0.8597      2269
#            1     0.8966    0.8586    0.8772      2716
#
#     accuracy                         0.8690      4985
#    macro avg     0.8678    0.8700    0.8684      4985
# weighted avg     0.8703    0.8690    0.8692      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 19s 23ms/step - loss: 0.5928 - accuracy: 0.7415 - val_loss: 0.4952 - val_accuracy: 0.8445
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4298 - accuracy: 0.8507 - val_loss: 0.3894 - val_accuracy: 0.8544
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3584 - accuracy: 0.8631 - val_loss: 0.3531 - val_accuracy: 0.8596
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3265 - accuracy: 0.8708 - val_loss: 0.3359 - val_accuracy: 0.8630
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3087 - accuracy: 0.8771 - val_loss: 0.3267 - val_accuracy: 0.8662
# Epoch 6/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.2973 - accuracy: 0.8805 - val_loss: 0.3189 - val_accuracy: 0.8710
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2890 - accuracy: 0.8843 - val_loss: 0.3177 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2821 - accuracy: 0.8872 - val_loss: 0.3172 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2767 - accuracy: 0.8890 - val_loss: 0.3164 - val_accuracy: 0.8702
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2721 - accuracy: 0.8911 - val_loss: 0.3171 - val_accuracy: 0.8698
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8698094487190247
# Validation Loss: 0.3170503079891205
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8565    0.8576    0.8571      2269
#            1     0.8809    0.8800    0.8805      2716
#
#     accuracy                         0.8698      4985
#    macro avg     0.8687    0.8688    0.8688      4985
# weighted avg     0.8698    0.8698    0.8698      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 22ms/step - loss: 0.5850 - accuracy: 0.7557 - val_loss: 0.4860 - val_accuracy: 0.8465
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4243 - accuracy: 0.8528 - val_loss: 0.3885 - val_accuracy: 0.8548
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3560 - accuracy: 0.8645 - val_loss: 0.3479 - val_accuracy: 0.8616
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3245 - accuracy: 0.8725 - val_loss: 0.3297 - val_accuracy: 0.8666
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3068 - accuracy: 0.8784 - val_loss: 0.3213 - val_accuracy: 0.8696
# Epoch 6/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.2951 - accuracy: 0.8824 - val_loss: 0.3180 - val_accuracy: 0.8730
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2860 - accuracy: 0.8853 - val_loss: 0.3151 - val_accuracy: 0.8734
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2789 - accuracy: 0.8882 - val_loss: 0.3144 - val_accuracy: 0.8726
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2732 - accuracy: 0.8900 - val_loss: 0.3146 - val_accuracy: 0.8706
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2676 - accuracy: 0.8920 - val_loss: 0.3151 - val_accuracy: 0.8704
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.870411217212677
# Validation Loss: 0.31507980823516846
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8654    0.8471    0.8561      2269
#            1     0.8745    0.8899    0.8821      2716
#
#     accuracy                         0.8704      4985
#    macro avg     0.8699    0.8685    0.8691      4985
# weighted avg     0.8703    0.8704    0.8703      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 22ms/step - loss: 0.5787 - accuracy: 0.7606 - val_loss: 0.4779 - val_accuracy: 0.8471
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4173 - accuracy: 0.8551 - val_loss: 0.3827 - val_accuracy: 0.8566
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3506 - accuracy: 0.8667 - val_loss: 0.3433 - val_accuracy: 0.8650
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3196 - accuracy: 0.8749 - val_loss: 0.3262 - val_accuracy: 0.8682
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3017 - accuracy: 0.8812 - val_loss: 0.3192 - val_accuracy: 0.8706
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2905 - accuracy: 0.8843 - val_loss: 0.3150 - val_accuracy: 0.8722
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2811 - accuracy: 0.8880 - val_loss: 0.3139 - val_accuracy: 0.8716
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2743 - accuracy: 0.8907 - val_loss: 0.3155 - val_accuracy: 0.8704
# Epoch 9/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.2687 - accuracy: 0.8925 - val_loss: 0.3149 - val_accuracy: 0.8716
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2631 - accuracy: 0.8945 - val_loss: 0.3151 - val_accuracy: 0.8710
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.3150613009929657
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8646    0.8497    0.8571      2269
#            1     0.8762    0.8888    0.8825      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8704    0.8693    0.8698      4985
# weighted avg     0.8709    0.8710    0.8709      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 22ms/step - loss: 0.5814 - accuracy: 0.7535 - val_loss: 0.4834 - val_accuracy: 0.8423
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4188 - accuracy: 0.8541 - val_loss: 0.3815 - val_accuracy: 0.8582
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3519 - accuracy: 0.8657 - val_loss: 0.3442 - val_accuracy: 0.8628
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3211 - accuracy: 0.8730 - val_loss: 0.3280 - val_accuracy: 0.8682
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3036 - accuracy: 0.8797 - val_loss: 0.3193 - val_accuracy: 0.8706
# Epoch 6/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2921 - accuracy: 0.8836 - val_loss: 0.3159 - val_accuracy: 0.8726
# Epoch 7/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2836 - accuracy: 0.8867 - val_loss: 0.3143 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2767 - accuracy: 0.8886 - val_loss: 0.3164 - val_accuracy: 0.8742
# Epoch 9/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2708 - accuracy: 0.8913 - val_loss: 0.3165 - val_accuracy: 0.8720
# Epoch 10/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2655 - accuracy: 0.8943 - val_loss: 0.3162 - val_accuracy: 0.8710
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.3162229061126709
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8709    0.8413    0.8559      2269
#            1     0.8711    0.8958    0.8833      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8710    0.8686    0.8696      4985
# weighted avg     0.8710    0.8710    0.8708      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM {idx + 1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8702507522567704
# Average Precision : 0.8798621069793944
# Average Recall : 0.8826215022091312
# Average F1 Score : 0.8811026183695082
