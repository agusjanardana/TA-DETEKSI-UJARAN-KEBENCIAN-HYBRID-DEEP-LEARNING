# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM MODEL
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 18s 21ms/step - loss: 0.6150 - accuracy: 0.7099 - val_loss: 0.5301 - val_accuracy: 0.8319
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4596 - accuracy: 0.8490 - val_loss: 0.4117 - val_accuracy: 0.8548
# Epoch 3/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3759 - accuracy: 0.8616 - val_loss: 0.3619 - val_accuracy: 0.8624
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3376 - accuracy: 0.8690 - val_loss: 0.3382 - val_accuracy: 0.8658
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3165 - accuracy: 0.8752 - val_loss: 0.3267 - val_accuracy: 0.8676
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3033 - accuracy: 0.8795 - val_loss: 0.3218 - val_accuracy: 0.8706
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2937 - accuracy: 0.8835 - val_loss: 0.3187 - val_accuracy: 0.8718
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2864 - accuracy: 0.8863 - val_loss: 0.3181 - val_accuracy: 0.8714
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2805 - accuracy: 0.8884 - val_loss: 0.3173 - val_accuracy: 0.8706
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2746 - accuracy: 0.8907 - val_loss: 0.3215 - val_accuracy: 0.8694
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8694082498550415
# Validation Loss: 0.3214792311191559
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8823    0.8228    0.8515      2269
#            1     0.8599    0.9083    0.8834      2716
#
#     accuracy                         0.8694      4985
#    macro avg     0.8711    0.8656    0.8675      4985
# weighted avg     0.8701    0.8694    0.8689      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 15s 20ms/step - loss: 0.5961 - accuracy: 0.7423 - val_loss: 0.5017 - val_accuracy: 0.8449
# Epoch 2/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.4351 - accuracy: 0.8541 - val_loss: 0.4003 - val_accuracy: 0.8441
# Epoch 3/10
# 701/701 [==============================] - 13s 19ms/step - loss: 0.3598 - accuracy: 0.8659 - val_loss: 0.3497 - val_accuracy: 0.8664
# Epoch 4/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3242 - accuracy: 0.8743 - val_loss: 0.3293 - val_accuracy: 0.8706
# Epoch 5/10
# 701/701 [==============================] - 13s 19ms/step - loss: 0.3041 - accuracy: 0.8807 - val_loss: 0.3197 - val_accuracy: 0.8692
# Epoch 6/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2910 - accuracy: 0.8851 - val_loss: 0.3153 - val_accuracy: 0.8728
# Epoch 7/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2812 - accuracy: 0.8884 - val_loss: 0.3139 - val_accuracy: 0.8726
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2734 - accuracy: 0.8913 - val_loss: 0.3138 - val_accuracy: 0.8732
# Epoch 9/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2668 - accuracy: 0.8938 - val_loss: 0.3155 - val_accuracy: 0.8720
# Epoch 10/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2609 - accuracy: 0.8965 - val_loss: 0.3149 - val_accuracy: 0.8736
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.31487131118774414
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8713    0.8475    0.8592      2269
#            1     0.8754    0.8954    0.8853      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8734    0.8715    0.8723      4985
# weighted avg     0.8736    0.8736    0.8735      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 20ms/step - loss: 0.6083 - accuracy: 0.7300 - val_loss: 0.5257 - val_accuracy: 0.7840
# Epoch 2/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.4544 - accuracy: 0.8488 - val_loss: 0.4096 - val_accuracy: 0.8552
# Epoch 3/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3744 - accuracy: 0.8637 - val_loss: 0.3617 - val_accuracy: 0.8614
# Epoch 4/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3367 - accuracy: 0.8700 - val_loss: 0.3375 - val_accuracy: 0.8684
# Epoch 5/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3151 - accuracy: 0.8760 - val_loss: 0.3258 - val_accuracy: 0.8690
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3013 - accuracy: 0.8805 - val_loss: 0.3236 - val_accuracy: 0.8690
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2911 - accuracy: 0.8850 - val_loss: 0.3166 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2833 - accuracy: 0.8874 - val_loss: 0.3158 - val_accuracy: 0.8736
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2770 - accuracy: 0.8903 - val_loss: 0.3167 - val_accuracy: 0.8712
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2711 - accuracy: 0.8921 - val_loss: 0.3181 - val_accuracy: 0.8718
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.31813082098960876
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8784    0.8338    0.8555      2269
#            1     0.8668    0.9035    0.8848      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8726    0.8687    0.8702      4985
# weighted avg     0.8721    0.8718    0.8715      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6115 - accuracy: 0.7250 - val_loss: 0.5243 - val_accuracy: 0.8477
# Epoch 2/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.4542 - accuracy: 0.8504 - val_loss: 0.4096 - val_accuracy: 0.8495
# Epoch 3/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3711 - accuracy: 0.8626 - val_loss: 0.3586 - val_accuracy: 0.8616
# Epoch 4/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3333 - accuracy: 0.8709 - val_loss: 0.3343 - val_accuracy: 0.8700
# Epoch 5/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3126 - accuracy: 0.8766 - val_loss: 0.3240 - val_accuracy: 0.8702
# Epoch 6/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2992 - accuracy: 0.8821 - val_loss: 0.3195 - val_accuracy: 0.8704
# Epoch 7/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2901 - accuracy: 0.8837 - val_loss: 0.3164 - val_accuracy: 0.8730
# Epoch 8/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2825 - accuracy: 0.8871 - val_loss: 0.3161 - val_accuracy: 0.8720
# Epoch 9/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2766 - accuracy: 0.8900 - val_loss: 0.3186 - val_accuracy: 0.8716
# Epoch 10/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2713 - accuracy: 0.8917 - val_loss: 0.3169 - val_accuracy: 0.8726
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.31691974401474
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8700    0.8466    0.8582      2269
#            1     0.8747    0.8943    0.8844      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8724    0.8705    0.8713      4985
# weighted avg     0.8726    0.8726    0.8725      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 15s 20ms/step - loss: 0.5990 - accuracy: 0.7354 - val_loss: 0.5147 - val_accuracy: 0.8311
# Epoch 2/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.4406 - accuracy: 0.8517 - val_loss: 0.3975 - val_accuracy: 0.8574
# Epoch 3/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3643 - accuracy: 0.8650 - val_loss: 0.3527 - val_accuracy: 0.8636
# Epoch 4/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3289 - accuracy: 0.8728 - val_loss: 0.3341 - val_accuracy: 0.8674
# Epoch 5/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3087 - accuracy: 0.8788 - val_loss: 0.3221 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2961 - accuracy: 0.8829 - val_loss: 0.3219 - val_accuracy: 0.8694
# Epoch 7/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2867 - accuracy: 0.8864 - val_loss: 0.3157 - val_accuracy: 0.8712
# Epoch 8/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2790 - accuracy: 0.8888 - val_loss: 0.3170 - val_accuracy: 0.8728
# Epoch 9/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2728 - accuracy: 0.8916 - val_loss: 0.3152 - val_accuracy: 0.8726
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2671 - accuracy: 0.8943 - val_loss: 0.3165 - val_accuracy: 0.8728
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.316529780626297
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8677    0.8502    0.8589      2269
#            1     0.8769    0.8918    0.8843      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8723    0.8710    0.8716      4985
# weighted avg     0.8727    0.8728    0.8727      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN Unigram_BiGRAM {idx + 1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8720561685055166
# Average Precision : 0.8707497344824763
# Average Recall : 0.8986745213549338
# Average F1 Score : 0.88444649625261
