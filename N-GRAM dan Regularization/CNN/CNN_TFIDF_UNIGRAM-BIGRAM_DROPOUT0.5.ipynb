# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM DROPOUT0.5 MODEL
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 22s 21ms/step - loss: 0.6241 - accuracy: 0.7039 - val_loss: 0.5463 - val_accuracy: 0.8391
# Epoch 2/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.4900 - accuracy: 0.8226 - val_loss: 0.4299 - val_accuracy: 0.8578
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4073 - accuracy: 0.8456 - val_loss: 0.3743 - val_accuracy: 0.8628
# Epoch 4/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.3655 - accuracy: 0.8577 - val_loss: 0.3472 - val_accuracy: 0.8674
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3419 - accuracy: 0.8683 - val_loss: 0.3319 - val_accuracy: 0.8698
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3245 - accuracy: 0.8736 - val_loss: 0.3223 - val_accuracy: 0.8718
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3107 - accuracy: 0.8783 - val_loss: 0.3156 - val_accuracy: 0.8704
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3016 - accuracy: 0.8807 - val_loss: 0.3129 - val_accuracy: 0.8722
# Epoch 9/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2933 - accuracy: 0.8857 - val_loss: 0.3092 - val_accuracy: 0.8726
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2852 - accuracy: 0.8884 - val_loss: 0.3065 - val_accuracy: 0.8724
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3065033257007599
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8680    0.8488    0.8583      2269
#            1     0.8760    0.8921    0.8840      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8720    0.8705    0.8711      4985
# weighted avg     0.8723    0.8724    0.8723      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6153 - accuracy: 0.7243 - val_loss: 0.5301 - val_accuracy: 0.8502
# Epoch 2/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.4750 - accuracy: 0.8254 - val_loss: 0.4179 - val_accuracy: 0.8566
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3999 - accuracy: 0.8472 - val_loss: 0.3678 - val_accuracy: 0.8594
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3613 - accuracy: 0.8602 - val_loss: 0.3435 - val_accuracy: 0.8658
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3388 - accuracy: 0.8686 - val_loss: 0.3301 - val_accuracy: 0.8682
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3217 - accuracy: 0.8745 - val_loss: 0.3201 - val_accuracy: 0.8692
# Epoch 7/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3103 - accuracy: 0.8780 - val_loss: 0.3158 - val_accuracy: 0.8728
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3003 - accuracy: 0.8832 - val_loss: 0.3117 - val_accuracy: 0.8734
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2910 - accuracy: 0.8858 - val_loss: 0.3084 - val_accuracy: 0.8730
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2840 - accuracy: 0.8898 - val_loss: 0.3067 - val_accuracy: 0.8744
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8744232654571533
# Validation Loss: 0.30672138929367065
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8819    0.8361    0.8584      2269
#            1     0.8687    0.9065    0.8872      2716
#
#     accuracy                         0.8744      4985
#    macro avg     0.8753    0.8713    0.8728      4985
# weighted avg     0.8747    0.8744    0.8741      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6073 - accuracy: 0.7306 - val_loss: 0.5156 - val_accuracy: 0.8495
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4640 - accuracy: 0.8288 - val_loss: 0.4100 - val_accuracy: 0.8582
# Epoch 3/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3924 - accuracy: 0.8496 - val_loss: 0.3599 - val_accuracy: 0.8630
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3564 - accuracy: 0.8616 - val_loss: 0.3360 - val_accuracy: 0.8670
# Epoch 5/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3350 - accuracy: 0.8698 - val_loss: 0.3250 - val_accuracy: 0.8708
# Epoch 6/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3193 - accuracy: 0.8758 - val_loss: 0.3181 - val_accuracy: 0.8708
# Epoch 7/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3070 - accuracy: 0.8800 - val_loss: 0.3130 - val_accuracy: 0.8716
# Epoch 8/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2955 - accuracy: 0.8841 - val_loss: 0.3095 - val_accuracy: 0.8732
# Epoch 9/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2864 - accuracy: 0.8883 - val_loss: 0.3070 - val_accuracy: 0.8748
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2795 - accuracy: 0.8898 - val_loss: 0.3050 - val_accuracy: 0.8738
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8738214373588562
# Validation Loss: 0.30501651763916016
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8704    0.8493    0.8597      2269
#            1     0.8766    0.8943    0.8854      2716
#
#     accuracy                         0.8738      4985
#    macro avg     0.8735    0.8718    0.8725      4985
# weighted avg     0.8738    0.8738    0.8737      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 20ms/step - loss: 0.6098 - accuracy: 0.7274 - val_loss: 0.5219 - val_accuracy: 0.8477
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4679 - accuracy: 0.8329 - val_loss: 0.4123 - val_accuracy: 0.8584
# Epoch 3/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3922 - accuracy: 0.8506 - val_loss: 0.3622 - val_accuracy: 0.8642
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3533 - accuracy: 0.8640 - val_loss: 0.3384 - val_accuracy: 0.8664
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3319 - accuracy: 0.8695 - val_loss: 0.3252 - val_accuracy: 0.8702
# Epoch 6/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3150 - accuracy: 0.8762 - val_loss: 0.3182 - val_accuracy: 0.8710
# Epoch 7/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3042 - accuracy: 0.8811 - val_loss: 0.3121 - val_accuracy: 0.8732
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2928 - accuracy: 0.8859 - val_loss: 0.3083 - val_accuracy: 0.8736
# Epoch 9/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2831 - accuracy: 0.8889 - val_loss: 0.3066 - val_accuracy: 0.8752
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2752 - accuracy: 0.8909 - val_loss: 0.3048 - val_accuracy: 0.8742
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8742226958274841
# Validation Loss: 0.3047665059566498
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8728    0.8471    0.8598      2269
#            1     0.8753    0.8969    0.8860      2716
#
#     accuracy                         0.8742      4985
#    macro avg     0.8741    0.8720    0.8729      4985
# weighted avg     0.8742    0.8742    0.8740      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 18s 23ms/step - loss: 0.6045 - accuracy: 0.7309 - val_loss: 0.5134 - val_accuracy: 0.8508
# Epoch 2/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.4614 - accuracy: 0.8306 - val_loss: 0.4107 - val_accuracy: 0.8598
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3910 - accuracy: 0.8509 - val_loss: 0.3605 - val_accuracy: 0.8648
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3540 - accuracy: 0.8615 - val_loss: 0.3388 - val_accuracy: 0.8674
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3305 - accuracy: 0.8718 - val_loss: 0.3243 - val_accuracy: 0.8718
# Epoch 6/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3156 - accuracy: 0.8760 - val_loss: 0.3208 - val_accuracy: 0.8710
# Epoch 7/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3038 - accuracy: 0.8818 - val_loss: 0.3132 - val_accuracy: 0.8734
# Epoch 8/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2938 - accuracy: 0.8863 - val_loss: 0.3093 - val_accuracy: 0.8726
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2850 - accuracy: 0.8886 - val_loss: 0.3063 - val_accuracy: 0.8732
# Epoch 10/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2763 - accuracy: 0.8906 - val_loss: 0.3046 - val_accuracy: 0.8734
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873420238494873
# Validation Loss: 0.30461785197257996
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8686    0.8506    0.8595      2269
#            1     0.8773    0.8925    0.8848      2716
#
#     accuracy                         0.8734      4985
#    macro avg     0.8729    0.8715    0.8722      4985
# weighted avg     0.8733    0.8734    0.8733      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM Dropout 0.5 {idx + 1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8736609829488465
# Average Precision : 0.8747863038610918
# Average Recall : 0.8964653902798233
# Average F1 Score : 0.8854737663001842
