# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM MODEL
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 20s 21ms/step - loss: 0.5991 - accuracy: 0.7365 - val_loss: 0.5087 - val_accuracy: 0.8487
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4447 - accuracy: 0.8512 - val_loss: 0.4039 - val_accuracy: 0.8546
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3705 - accuracy: 0.8636 - val_loss: 0.3600 - val_accuracy: 0.8642
# Epoch 4/10
# 701/701 [==============================] - 13s 19ms/step - loss: 0.3352 - accuracy: 0.8713 - val_loss: 0.3382 - val_accuracy: 0.8664
# Epoch 5/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3146 - accuracy: 0.8782 - val_loss: 0.3274 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3015 - accuracy: 0.8821 - val_loss: 0.3224 - val_accuracy: 0.8674
# Epoch 7/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.2923 - accuracy: 0.8849 - val_loss: 0.3198 - val_accuracy: 0.8668
# Epoch 8/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.2849 - accuracy: 0.8887 - val_loss: 0.3196 - val_accuracy: 0.8670
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2785 - accuracy: 0.8919 - val_loss: 0.3197 - val_accuracy: 0.8694
# Epoch 10/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.2735 - accuracy: 0.8937 - val_loss: 0.3209 - val_accuracy: 0.8682
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8682045936584473
# Validation Loss: 0.32087814807891846
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8570    0.8528    0.8549      2269
#            1     0.8775    0.8811    0.8793      2716
#
#     accuracy                         0.8682      4985
#    macro avg     0.8672    0.8669    0.8671      4985
# weighted avg     0.8682    0.8682    0.8682      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 21s 23ms/step - loss: 0.6017 - accuracy: 0.7327 - val_loss: 0.5099 - val_accuracy: 0.8467
# Epoch 2/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.4455 - accuracy: 0.8500 - val_loss: 0.4072 - val_accuracy: 0.8546
# Epoch 3/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3701 - accuracy: 0.8633 - val_loss: 0.3596 - val_accuracy: 0.8574
# Epoch 4/10
# 701/701 [==============================] - 16s 22ms/step - loss: 0.3337 - accuracy: 0.8716 - val_loss: 0.3379 - val_accuracy: 0.8660
# Epoch 5/10
# 701/701 [==============================] - 16s 24ms/step - loss: 0.3133 - accuracy: 0.8778 - val_loss: 0.3261 - val_accuracy: 0.8662
# Epoch 6/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.2995 - accuracy: 0.8818 - val_loss: 0.3205 - val_accuracy: 0.8678
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2889 - accuracy: 0.8859 - val_loss: 0.3172 - val_accuracy: 0.8684
# Epoch 8/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.2806 - accuracy: 0.8889 - val_loss: 0.3154 - val_accuracy: 0.8698
# Epoch 9/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2728 - accuracy: 0.8917 - val_loss: 0.3122 - val_accuracy: 0.8716
# Epoch 10/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.2654 - accuracy: 0.8960 - val_loss: 0.3118 - val_accuracy: 0.8712
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.31177109479904175
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8659    0.8484    0.8571      2269
#            1     0.8755    0.8903    0.8828      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8707    0.8693    0.8699      4985
# weighted avg     0.8711    0.8712    0.8711      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 22ms/step - loss: 0.5916 - accuracy: 0.7405 - val_loss: 0.4962 - val_accuracy: 0.8425
# Epoch 2/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.4333 - accuracy: 0.8526 - val_loss: 0.3949 - val_accuracy: 0.8552
# Epoch 3/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3625 - accuracy: 0.8651 - val_loss: 0.3535 - val_accuracy: 0.8646
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3301 - accuracy: 0.8721 - val_loss: 0.3361 - val_accuracy: 0.8664
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3111 - accuracy: 0.8777 - val_loss: 0.3262 - val_accuracy: 0.8660
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2993 - accuracy: 0.8828 - val_loss: 0.3235 - val_accuracy: 0.8680
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2901 - accuracy: 0.8859 - val_loss: 0.3197 - val_accuracy: 0.8668
# Epoch 8/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2821 - accuracy: 0.8896 - val_loss: 0.3211 - val_accuracy: 0.8688
# Epoch 9/10
# 701/701 [==============================] - 16s 22ms/step - loss: 0.2753 - accuracy: 0.8918 - val_loss: 0.3181 - val_accuracy: 0.8708
# Epoch 10/10
# 701/701 [==============================] - 16s 22ms/step - loss: 0.2684 - accuracy: 0.8942 - val_loss: 0.3156 - val_accuracy: 0.8702
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8702106475830078
# Validation Loss: 0.3155696392059326
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8640    0.8484    0.8561      2269
#            1     0.8752    0.8884    0.8818      2716
#
#     accuracy                         0.8702      4985
#    macro avg     0.8696    0.8684    0.8690      4985
# weighted avg     0.8701    0.8702    0.8701      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 22ms/step - loss: 0.5974 - accuracy: 0.7377 - val_loss: 0.5036 - val_accuracy: 0.8461
# Epoch 2/10
# 701/701 [==============================] - 16s 22ms/step - loss: 0.4397 - accuracy: 0.8527 - val_loss: 0.4038 - val_accuracy: 0.8512
# Epoch 3/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3668 - accuracy: 0.8635 - val_loss: 0.3565 - val_accuracy: 0.8646
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3329 - accuracy: 0.8711 - val_loss: 0.3364 - val_accuracy: 0.8674
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3134 - accuracy: 0.8781 - val_loss: 0.3270 - val_accuracy: 0.8664
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3004 - accuracy: 0.8824 - val_loss: 0.3220 - val_accuracy: 0.8674
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2915 - accuracy: 0.8857 - val_loss: 0.3212 - val_accuracy: 0.8686
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2843 - accuracy: 0.8893 - val_loss: 0.3214 - val_accuracy: 0.8666
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2787 - accuracy: 0.8911 - val_loss: 0.3222 - val_accuracy: 0.8674
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2735 - accuracy: 0.8939 - val_loss: 0.3231 - val_accuracy: 0.8686
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8686057925224304
# Validation Loss: 0.3230897784233093
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8682    0.8387    0.8532      2269
#            1     0.8690    0.8936    0.8811      2716
#
#     accuracy                         0.8686      4985
#    macro avg     0.8686    0.8661    0.8671      4985
# weighted avg     0.8686    0.8686    0.8684      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6036 - accuracy: 0.7396 - val_loss: 0.5142 - val_accuracy: 0.8437
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4501 - accuracy: 0.8510 - val_loss: 0.4120 - val_accuracy: 0.8524
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3742 - accuracy: 0.8619 - val_loss: 0.3626 - val_accuracy: 0.8632
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3368 - accuracy: 0.8704 - val_loss: 0.3393 - val_accuracy: 0.8666
# Epoch 5/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3156 - accuracy: 0.8771 - val_loss: 0.3285 - val_accuracy: 0.8678
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3014 - accuracy: 0.8811 - val_loss: 0.3219 - val_accuracy: 0.8686
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2911 - accuracy: 0.8851 - val_loss: 0.3196 - val_accuracy: 0.8666
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2827 - accuracy: 0.8886 - val_loss: 0.3169 - val_accuracy: 0.8672
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2753 - accuracy: 0.8909 - val_loss: 0.3170 - val_accuracy: 0.8714
# Epoch 10/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2686 - accuracy: 0.8936 - val_loss: 0.3136 - val_accuracy: 0.8714
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.31357741355895996
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8717    0.8413    0.8562      2269
#            1     0.8712    0.8965    0.8837      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8714    0.8689    0.8700      4985
# weighted avg     0.8714    0.8714    0.8712      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN Unigram {idx + 1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8699297893681044
# Average Precision : 0.8736714060318412
# Average Recall : 0.8899852724594993
# Average F1 Score : 0.8817345138547408
