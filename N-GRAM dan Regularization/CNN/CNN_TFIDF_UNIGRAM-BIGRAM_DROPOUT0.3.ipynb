# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM DROPOUT0.3 MODEL
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 21s 22ms/step - loss: 0.6057 - accuracy: 0.7258 - val_loss: 0.5143 - val_accuracy: 0.8317
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4528 - accuracy: 0.8387 - val_loss: 0.4031 - val_accuracy: 0.8570
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3784 - accuracy: 0.8563 - val_loss: 0.3566 - val_accuracy: 0.8642
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3429 - accuracy: 0.8646 - val_loss: 0.3346 - val_accuracy: 0.8650
# Epoch 5/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3206 - accuracy: 0.8738 - val_loss: 0.3237 - val_accuracy: 0.8694
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3068 - accuracy: 0.8784 - val_loss: 0.3189 - val_accuracy: 0.8698
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2968 - accuracy: 0.8826 - val_loss: 0.3138 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2861 - accuracy: 0.8860 - val_loss: 0.3108 - val_accuracy: 0.8726
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2790 - accuracy: 0.8899 - val_loss: 0.3093 - val_accuracy: 0.8736
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2701 - accuracy: 0.8929 - val_loss: 0.3071 - val_accuracy: 0.8724
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.30714860558509827
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8757    0.8387    0.8568      2269
#            1     0.8698    0.9006    0.8849      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8728    0.8696    0.8709      4985
# weighted avg     0.8725    0.8724    0.8721      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 21ms/step - loss: 0.6137 - accuracy: 0.7236 - val_loss: 0.5283 - val_accuracy: 0.8373
# Epoch 2/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.4685 - accuracy: 0.8336 - val_loss: 0.4172 - val_accuracy: 0.8552
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3898 - accuracy: 0.8525 - val_loss: 0.3700 - val_accuracy: 0.8604
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3504 - accuracy: 0.8631 - val_loss: 0.3409 - val_accuracy: 0.8668
# Epoch 5/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3277 - accuracy: 0.8711 - val_loss: 0.3276 - val_accuracy: 0.8684
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3125 - accuracy: 0.8759 - val_loss: 0.3199 - val_accuracy: 0.8704
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2996 - accuracy: 0.8813 - val_loss: 0.3152 - val_accuracy: 0.8716
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2904 - accuracy: 0.8849 - val_loss: 0.3128 - val_accuracy: 0.8726
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2831 - accuracy: 0.8873 - val_loss: 0.3099 - val_accuracy: 0.8750
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2754 - accuracy: 0.8899 - val_loss: 0.3079 - val_accuracy: 0.8746
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8746238946914673
# Validation Loss: 0.30791786313056946
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8716    0.8497    0.8605      2269
#            1     0.8770    0.8954    0.8861      2716
#
#     accuracy                         0.8746      4985
#    macro avg     0.8743    0.8726    0.8733      4985
# weighted avg     0.8746    0.8746    0.8745      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6094 - accuracy: 0.7238 - val_loss: 0.5214 - val_accuracy: 0.8469
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4615 - accuracy: 0.8381 - val_loss: 0.4127 - val_accuracy: 0.8514
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3839 - accuracy: 0.8548 - val_loss: 0.3606 - val_accuracy: 0.8630
# Epoch 4/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.3460 - accuracy: 0.8660 - val_loss: 0.3370 - val_accuracy: 0.8682
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3243 - accuracy: 0.8725 - val_loss: 0.3257 - val_accuracy: 0.8692
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3104 - accuracy: 0.8769 - val_loss: 0.3204 - val_accuracy: 0.8700
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2994 - accuracy: 0.8810 - val_loss: 0.3151 - val_accuracy: 0.8714
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2897 - accuracy: 0.8852 - val_loss: 0.3117 - val_accuracy: 0.8704
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2808 - accuracy: 0.8890 - val_loss: 0.3094 - val_accuracy: 0.8738
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2737 - accuracy: 0.8918 - val_loss: 0.3083 - val_accuracy: 0.8710
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.3082873523235321
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8581    0.8585    0.8583      2269
#            1     0.8818    0.8814    0.8816      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8700    0.8700    0.8700      4985
# weighted avg     0.8710    0.8710    0.8710      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6144 - accuracy: 0.7230 - val_loss: 0.5276 - val_accuracy: 0.8475
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4669 - accuracy: 0.8342 - val_loss: 0.4140 - val_accuracy: 0.8562
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3859 - accuracy: 0.8553 - val_loss: 0.3622 - val_accuracy: 0.8638
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3467 - accuracy: 0.8635 - val_loss: 0.3384 - val_accuracy: 0.8684
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3245 - accuracy: 0.8714 - val_loss: 0.3271 - val_accuracy: 0.8696
# Epoch 6/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3112 - accuracy: 0.8771 - val_loss: 0.3186 - val_accuracy: 0.8714
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2990 - accuracy: 0.8806 - val_loss: 0.3147 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2889 - accuracy: 0.8850 - val_loss: 0.3118 - val_accuracy: 0.8744
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2808 - accuracy: 0.8892 - val_loss: 0.3098 - val_accuracy: 0.8738
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2734 - accuracy: 0.8914 - val_loss: 0.3081 - val_accuracy: 0.8724
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3081473410129547
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8754    0.8391    0.8569      2269
#            1     0.8701    0.9002    0.8849      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8728    0.8697    0.8709      4985
# weighted avg     0.8725    0.8724    0.8722      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6097 - accuracy: 0.7307 - val_loss: 0.5218 - val_accuracy: 0.8499
# Epoch 2/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.4613 - accuracy: 0.8359 - val_loss: 0.4116 - val_accuracy: 0.8560
# Epoch 3/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3831 - accuracy: 0.8540 - val_loss: 0.3615 - val_accuracy: 0.8634
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3459 - accuracy: 0.8655 - val_loss: 0.3371 - val_accuracy: 0.8690
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3223 - accuracy: 0.8729 - val_loss: 0.3249 - val_accuracy: 0.8704
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3070 - accuracy: 0.8793 - val_loss: 0.3212 - val_accuracy: 0.8698
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2936 - accuracy: 0.8838 - val_loss: 0.3136 - val_accuracy: 0.8750
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2855 - accuracy: 0.8870 - val_loss: 0.3109 - val_accuracy: 0.8758
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2786 - accuracy: 0.8900 - val_loss: 0.3083 - val_accuracy: 0.8722
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2690 - accuracy: 0.8929 - val_loss: 0.3068 - val_accuracy: 0.8744
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8744232654571533
# Validation Loss: 0.30676233768463135
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8794    0.8391    0.8588      2269
#            1     0.8706    0.9039    0.8869      2716
#
#     accuracy                         0.8744      4985
#    macro avg     0.8750    0.8715    0.8729      4985
# weighted avg     0.8746    0.8744    0.8741      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM Dropout 0.3 {idx + 1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8729789368104314
# Average Precision : 0.8738628219985625
# Average Recall : 0.8963181148748159
# Average F1 Score : 0.8849041057551229
