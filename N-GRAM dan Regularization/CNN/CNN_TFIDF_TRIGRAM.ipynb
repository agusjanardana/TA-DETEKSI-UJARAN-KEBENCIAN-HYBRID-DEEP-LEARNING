# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_TRIGRAM MODEL
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(3,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 20s 20ms/step - loss: 0.6845 - accuracy: 0.5522 - val_loss: 0.6763 - val_accuracy: 0.5906
# Epoch 2/10
# 701/701 [==============================] - 13s 19ms/step - loss: 0.6602 - accuracy: 0.6281 - val_loss: 0.6499 - val_accuracy: 0.6491
# Epoch 3/10
# 701/701 [==============================] - 13s 19ms/step - loss: 0.6271 - accuracy: 0.6643 - val_loss: 0.6238 - val_accuracy: 0.6518
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5983 - accuracy: 0.6750 - val_loss: 0.6072 - val_accuracy: 0.6508
# Epoch 5/10
# 701/701 [==============================] - 13s 19ms/step - loss: 0.5785 - accuracy: 0.6800 - val_loss: 0.5971 - val_accuracy: 0.6548
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5654 - accuracy: 0.6819 - val_loss: 0.5929 - val_accuracy: 0.6554
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5553 - accuracy: 0.6836 - val_loss: 0.5907 - val_accuracy: 0.6568
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5482 - accuracy: 0.6855 - val_loss: 0.5894 - val_accuracy: 0.6584
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5425 - accuracy: 0.6863 - val_loss: 0.5908 - val_accuracy: 0.6590
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5377 - accuracy: 0.6879 - val_loss: 0.5916 - val_accuracy: 0.6582
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.6581745147705078
# Validation Loss: 0.5915716290473938
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8192    0.3195    0.4597      2269
#            1     0.6234    0.9411    0.7500      2716
#
#     accuracy                         0.6582      4985
#    macro avg     0.7213    0.6303    0.6049      4985
# weighted avg     0.7125    0.6582    0.6179      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 20ms/step - loss: 0.6853 - accuracy: 0.5505 - val_loss: 0.6791 - val_accuracy: 0.5892
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6661 - accuracy: 0.6113 - val_loss: 0.6575 - val_accuracy: 0.6221
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6379 - accuracy: 0.6586 - val_loss: 0.6344 - val_accuracy: 0.6457
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6113 - accuracy: 0.6738 - val_loss: 0.6165 - val_accuracy: 0.6522
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5902 - accuracy: 0.6786 - val_loss: 0.6070 - val_accuracy: 0.6596
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5744 - accuracy: 0.6822 - val_loss: 0.5961 - val_accuracy: 0.6580
# Epoch 7/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.5634 - accuracy: 0.6844 - val_loss: 0.5915 - val_accuracy: 0.6592
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5542 - accuracy: 0.6862 - val_loss: 0.5898 - val_accuracy: 0.6602
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.5477 - accuracy: 0.6874 - val_loss: 0.5897 - val_accuracy: 0.6588
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.5423 - accuracy: 0.6885 - val_loss: 0.5891 - val_accuracy: 0.6590
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.6589769124984741
# Validation Loss: 0.589148223400116
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8391    0.3103    0.4530      2269
#            1     0.6225    0.9503    0.7523      2716
#
#     accuracy                         0.6590      4985
#    macro avg     0.7308    0.6303    0.6026      4985
# weighted avg     0.7211    0.6590    0.6161      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6811 - accuracy: 0.5665 - val_loss: 0.6702 - val_accuracy: 0.5823
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6502 - accuracy: 0.6441 - val_loss: 0.6407 - val_accuracy: 0.6365
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6153 - accuracy: 0.6691 - val_loss: 0.6166 - val_accuracy: 0.6495
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5889 - accuracy: 0.6782 - val_loss: 0.6013 - val_accuracy: 0.6548
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5714 - accuracy: 0.6809 - val_loss: 0.5937 - val_accuracy: 0.6576
# Epoch 6/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.5591 - accuracy: 0.6833 - val_loss: 0.5916 - val_accuracy: 0.6562
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5507 - accuracy: 0.6848 - val_loss: 0.5887 - val_accuracy: 0.6592
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5442 - accuracy: 0.6867 - val_loss: 0.5891 - val_accuracy: 0.6596
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5387 - accuracy: 0.6872 - val_loss: 0.5897 - val_accuracy: 0.6588
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5344 - accuracy: 0.6887 - val_loss: 0.5935 - val_accuracy: 0.6582
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.6581745147705078
# Validation Loss: 0.5935284495353699
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8281    0.3142    0.4556      2269
#            1     0.6227    0.9455    0.7509      2716
#
#     accuracy                         0.6582      4985
#    macro avg     0.7254    0.6299    0.6032      4985
# weighted avg     0.7162    0.6582    0.6165      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 21ms/step - loss: 0.6852 - accuracy: 0.5521 - val_loss: 0.6790 - val_accuracy: 0.5533
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6644 - accuracy: 0.6177 - val_loss: 0.6551 - val_accuracy: 0.6477
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6328 - accuracy: 0.6620 - val_loss: 0.6297 - val_accuracy: 0.6548
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6037 - accuracy: 0.6737 - val_loss: 0.6107 - val_accuracy: 0.6554
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5821 - accuracy: 0.6798 - val_loss: 0.5991 - val_accuracy: 0.6584
# Epoch 6/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.5670 - accuracy: 0.6822 - val_loss: 0.5926 - val_accuracy: 0.6580
# Epoch 7/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.5567 - accuracy: 0.6843 - val_loss: 0.5899 - val_accuracy: 0.6602
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5493 - accuracy: 0.6856 - val_loss: 0.5892 - val_accuracy: 0.6604
# Epoch 9/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.5427 - accuracy: 0.6871 - val_loss: 0.5892 - val_accuracy: 0.6600
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.5378 - accuracy: 0.6877 - val_loss: 0.5898 - val_accuracy: 0.6598
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.6597793102264404
# Validation Loss: 0.5897876620292664
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8259    0.3200    0.4612      2269
#            1     0.6242    0.9437    0.7514      2716
#
#     accuracy                         0.6598      4985
#    macro avg     0.7251    0.6318    0.6063      4985
# weighted avg     0.7160    0.6598    0.6193      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 16s 20ms/step - loss: 0.6855 - accuracy: 0.5500 - val_loss: 0.6797 - val_accuracy: 0.5496
# Epoch 2/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.6679 - accuracy: 0.6083 - val_loss: 0.6605 - val_accuracy: 0.6405
# Epoch 3/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.6417 - accuracy: 0.6550 - val_loss: 0.6373 - val_accuracy: 0.6485
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.6151 - accuracy: 0.6700 - val_loss: 0.6187 - val_accuracy: 0.6516
# Epoch 5/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5945 - accuracy: 0.6761 - val_loss: 0.6060 - val_accuracy: 0.6550
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.5785 - accuracy: 0.6794 - val_loss: 0.5987 - val_accuracy: 0.6552
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.5674 - accuracy: 0.6823 - val_loss: 0.5930 - val_accuracy: 0.6574
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.5587 - accuracy: 0.6833 - val_loss: 0.5903 - val_accuracy: 0.6592
# Epoch 9/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.5519 - accuracy: 0.6845 - val_loss: 0.5889 - val_accuracy: 0.6598
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.5464 - accuracy: 0.6857 - val_loss: 0.5898 - val_accuracy: 0.6584
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.6583751440048218
# Validation Loss: 0.5897648930549622
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8337    0.3116    0.4536      2269
#            1     0.6224    0.9481    0.7515      2716
#
#     accuracy                         0.6584      4985
#    macro avg     0.7281    0.6298    0.6026      4985
# weighted avg     0.7186    0.6584    0.6159      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN TRIGRAM {idx + 1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.6586960882647944
# Average Precision : 0.6230557944360132
# Average Recall : 0.9457290132547864
# Average F1 Score : 0.7512048516946545
