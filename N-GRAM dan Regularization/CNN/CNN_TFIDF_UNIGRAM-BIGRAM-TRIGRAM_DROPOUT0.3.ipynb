# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences v 2.9 kebawah
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia V100')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia V100

# %% [markdown]
# ## CNN_TFIDF_UNIGRAM-BIGRAM-TRIGRAM DROPOUT 0.3
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00005)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
  # predict
  y_pred = model.predict(X_test)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round())
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round())

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 23s 22ms/step - loss: 0.6004 - accuracy: 0.7291 - val_loss: 0.5073 - val_accuracy: 0.8437
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4481 - accuracy: 0.8414 - val_loss: 0.3993 - val_accuracy: 0.8572
# Epoch 3/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3736 - accuracy: 0.8583 - val_loss: 0.3524 - val_accuracy: 0.8624
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3392 - accuracy: 0.8674 - val_loss: 0.3337 - val_accuracy: 0.8676
# Epoch 5/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3169 - accuracy: 0.8741 - val_loss: 0.3242 - val_accuracy: 0.8700
# Epoch 6/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3029 - accuracy: 0.8799 - val_loss: 0.3161 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2931 - accuracy: 0.8846 - val_loss: 0.3152 - val_accuracy: 0.8736
# Epoch 8/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2853 - accuracy: 0.8871 - val_loss: 0.3099 - val_accuracy: 0.8752
# Epoch 9/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2765 - accuracy: 0.8903 - val_loss: 0.3078 - val_accuracy: 0.8742
# Epoch 10/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.2676 - accuracy: 0.8933 - val_loss: 0.3071 - val_accuracy: 0.8732
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8732196688652039
# Validation Loss: 0.307142049074173
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8705    0.8475    0.8589      2269
#            1     0.8754    0.8947    0.8849      2716
#
#     accuracy                         0.8732      4985
#    macro avg     0.8729    0.8711    0.8719      4985
# weighted avg     0.8732    0.8732    0.8731      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 18s 22ms/step - loss: 0.6269 - accuracy: 0.6952 - val_loss: 0.5500 - val_accuracy: 0.8371
# Epoch 2/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.4846 - accuracy: 0.8317 - val_loss: 0.4276 - val_accuracy: 0.8528
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3956 - accuracy: 0.8534 - val_loss: 0.3699 - val_accuracy: 0.8606
# Epoch 4/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.3521 - accuracy: 0.8643 - val_loss: 0.3410 - val_accuracy: 0.8638
# Epoch 5/10
# 701/701 [==============================] - 15s 22ms/step - loss: 0.3272 - accuracy: 0.8703 - val_loss: 0.3267 - val_accuracy: 0.8682
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3122 - accuracy: 0.8770 - val_loss: 0.3189 - val_accuracy: 0.8694
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3006 - accuracy: 0.8814 - val_loss: 0.3135 - val_accuracy: 0.8722
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2900 - accuracy: 0.8855 - val_loss: 0.3115 - val_accuracy: 0.8734
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2829 - accuracy: 0.8878 - val_loss: 0.3074 - val_accuracy: 0.8740
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2753 - accuracy: 0.8898 - val_loss: 0.3062 - val_accuracy: 0.8740
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8740220665931702
# Validation Loss: 0.30622997879981995
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8698    0.8506    0.8601      2269
#            1     0.8774    0.8936    0.8854      2716
#
#     accuracy                         0.8740      4985
#    macro avg     0.8736    0.8721    0.8728      4985
# weighted avg     0.8739    0.8740    0.8739      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 21ms/step - loss: 0.6225 - accuracy: 0.6992 - val_loss: 0.5443 - val_accuracy: 0.8367
# Epoch 2/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.4812 - accuracy: 0.8319 - val_loss: 0.4257 - val_accuracy: 0.8564
# Epoch 3/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.3959 - accuracy: 0.8533 - val_loss: 0.3704 - val_accuracy: 0.8614
# Epoch 4/10
# 701/701 [==============================] - 18s 25ms/step - loss: 0.3521 - accuracy: 0.8637 - val_loss: 0.3443 - val_accuracy: 0.8640
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3279 - accuracy: 0.8715 - val_loss: 0.3284 - val_accuracy: 0.8688
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3113 - accuracy: 0.8762 - val_loss: 0.3196 - val_accuracy: 0.8702
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2993 - accuracy: 0.8810 - val_loss: 0.3158 - val_accuracy: 0.8720
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2907 - accuracy: 0.8845 - val_loss: 0.3114 - val_accuracy: 0.8730
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2832 - accuracy: 0.8865 - val_loss: 0.3101 - val_accuracy: 0.8742
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2762 - accuracy: 0.8894 - val_loss: 0.3081 - val_accuracy: 0.8738
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8738214373588562
# Validation Loss: 0.30805954337120056
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8619    0.8607    0.8613      2269
#            1     0.8838    0.8848    0.8843      2716
#
#     accuracy                         0.8738      4985
#    macro avg     0.8728    0.8727    0.8728      4985
# weighted avg     0.8738    0.8738    0.8738      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 22ms/step - loss: 0.6074 - accuracy: 0.7256 - val_loss: 0.5192 - val_accuracy: 0.8493
# Epoch 2/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.4593 - accuracy: 0.8381 - val_loss: 0.4076 - val_accuracy: 0.8570
# Epoch 3/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3822 - accuracy: 0.8545 - val_loss: 0.3600 - val_accuracy: 0.8608
# Epoch 4/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3451 - accuracy: 0.8659 - val_loss: 0.3356 - val_accuracy: 0.8662
# Epoch 5/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3210 - accuracy: 0.8730 - val_loss: 0.3240 - val_accuracy: 0.8698
# Epoch 6/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3067 - accuracy: 0.8779 - val_loss: 0.3171 - val_accuracy: 0.8710
# Epoch 7/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2949 - accuracy: 0.8819 - val_loss: 0.3122 - val_accuracy: 0.8734
# Epoch 8/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2862 - accuracy: 0.8869 - val_loss: 0.3089 - val_accuracy: 0.8740
# Epoch 9/10
# 701/701 [==============================] - 14s 21ms/step - loss: 0.2780 - accuracy: 0.8896 - val_loss: 0.3069 - val_accuracy: 0.8722
# Epoch 10/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.2702 - accuracy: 0.8923 - val_loss: 0.3056 - val_accuracy: 0.8736
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.873620867729187
# Validation Loss: 0.3055625259876251
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8754    0.8422    0.8585      2269
#            1     0.8722    0.8999    0.8858      2716
#
#     accuracy                         0.8736      4985
#    macro avg     0.8738    0.8710    0.8722      4985
# weighted avg     0.8737    0.8736    0.8734      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 22ms/step - loss: 0.6130 - accuracy: 0.7048 - val_loss: 0.5268 - val_accuracy: 0.8387
# Epoch 2/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.4676 - accuracy: 0.8322 - val_loss: 0.4145 - val_accuracy: 0.8546
# Epoch 3/10
# 701/701 [==============================] - 15s 21ms/step - loss: 0.3892 - accuracy: 0.8520 - val_loss: 0.3639 - val_accuracy: 0.8610
# Epoch 4/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3499 - accuracy: 0.8628 - val_loss: 0.3382 - val_accuracy: 0.8670
# Epoch 5/10
# 701/701 [==============================] - 14s 19ms/step - loss: 0.3292 - accuracy: 0.8694 - val_loss: 0.3302 - val_accuracy: 0.8672
# Epoch 6/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3140 - accuracy: 0.8756 - val_loss: 0.3215 - val_accuracy: 0.8716
# Epoch 7/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.3031 - accuracy: 0.8800 - val_loss: 0.3199 - val_accuracy: 0.8716
# Epoch 8/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2956 - accuracy: 0.8844 - val_loss: 0.3160 - val_accuracy: 0.8718
# Epoch 9/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2878 - accuracy: 0.8869 - val_loss: 0.3126 - val_accuracy: 0.8718
# Epoch 10/10
# 701/701 [==============================] - 14s 20ms/step - loss: 0.2811 - accuracy: 0.8881 - val_loss: 0.3117 - val_accuracy: 0.8724
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.31166914105415344
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8670    0.8502    0.8585      2269
#            1     0.8768    0.8910    0.8839      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8719    0.8706    0.8712      4985
# weighted avg     0.8723    0.8724    0.8723      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN UNIGRAM_BIGRAM_TRIGRAM Dropout 0.3 {idx + 1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8734202607823469
# Average Precision : 0.8771254184148365
# Average Recall : 0.8927835051546392
# Average F1 Score : 0.8848640903375449
