# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 12s 10ms/step - loss: 0.6918 - accuracy: 0.5449 - val_loss: 0.6898 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6849 - accuracy: 0.5461 - val_loss: 0.6784 - val_accuracy: 0.5533
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6673 - accuracy: 0.6229 - val_loss: 0.6562 - val_accuracy: 0.6688
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6392 - accuracy: 0.7105 - val_loss: 0.6251 - val_accuracy: 0.7382
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6025 - accuracy: 0.7721 - val_loss: 0.5874 - val_accuracy: 0.7856
# Epoch 6/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5609 - accuracy: 0.8171 - val_loss: 0.5477 - val_accuracy: 0.8052
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5184 - accuracy: 0.8412 - val_loss: 0.5083 - val_accuracy: 0.8351
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4771 - accuracy: 0.8588 - val_loss: 0.4716 - val_accuracy: 0.8481
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4388 - accuracy: 0.8693 - val_loss: 0.4383 - val_accuracy: 0.8610
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4047 - accuracy: 0.8777 - val_loss: 0.4099 - val_accuracy: 0.8642
#
# Validation Accuracy: 0.8641926050186157
# Validation Loss: 0.40994027256965637
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9041    0.7849    0.8403      2269
#            1     0.8381    0.9304    0.8819      2716
#
#     accuracy                         0.8642      4985
#    macro avg     0.8711    0.8577    0.8611      4985
# weighted avg     0.8681    0.8642    0.8629      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6917 - accuracy: 0.5449 - val_loss: 0.6894 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6846 - accuracy: 0.5450 - val_loss: 0.6788 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6696 - accuracy: 0.5703 - val_loss: 0.6605 - val_accuracy: 0.6219
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6467 - accuracy: 0.6610 - val_loss: 0.6354 - val_accuracy: 0.6891
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6175 - accuracy: 0.7206 - val_loss: 0.6055 - val_accuracy: 0.7308
# Epoch 6/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5841 - accuracy: 0.7691 - val_loss: 0.5730 - val_accuracy: 0.7723
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5489 - accuracy: 0.8055 - val_loss: 0.5400 - val_accuracy: 0.8010
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5137 - accuracy: 0.8329 - val_loss: 0.5080 - val_accuracy: 0.8253
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4797 - accuracy: 0.8524 - val_loss: 0.4777 - val_accuracy: 0.8417
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4479 - accuracy: 0.8649 - val_loss: 0.4499 - val_accuracy: 0.8506
#
# Validation Accuracy: 0.8505516648292542
# Validation Loss: 0.4498550295829773
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9238    0.7320    0.8168      2269
#            1     0.8092    0.9496    0.8738      2716
#
#     accuracy                         0.8506      4985
#    macro avg     0.8665    0.8408    0.8453      4985
# weighted avg     0.8614    0.8506    0.8479      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6922 - accuracy: 0.5454 - val_loss: 0.6905 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6867 - accuracy: 0.5507 - val_loss: 0.6818 - val_accuracy: 0.5886
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6735 - accuracy: 0.6493 - val_loss: 0.6651 - val_accuracy: 0.6853
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6519 - accuracy: 0.7263 - val_loss: 0.6406 - val_accuracy: 0.7436
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6220 - accuracy: 0.7818 - val_loss: 0.6086 - val_accuracy: 0.7834
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5852 - accuracy: 0.8187 - val_loss: 0.5715 - val_accuracy: 0.8132
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5439 - accuracy: 0.8438 - val_loss: 0.5316 - val_accuracy: 0.8377
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5012 - accuracy: 0.8589 - val_loss: 0.4924 - val_accuracy: 0.8499
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4600 - accuracy: 0.8688 - val_loss: 0.4556 - val_accuracy: 0.8592
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4218 - accuracy: 0.8769 - val_loss: 0.4228 - val_accuracy: 0.8630
#
# Validation Accuracy: 0.8629889488220215
# Validation Loss: 0.42279088497161865
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9034    0.7827    0.8387      2269
#            1     0.8367    0.9300    0.8809      2716
#
#     accuracy                         0.8630      4985
#    macro avg     0.8700    0.8564    0.8598      4985
# weighted avg     0.8670    0.8630    0.8617      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 9s 10ms/step - loss: 0.6916 - accuracy: 0.5456 - val_loss: 0.6891 - val_accuracy: 0.5468
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6830 - accuracy: 0.6009 - val_loss: 0.6758 - val_accuracy: 0.6588
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6647 - accuracy: 0.7065 - val_loss: 0.6541 - val_accuracy: 0.7252
# Epoch 4/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6381 - accuracy: 0.7594 - val_loss: 0.6253 - val_accuracy: 0.7697
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6046 - accuracy: 0.8001 - val_loss: 0.5912 - val_accuracy: 0.7958
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5665 - accuracy: 0.8277 - val_loss: 0.5543 - val_accuracy: 0.8215
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5268 - accuracy: 0.8478 - val_loss: 0.5173 - val_accuracy: 0.8359
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4873 - accuracy: 0.8607 - val_loss: 0.4816 - val_accuracy: 0.8493
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4500 - accuracy: 0.8709 - val_loss: 0.4488 - val_accuracy: 0.8622
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4160 - accuracy: 0.8786 - val_loss: 0.4198 - val_accuracy: 0.8652
#
# Validation Accuracy: 0.8651955723762512
# Validation Loss: 0.4198066294193268
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9084    0.7827    0.8409      2269
#            1     0.8373    0.9341    0.8830      2716
#
#     accuracy                         0.8652      4985
#    macro avg     0.8729    0.8584    0.8620      4985
# weighted avg     0.8697    0.8652    0.8639      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6919 - accuracy: 0.5446 - val_loss: 0.6898 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6847 - accuracy: 0.5688 - val_loss: 0.6783 - val_accuracy: 0.6249
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6681 - accuracy: 0.6849 - val_loss: 0.6578 - val_accuracy: 0.7194
# Epoch 4/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6426 - accuracy: 0.7596 - val_loss: 0.6299 - val_accuracy: 0.7691
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6100 - accuracy: 0.8045 - val_loss: 0.5964 - val_accuracy: 0.8002
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5724 - accuracy: 0.8304 - val_loss: 0.5595 - val_accuracy: 0.8243
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5322 - accuracy: 0.8484 - val_loss: 0.5216 - val_accuracy: 0.8363
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4917 - accuracy: 0.8613 - val_loss: 0.4848 - val_accuracy: 0.8489
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4532 - accuracy: 0.8707 - val_loss: 0.4508 - val_accuracy: 0.8598
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4177 - accuracy: 0.8772 - val_loss: 0.4205 - val_accuracy: 0.8622
#
# Validation Accuracy: 0.8621865510940552
# Validation Loss: 0.42047902941703796
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9023    0.7818    0.8378      2269
#            1     0.8360    0.9293    0.8802      2716
#
#     accuracy                         0.8622      4985
#    macro avg     0.8692    0.8556    0.8590      4985
# weighted avg     0.8662    0.8622    0.8609      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8610230692076228
# Average Precision : 0.8314801287453719
# Average Recall : 0.9346833578792342
# Average F1 Score : 0.8594556492523961
