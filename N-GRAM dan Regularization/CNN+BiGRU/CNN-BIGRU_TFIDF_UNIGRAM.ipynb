# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 18s 11ms/step - loss: 0.6919 - accuracy: 0.5437 - val_loss: 0.6898 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6856 - accuracy: 0.5549 - val_loss: 0.6805 - val_accuracy: 0.5769
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6720 - accuracy: 0.6389 - val_loss: 0.6636 - val_accuracy: 0.6796
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6504 - accuracy: 0.7228 - val_loss: 0.6394 - val_accuracy: 0.7412
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6215 - accuracy: 0.7798 - val_loss: 0.6090 - val_accuracy: 0.7904
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5870 - accuracy: 0.8191 - val_loss: 0.5748 - val_accuracy: 0.8199
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5495 - accuracy: 0.8443 - val_loss: 0.5390 - val_accuracy: 0.8355
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5110 - accuracy: 0.8578 - val_loss: 0.5035 - val_accuracy: 0.8465
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4734 - accuracy: 0.8689 - val_loss: 0.4699 - val_accuracy: 0.8552
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4382 - accuracy: 0.8751 - val_loss: 0.4393 - val_accuracy: 0.8608
#
# Validation Accuracy: 0.8607823252677917
# Validation Loss: 0.43931862711906433
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9049    0.7757    0.8353      2269
#            1     0.8326    0.9319    0.8794      2716
#
#     accuracy                         0.8608      4985
#    macro avg     0.8687    0.8538    0.8574      4985
# weighted avg     0.8655    0.8608    0.8593      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6921 - accuracy: 0.5437 - val_loss: 0.6905 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6870 - accuracy: 0.5456 - val_loss: 0.6824 - val_accuracy: 0.5545
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6740 - accuracy: 0.6325 - val_loss: 0.6655 - val_accuracy: 0.6873
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6521 - accuracy: 0.7439 - val_loss: 0.6408 - val_accuracy: 0.7571
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6221 - accuracy: 0.8021 - val_loss: 0.6089 - val_accuracy: 0.7994
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5859 - accuracy: 0.8345 - val_loss: 0.5728 - val_accuracy: 0.8307
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5461 - accuracy: 0.8531 - val_loss: 0.5347 - val_accuracy: 0.8437
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5051 - accuracy: 0.8637 - val_loss: 0.4967 - val_accuracy: 0.8516
# Epoch 9/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4651 - accuracy: 0.8706 - val_loss: 0.4613 - val_accuracy: 0.8572
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4284 - accuracy: 0.8757 - val_loss: 0.4298 - val_accuracy: 0.8620
#
# Validation Accuracy: 0.861985981464386
# Validation Loss: 0.4297863841056824
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8974    0.7867    0.8384      2269
#            1     0.8385    0.9249    0.8796      2716
#
#     accuracy                         0.8620      4985
#    macro avg     0.8679    0.8558    0.8590      4985
# weighted avg     0.8653    0.8620    0.8608      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6919 - accuracy: 0.5454 - val_loss: 0.6900 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6861 - accuracy: 0.5491 - val_loss: 0.6813 - val_accuracy: 0.5645
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6736 - accuracy: 0.6194 - val_loss: 0.6658 - val_accuracy: 0.6584
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6530 - accuracy: 0.7134 - val_loss: 0.6423 - val_accuracy: 0.7364
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6259 - accuracy: 0.7730 - val_loss: 0.6144 - val_accuracy: 0.7775
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5941 - accuracy: 0.8126 - val_loss: 0.5826 - val_accuracy: 0.8070
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5588 - accuracy: 0.8381 - val_loss: 0.5484 - val_accuracy: 0.8285
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5216 - accuracy: 0.8547 - val_loss: 0.5137 - val_accuracy: 0.8417
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4845 - accuracy: 0.8670 - val_loss: 0.4802 - val_accuracy: 0.8508
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4491 - accuracy: 0.8729 - val_loss: 0.4488 - val_accuracy: 0.8606
#
# Validation Accuracy: 0.8605817556381226
# Validation Loss: 0.4487746059894562
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9078    0.7721    0.8345      2269
#            1     0.8308    0.9345    0.8796      2716
#
#     accuracy                         0.8606      4985
#    macro avg     0.8693    0.8533    0.8570      4985
# weighted avg     0.8658    0.8606    0.8590      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6918 - accuracy: 0.5441 - val_loss: 0.6897 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6850 - accuracy: 0.5467 - val_loss: 0.6792 - val_accuracy: 0.5583
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6698 - accuracy: 0.6149 - val_loss: 0.6603 - val_accuracy: 0.6646
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6460 - accuracy: 0.6984 - val_loss: 0.6342 - val_accuracy: 0.7170
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6156 - accuracy: 0.7540 - val_loss: 0.6032 - val_accuracy: 0.7595
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5812 - accuracy: 0.7959 - val_loss: 0.5697 - val_accuracy: 0.7972
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5448 - accuracy: 0.8288 - val_loss: 0.5357 - val_accuracy: 0.8185
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5083 - accuracy: 0.8483 - val_loss: 0.5022 - val_accuracy: 0.8389
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4732 - accuracy: 0.8630 - val_loss: 0.4714 - val_accuracy: 0.8487
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4406 - accuracy: 0.8721 - val_loss: 0.4430 - val_accuracy: 0.8600
#
# Validation Accuracy: 0.8599799275398254
# Validation Loss: 0.44296571612358093
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9149    0.7633    0.8323      2269
#            1     0.8263    0.9407    0.8798      2716
#
#     accuracy                         0.8600      4985
#    macro avg     0.8706    0.8520    0.8561      4985
# weighted avg     0.8667    0.8600    0.8582      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6920 - accuracy: 0.5445 - val_loss: 0.6902 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6857 - accuracy: 0.5450 - val_loss: 0.6800 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6704 - accuracy: 0.5730 - val_loss: 0.6609 - val_accuracy: 0.6100
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6461 - accuracy: 0.6653 - val_loss: 0.6337 - val_accuracy: 0.6955
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6145 - accuracy: 0.7343 - val_loss: 0.6012 - val_accuracy: 0.7517
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5782 - accuracy: 0.7860 - val_loss: 0.5661 - val_accuracy: 0.7890
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5398 - accuracy: 0.8241 - val_loss: 0.5301 - val_accuracy: 0.8195
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5018 - accuracy: 0.8482 - val_loss: 0.4960 - val_accuracy: 0.8389
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4661 - accuracy: 0.8636 - val_loss: 0.4648 - val_accuracy: 0.8546
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4331 - accuracy: 0.8737 - val_loss: 0.4364 - val_accuracy: 0.8590
#
# Validation Accuracy: 0.8589769601821899
# Validation Loss: 0.43643665313720703
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9138    0.7620    0.8311      2269
#            1     0.8254    0.9400    0.8790      2716
#
#     accuracy                         0.8590      4985
#    macro avg     0.8696    0.8510    0.8550      4985
# weighted avg     0.8657    0.8590    0.8572      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8604613841524573
# Average Precision : 0.8307049024665135
# Average Recall : 0.9343888070692195
# Average F1 Score : 0.8589160312314202
