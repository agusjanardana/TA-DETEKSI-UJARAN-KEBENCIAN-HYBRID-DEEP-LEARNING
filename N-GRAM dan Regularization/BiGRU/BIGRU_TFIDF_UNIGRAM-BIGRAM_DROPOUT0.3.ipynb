# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_5 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_10 (Dense)            (44856, 32)               2080
#
#  dropout_5 (Dropout)         (44856, 32)               0
#
#  dense_11 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 30ms/step - loss: 0.6880 - accuracy: 0.5504 - val_loss: 0.6776 - val_accuracy: 0.5801
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6529 - accuracy: 0.6928 - val_loss: 0.6229 - val_accuracy: 0.7563
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5815 - accuracy: 0.8096 - val_loss: 0.5425 - val_accuracy: 0.8297
# Epoch 4/10
# 351/351 [==============================] - 9s 24ms/step - loss: 0.4971 - accuracy: 0.8477 - val_loss: 0.4645 - val_accuracy: 0.8562
# Epoch 5/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.4272 - accuracy: 0.8619 - val_loss: 0.4079 - val_accuracy: 0.8598
# Epoch 6/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.3773 - accuracy: 0.8684 - val_loss: 0.3713 - val_accuracy: 0.8612
# Epoch 7/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3443 - accuracy: 0.8754 - val_loss: 0.3484 - val_accuracy: 0.8636
# Epoch 8/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.3213 - accuracy: 0.8803 - val_loss: 0.3336 - val_accuracy: 0.8682
# Epoch 9/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.3037 - accuracy: 0.8842 - val_loss: 0.3237 - val_accuracy: 0.8700
# Epoch 10/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.2910 - accuracy: 0.8884 - val_loss: 0.3180 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.3179704546928406
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8784    0.8338    0.8555      2269
#            1     0.8668    0.9035    0.8848      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8726    0.8687    0.8702      4985
# weighted avg     0.8721    0.8718    0.8715      4985
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_6 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_12 (Dense)            (44856, 32)               2080
#
#  dropout_6 (Dropout)         (44856, 32)               0
#
#  dense_13 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 27ms/step - loss: 0.6854 - accuracy: 0.5578 - val_loss: 0.6703 - val_accuracy: 0.6162
# Epoch 2/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.6367 - accuracy: 0.7235 - val_loss: 0.5977 - val_accuracy: 0.7854
# Epoch 3/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.5500 - accuracy: 0.8236 - val_loss: 0.5088 - val_accuracy: 0.8415
# Epoch 4/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.4640 - accuracy: 0.8547 - val_loss: 0.4360 - val_accuracy: 0.8566
# Epoch 5/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.4009 - accuracy: 0.8651 - val_loss: 0.3878 - val_accuracy: 0.8624
# Epoch 6/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.3581 - accuracy: 0.8746 - val_loss: 0.3576 - val_accuracy: 0.8630
# Epoch 7/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3300 - accuracy: 0.8776 - val_loss: 0.3391 - val_accuracy: 0.8658
# Epoch 8/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.3098 - accuracy: 0.8826 - val_loss: 0.3271 - val_accuracy: 0.8702
# Epoch 9/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.2944 - accuracy: 0.8885 - val_loss: 0.3199 - val_accuracy: 0.8718
# Epoch 10/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.2833 - accuracy: 0.8918 - val_loss: 0.3151 - val_accuracy: 0.8730
#
# Validation Accuracy: 0.8730190396308899
# Validation Loss: 0.3151109218597412
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8732    0.8435    0.8581      2269
#            1     0.8729    0.8976    0.8851      2716
#
#     accuracy                         0.8730      4985
#    macro avg     0.8730    0.8706    0.8716      4985
# weighted avg     0.8730    0.8730    0.8728      4985
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_7 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_14 (Dense)            (44856, 32)               2080
#
#  dropout_7 (Dropout)         (44856, 32)               0
#
#  dense_15 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 26ms/step - loss: 0.6870 - accuracy: 0.5460 - val_loss: 0.6758 - val_accuracy: 0.5545
# Epoch 2/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.6527 - accuracy: 0.6493 - val_loss: 0.6256 - val_accuracy: 0.7119
# Epoch 3/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.5897 - accuracy: 0.7720 - val_loss: 0.5559 - val_accuracy: 0.8000
# Epoch 4/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.5142 - accuracy: 0.8341 - val_loss: 0.4841 - val_accuracy: 0.8405
# Epoch 5/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.4459 - accuracy: 0.8577 - val_loss: 0.4249 - val_accuracy: 0.8586
# Epoch 6/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3929 - accuracy: 0.8685 - val_loss: 0.3833 - val_accuracy: 0.8632
# Epoch 7/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3551 - accuracy: 0.8748 - val_loss: 0.3559 - val_accuracy: 0.8662
# Epoch 8/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.3292 - accuracy: 0.8794 - val_loss: 0.3383 - val_accuracy: 0.8688
# Epoch 9/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3097 - accuracy: 0.8837 - val_loss: 0.3271 - val_accuracy: 0.8706
# Epoch 10/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.2970 - accuracy: 0.8868 - val_loss: 0.3200 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710130453109741
# Validation Loss: 0.32004404067993164
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8750    0.8361    0.8551      2269
#            1     0.8679    0.9002    0.8838      2716
#
#     accuracy                         0.8710      4985
#    macro avg     0.8715    0.8681    0.8694      4985
# weighted avg     0.8712    0.8710    0.8707      4985
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_8 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_16 (Dense)            (44856, 32)               2080
#
#  dropout_8 (Dropout)         (44856, 32)               0
#
#  dense_17 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 12s 24ms/step - loss: 0.6865 - accuracy: 0.5650 - val_loss: 0.6732 - val_accuracy: 0.6381
# Epoch 2/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.6441 - accuracy: 0.7453 - val_loss: 0.6101 - val_accuracy: 0.8108
# Epoch 3/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.5643 - accuracy: 0.8314 - val_loss: 0.5239 - val_accuracy: 0.8433
# Epoch 4/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.4780 - accuracy: 0.8558 - val_loss: 0.4474 - val_accuracy: 0.8576
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4101 - accuracy: 0.8665 - val_loss: 0.3949 - val_accuracy: 0.8618
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3636 - accuracy: 0.8724 - val_loss: 0.3618 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3336 - accuracy: 0.8789 - val_loss: 0.3415 - val_accuracy: 0.8668
# Epoch 8/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3130 - accuracy: 0.8824 - val_loss: 0.3288 - val_accuracy: 0.8688
# Epoch 9/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.2957 - accuracy: 0.8874 - val_loss: 0.3203 - val_accuracy: 0.8710
# Epoch 10/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.2849 - accuracy: 0.8911 - val_loss: 0.3151 - val_accuracy: 0.8734
#
# Validation Accuracy: 0.873420238494873
# Validation Loss: 0.3150561451911926
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8730    0.8449    0.8587      2269
#            1     0.8738    0.8973    0.8854      2716
#
#     accuracy                         0.8734      4985
#    macro avg     0.8734    0.8711    0.8720      4985
# weighted avg     0.8734    0.8734    0.8732      4985
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_9 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_9 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_18 (Dense)            (44856, 32)               2080
#
#  dropout_9 (Dropout)         (44856, 32)               0
#
#  dense_19 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 24ms/step - loss: 0.6872 - accuracy: 0.5560 - val_loss: 0.6749 - val_accuracy: 0.6090
# Epoch 2/10
# 351/351 [==============================] - 8s 22ms/step - loss: 0.6479 - accuracy: 0.7144 - val_loss: 0.6147 - val_accuracy: 0.7753
# Epoch 3/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.5689 - accuracy: 0.8218 - val_loss: 0.5283 - val_accuracy: 0.8351
# Epoch 4/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.4824 - accuracy: 0.8523 - val_loss: 0.4510 - val_accuracy: 0.8538
# Epoch 5/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.4145 - accuracy: 0.8626 - val_loss: 0.3974 - val_accuracy: 0.8586
# Epoch 6/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3676 - accuracy: 0.8712 - val_loss: 0.3639 - val_accuracy: 0.8636
# Epoch 7/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3370 - accuracy: 0.8769 - val_loss: 0.3430 - val_accuracy: 0.8660
# Epoch 8/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.3144 - accuracy: 0.8832 - val_loss: 0.3297 - val_accuracy: 0.8678
# Epoch 9/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.2992 - accuracy: 0.8862 - val_loss: 0.3213 - val_accuracy: 0.8682
# Epoch 10/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.2854 - accuracy: 0.8910 - val_loss: 0.3158 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.31575989723205566
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8702    0.8449    0.8573      2269
#            1     0.8735    0.8947    0.8840      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8718    0.8698    0.8706      4985
# weighted avg     0.8720    0.8720    0.8718      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8722567703109328
# Average Precision : 0.8709869736381108
# Average Recall : 0.8986745213549338
# Average F1 Score : 0.8720150350656416
