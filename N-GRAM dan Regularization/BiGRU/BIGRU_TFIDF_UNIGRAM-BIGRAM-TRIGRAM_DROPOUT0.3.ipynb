# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 33ms/step - loss: 0.6862 - accuracy: 0.5479 - val_loss: 0.6732 - val_accuracy: 0.5713
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6443 - accuracy: 0.6722 - val_loss: 0.6126 - val_accuracy: 0.7384
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5706 - accuracy: 0.7952 - val_loss: 0.5349 - val_accuracy: 0.8221
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4913 - accuracy: 0.8437 - val_loss: 0.4624 - val_accuracy: 0.8481
# Epoch 5/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4242 - accuracy: 0.8608 - val_loss: 0.4084 - val_accuracy: 0.8590
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3767 - accuracy: 0.8727 - val_loss: 0.3721 - val_accuracy: 0.8634
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3439 - accuracy: 0.8772 - val_loss: 0.3488 - val_accuracy: 0.8670
# Epoch 8/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3197 - accuracy: 0.8827 - val_loss: 0.3340 - val_accuracy: 0.8698
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3029 - accuracy: 0.8854 - val_loss: 0.3248 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2896 - accuracy: 0.8899 - val_loss: 0.3188 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.3187900483608246
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8745    0.8387    0.8562      2269
#            1     0.8697    0.8995    0.8843      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8721    0.8691    0.8703      4985
# weighted avg     0.8719    0.8718    0.8716      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 33ms/step - loss: 0.6844 - accuracy: 0.5478 - val_loss: 0.6694 - val_accuracy: 0.5663
# Epoch 2/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6418 - accuracy: 0.6571 - val_loss: 0.6116 - val_accuracy: 0.7141
# Epoch 3/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.5725 - accuracy: 0.7778 - val_loss: 0.5373 - val_accuracy: 0.8026
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4956 - accuracy: 0.8389 - val_loss: 0.4669 - val_accuracy: 0.8435
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4292 - accuracy: 0.8614 - val_loss: 0.4124 - val_accuracy: 0.8600
# Epoch 6/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3805 - accuracy: 0.8709 - val_loss: 0.3750 - val_accuracy: 0.8630
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3467 - accuracy: 0.8768 - val_loss: 0.3506 - val_accuracy: 0.8666
# Epoch 8/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3222 - accuracy: 0.8812 - val_loss: 0.3348 - val_accuracy: 0.8680
# Epoch 9/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3048 - accuracy: 0.8853 - val_loss: 0.3254 - val_accuracy: 0.8696
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2920 - accuracy: 0.8898 - val_loss: 0.3188 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.3188111484050751
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8710    0.8422    0.8564      2269
#            1     0.8717    0.8958    0.8836      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8714    0.8690    0.8700      4985
# weighted avg     0.8714    0.8714    0.8712      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 37ms/step - loss: 0.6884 - accuracy: 0.5721 - val_loss: 0.6785 - val_accuracy: 0.6343
# Epoch 2/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.6520 - accuracy: 0.7638 - val_loss: 0.6189 - val_accuracy: 0.8387
# Epoch 3/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.5724 - accuracy: 0.8435 - val_loss: 0.5309 - val_accuracy: 0.8538
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4840 - accuracy: 0.8568 - val_loss: 0.4528 - val_accuracy: 0.8552
# Epoch 5/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.4153 - accuracy: 0.8629 - val_loss: 0.3996 - val_accuracy: 0.8578
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3695 - accuracy: 0.8706 - val_loss: 0.3665 - val_accuracy: 0.8604
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3379 - accuracy: 0.8762 - val_loss: 0.3453 - val_accuracy: 0.8638
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3177 - accuracy: 0.8812 - val_loss: 0.3319 - val_accuracy: 0.8664
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3016 - accuracy: 0.8845 - val_loss: 0.3231 - val_accuracy: 0.8692
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2887 - accuracy: 0.8886 - val_loss: 0.3179 - val_accuracy: 0.8694
#
# Validation Accuracy: 0.8694082498550415
# Validation Loss: 0.31791752576828003
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8759    0.8308    0.8527      2269
#            1     0.8645    0.9017    0.8827      2716
#
#     accuracy                         0.8694      4985
#    macro avg     0.8702    0.8662    0.8677      4985
# weighted avg     0.8697    0.8694    0.8691      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 30ms/step - loss: 0.6856 - accuracy: 0.5674 - val_loss: 0.6709 - val_accuracy: 0.6383
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6388 - accuracy: 0.7446 - val_loss: 0.6018 - val_accuracy: 0.7994
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5539 - accuracy: 0.8341 - val_loss: 0.5127 - val_accuracy: 0.8429
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4657 - accuracy: 0.8560 - val_loss: 0.4367 - val_accuracy: 0.8566
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4002 - accuracy: 0.8659 - val_loss: 0.3868 - val_accuracy: 0.8604
# Epoch 6/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3560 - accuracy: 0.8732 - val_loss: 0.3568 - val_accuracy: 0.8642
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3285 - accuracy: 0.8789 - val_loss: 0.3383 - val_accuracy: 0.8688
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3088 - accuracy: 0.8832 - val_loss: 0.3269 - val_accuracy: 0.8702
# Epoch 9/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2915 - accuracy: 0.8880 - val_loss: 0.3194 - val_accuracy: 0.8698
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2811 - accuracy: 0.8913 - val_loss: 0.3149 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.31488722562789917
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8708    0.8435    0.8570      2269
#            1     0.8726    0.8954    0.8839      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8717    0.8695    0.8704      4985
# weighted avg     0.8718    0.8718    0.8716      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 33ms/step - loss: 0.6869 - accuracy: 0.5603 - val_loss: 0.6743 - val_accuracy: 0.6307
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6441 - accuracy: 0.7386 - val_loss: 0.6088 - val_accuracy: 0.7992
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5625 - accuracy: 0.8317 - val_loss: 0.5217 - val_accuracy: 0.8479
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4760 - accuracy: 0.8551 - val_loss: 0.4463 - val_accuracy: 0.8550
# Epoch 5/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.4093 - accuracy: 0.8650 - val_loss: 0.3948 - val_accuracy: 0.8566
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3639 - accuracy: 0.8726 - val_loss: 0.3625 - val_accuracy: 0.8618
# Epoch 7/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3338 - accuracy: 0.8769 - val_loss: 0.3424 - val_accuracy: 0.8676
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3129 - accuracy: 0.8835 - val_loss: 0.3295 - val_accuracy: 0.8704
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2957 - accuracy: 0.8864 - val_loss: 0.3212 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2849 - accuracy: 0.8906 - val_loss: 0.3161 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.316084086894989
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8718    0.8422    0.8568      2269
#            1     0.8718    0.8965    0.8840      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8718    0.8694    0.8704      4985
# weighted avg     0.8718    0.8718    0.8716      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8712537612838516
# Average Precision : 0.8700670061202451
# Average Recall : 0.8977908689248896
# Average F1 Score : 0.8710096697852674
