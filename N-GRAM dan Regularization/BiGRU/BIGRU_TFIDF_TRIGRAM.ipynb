# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_TRIGRAM
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(3,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 22s 38ms/step - loss: 0.6915 - accuracy: 0.5487 - val_loss: 0.6899 - val_accuracy: 0.5450
# Epoch 2/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.6875 - accuracy: 0.5475 - val_loss: 0.6861 - val_accuracy: 0.5470
# Epoch 3/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.6817 - accuracy: 0.5622 - val_loss: 0.6806 - val_accuracy: 0.5777
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6719 - accuracy: 0.6077 - val_loss: 0.6712 - val_accuracy: 0.6173
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6564 - accuracy: 0.6547 - val_loss: 0.6578 - val_accuracy: 0.6381
# Epoch 6/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.6365 - accuracy: 0.6779 - val_loss: 0.6430 - val_accuracy: 0.6489
# Epoch 7/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.6154 - accuracy: 0.6877 - val_loss: 0.6288 - val_accuracy: 0.6558
# Epoch 8/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.5953 - accuracy: 0.6918 - val_loss: 0.6170 - val_accuracy: 0.6588
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5780 - accuracy: 0.6937 - val_loss: 0.6081 - val_accuracy: 0.6600
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5638 - accuracy: 0.6954 - val_loss: 0.6015 - val_accuracy: 0.6602
#
# Validation Accuracy: 0.6601805686950684
# Validation Loss: 0.6014713644981384
#
# 156/156 [==============================] - 2s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8331    0.3169    0.4591      2269
#            1     0.6240    0.9470    0.7523      2716
#
#     accuracy                         0.6602      4985
#    macro avg     0.7286    0.6319    0.6057      4985
# weighted avg     0.7192    0.6602    0.6188      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 39ms/step - loss: 0.6921 - accuracy: 0.5442 - val_loss: 0.6908 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.6888 - accuracy: 0.5450 - val_loss: 0.6874 - val_accuracy: 0.5448
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6843 - accuracy: 0.5466 - val_loss: 0.6830 - val_accuracy: 0.5503
# Epoch 4/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6766 - accuracy: 0.5778 - val_loss: 0.6752 - val_accuracy: 0.5922
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6633 - accuracy: 0.6260 - val_loss: 0.6632 - val_accuracy: 0.6239
# Epoch 6/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.6449 - accuracy: 0.6598 - val_loss: 0.6486 - val_accuracy: 0.6443
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.6239 - accuracy: 0.6817 - val_loss: 0.6340 - val_accuracy: 0.6489
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6030 - accuracy: 0.6901 - val_loss: 0.6205 - val_accuracy: 0.6602
# Epoch 9/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.5842 - accuracy: 0.6936 - val_loss: 0.6099 - val_accuracy: 0.6612
# Epoch 10/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.5683 - accuracy: 0.6951 - val_loss: 0.6019 - val_accuracy: 0.6622
#
# Validation Accuracy: 0.6621865630149841
# Validation Loss: 0.6018602252006531
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8405    0.3182    0.4616      2269
#            1     0.6251    0.9496    0.7539      2716
#
#     accuracy                         0.6622      4985
#    macro avg     0.7328    0.6339    0.6078      4985
# weighted avg     0.7231    0.6622    0.6209      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 30ms/step - loss: 0.6914 - accuracy: 0.5463 - val_loss: 0.6899 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6876 - accuracy: 0.5456 - val_loss: 0.6862 - val_accuracy: 0.5454
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6820 - accuracy: 0.5575 - val_loss: 0.6806 - val_accuracy: 0.5713
# Epoch 4/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.6723 - accuracy: 0.6018 - val_loss: 0.6713 - val_accuracy: 0.6062
# Epoch 5/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.6570 - accuracy: 0.6439 - val_loss: 0.6582 - val_accuracy: 0.6355
# Epoch 6/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.6373 - accuracy: 0.6720 - val_loss: 0.6430 - val_accuracy: 0.6467
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6160 - accuracy: 0.6865 - val_loss: 0.6289 - val_accuracy: 0.6516
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5960 - accuracy: 0.6914 - val_loss: 0.6168 - val_accuracy: 0.6556
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.5787 - accuracy: 0.6936 - val_loss: 0.6074 - val_accuracy: 0.6600
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5643 - accuracy: 0.6949 - val_loss: 0.6006 - val_accuracy: 0.6626
#
# Validation Accuracy: 0.6625877618789673
# Validation Loss: 0.6006250977516174
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8377    0.3208    0.4640      2269
#            1     0.6256    0.9481    0.7538      2716
#
#     accuracy                         0.6626      4985
#    macro avg     0.7317    0.6345    0.6089      4985
# weighted avg     0.7222    0.6626    0.6219      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 14s 28ms/step - loss: 0.6915 - accuracy: 0.5440 - val_loss: 0.6898 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6876 - accuracy: 0.5451 - val_loss: 0.6864 - val_accuracy: 0.5452
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6827 - accuracy: 0.5524 - val_loss: 0.6818 - val_accuracy: 0.5623
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6744 - accuracy: 0.5904 - val_loss: 0.6738 - val_accuracy: 0.5946
# Epoch 5/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6607 - accuracy: 0.6322 - val_loss: 0.6617 - val_accuracy: 0.6249
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6421 - accuracy: 0.6633 - val_loss: 0.6472 - val_accuracy: 0.6407
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6212 - accuracy: 0.6805 - val_loss: 0.6327 - val_accuracy: 0.6489
# Epoch 8/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6007 - accuracy: 0.6894 - val_loss: 0.6201 - val_accuracy: 0.6540
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5827 - accuracy: 0.6929 - val_loss: 0.6102 - val_accuracy: 0.6610
# Epoch 10/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.5675 - accuracy: 0.6947 - val_loss: 0.6028 - val_accuracy: 0.6620
#
# Validation Accuracy: 0.6619859337806702
# Validation Loss: 0.6028201580047607
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8380    0.3191    0.4622      2269
#            1     0.6251    0.9485    0.7535      2716
#
#     accuracy                         0.6620      4985
#    macro avg     0.7315    0.6338    0.6079      4985
# weighted avg     0.7220    0.6620    0.6209      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 31ms/step - loss: 0.6916 - accuracy: 0.5447 - val_loss: 0.6900 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6876 - accuracy: 0.5452 - val_loss: 0.6862 - val_accuracy: 0.5452
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6825 - accuracy: 0.5521 - val_loss: 0.6814 - val_accuracy: 0.5607
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6741 - accuracy: 0.5883 - val_loss: 0.6732 - val_accuracy: 0.5956
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6607 - accuracy: 0.6306 - val_loss: 0.6615 - val_accuracy: 0.6201
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6429 - accuracy: 0.6594 - val_loss: 0.6474 - val_accuracy: 0.6411
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6225 - accuracy: 0.6782 - val_loss: 0.6329 - val_accuracy: 0.6518
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6022 - accuracy: 0.6883 - val_loss: 0.6202 - val_accuracy: 0.6588
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5841 - accuracy: 0.6930 - val_loss: 0.6100 - val_accuracy: 0.6602
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5688 - accuracy: 0.6950 - val_loss: 0.6022 - val_accuracy: 0.6606
#
# Validation Accuracy: 0.6605817675590515
# Validation Loss: 0.6022268533706665
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8414    0.3134    0.4566      2269
#            1     0.6237    0.9507    0.7532      2716
#
#     accuracy                         0.6606      4985
#    macro avg     0.7325    0.6320    0.6049      4985
# weighted avg     0.7228    0.6606    0.6182      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU TRIGRAM {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.6615045135406219
# Average Precision : 0.6246798838423188
# Average Recall : 0.9487481590574374
# Average F1 Score : 0.6201480063734459
