# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 22s 42ms/step - loss: 0.6857 - accuracy: 0.5765 - val_loss: 0.6706 - val_accuracy: 0.6694
# Epoch 2/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.6374 - accuracy: 0.7618 - val_loss: 0.5989 - val_accuracy: 0.8114
# Epoch 3/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.5464 - accuracy: 0.8443 - val_loss: 0.5049 - val_accuracy: 0.8487
# Epoch 4/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.4544 - accuracy: 0.8620 - val_loss: 0.4304 - val_accuracy: 0.8556
# Epoch 5/10
# 351/351 [==============================] - 13s 36ms/step - loss: 0.3880 - accuracy: 0.8713 - val_loss: 0.3829 - val_accuracy: 0.8584
# Epoch 6/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.3451 - accuracy: 0.8770 - val_loss: 0.3543 - val_accuracy: 0.8632
# Epoch 7/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.3168 - accuracy: 0.8835 - val_loss: 0.3368 - val_accuracy: 0.8654
# Epoch 8/10
# 351/351 [==============================] - 15s 42ms/step - loss: 0.2970 - accuracy: 0.8878 - val_loss: 0.3258 - val_accuracy: 0.8676
# Epoch 9/10
# 351/351 [==============================] - 16s 47ms/step - loss: 0.2823 - accuracy: 0.8918 - val_loss: 0.3188 - val_accuracy: 0.8696
# Epoch 10/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.2708 - accuracy: 0.8949 - val_loss: 0.3147 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.31474003195762634
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8684    0.8493    0.8587      2269
#            1     0.8764    0.8925    0.8843      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8724    0.8709    0.8715      4985
# weighted avg     0.8727    0.8728    0.8727      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 30s 61ms/step - loss: 0.6863 - accuracy: 0.5915 - val_loss: 0.6715 - val_accuracy: 0.6841
# Epoch 2/10
# 351/351 [==============================] - 18s 52ms/step - loss: 0.6388 - accuracy: 0.7848 - val_loss: 0.6029 - val_accuracy: 0.8171
# Epoch 3/10
# 351/351 [==============================] - 19s 55ms/step - loss: 0.5537 - accuracy: 0.8473 - val_loss: 0.5151 - val_accuracy: 0.8489
# Epoch 4/10
# 351/351 [==============================] - 19s 54ms/step - loss: 0.4653 - accuracy: 0.8622 - val_loss: 0.4410 - val_accuracy: 0.8552
# Epoch 5/10
# 351/351 [==============================] - 17s 48ms/step - loss: 0.3980 - accuracy: 0.8695 - val_loss: 0.3915 - val_accuracy: 0.8588
# Epoch 6/10
# 351/351 [==============================] - 16s 45ms/step - loss: 0.3527 - accuracy: 0.8759 - val_loss: 0.3605 - val_accuracy: 0.8620
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3226 - accuracy: 0.8819 - val_loss: 0.3413 - val_accuracy: 0.8672
# Epoch 8/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3016 - accuracy: 0.8869 - val_loss: 0.3286 - val_accuracy: 0.8694
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2858 - accuracy: 0.8909 - val_loss: 0.3207 - val_accuracy: 0.8694
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2737 - accuracy: 0.8941 - val_loss: 0.3159 - val_accuracy: 0.8718
#
# Validation Accuracy: 0.8718154430389404
# Validation Loss: 0.3158568739891052
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8681    0.8471    0.8575      2269
#            1     0.8748    0.8925    0.8835      2716
#
#     accuracy                         0.8718      4985
#    macro avg     0.8714    0.8698    0.8705      4985
# weighted avg     0.8717    0.8718    0.8717      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 36ms/step - loss: 0.6864 - accuracy: 0.5762 - val_loss: 0.6724 - val_accuracy: 0.6820
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6422 - accuracy: 0.7700 - val_loss: 0.6089 - val_accuracy: 0.8046
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5631 - accuracy: 0.8384 - val_loss: 0.5259 - val_accuracy: 0.8417
# Epoch 4/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4775 - accuracy: 0.8575 - val_loss: 0.4514 - val_accuracy: 0.8570
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4084 - accuracy: 0.8695 - val_loss: 0.3986 - val_accuracy: 0.8596
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3603 - accuracy: 0.8752 - val_loss: 0.3648 - val_accuracy: 0.8616
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3283 - accuracy: 0.8812 - val_loss: 0.3439 - val_accuracy: 0.8644
# Epoch 8/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3060 - accuracy: 0.8861 - val_loss: 0.3305 - val_accuracy: 0.8670
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.2898 - accuracy: 0.8892 - val_loss: 0.3218 - val_accuracy: 0.8686
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2773 - accuracy: 0.8929 - val_loss: 0.3164 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.3164367973804474
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8679    0.8457    0.8567      2269
#            1     0.8738    0.8925    0.8831      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8709    0.8691    0.8699      4985
# weighted avg     0.8711    0.8712    0.8711      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 28ms/step - loss: 0.6860 - accuracy: 0.5680 - val_loss: 0.6709 - val_accuracy: 0.6678
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6369 - accuracy: 0.7542 - val_loss: 0.5980 - val_accuracy: 0.8144
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5461 - accuracy: 0.8419 - val_loss: 0.5052 - val_accuracy: 0.8419
# Epoch 4/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.4545 - accuracy: 0.8618 - val_loss: 0.4302 - val_accuracy: 0.8550
# Epoch 5/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3876 - accuracy: 0.8709 - val_loss: 0.3824 - val_accuracy: 0.8576
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3445 - accuracy: 0.8778 - val_loss: 0.3535 - val_accuracy: 0.8620
# Epoch 7/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3161 - accuracy: 0.8836 - val_loss: 0.3369 - val_accuracy: 0.8660
# Epoch 8/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.2965 - accuracy: 0.8878 - val_loss: 0.3252 - val_accuracy: 0.8686
# Epoch 9/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2820 - accuracy: 0.8915 - val_loss: 0.3185 - val_accuracy: 0.8706
# Epoch 10/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.2706 - accuracy: 0.8949 - val_loss: 0.3146 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.31456366181373596
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8719    0.8427    0.8570      2269
#            1     0.8721    0.8965    0.8842      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8720    0.8696    0.8706      4985
# weighted avg     0.8720    0.8720    0.8718      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 17s 36ms/step - loss: 0.6846 - accuracy: 0.5520 - val_loss: 0.6681 - val_accuracy: 0.6036
# Epoch 2/10
# 351/351 [==============================] - 14s 40ms/step - loss: 0.6335 - accuracy: 0.7117 - val_loss: 0.5951 - val_accuracy: 0.7707
# Epoch 3/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.5454 - accuracy: 0.8236 - val_loss: 0.5063 - val_accuracy: 0.8341
# Epoch 4/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.4568 - accuracy: 0.8586 - val_loss: 0.4321 - val_accuracy: 0.8562
# Epoch 5/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.3896 - accuracy: 0.8706 - val_loss: 0.3836 - val_accuracy: 0.8590
# Epoch 6/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.3458 - accuracy: 0.8774 - val_loss: 0.3544 - val_accuracy: 0.8632
# Epoch 7/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3170 - accuracy: 0.8826 - val_loss: 0.3365 - val_accuracy: 0.8656
# Epoch 8/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.2970 - accuracy: 0.8878 - val_loss: 0.3255 - val_accuracy: 0.8686
# Epoch 9/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.2823 - accuracy: 0.8913 - val_loss: 0.3185 - val_accuracy: 0.8714
# Epoch 10/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.2709 - accuracy: 0.8950 - val_loss: 0.3145 - val_accuracy: 0.8724
#
# Validation Accuracy: 0.8724172711372375
# Validation Loss: 0.3145391643047333
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8686    0.8480    0.8582      2269
#            1     0.8755    0.8929    0.8841      2716
#
#     accuracy                         0.8724      4985
#    macro avg     0.8720    0.8704    0.8711      4985
# weighted avg     0.8723    0.8724    0.8723      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_TRIGRAM {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8720561685055165
# Average Precision : 0.8745089077376595
# Average Recall : 0.8933726067746687
# Average F1 Score : 0.8719015666296659
