# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(use_idf=True, smooth_idf=False, ngram_range=(1,1), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 23s 35ms/step - loss: 0.6857 - accuracy: 0.5480 - val_loss: 0.6713 - val_accuracy: 0.5829
# Epoch 2/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6389 - accuracy: 0.7055 - val_loss: 0.6024 - val_accuracy: 0.7968
# Epoch 3/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.5538 - accuracy: 0.8282 - val_loss: 0.5157 - val_accuracy: 0.8437
# Epoch 4/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.4676 - accuracy: 0.8587 - val_loss: 0.4442 - val_accuracy: 0.8526
# Epoch 5/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4017 - accuracy: 0.8688 - val_loss: 0.3957 - val_accuracy: 0.8564
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3572 - accuracy: 0.8748 - val_loss: 0.3659 - val_accuracy: 0.8592
# Epoch 7/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.3274 - accuracy: 0.8805 - val_loss: 0.3476 - val_accuracy: 0.8636
# Epoch 8/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.3066 - accuracy: 0.8852 - val_loss: 0.3358 - val_accuracy: 0.8646
# Epoch 9/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2911 - accuracy: 0.8900 - val_loss: 0.3289 - val_accuracy: 0.8626
# Epoch 10/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.2791 - accuracy: 0.8937 - val_loss: 0.3244 - val_accuracy: 0.8632
#
# Validation Accuracy: 0.8631895780563354
# Validation Loss: 0.32435983419418335
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8632    0.8312    0.8469      2269
#            1     0.8632    0.8899    0.8764      2716
#
#     accuracy                         0.8632      4985
#    macro avg     0.8632    0.8606    0.8616      4985
# weighted avg     0.8632    0.8632    0.8629      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 23s 50ms/step - loss: 0.6833 - accuracy: 0.5473 - val_loss: 0.6657 - val_accuracy: 0.5685
# Epoch 2/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.6330 - accuracy: 0.6649 - val_loss: 0.5986 - val_accuracy: 0.7420
# Epoch 3/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.5548 - accuracy: 0.7965 - val_loss: 0.5217 - val_accuracy: 0.8233
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4772 - accuracy: 0.8519 - val_loss: 0.4561 - val_accuracy: 0.8504
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4137 - accuracy: 0.8697 - val_loss: 0.4075 - val_accuracy: 0.8588
# Epoch 6/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.3669 - accuracy: 0.8777 - val_loss: 0.3736 - val_accuracy: 0.8612
# Epoch 7/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3337 - accuracy: 0.8837 - val_loss: 0.3518 - val_accuracy: 0.8640
# Epoch 8/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3102 - accuracy: 0.8876 - val_loss: 0.3383 - val_accuracy: 0.8650
# Epoch 9/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.2932 - accuracy: 0.8922 - val_loss: 0.3302 - val_accuracy: 0.8658
# Epoch 10/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.2804 - accuracy: 0.8958 - val_loss: 0.3254 - val_accuracy: 0.8672
#
# Validation Accuracy: 0.8672016263008118
# Validation Loss: 0.3253902494907379
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8687    0.8343    0.8512      2269
#            1     0.8660    0.8947    0.8801      2716
#
#     accuracy                         0.8672      4985
#    macro avg     0.8674    0.8645    0.8656      4985
# weighted avg     0.8673    0.8672    0.8669      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 20s 36ms/step - loss: 0.6857 - accuracy: 0.5673 - val_loss: 0.6711 - val_accuracy: 0.6774
# Epoch 2/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.6422 - accuracy: 0.7701 - val_loss: 0.6092 - val_accuracy: 0.8150
# Epoch 3/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5649 - accuracy: 0.8438 - val_loss: 0.5280 - val_accuracy: 0.8467
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4816 - accuracy: 0.8614 - val_loss: 0.4564 - val_accuracy: 0.8540
# Epoch 5/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.4147 - accuracy: 0.8682 - val_loss: 0.4055 - val_accuracy: 0.8564
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3679 - accuracy: 0.8739 - val_loss: 0.3728 - val_accuracy: 0.8590
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3360 - accuracy: 0.8798 - val_loss: 0.3522 - val_accuracy: 0.8614
# Epoch 8/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3135 - accuracy: 0.8841 - val_loss: 0.3389 - val_accuracy: 0.8642
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.2967 - accuracy: 0.8880 - val_loss: 0.3304 - val_accuracy: 0.8624
# Epoch 10/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.2840 - accuracy: 0.8923 - val_loss: 0.3251 - val_accuracy: 0.8648
#
# Validation Accuracy: 0.8647943735122681
# Validation Loss: 0.32509130239486694
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8687    0.8281    0.8479      2269
#            1     0.8618    0.8954    0.8783      2716
#
#     accuracy                         0.8648      4985
#    macro avg     0.8653    0.8618    0.8631      4985
# weighted avg     0.8649    0.8648    0.8645      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 38ms/step - loss: 0.6839 - accuracy: 0.5507 - val_loss: 0.6683 - val_accuracy: 0.5868
# Epoch 2/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.6374 - accuracy: 0.7005 - val_loss: 0.6034 - val_accuracy: 0.7577
# Epoch 3/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.5588 - accuracy: 0.8164 - val_loss: 0.5238 - val_accuracy: 0.8285
# Epoch 4/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4782 - accuracy: 0.8546 - val_loss: 0.4550 - val_accuracy: 0.8540
# Epoch 5/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4134 - accuracy: 0.8687 - val_loss: 0.4056 - val_accuracy: 0.8596
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3668 - accuracy: 0.8748 - val_loss: 0.3726 - val_accuracy: 0.8606
# Epoch 7/10
# 351/351 [==============================] - 14s 41ms/step - loss: 0.3347 - accuracy: 0.8805 - val_loss: 0.3522 - val_accuracy: 0.8650
# Epoch 8/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3120 - accuracy: 0.8848 - val_loss: 0.3390 - val_accuracy: 0.8638
# Epoch 9/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.2956 - accuracy: 0.8895 - val_loss: 0.3308 - val_accuracy: 0.8656
# Epoch 10/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.2829 - accuracy: 0.8929 - val_loss: 0.3268 - val_accuracy: 0.8660
#
# Validation Accuracy: 0.8659979701042175
# Validation Loss: 0.32682862877845764
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8749    0.8233    0.8483      2269
#            1     0.8593    0.9017    0.8800      2716
#
#     accuracy                         0.8660      4985
#    macro avg     0.8671    0.8625    0.8642      4985
# weighted avg     0.8664    0.8660    0.8656      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 39ms/step - loss: 0.6846 - accuracy: 0.5574 - val_loss: 0.6685 - val_accuracy: 0.6056
# Epoch 2/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6362 - accuracy: 0.7131 - val_loss: 0.6011 - val_accuracy: 0.7821
# Epoch 3/10
# 351/351 [==============================] - 13s 36ms/step - loss: 0.5542 - accuracy: 0.8285 - val_loss: 0.5178 - val_accuracy: 0.8355
# Epoch 4/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.4708 - accuracy: 0.8583 - val_loss: 0.4481 - val_accuracy: 0.8552
# Epoch 5/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4063 - accuracy: 0.8686 - val_loss: 0.4002 - val_accuracy: 0.8602
# Epoch 6/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3619 - accuracy: 0.8750 - val_loss: 0.3698 - val_accuracy: 0.8624
# Epoch 7/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3315 - accuracy: 0.8802 - val_loss: 0.3503 - val_accuracy: 0.8642
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3100 - accuracy: 0.8850 - val_loss: 0.3378 - val_accuracy: 0.8618
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.2941 - accuracy: 0.8894 - val_loss: 0.3303 - val_accuracy: 0.8642
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2818 - accuracy: 0.8936 - val_loss: 0.3251 - val_accuracy: 0.8636
#
# Validation Accuracy: 0.8635907769203186
# Validation Loss: 0.32514485716819763
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8626    0.8330    0.8475      2269
#            1     0.8644    0.8892    0.8766      2716
#
#     accuracy                         0.8636      4985
#    macro avg     0.8635    0.8611    0.8621      4985
# weighted avg     0.8636    0.8636    0.8634      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function Bi-GRU UNIGRAM {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8649548645937812
# Average Precision : 0.8629332563676673
# Average Recall : 0.894182621502209
# Average F1 Score : 0.8646577652950942
