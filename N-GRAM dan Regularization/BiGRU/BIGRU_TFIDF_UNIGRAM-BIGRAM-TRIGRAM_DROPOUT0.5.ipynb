# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 27ms/step - loss: 0.6863 - accuracy: 0.5558 - val_loss: 0.6740 - val_accuracy: 0.5898
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.6489 - accuracy: 0.6885 - val_loss: 0.6200 - val_accuracy: 0.7440
# Epoch 3/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.5834 - accuracy: 0.7850 - val_loss: 0.5482 - val_accuracy: 0.8150
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5111 - accuracy: 0.8310 - val_loss: 0.4798 - val_accuracy: 0.8469
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4497 - accuracy: 0.8507 - val_loss: 0.4261 - val_accuracy: 0.8578
# Epoch 6/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4030 - accuracy: 0.8608 - val_loss: 0.3877 - val_accuracy: 0.8624
# Epoch 7/10
# 351/351 [==============================] - 15s 42ms/step - loss: 0.3701 - accuracy: 0.8681 - val_loss: 0.3619 - val_accuracy: 0.8670
# Epoch 8/10
# 351/351 [==============================] - 13s 36ms/step - loss: 0.3457 - accuracy: 0.8739 - val_loss: 0.3443 - val_accuracy: 0.8680
# Epoch 9/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3284 - accuracy: 0.8781 - val_loss: 0.3326 - val_accuracy: 0.8700
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3150 - accuracy: 0.8828 - val_loss: 0.3252 - val_accuracy: 0.8696
#
# Validation Accuracy: 0.8696088194847107
# Validation Loss: 0.32523393630981445
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8781    0.8286    0.8526      2269
#            1     0.8632    0.9039    0.8831      2716
#
#     accuracy                         0.8696      4985
#    macro avg     0.8707    0.8662    0.8679      4985
# weighted avg     0.8700    0.8696    0.8692      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 33ms/step - loss: 0.6881 - accuracy: 0.5492 - val_loss: 0.6784 - val_accuracy: 0.5543
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6555 - accuracy: 0.6691 - val_loss: 0.6277 - val_accuracy: 0.7268
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5906 - accuracy: 0.7882 - val_loss: 0.5527 - val_accuracy: 0.8249
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5120 - accuracy: 0.8386 - val_loss: 0.4764 - val_accuracy: 0.8499
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4449 - accuracy: 0.8539 - val_loss: 0.4188 - val_accuracy: 0.8602
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3954 - accuracy: 0.8629 - val_loss: 0.3806 - val_accuracy: 0.8598
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3624 - accuracy: 0.8696 - val_loss: 0.3556 - val_accuracy: 0.8654
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3389 - accuracy: 0.8754 - val_loss: 0.3395 - val_accuracy: 0.8682
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3214 - accuracy: 0.8788 - val_loss: 0.3290 - val_accuracy: 0.8686
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3086 - accuracy: 0.8839 - val_loss: 0.3217 - val_accuracy: 0.8726
#
# Validation Accuracy: 0.8726178407669067
# Validation Loss: 0.3216705918312073
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8755    0.8396    0.8571      2269
#            1     0.8704    0.9002    0.8851      2716
#
#     accuracy                         0.8726      4985
#    macro avg     0.8729    0.8699    0.8711      4985
# weighted avg     0.8727    0.8726    0.8724      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 18s 36ms/step - loss: 0.6881 - accuracy: 0.5504 - val_loss: 0.6783 - val_accuracy: 0.5633
# Epoch 2/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6551 - accuracy: 0.6671 - val_loss: 0.6250 - val_accuracy: 0.7492
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5844 - accuracy: 0.7904 - val_loss: 0.5460 - val_accuracy: 0.8235
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5053 - accuracy: 0.8347 - val_loss: 0.4716 - val_accuracy: 0.8487
# Epoch 5/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4403 - accuracy: 0.8521 - val_loss: 0.4163 - val_accuracy: 0.8588
# Epoch 6/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3937 - accuracy: 0.8620 - val_loss: 0.3791 - val_accuracy: 0.8630
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3598 - accuracy: 0.8706 - val_loss: 0.3548 - val_accuracy: 0.8656
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3380 - accuracy: 0.8733 - val_loss: 0.3393 - val_accuracy: 0.8682
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3201 - accuracy: 0.8801 - val_loss: 0.3289 - val_accuracy: 0.8698
# Epoch 10/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3060 - accuracy: 0.8855 - val_loss: 0.3214 - val_accuracy: 0.8706
#
# Validation Accuracy: 0.870611846446991
# Validation Loss: 0.3214411437511444
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8738    0.8365    0.8548      2269
#            1     0.8681    0.8991    0.8833      2716
#
#     accuracy                         0.8706      4985
#    macro avg     0.8710    0.8678    0.8691      4985
# weighted avg     0.8707    0.8706    0.8703      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 20s 33ms/step - loss: 0.6893 - accuracy: 0.6076 - val_loss: 0.6811 - val_accuracy: 0.7276
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6604 - accuracy: 0.7919 - val_loss: 0.6347 - val_accuracy: 0.8491
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5996 - accuracy: 0.8339 - val_loss: 0.5644 - val_accuracy: 0.8554
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5251 - accuracy: 0.8465 - val_loss: 0.4914 - val_accuracy: 0.8564
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4598 - accuracy: 0.8527 - val_loss: 0.4335 - val_accuracy: 0.8606
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4103 - accuracy: 0.8612 - val_loss: 0.3928 - val_accuracy: 0.8618
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3748 - accuracy: 0.8675 - val_loss: 0.3651 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.3492 - accuracy: 0.8736 - val_loss: 0.3464 - val_accuracy: 0.8680
# Epoch 9/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3304 - accuracy: 0.8785 - val_loss: 0.3336 - val_accuracy: 0.8692
# Epoch 10/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3163 - accuracy: 0.8825 - val_loss: 0.3248 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.32482922077178955
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8758    0.8356    0.8552      2269
#            1     0.8677    0.9010    0.8840      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8717    0.8683    0.8696      4985
# weighted avg     0.8714    0.8712    0.8709      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 31ms/step - loss: 0.6879 - accuracy: 0.5886 - val_loss: 0.6775 - val_accuracy: 0.6556
# Epoch 2/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6539 - accuracy: 0.7476 - val_loss: 0.6249 - val_accuracy: 0.8138
# Epoch 3/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.5845 - accuracy: 0.8256 - val_loss: 0.5443 - val_accuracy: 0.8504
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5015 - accuracy: 0.8492 - val_loss: 0.4660 - val_accuracy: 0.8560
# Epoch 5/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4322 - accuracy: 0.8566 - val_loss: 0.4089 - val_accuracy: 0.8584
# Epoch 6/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3854 - accuracy: 0.8660 - val_loss: 0.3726 - val_accuracy: 0.8628
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3536 - accuracy: 0.8710 - val_loss: 0.3493 - val_accuracy: 0.8648
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3308 - accuracy: 0.8763 - val_loss: 0.3343 - val_accuracy: 0.8666
# Epoch 9/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3138 - accuracy: 0.8819 - val_loss: 0.3243 - val_accuracy: 0.8702
# Epoch 10/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3007 - accuracy: 0.8853 - val_loss: 0.3182 - val_accuracy: 0.8706
#
# Validation Accuracy: 0.870611846446991
# Validation Loss: 0.3181534707546234
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8738    0.8365    0.8548      2269
#            1     0.8681    0.8991    0.8833      2716
#
#     accuracy                         0.8706      4985
#    macro avg     0.8710    0.8678    0.8691      4985
# weighted avg     0.8707    0.8706    0.8703      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8709327983951856
# Average Precision : 0.8675185003419716
# Average Recall : 0.9006627393225332
# Average F1 Score : 0.8706310689770367
