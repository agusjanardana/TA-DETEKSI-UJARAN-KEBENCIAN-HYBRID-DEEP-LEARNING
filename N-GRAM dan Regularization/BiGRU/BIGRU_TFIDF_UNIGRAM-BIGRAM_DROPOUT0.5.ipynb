# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.3
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 27ms/step - loss: 0.6869 - accuracy: 0.5950 - val_loss: 0.6741 - val_accuracy: 0.6913
# Epoch 2/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6443 - accuracy: 0.7727 - val_loss: 0.6093 - val_accuracy: 0.8309
# Epoch 3/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.5654 - accuracy: 0.8347 - val_loss: 0.5245 - val_accuracy: 0.8471
# Epoch 4/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.4831 - accuracy: 0.8504 - val_loss: 0.4500 - val_accuracy: 0.8602
# Epoch 5/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.4192 - accuracy: 0.8602 - val_loss: 0.3985 - val_accuracy: 0.8626
# Epoch 6/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3779 - accuracy: 0.8674 - val_loss: 0.3659 - val_accuracy: 0.8656
# Epoch 7/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.3465 - accuracy: 0.8738 - val_loss: 0.3446 - val_accuracy: 0.8680
# Epoch 8/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3252 - accuracy: 0.8793 - val_loss: 0.3305 - val_accuracy: 0.8704
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3084 - accuracy: 0.8850 - val_loss: 0.3214 - val_accuracy: 0.8722
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2973 - accuracy: 0.8877 - val_loss: 0.3157 - val_accuracy: 0.8728
#
# Validation Accuracy: 0.8728184700012207
# Validation Loss: 0.3156527578830719
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8707    0.8462    0.8583      2269
#            1     0.8745    0.8951    0.8846      2716
#
#     accuracy                         0.8728      4985
#    macro avg     0.8726    0.8706    0.8715      4985
# weighted avg     0.8728    0.8728    0.8726      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 28ms/step - loss: 0.6877 - accuracy: 0.5770 - val_loss: 0.6766 - val_accuracy: 0.6598
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6481 - accuracy: 0.7551 - val_loss: 0.6141 - val_accuracy: 0.8100
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5699 - accuracy: 0.8257 - val_loss: 0.5286 - val_accuracy: 0.8403
# Epoch 4/10
# 351/351 [==============================] - 9s 24ms/step - loss: 0.4860 - accuracy: 0.8475 - val_loss: 0.4530 - val_accuracy: 0.8560
# Epoch 5/10
# 351/351 [==============================] - 8s 23ms/step - loss: 0.4213 - accuracy: 0.8580 - val_loss: 0.4010 - val_accuracy: 0.8602
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3785 - accuracy: 0.8668 - val_loss: 0.3680 - val_accuracy: 0.8612
# Epoch 7/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.3491 - accuracy: 0.8732 - val_loss: 0.3470 - val_accuracy: 0.8640
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3262 - accuracy: 0.8776 - val_loss: 0.3331 - val_accuracy: 0.8696
# Epoch 9/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.3116 - accuracy: 0.8811 - val_loss: 0.3241 - val_accuracy: 0.8706
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.2996 - accuracy: 0.8863 - val_loss: 0.3182 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.31821978092193604
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8740    0.8378    0.8555      2269
#            1     0.8690    0.8991    0.8838      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8715    0.8685    0.8697      4985
# weighted avg     0.8713    0.8712    0.8709      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 16s 27ms/step - loss: 0.6866 - accuracy: 0.5466 - val_loss: 0.6755 - val_accuracy: 0.5490
# Epoch 2/10
# 351/351 [==============================] - 8s 24ms/step - loss: 0.6522 - accuracy: 0.6469 - val_loss: 0.6233 - val_accuracy: 0.7364
# Epoch 3/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5853 - accuracy: 0.7866 - val_loss: 0.5473 - val_accuracy: 0.8217
# Epoch 4/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.5063 - accuracy: 0.8376 - val_loss: 0.4715 - val_accuracy: 0.8508
# Epoch 5/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4375 - accuracy: 0.8558 - val_loss: 0.4137 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3884 - accuracy: 0.8645 - val_loss: 0.3755 - val_accuracy: 0.8658
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3544 - accuracy: 0.8738 - val_loss: 0.3507 - val_accuracy: 0.8666
# Epoch 8/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3309 - accuracy: 0.8770 - val_loss: 0.3352 - val_accuracy: 0.8692
# Epoch 9/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3144 - accuracy: 0.8824 - val_loss: 0.3257 - val_accuracy: 0.8710
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3007 - accuracy: 0.8859 - val_loss: 0.3191 - val_accuracy: 0.8704
#
# Validation Accuracy: 0.870411217212677
# Validation Loss: 0.3190821707248688
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8748    0.8347    0.8543      2269
#            1     0.8670    0.9002    0.8833      2716
#
#     accuracy                         0.8704      4985
#    macro avg     0.8709    0.8675    0.8688      4985
# weighted avg     0.8706    0.8704    0.8701      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 29ms/step - loss: 0.6880 - accuracy: 0.5933 - val_loss: 0.6779 - val_accuracy: 0.6584
# Epoch 2/10
# 351/351 [==============================] - 9s 24ms/step - loss: 0.6551 - accuracy: 0.7500 - val_loss: 0.6267 - val_accuracy: 0.8020
# Epoch 3/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.5876 - accuracy: 0.8215 - val_loss: 0.5484 - val_accuracy: 0.8421
# Epoch 4/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.5075 - accuracy: 0.8441 - val_loss: 0.4718 - val_accuracy: 0.8564
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4411 - accuracy: 0.8530 - val_loss: 0.4150 - val_accuracy: 0.8622
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3913 - accuracy: 0.8638 - val_loss: 0.3766 - val_accuracy: 0.8660
# Epoch 7/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3597 - accuracy: 0.8686 - val_loss: 0.3525 - val_accuracy: 0.8664
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3365 - accuracy: 0.8754 - val_loss: 0.3366 - val_accuracy: 0.8676
# Epoch 9/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.3165 - accuracy: 0.8810 - val_loss: 0.3259 - val_accuracy: 0.8702
# Epoch 10/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3056 - accuracy: 0.8846 - val_loss: 0.3192 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.8716148734092712
# Validation Loss: 0.31918007135391235
#
# 156/156 [==============================] - 1s 5ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8762    0.8361    0.8557      2269
#            1     0.8681    0.9013    0.8844      2716
#
#     accuracy                         0.8716      4985
#    macro avg     0.8721    0.8687    0.8700      4985
# weighted avg     0.8718    0.8716    0.8713      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 15s 31ms/step - loss: 0.6893 - accuracy: 0.5795 - val_loss: 0.6815 - val_accuracy: 0.6325
# Epoch 2/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.6625 - accuracy: 0.7430 - val_loss: 0.6374 - val_accuracy: 0.8339
# Epoch 3/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.6020 - accuracy: 0.8284 - val_loss: 0.5660 - val_accuracy: 0.8536
# Epoch 4/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.5262 - accuracy: 0.8475 - val_loss: 0.4912 - val_accuracy: 0.8586
# Epoch 5/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4572 - accuracy: 0.8550 - val_loss: 0.4308 - val_accuracy: 0.8608
# Epoch 6/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.4063 - accuracy: 0.8619 - val_loss: 0.3882 - val_accuracy: 0.8618
# Epoch 7/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3683 - accuracy: 0.8683 - val_loss: 0.3600 - val_accuracy: 0.8646
# Epoch 8/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3421 - accuracy: 0.8752 - val_loss: 0.3417 - val_accuracy: 0.8668
# Epoch 9/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3235 - accuracy: 0.8796 - val_loss: 0.3296 - val_accuracy: 0.8686
# Epoch 10/10
# 351/351 [==============================] - 9s 25ms/step - loss: 0.3096 - accuracy: 0.8839 - val_loss: 0.3214 - val_accuracy: 0.8712
#
# Validation Accuracy: 0.8712136149406433
# Validation Loss: 0.32143497467041016
#
# 156/156 [==============================] - 1s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8730    0.8391    0.8557      2269
#            1     0.8698    0.8980    0.8837      2716
#
#     accuracy                         0.8712      4985
#    macro avg     0.8714    0.8686    0.8697      4985
# weighted avg     0.8713    0.8712    0.8710      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM_DROPOUT0.3 {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8714543630892677
# Average Precision : 0.8696869553036096
# Average Recall : 0.8987481590574374
# Average F1 Score : 0.8711973789989935
