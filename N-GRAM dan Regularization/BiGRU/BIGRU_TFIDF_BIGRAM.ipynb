# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_BIGRAM
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(2,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 34ms/step - loss: 0.6895 - accuracy: 0.5444 - val_loss: 0.6845 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6727 - accuracy: 0.5732 - val_loss: 0.6574 - val_accuracy: 0.6291
# Epoch 3/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.6312 - accuracy: 0.6794 - val_loss: 0.6096 - val_accuracy: 0.7027
# Epoch 4/10
# 351/351 [==============================] - 13s 36ms/step - loss: 0.5737 - accuracy: 0.7409 - val_loss: 0.5580 - val_accuracy: 0.7476
# Epoch 5/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.5186 - accuracy: 0.7747 - val_loss: 0.5163 - val_accuracy: 0.7581
# Epoch 6/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.4748 - accuracy: 0.7885 - val_loss: 0.4873 - val_accuracy: 0.7643
# Epoch 7/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4425 - accuracy: 0.7956 - val_loss: 0.4688 - val_accuracy: 0.7641
# Epoch 8/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4190 - accuracy: 0.7997 - val_loss: 0.4577 - val_accuracy: 0.7643
# Epoch 9/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4016 - accuracy: 0.8073 - val_loss: 0.4515 - val_accuracy: 0.7693
# Epoch 10/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3884 - accuracy: 0.8154 - val_loss: 0.4485 - val_accuracy: 0.7691
#
# Validation Accuracy: 0.7691073417663574
# Validation Loss: 0.44850602746009827
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7208    0.8043    0.7603      2269
#            1     0.8190    0.7397    0.7773      2716
#
#     accuracy                         0.7691      4985
#    macro avg     0.7699    0.7720    0.7688      4985
# weighted avg     0.7743    0.7691    0.7696      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 20s 39ms/step - loss: 0.6899 - accuracy: 0.5446 - val_loss: 0.6850 - val_accuracy: 0.5555
# Epoch 2/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.6730 - accuracy: 0.5904 - val_loss: 0.6578 - val_accuracy: 0.6423
# Epoch 3/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.6319 - accuracy: 0.6889 - val_loss: 0.6112 - val_accuracy: 0.7011
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5754 - accuracy: 0.7465 - val_loss: 0.5598 - val_accuracy: 0.7452
# Epoch 5/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.5201 - accuracy: 0.7764 - val_loss: 0.5175 - val_accuracy: 0.7581
# Epoch 6/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4744 - accuracy: 0.7884 - val_loss: 0.4872 - val_accuracy: 0.7635
# Epoch 7/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.4412 - accuracy: 0.7944 - val_loss: 0.4689 - val_accuracy: 0.7641
# Epoch 8/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4177 - accuracy: 0.8005 - val_loss: 0.4582 - val_accuracy: 0.7639
# Epoch 9/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.4005 - accuracy: 0.8091 - val_loss: 0.4528 - val_accuracy: 0.7635
# Epoch 10/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3876 - accuracy: 0.8133 - val_loss: 0.4499 - val_accuracy: 0.7659
#
# Validation Accuracy: 0.7658976912498474
# Validation Loss: 0.44992712140083313
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8152    0.6280    0.7095      2269
#            1     0.7393    0.8811    0.8040      2716
#
#     accuracy                         0.7659      4985
#    macro avg     0.7772    0.7546    0.7567      4985
# weighted avg     0.7738    0.7659    0.7610      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 24s 54ms/step - loss: 0.6899 - accuracy: 0.5426 - val_loss: 0.6850 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.6745 - accuracy: 0.5673 - val_loss: 0.6612 - val_accuracy: 0.6209
# Epoch 3/10
# 351/351 [==============================] - 11s 33ms/step - loss: 0.6361 - accuracy: 0.6757 - val_loss: 0.6138 - val_accuracy: 0.7107
# Epoch 4/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.5779 - accuracy: 0.7451 - val_loss: 0.5606 - val_accuracy: 0.7438
# Epoch 5/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.5205 - accuracy: 0.7758 - val_loss: 0.5168 - val_accuracy: 0.7585
# Epoch 6/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4747 - accuracy: 0.7883 - val_loss: 0.4870 - val_accuracy: 0.7631
# Epoch 7/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.4417 - accuracy: 0.7942 - val_loss: 0.4687 - val_accuracy: 0.7637
# Epoch 8/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.4181 - accuracy: 0.8004 - val_loss: 0.4583 - val_accuracy: 0.7665
# Epoch 9/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.4010 - accuracy: 0.8102 - val_loss: 0.4523 - val_accuracy: 0.7683
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3879 - accuracy: 0.8149 - val_loss: 0.4496 - val_accuracy: 0.7683
#
# Validation Accuracy: 0.7683049440383911
# Validation Loss: 0.44964316487312317
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7210    0.8008    0.7588      2269
#            1     0.8166    0.7412    0.7771      2716
#
#     accuracy                         0.7683      4985
#    macro avg     0.7688    0.7710    0.7679      4985
# weighted avg     0.7731    0.7683    0.7688      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 20s 42ms/step - loss: 0.6898 - accuracy: 0.5443 - val_loss: 0.6852 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.6746 - accuracy: 0.5606 - val_loss: 0.6620 - val_accuracy: 0.5980
# Epoch 3/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.6390 - accuracy: 0.6539 - val_loss: 0.6199 - val_accuracy: 0.6869
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5860 - accuracy: 0.7253 - val_loss: 0.5708 - val_accuracy: 0.7270
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5312 - accuracy: 0.7682 - val_loss: 0.5263 - val_accuracy: 0.7557
# Epoch 6/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.4834 - accuracy: 0.7873 - val_loss: 0.4937 - val_accuracy: 0.7609
# Epoch 7/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.4477 - accuracy: 0.7952 - val_loss: 0.4729 - val_accuracy: 0.7649
# Epoch 8/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.4221 - accuracy: 0.8039 - val_loss: 0.4606 - val_accuracy: 0.7679
# Epoch 9/10
# 351/351 [==============================] - 12s 33ms/step - loss: 0.4035 - accuracy: 0.8096 - val_loss: 0.4537 - val_accuracy: 0.7681
# Epoch 10/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3896 - accuracy: 0.8142 - val_loss: 0.4506 - val_accuracy: 0.7679
#
# Validation Accuracy: 0.7679036855697632
# Validation Loss: 0.45055919885635376
#
# 156/156 [==============================] - 1s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7174    0.8087    0.7603      2269
#            1     0.8212    0.7338    0.7750      2716
#
#     accuracy                         0.7679      4985
#    macro avg     0.7693    0.7713    0.7677      4985
# weighted avg     0.7739    0.7679    0.7683      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 19s 38ms/step - loss: 0.6888 - accuracy: 0.5451 - val_loss: 0.6825 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6691 - accuracy: 0.5757 - val_loss: 0.6531 - val_accuracy: 0.6269
# Epoch 3/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.6262 - accuracy: 0.6811 - val_loss: 0.6051 - val_accuracy: 0.7021
# Epoch 4/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.5692 - accuracy: 0.7414 - val_loss: 0.5546 - val_accuracy: 0.7480
# Epoch 5/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.5147 - accuracy: 0.7769 - val_loss: 0.5134 - val_accuracy: 0.7555
# Epoch 6/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.4710 - accuracy: 0.7887 - val_loss: 0.4850 - val_accuracy: 0.7649
# Epoch 7/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4388 - accuracy: 0.7966 - val_loss: 0.4669 - val_accuracy: 0.7659
# Epoch 8/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4153 - accuracy: 0.8018 - val_loss: 0.4563 - val_accuracy: 0.7673
# Epoch 9/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3981 - accuracy: 0.8095 - val_loss: 0.4509 - val_accuracy: 0.7697
# Epoch 10/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.3851 - accuracy: 0.8159 - val_loss: 0.4484 - val_accuracy: 0.7713
#
# Validation Accuracy: 0.7713139653205872
# Validation Loss: 0.4484030604362488
#
# 156/156 [==============================] - 2s 6ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7222    0.8087    0.7630      2269
#            1     0.8224    0.7401    0.7791      2716
#
#     accuracy                         0.7713      4985
#    macro avg     0.7723    0.7744    0.7710      4985
# weighted avg     0.7768    0.7713    0.7718      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function Bi-GRU BIGRAM {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_BIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_BIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.7685055165496488
# Average Precision : 0.8036990851713032
# Average Recall : 0.7671575846833579
# Average F1 Score : 0.7678731007114423
