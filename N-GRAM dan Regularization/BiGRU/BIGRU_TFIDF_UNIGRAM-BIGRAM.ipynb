# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'device_name': 'NVIDIA GeForce GTX 1660 Ti with Max-Q Design', 'compute_capability': (7, 5)}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGRU_TFIDF_UNIGRAM_BIGRAM
# Copyright @ I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           1926528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 24s 44ms/step - loss: 0.6840 - accuracy: 0.5548 - val_loss: 0.6670 - val_accuracy: 0.6197
# Epoch 2/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.6314 - accuracy: 0.7272 - val_loss: 0.5926 - val_accuracy: 0.7904
# Epoch 3/10
# 351/351 [==============================] - 15s 44ms/step - loss: 0.5419 - accuracy: 0.8324 - val_loss: 0.5031 - val_accuracy: 0.8379
# Epoch 4/10
# 351/351 [==============================] - 19s 54ms/step - loss: 0.4536 - accuracy: 0.8603 - val_loss: 0.4303 - val_accuracy: 0.8558
# Epoch 5/10
# 351/351 [==============================] - 18s 51ms/step - loss: 0.3876 - accuracy: 0.8713 - val_loss: 0.3823 - val_accuracy: 0.8606
# Epoch 6/10
# 351/351 [==============================] - 16s 45ms/step - loss: 0.3439 - accuracy: 0.8780 - val_loss: 0.3530 - val_accuracy: 0.8632
# Epoch 7/10
# 351/351 [==============================] - 17s 49ms/step - loss: 0.3150 - accuracy: 0.8838 - val_loss: 0.3350 - val_accuracy: 0.8654
# Epoch 8/10
# 351/351 [==============================] - 19s 53ms/step - loss: 0.2949 - accuracy: 0.8887 - val_loss: 0.3242 - val_accuracy: 0.8704
# Epoch 9/10
# 351/351 [==============================] - 18s 51ms/step - loss: 0.2801 - accuracy: 0.8927 - val_loss: 0.3174 - val_accuracy: 0.8706
# Epoch 10/10
# 351/351 [==============================] - 17s 48ms/step - loss: 0.2688 - accuracy: 0.8962 - val_loss: 0.3134 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714142441749573
# Validation Loss: 0.31335607171058655
#
# 156/156 [==============================] - 3s 11ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8677    0.8466    0.8570      2269
#            1     0.8744    0.8921    0.8832      2716
#
#     accuracy                         0.8714      4985
#    macro avg     0.8710    0.8694    0.8701      4985
# weighted avg     0.8713    0.8714    0.8713      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 30s 59ms/step - loss: 0.6855 - accuracy: 0.5599 - val_loss: 0.6697 - val_accuracy: 0.6331
# Epoch 2/10
# 351/351 [==============================] - 18s 51ms/step - loss: 0.6351 - accuracy: 0.7291 - val_loss: 0.5967 - val_accuracy: 0.7966
# Epoch 3/10
# 351/351 [==============================] - 18s 50ms/step - loss: 0.5471 - accuracy: 0.8290 - val_loss: 0.5083 - val_accuracy: 0.8361
# Epoch 4/10
# 351/351 [==============================] - 15s 42ms/step - loss: 0.4596 - accuracy: 0.8578 - val_loss: 0.4359 - val_accuracy: 0.8556
# Epoch 5/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.3936 - accuracy: 0.8707 - val_loss: 0.3875 - val_accuracy: 0.8612
# Epoch 6/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.3492 - accuracy: 0.8779 - val_loss: 0.3571 - val_accuracy: 0.8632
# Epoch 7/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.3194 - accuracy: 0.8839 - val_loss: 0.3380 - val_accuracy: 0.8662
# Epoch 8/10
# 351/351 [==============================] - 13s 36ms/step - loss: 0.2984 - accuracy: 0.8887 - val_loss: 0.3260 - val_accuracy: 0.8664
# Epoch 9/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.2830 - accuracy: 0.8924 - val_loss: 0.3188 - val_accuracy: 0.8696
# Epoch 10/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.2710 - accuracy: 0.8957 - val_loss: 0.3145 - val_accuracy: 0.8720
#
# Validation Accuracy: 0.8720160722732544
# Validation Loss: 0.3144591450691223
#
# 156/156 [==============================] - 2s 7ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8749    0.8387    0.8564      2269
#            1     0.8698    0.8999    0.8845      2716
#
#     accuracy                         0.8720      4985
#    macro avg     0.8723    0.8693    0.8705      4985
# weighted avg     0.8721    0.8720    0.8718      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 24s 38ms/step - loss: 0.6855 - accuracy: 0.5898 - val_loss: 0.6713 - val_accuracy: 0.6740
# Epoch 2/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.6399 - accuracy: 0.7638 - val_loss: 0.6039 - val_accuracy: 0.8142
# Epoch 3/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.5548 - accuracy: 0.8394 - val_loss: 0.5154 - val_accuracy: 0.8439
# Epoch 4/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.4657 - accuracy: 0.8605 - val_loss: 0.4403 - val_accuracy: 0.8566
# Epoch 5/10
# 351/351 [==============================] - 14s 41ms/step - loss: 0.3975 - accuracy: 0.8705 - val_loss: 0.3900 - val_accuracy: 0.8612
# Epoch 6/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.3520 - accuracy: 0.8762 - val_loss: 0.3588 - val_accuracy: 0.8610
# Epoch 7/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.3218 - accuracy: 0.8821 - val_loss: 0.3396 - val_accuracy: 0.8658
# Epoch 8/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.3007 - accuracy: 0.8871 - val_loss: 0.3276 - val_accuracy: 0.8686
# Epoch 9/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.2852 - accuracy: 0.8908 - val_loss: 0.3200 - val_accuracy: 0.8702
# Epoch 10/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.2733 - accuracy: 0.8944 - val_loss: 0.3149 - val_accuracy: 0.8702
#
# Validation Accuracy: 0.8702106475830078
# Validation Loss: 0.31494376063346863
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8696    0.8409    0.8550      2269
#            1     0.8707    0.8947    0.8825      2716
#
#     accuracy                         0.8702      4985
#    macro avg     0.8702    0.8678    0.8688      4985
# weighted avg     0.8702    0.8702    0.8700      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 20s 40ms/step - loss: 0.6841 - accuracy: 0.5701 - val_loss: 0.6660 - val_accuracy: 0.6662
# Epoch 2/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.6295 - accuracy: 0.7608 - val_loss: 0.5898 - val_accuracy: 0.7976
# Epoch 3/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.5397 - accuracy: 0.8389 - val_loss: 0.5016 - val_accuracy: 0.8441
# Epoch 4/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.4531 - accuracy: 0.8619 - val_loss: 0.4304 - val_accuracy: 0.8564
# Epoch 5/10
# 351/351 [==============================] - 14s 39ms/step - loss: 0.3887 - accuracy: 0.8717 - val_loss: 0.3841 - val_accuracy: 0.8600
# Epoch 6/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.3459 - accuracy: 0.8779 - val_loss: 0.3546 - val_accuracy: 0.8614
# Epoch 7/10
# 351/351 [==============================] - 14s 40ms/step - loss: 0.3172 - accuracy: 0.8841 - val_loss: 0.3367 - val_accuracy: 0.8658
# Epoch 8/10
# 351/351 [==============================] - 14s 38ms/step - loss: 0.2970 - accuracy: 0.8884 - val_loss: 0.3252 - val_accuracy: 0.8692
# Epoch 9/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.2821 - accuracy: 0.8924 - val_loss: 0.3183 - val_accuracy: 0.8702
# Epoch 10/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.2706 - accuracy: 0.8957 - val_loss: 0.3142 - val_accuracy: 0.8704
#
# Validation Accuracy: 0.870411217212677
# Validation Loss: 0.3141748309135437
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8721    0.8383    0.8548      2269
#            1     0.8691    0.8973    0.8830      2716
#
#     accuracy                         0.8704      4985
#    macro avg     0.8706    0.8678    0.8689      4985
# weighted avg     0.8705    0.8704    0.8702      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 22s 44ms/step - loss: 0.6836 - accuracy: 0.5556 - val_loss: 0.6665 - val_accuracy: 0.6060
# Epoch 2/10
# 351/351 [==============================] - 15s 41ms/step - loss: 0.6346 - accuracy: 0.6941 - val_loss: 0.6009 - val_accuracy: 0.7535
# Epoch 3/10
# 351/351 [==============================] - 13s 36ms/step - loss: 0.5569 - accuracy: 0.8032 - val_loss: 0.5223 - val_accuracy: 0.8150
# Epoch 4/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.4760 - accuracy: 0.8482 - val_loss: 0.4520 - val_accuracy: 0.8453
# Epoch 5/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.4095 - accuracy: 0.8672 - val_loss: 0.4003 - val_accuracy: 0.8596
# Epoch 6/10
# 351/351 [==============================] - 13s 38ms/step - loss: 0.3611 - accuracy: 0.8768 - val_loss: 0.3658 - val_accuracy: 0.8640
# Epoch 7/10
# 351/351 [==============================] - 13s 37ms/step - loss: 0.3276 - accuracy: 0.8833 - val_loss: 0.3439 - val_accuracy: 0.8664
# Epoch 8/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.3042 - accuracy: 0.8874 - val_loss: 0.3298 - val_accuracy: 0.8694
# Epoch 9/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.2873 - accuracy: 0.8914 - val_loss: 0.3213 - val_accuracy: 0.8690
# Epoch 10/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.2744 - accuracy: 0.8953 - val_loss: 0.3165 - val_accuracy: 0.8700
#
# Validation Accuracy: 0.8700100183486938
# Validation Loss: 0.31649085879325867
#
# 156/156 [==============================] - 2s 8ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8726    0.8365    0.8542      2269
#            1     0.8680    0.8980    0.8827      2716
#
#     accuracy                         0.8700      4985
#    macro avg     0.8703    0.8673    0.8685      4985
# weighted avg     0.8701    0.8700    0.8697      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function BiGRU UNIGRAM_BIGRAM {idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_TFIDF_BIGRU_UNIGRAM_BIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_TFIDF_BIGRU_UNIGRAM_BIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8708124373119357
# Average Precision : 0.8703814434441938
# Average Recall : 0.8963917525773196
# Average F1 Score : 0.870585705343222
