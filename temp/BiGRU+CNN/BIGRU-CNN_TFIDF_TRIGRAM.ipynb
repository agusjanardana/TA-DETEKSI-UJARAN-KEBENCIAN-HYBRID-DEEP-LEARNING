# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_BIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(3,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 10s 16ms/step - loss: 0.6918 - accuracy: 0.5464 - val_loss: 0.6905 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6885 - accuracy: 0.5452 - val_loss: 0.6869 - val_accuracy: 0.5468
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6817 - accuracy: 0.5675 - val_loss: 0.6792 - val_accuracy: 0.5937
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6652 - accuracy: 0.6424 - val_loss: 0.6621 - val_accuracy: 0.6365
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6361 - accuracy: 0.6850 - val_loss: 0.6389 - val_accuracy: 0.6537
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6020 - accuracy: 0.6939 - val_loss: 0.6173 - val_accuracy: 0.6590
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5725 - accuracy: 0.6972 - val_loss: 0.6034 - val_accuracy: 0.6594
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5509 - accuracy: 0.6982 - val_loss: 0.5956 - val_accuracy: 0.6593
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5360 - accuracy: 0.6997 - val_loss: 0.5926 - val_accuracy: 0.6592
# Epoch 10/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.5255 - accuracy: 0.7011 - val_loss: 0.5925 - val_accuracy: 0.6593
#
# Validation Accuracy: 0.659343957901001
# Validation Loss: 0.5924819707870483
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8121    0.3268    0.4660      4535
#            1     0.6251    0.9369    0.7499      5434
#
#     accuracy                         0.6593      9969
#    macro avg     0.7186    0.6318    0.6080      9969
# weighted avg     0.7102    0.6593    0.6208      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 16ms/step - loss: 0.6915 - accuracy: 0.5451 - val_loss: 0.6900 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6882 - accuracy: 0.5450 - val_loss: 0.6867 - val_accuracy: 0.5451
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6826 - accuracy: 0.5514 - val_loss: 0.6805 - val_accuracy: 0.5696
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6704 - accuracy: 0.6062 - val_loss: 0.6682 - val_accuracy: 0.6145
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6488 - accuracy: 0.6597 - val_loss: 0.6491 - val_accuracy: 0.6442
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6186 - accuracy: 0.6862 - val_loss: 0.6266 - val_accuracy: 0.6578
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5872 - accuracy: 0.6943 - val_loss: 0.6082 - val_accuracy: 0.6597
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5620 - accuracy: 0.6969 - val_loss: 0.5969 - val_accuracy: 0.6598
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5439 - accuracy: 0.6990 - val_loss: 0.5906 - val_accuracy: 0.6605
# Epoch 10/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.5313 - accuracy: 0.6996 - val_loss: 0.5888 - val_accuracy: 0.6603
#
# Validation Accuracy: 0.6603471040725708
# Validation Loss: 0.5887776017189026
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8281    0.3197    0.4613      4535
#            1     0.6246    0.9446    0.7520      5434
#
#     accuracy                         0.6603      9969
#    macro avg     0.7264    0.6322    0.6067      9969
# weighted avg     0.7172    0.6603    0.6198      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 16ms/step - loss: 0.6913 - accuracy: 0.5440 - val_loss: 0.6896 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6874 - accuracy: 0.5452 - val_loss: 0.6857 - val_accuracy: 0.5468
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6795 - accuracy: 0.5750 - val_loss: 0.6764 - val_accuracy: 0.5957
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6613 - accuracy: 0.6483 - val_loss: 0.6587 - val_accuracy: 0.6441
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6316 - accuracy: 0.6863 - val_loss: 0.6350 - val_accuracy: 0.6561
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5972 - accuracy: 0.6948 - val_loss: 0.6132 - val_accuracy: 0.6603
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5676 - accuracy: 0.6969 - val_loss: 0.5990 - val_accuracy: 0.6604
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5466 - accuracy: 0.6984 - val_loss: 0.5920 - val_accuracy: 0.6601
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5322 - accuracy: 0.6995 - val_loss: 0.5903 - val_accuracy: 0.6609
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5226 - accuracy: 0.7006 - val_loss: 0.5898 - val_accuracy: 0.6596
#
# Validation Accuracy: 0.6596449017524719
# Validation Loss: 0.5898386836051941
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8151    0.3257    0.4654      4535
#            1     0.6251    0.9384    0.7503      5434
#
#     accuracy                         0.6596      9969
#    macro avg     0.7201    0.6320    0.6079      9969
# weighted avg     0.7115    0.6596    0.6207      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 16ms/step - loss: 0.6912 - accuracy: 0.5445 - val_loss: 0.6894 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6870 - accuracy: 0.5452 - val_loss: 0.6850 - val_accuracy: 0.5469
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6780 - accuracy: 0.5778 - val_loss: 0.6747 - val_accuracy: 0.6004
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6601 - accuracy: 0.6468 - val_loss: 0.6588 - val_accuracy: 0.6419
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6337 - accuracy: 0.6805 - val_loss: 0.6375 - val_accuracy: 0.6565
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6021 - accuracy: 0.6924 - val_loss: 0.6164 - val_accuracy: 0.6566
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5733 - accuracy: 0.6964 - val_loss: 0.6015 - val_accuracy: 0.6581
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5512 - accuracy: 0.6981 - val_loss: 0.5934 - val_accuracy: 0.6583
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5359 - accuracy: 0.6996 - val_loss: 0.5895 - val_accuracy: 0.6584
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5253 - accuracy: 0.7004 - val_loss: 0.5906 - val_accuracy: 0.6592
#
# Validation Accuracy: 0.659243643283844
# Validation Loss: 0.5905672907829285
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8244    0.3189    0.4599      4535
#            1     0.6240    0.9433    0.7511      5434
#
#     accuracy                         0.6592      9969
#    macro avg     0.7242    0.6311    0.6055      9969
# weighted avg     0.7152    0.6592    0.6186      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6915 - accuracy: 0.5439 - val_loss: 0.6898 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6877 - accuracy: 0.5450 - val_loss: 0.6861 - val_accuracy: 0.5452
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6814 - accuracy: 0.5569 - val_loss: 0.6792 - val_accuracy: 0.5748
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6679 - accuracy: 0.6170 - val_loss: 0.6655 - val_accuracy: 0.6220
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6435 - accuracy: 0.6698 - val_loss: 0.6442 - val_accuracy: 0.6487
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6110 - accuracy: 0.6902 - val_loss: 0.6209 - val_accuracy: 0.6561
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5791 - accuracy: 0.6956 - val_loss: 0.6034 - val_accuracy: 0.6604
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5545 - accuracy: 0.6980 - val_loss: 0.5941 - val_accuracy: 0.6601
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5378 - accuracy: 0.6995 - val_loss: 0.5892 - val_accuracy: 0.6599
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5265 - accuracy: 0.7007 - val_loss: 0.5883 - val_accuracy: 0.6594
#
# Validation Accuracy: 0.659444272518158
# Validation Loss: 0.5883143544197083
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8191    0.3226    0.4629      4535
#            1     0.6246    0.9406    0.7507      5434
#
#     accuracy                         0.6594      9969
#    macro avg     0.7219    0.6316    0.6068      9969
# weighted avg     0.7131    0.6594    0.6198      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN TRIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.6596047748018858
# Average Precision : 0.6246805338539554
# Average Recall : 0.9407434670592565
# Average F1 Score : 0.619928252579622
