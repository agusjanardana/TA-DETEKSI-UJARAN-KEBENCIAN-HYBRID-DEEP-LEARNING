# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM-BIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 10s 17ms/step - loss: 0.6884 - accuracy: 0.5497 - val_loss: 0.6776 - val_accuracy: 0.6085
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6459 - accuracy: 0.7204 - val_loss: 0.6052 - val_accuracy: 0.7827
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5421 - accuracy: 0.8321 - val_loss: 0.4883 - val_accuracy: 0.8448
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.4264 - accuracy: 0.8684 - val_loss: 0.3987 - val_accuracy: 0.8634
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3488 - accuracy: 0.8806 - val_loss: 0.3516 - val_accuracy: 0.8679
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3052 - accuracy: 0.8884 - val_loss: 0.3296 - val_accuracy: 0.8700
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2797 - accuracy: 0.8939 - val_loss: 0.3205 - val_accuracy: 0.8715
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2628 - accuracy: 0.8993 - val_loss: 0.3172 - val_accuracy: 0.8717
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2506 - accuracy: 0.9027 - val_loss: 0.3172 - val_accuracy: 0.8721
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2410 - accuracy: 0.9065 - val_loss: 0.3192 - val_accuracy: 0.8715
#
# Validation Accuracy: 0.8715016841888428
# Validation Loss: 0.3192458152770996
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8627    0.8534    0.8580      4535
#            1     0.8787    0.8866    0.8827      5434
#
#     accuracy                         0.8715      9969
#    macro avg     0.8707    0.8700    0.8703      9969
# weighted avg     0.8714    0.8715    0.8714      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6857 - accuracy: 0.5606 - val_loss: 0.6693 - val_accuracy: 0.6444
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6252 - accuracy: 0.7529 - val_loss: 0.5712 - val_accuracy: 0.8222
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5004 - accuracy: 0.8523 - val_loss: 0.4492 - val_accuracy: 0.8497
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3885 - accuracy: 0.8743 - val_loss: 0.3720 - val_accuracy: 0.8643
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3235 - accuracy: 0.8843 - val_loss: 0.3376 - val_accuracy: 0.8682
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2885 - accuracy: 0.8921 - val_loss: 0.3230 - val_accuracy: 0.8695
# Epoch 7/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.2676 - accuracy: 0.8976 - val_loss: 0.3180 - val_accuracy: 0.8699
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2532 - accuracy: 0.9021 - val_loss: 0.3173 - val_accuracy: 0.8699
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2423 - accuracy: 0.9059 - val_loss: 0.3190 - val_accuracy: 0.8710
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2337 - accuracy: 0.9095 - val_loss: 0.3222 - val_accuracy: 0.8700
#
# Validation Accuracy: 0.869996964931488
# Validation Loss: 0.32222825288772583
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8589    0.8547    0.8568      4535
#            1     0.8792    0.8828    0.8810      5434
#
#     accuracy                         0.8700      9969
#    macro avg     0.8690    0.8687    0.8689      9969
# weighted avg     0.8700    0.8700    0.8700      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6858 - accuracy: 0.5508 - val_loss: 0.6699 - val_accuracy: 0.5976
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6264 - accuracy: 0.7130 - val_loss: 0.5690 - val_accuracy: 0.8080
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4921 - accuracy: 0.8465 - val_loss: 0.4361 - val_accuracy: 0.8582
# Epoch 4/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.3758 - accuracy: 0.8767 - val_loss: 0.3621 - val_accuracy: 0.8660
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3140 - accuracy: 0.8854 - val_loss: 0.3318 - val_accuracy: 0.8701
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2819 - accuracy: 0.8923 - val_loss: 0.3203 - val_accuracy: 0.8711
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2626 - accuracy: 0.8983 - val_loss: 0.3171 - val_accuracy: 0.8717
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2489 - accuracy: 0.9026 - val_loss: 0.3176 - val_accuracy: 0.8715
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2383 - accuracy: 0.9073 - val_loss: 0.3197 - val_accuracy: 0.8705
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2297 - accuracy: 0.9107 - val_loss: 0.3235 - val_accuracy: 0.8702
#
# Validation Accuracy: 0.870197594165802
# Validation Loss: 0.32346612215042114
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8599    0.8538    0.8568      4535
#            1     0.8787    0.8839    0.8813      5434
#
#     accuracy                         0.8702      9969
#    macro avg     0.8693    0.8688    0.8691      9969
# weighted avg     0.8701    0.8702    0.8702      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 15ms/step - loss: 0.6865 - accuracy: 0.5608 - val_loss: 0.6707 - val_accuracy: 0.6509
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6221 - accuracy: 0.7728 - val_loss: 0.5619 - val_accuracy: 0.8249
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4848 - accuracy: 0.8587 - val_loss: 0.4307 - val_accuracy: 0.8612
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3711 - accuracy: 0.8775 - val_loss: 0.3590 - val_accuracy: 0.8674
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3108 - accuracy: 0.8870 - val_loss: 0.3303 - val_accuracy: 0.8711
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2796 - accuracy: 0.8947 - val_loss: 0.3193 - val_accuracy: 0.8707
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2605 - accuracy: 0.9002 - val_loss: 0.3163 - val_accuracy: 0.8710
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2472 - accuracy: 0.9049 - val_loss: 0.3170 - val_accuracy: 0.8692
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2368 - accuracy: 0.9089 - val_loss: 0.3200 - val_accuracy: 0.8697
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2285 - accuracy: 0.9123 - val_loss: 0.3237 - val_accuracy: 0.8690
#
# Validation Accuracy: 0.868993878364563
# Validation Loss: 0.32373395562171936
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8595    0.8512    0.8553      4535
#            1     0.8768    0.8839    0.8803      5434
#
#     accuracy                         0.8690      9969
#    macro avg     0.8681    0.8675    0.8678      9969
# weighted avg     0.8689    0.8690    0.8689      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6879 - accuracy: 0.5465 - val_loss: 0.6765 - val_accuracy: 0.5669
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6405 - accuracy: 0.7224 - val_loss: 0.5936 - val_accuracy: 0.8027
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5238 - accuracy: 0.8457 - val_loss: 0.4677 - val_accuracy: 0.8554
# Epoch 4/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.4029 - accuracy: 0.8723 - val_loss: 0.3799 - val_accuracy: 0.8622
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3302 - accuracy: 0.8839 - val_loss: 0.3411 - val_accuracy: 0.8674
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2925 - accuracy: 0.8907 - val_loss: 0.3243 - val_accuracy: 0.8695
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2704 - accuracy: 0.8964 - val_loss: 0.3184 - val_accuracy: 0.8703
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2553 - accuracy: 0.9010 - val_loss: 0.3170 - val_accuracy: 0.8718
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2441 - accuracy: 0.9046 - val_loss: 0.3184 - val_accuracy: 0.8712
# Epoch 10/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.2350 - accuracy: 0.9092 - val_loss: 0.3210 - val_accuracy: 0.8698
#
# Validation Accuracy: 0.8697963953018188
# Validation Loss: 0.32104358077049255
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8609    0.8514    0.8561      4535
#            1     0.8771    0.8852    0.8811      5434
#
#     accuracy                         0.8698      9969
#    macro avg     0.8690    0.8683    0.8686      9969
# weighted avg     0.8697    0.8698    0.8697      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN TRIGRAM_BIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8700973016350687
# Average Precision : 0.8781026300241985
# Average Recall : 0.8844681634155318
# Average F1 Score : 0.870048397269972
