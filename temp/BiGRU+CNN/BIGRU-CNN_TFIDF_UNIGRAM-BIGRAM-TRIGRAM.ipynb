# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 9s 15ms/step - loss: 0.6890 - accuracy: 0.5487 - val_loss: 0.6785 - val_accuracy: 0.6012
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6391 - accuracy: 0.7621 - val_loss: 0.5840 - val_accuracy: 0.8339
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5073 - accuracy: 0.8584 - val_loss: 0.4478 - val_accuracy: 0.8572
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3865 - accuracy: 0.8730 - val_loss: 0.3682 - val_accuracy: 0.8628
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3222 - accuracy: 0.8821 - val_loss: 0.3354 - val_accuracy: 0.8677
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2891 - accuracy: 0.8898 - val_loss: 0.3219 - val_accuracy: 0.8707
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2689 - accuracy: 0.8953 - val_loss: 0.3171 - val_accuracy: 0.8725
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2551 - accuracy: 0.9004 - val_loss: 0.3162 - val_accuracy: 0.8711
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2444 - accuracy: 0.9039 - val_loss: 0.3177 - val_accuracy: 0.8701
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2359 - accuracy: 0.9077 - val_loss: 0.3207 - val_accuracy: 0.8705
#
# Validation Accuracy: 0.870498538017273
# Validation Loss: 0.3206707239151001
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8621    0.8516    0.8568      4535
#            1     0.8774    0.8863    0.8818      5434
#
#     accuracy                         0.8705      9969
#    macro avg     0.8697    0.8689    0.8693      9969
# weighted avg     0.8704    0.8705    0.8704      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6860 - accuracy: 0.5624 - val_loss: 0.6696 - val_accuracy: 0.6508
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6261 - accuracy: 0.7469 - val_loss: 0.5738 - val_accuracy: 0.8053
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5056 - accuracy: 0.8423 - val_loss: 0.4537 - val_accuracy: 0.8563
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3954 - accuracy: 0.8729 - val_loss: 0.3767 - val_accuracy: 0.8629
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3298 - accuracy: 0.8833 - val_loss: 0.3400 - val_accuracy: 0.8694
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2938 - accuracy: 0.8900 - val_loss: 0.3243 - val_accuracy: 0.8716
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2723 - accuracy: 0.8947 - val_loss: 0.3185 - val_accuracy: 0.8715
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2576 - accuracy: 0.8997 - val_loss: 0.3170 - val_accuracy: 0.8714
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2467 - accuracy: 0.9037 - val_loss: 0.3186 - val_accuracy: 0.8707
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2381 - accuracy: 0.9071 - val_loss: 0.3210 - val_accuracy: 0.8705
#
# Validation Accuracy: 0.870498538017273
# Validation Loss: 0.32100215554237366
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8590    0.8558    0.8574      4535
#            1     0.8800    0.8828    0.8814      5434
#
#     accuracy                         0.8705      9969
#    macro avg     0.8695    0.8693    0.8694      9969
# weighted avg     0.8705    0.8705    0.8705      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6861 - accuracy: 0.5614 - val_loss: 0.6704 - val_accuracy: 0.6592
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6250 - accuracy: 0.7679 - val_loss: 0.5667 - val_accuracy: 0.8297
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4888 - accuracy: 0.8577 - val_loss: 0.4320 - val_accuracy: 0.8581
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3719 - accuracy: 0.8742 - val_loss: 0.3587 - val_accuracy: 0.8666
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3133 - accuracy: 0.8833 - val_loss: 0.3305 - val_accuracy: 0.8703
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2832 - accuracy: 0.8910 - val_loss: 0.3194 - val_accuracy: 0.8717
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2645 - accuracy: 0.8962 - val_loss: 0.3159 - val_accuracy: 0.8734
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2514 - accuracy: 0.9011 - val_loss: 0.3162 - val_accuracy: 0.8727
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2411 - accuracy: 0.9049 - val_loss: 0.3187 - val_accuracy: 0.8717
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2328 - accuracy: 0.9086 - val_loss: 0.3221 - val_accuracy: 0.8704
#
# Validation Accuracy: 0.870398223400116
# Validation Loss: 0.32214149832725525
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8591    0.8553    0.8572      4535
#            1     0.8797    0.8830    0.8813      5434
#
#     accuracy                         0.8704      9969
#    macro avg     0.8694    0.8692    0.8693      9969
# weighted avg     0.8704    0.8704    0.8704      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 15ms/step - loss: 0.6880 - accuracy: 0.5445 - val_loss: 0.6756 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6368 - accuracy: 0.6732 - val_loss: 0.5888 - val_accuracy: 0.7586
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5265 - accuracy: 0.8208 - val_loss: 0.4794 - val_accuracy: 0.8422
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4202 - accuracy: 0.8702 - val_loss: 0.3978 - val_accuracy: 0.8615
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3456 - accuracy: 0.8854 - val_loss: 0.3512 - val_accuracy: 0.8691
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3009 - accuracy: 0.8929 - val_loss: 0.3293 - val_accuracy: 0.8717
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2745 - accuracy: 0.8975 - val_loss: 0.3210 - val_accuracy: 0.8736
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2579 - accuracy: 0.9013 - val_loss: 0.3190 - val_accuracy: 0.8732
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2461 - accuracy: 0.9059 - val_loss: 0.3204 - val_accuracy: 0.8721
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2369 - accuracy: 0.9088 - val_loss: 0.3226 - val_accuracy: 0.8709
#
# Validation Accuracy: 0.8708997964859009
# Validation Loss: 0.32264116406440735
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8607    0.8545    0.8576      4535
#            1     0.8793    0.8846    0.8819      5434
#
#     accuracy                         0.8709      9969
#    macro avg     0.8700    0.8695    0.8698      9969
# weighted avg     0.8708    0.8709    0.8709      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6880 - accuracy: 0.5573 - val_loss: 0.6750 - val_accuracy: 0.6639
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6324 - accuracy: 0.7897 - val_loss: 0.5776 - val_accuracy: 0.8398
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5019 - accuracy: 0.8601 - val_loss: 0.4449 - val_accuracy: 0.8583
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3842 - accuracy: 0.8744 - val_loss: 0.3675 - val_accuracy: 0.8631
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3210 - accuracy: 0.8834 - val_loss: 0.3350 - val_accuracy: 0.8689
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2880 - accuracy: 0.8907 - val_loss: 0.3218 - val_accuracy: 0.8718
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2678 - accuracy: 0.8962 - val_loss: 0.3173 - val_accuracy: 0.8718
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2537 - accuracy: 0.9012 - val_loss: 0.3171 - val_accuracy: 0.8716
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2432 - accuracy: 0.9051 - val_loss: 0.3182 - val_accuracy: 0.8709
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2344 - accuracy: 0.9088 - val_loss: 0.3211 - val_accuracy: 0.8715
#
# Validation Accuracy: 0.8715016841888428
# Validation Loss: 0.3210993707180023
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8655    0.8496    0.8575      4535
#            1     0.8764    0.8898    0.8830      5434
#
#     accuracy                         0.8715      9969
#    macro avg     0.8709    0.8697    0.8702      9969
# weighted avg     0.8714    0.8715    0.8714      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN TRIGRAM_BIGRAM_TRIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8707593539973921
# Average Precision : 0.8785584422682909
# Average Recall : 0.8852778800147222
# Average F1 Score : 0.8707072803749535
