# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dropout (Dropout)           (39872, 32)               0
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 9s 15ms/step - loss: 0.6881 - accuracy: 0.5448 - val_loss: 0.6777 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.6479 - accuracy: 0.6277 - val_loss: 0.6083 - val_accuracy: 0.7197
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5507 - accuracy: 0.7987 - val_loss: 0.4962 - val_accuracy: 0.8339
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4375 - accuracy: 0.8612 - val_loss: 0.4018 - val_accuracy: 0.8619
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3581 - accuracy: 0.8776 - val_loss: 0.3509 - val_accuracy: 0.8682
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3140 - accuracy: 0.8853 - val_loss: 0.3287 - val_accuracy: 0.8713
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2882 - accuracy: 0.8907 - val_loss: 0.3200 - val_accuracy: 0.8711
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2720 - accuracy: 0.8979 - val_loss: 0.3183 - val_accuracy: 0.8724
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2599 - accuracy: 0.9004 - val_loss: 0.3176 - val_accuracy: 0.8731
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2505 - accuracy: 0.9048 - val_loss: 0.3194 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.871601939201355
# Validation Loss: 0.3193608820438385
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8606    0.8564    0.8585      4535
#            1     0.8807    0.8842    0.8825      5434
#
#     accuracy                         0.8716      9969
#    macro avg     0.8707    0.8703    0.8705      9969
# weighted avg     0.8716    0.8716    0.8716      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dropout_1 (Dropout)         (39872, 32)               0
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6892 - accuracy: 0.5568 - val_loss: 0.6793 - val_accuracy: 0.6504
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6468 - accuracy: 0.7630 - val_loss: 0.6016 - val_accuracy: 0.8258
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5351 - accuracy: 0.8481 - val_loss: 0.4744 - val_accuracy: 0.8605
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4150 - accuracy: 0.8700 - val_loss: 0.3840 - val_accuracy: 0.8643
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3430 - accuracy: 0.8805 - val_loss: 0.3427 - val_accuracy: 0.8691
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3058 - accuracy: 0.8875 - val_loss: 0.3259 - val_accuracy: 0.8715
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2840 - accuracy: 0.8937 - val_loss: 0.3191 - val_accuracy: 0.8711
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2666 - accuracy: 0.8982 - val_loss: 0.3173 - val_accuracy: 0.8695
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2564 - accuracy: 0.9026 - val_loss: 0.3182 - val_accuracy: 0.8708
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2468 - accuracy: 0.9078 - val_loss: 0.3209 - val_accuracy: 0.8708
#
# Validation Accuracy: 0.8707994818687439
# Validation Loss: 0.32085853815078735
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8570    0.8593    0.8582      4535
#            1     0.8823    0.8804    0.8814      5434
#
#     accuracy                         0.8708      9969
#    macro avg     0.8697    0.8698    0.8698      9969
# weighted avg     0.8708    0.8708    0.8708      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dropout_2 (Dropout)         (39872, 32)               0
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6876 - accuracy: 0.5454 - val_loss: 0.6750 - val_accuracy: 0.5465
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6390 - accuracy: 0.6649 - val_loss: 0.5937 - val_accuracy: 0.7592
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5372 - accuracy: 0.8108 - val_loss: 0.4900 - val_accuracy: 0.8440
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4375 - accuracy: 0.8617 - val_loss: 0.4094 - val_accuracy: 0.8627
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3655 - accuracy: 0.8786 - val_loss: 0.3597 - val_accuracy: 0.8691
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3207 - accuracy: 0.8870 - val_loss: 0.3348 - val_accuracy: 0.8716
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2931 - accuracy: 0.8928 - val_loss: 0.3244 - val_accuracy: 0.8699
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2758 - accuracy: 0.8966 - val_loss: 0.3209 - val_accuracy: 0.8714
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2619 - accuracy: 0.9029 - val_loss: 0.3215 - val_accuracy: 0.8717
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2535 - accuracy: 0.9049 - val_loss: 0.3230 - val_accuracy: 0.8710
#
# Validation Accuracy: 0.8710001111030579
# Validation Loss: 0.32300129532814026
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8633    0.8512    0.8572      4535
#            1     0.8772    0.8876    0.8824      5434
#
#     accuracy                         0.8710      9969
#    macro avg     0.8703    0.8694    0.8698      9969
# weighted avg     0.8709    0.8710    0.8709      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dropout_3 (Dropout)         (39872, 32)               0
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 16ms/step - loss: 0.6889 - accuracy: 0.6390 - val_loss: 0.6772 - val_accuracy: 0.8308
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6390 - accuracy: 0.8367 - val_loss: 0.5901 - val_accuracy: 0.8440
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5251 - accuracy: 0.8567 - val_loss: 0.4699 - val_accuracy: 0.8559
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4137 - accuracy: 0.8714 - val_loss: 0.3859 - val_accuracy: 0.8620
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3452 - accuracy: 0.8824 - val_loss: 0.3442 - val_accuracy: 0.8680
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3067 - accuracy: 0.8893 - val_loss: 0.3258 - val_accuracy: 0.8705
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2820 - accuracy: 0.8951 - val_loss: 0.3183 - val_accuracy: 0.8723
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2670 - accuracy: 0.9023 - val_loss: 0.3162 - val_accuracy: 0.8719
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2554 - accuracy: 0.9056 - val_loss: 0.3177 - val_accuracy: 0.8719
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2456 - accuracy: 0.9092 - val_loss: 0.3201 - val_accuracy: 0.8686
#
# Validation Accuracy: 0.8685926198959351
# Validation Loss: 0.32014697790145874
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8631    0.8452    0.8541      4535
#            1     0.8730    0.8881    0.8805      5434
#
#     accuracy                         0.8686      9969
#    macro avg     0.8681    0.8667    0.8673      9969
# weighted avg     0.8685    0.8686    0.8685      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dropout_4 (Dropout)         (39872, 32)               0
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6873 - accuracy: 0.5467 - val_loss: 0.6745 - val_accuracy: 0.5573
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6360 - accuracy: 0.6813 - val_loss: 0.5855 - val_accuracy: 0.7687
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5199 - accuracy: 0.8290 - val_loss: 0.4648 - val_accuracy: 0.8501
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4103 - accuracy: 0.8657 - val_loss: 0.3837 - val_accuracy: 0.8641
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3419 - accuracy: 0.8793 - val_loss: 0.3433 - val_accuracy: 0.8684
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3052 - accuracy: 0.8866 - val_loss: 0.3260 - val_accuracy: 0.8710
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2815 - accuracy: 0.8925 - val_loss: 0.3191 - val_accuracy: 0.8716
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2669 - accuracy: 0.8988 - val_loss: 0.3183 - val_accuracy: 0.8721
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2553 - accuracy: 0.9019 - val_loss: 0.3182 - val_accuracy: 0.8703
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2460 - accuracy: 0.9052 - val_loss: 0.3209 - val_accuracy: 0.8704
#
# Validation Accuracy: 0.870398223400116
# Validation Loss: 0.32087284326553345
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8635    0.8494    0.8564      4535
#            1     0.8760    0.8879    0.8819      5434
#
#     accuracy                         0.8704      9969
#    macro avg     0.8697    0.8687    0.8692      9969
# weighted avg     0.8703    0.8704    0.8703      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN TRIGRAM_BIGRAM_DROPOUT0.3-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8704784832982245
# Average Precision : 0.8778499644035994
# Average Recall : 0.885645933014354
# Average F1 Score : 0.870415949577762
