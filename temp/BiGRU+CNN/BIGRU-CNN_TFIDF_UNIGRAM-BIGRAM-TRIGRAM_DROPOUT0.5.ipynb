# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dropout (Dropout)           (39872, 32)               0
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 13s 16ms/step - loss: 0.6890 - accuracy: 0.5463 - val_loss: 0.6801 - val_accuracy: 0.5515
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6513 - accuracy: 0.6973 - val_loss: 0.6107 - val_accuracy: 0.7970
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5556 - accuracy: 0.8274 - val_loss: 0.4993 - val_accuracy: 0.8440
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4493 - accuracy: 0.8601 - val_loss: 0.4072 - val_accuracy: 0.8634
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3757 - accuracy: 0.8726 - val_loss: 0.3563 - val_accuracy: 0.8682
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3340 - accuracy: 0.8806 - val_loss: 0.3327 - val_accuracy: 0.8719
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3100 - accuracy: 0.8873 - val_loss: 0.3226 - val_accuracy: 0.8721
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2926 - accuracy: 0.8926 - val_loss: 0.3179 - val_accuracy: 0.8738
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2784 - accuracy: 0.8983 - val_loss: 0.3171 - val_accuracy: 0.8735
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2692 - accuracy: 0.9009 - val_loss: 0.3169 - val_accuracy: 0.8717
#
# Validation Accuracy: 0.871702253818512
# Validation Loss: 0.3169071078300476
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8615    0.8556    0.8585      4535
#            1     0.8801    0.8852    0.8826      5434
#
#     accuracy                         0.8717      9969
#    macro avg     0.8708    0.8704    0.8706      9969
# weighted avg     0.8716    0.8717    0.8717      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dropout_1 (Dropout)         (39872, 32)               0
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6894 - accuracy: 0.5470 - val_loss: 0.6810 - val_accuracy: 0.5725
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6563 - accuracy: 0.6815 - val_loss: 0.6221 - val_accuracy: 0.7655
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5710 - accuracy: 0.7932 - val_loss: 0.5212 - val_accuracy: 0.8343
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4725 - accuracy: 0.8487 - val_loss: 0.4335 - val_accuracy: 0.8603
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3987 - accuracy: 0.8696 - val_loss: 0.3782 - val_accuracy: 0.8681
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3541 - accuracy: 0.8803 - val_loss: 0.3481 - val_accuracy: 0.8708
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3255 - accuracy: 0.8862 - val_loss: 0.3324 - val_accuracy: 0.8719
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3070 - accuracy: 0.8923 - val_loss: 0.3260 - val_accuracy: 0.8725
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2913 - accuracy: 0.8973 - val_loss: 0.3236 - val_accuracy: 0.8717
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2812 - accuracy: 0.9001 - val_loss: 0.3235 - val_accuracy: 0.8708
#
# Validation Accuracy: 0.8707994818687439
# Validation Loss: 0.3234919607639313
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8657    0.8474    0.8565      4535
#            1     0.8749    0.8903    0.8825      5434
#
#     accuracy                         0.8708      9969
#    macro avg     0.8703    0.8689    0.8695      9969
# weighted avg     0.8707    0.8708    0.8707      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dropout_2 (Dropout)         (39872, 32)               0
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6889 - accuracy: 0.5443 - val_loss: 0.6799 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6526 - accuracy: 0.6113 - val_loss: 0.6143 - val_accuracy: 0.7129
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5654 - accuracy: 0.7795 - val_loss: 0.5175 - val_accuracy: 0.8230
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4713 - accuracy: 0.8518 - val_loss: 0.4345 - val_accuracy: 0.8600
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3977 - accuracy: 0.8746 - val_loss: 0.3786 - val_accuracy: 0.8656
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3489 - accuracy: 0.8824 - val_loss: 0.3458 - val_accuracy: 0.8718
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3177 - accuracy: 0.8878 - val_loss: 0.3308 - val_accuracy: 0.8709
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2975 - accuracy: 0.8932 - val_loss: 0.3239 - val_accuracy: 0.8730
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2823 - accuracy: 0.8979 - val_loss: 0.3220 - val_accuracy: 0.8715
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2709 - accuracy: 0.9026 - val_loss: 0.3235 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.871601939201355
# Validation Loss: 0.3235362768173218
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8661    0.8490    0.8575      4535
#            1     0.8760    0.8905    0.8832      5434
#
#     accuracy                         0.8716      9969
#    macro avg     0.8711    0.8697    0.8703      9969
# weighted avg     0.8715    0.8716    0.8715      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dropout_3 (Dropout)         (39872, 32)               0
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 15ms/step - loss: 0.6894 - accuracy: 0.5587 - val_loss: 0.6801 - val_accuracy: 0.6507
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6500 - accuracy: 0.7547 - val_loss: 0.6077 - val_accuracy: 0.8206
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5453 - accuracy: 0.8360 - val_loss: 0.4839 - val_accuracy: 0.8574
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4327 - accuracy: 0.8592 - val_loss: 0.3927 - val_accuracy: 0.8637
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3624 - accuracy: 0.8709 - val_loss: 0.3485 - val_accuracy: 0.8685
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3247 - accuracy: 0.8801 - val_loss: 0.3288 - val_accuracy: 0.8718
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3015 - accuracy: 0.8881 - val_loss: 0.3215 - val_accuracy: 0.8726
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2866 - accuracy: 0.8933 - val_loss: 0.3177 - val_accuracy: 0.8724
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2723 - accuracy: 0.8987 - val_loss: 0.3174 - val_accuracy: 0.8724
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2650 - accuracy: 0.9014 - val_loss: 0.3185 - val_accuracy: 0.8716
#
# Validation Accuracy: 0.871601939201355
# Validation Loss: 0.318482369184494
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8645    0.8512    0.8578      4535
#            1     0.8774    0.8887    0.8830      5434
#
#     accuracy                         0.8716      9969
#    macro avg     0.8709    0.8699    0.8704      9969
# weighted avg     0.8715    0.8716    0.8715      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dropout_4 (Dropout)         (39872, 32)               0
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6900 - accuracy: 0.5441 - val_loss: 0.6829 - val_accuracy: 0.5454
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6587 - accuracy: 0.6523 - val_loss: 0.6230 - val_accuracy: 0.7583
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5687 - accuracy: 0.8037 - val_loss: 0.5134 - val_accuracy: 0.8419
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4597 - accuracy: 0.8579 - val_loss: 0.4169 - val_accuracy: 0.8651
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3808 - accuracy: 0.8746 - val_loss: 0.3611 - val_accuracy: 0.8699
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3327 - accuracy: 0.8837 - val_loss: 0.3350 - val_accuracy: 0.8720
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3078 - accuracy: 0.8905 - val_loss: 0.3246 - val_accuracy: 0.8721
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2890 - accuracy: 0.8960 - val_loss: 0.3205 - val_accuracy: 0.8747
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2761 - accuracy: 0.8999 - val_loss: 0.3194 - val_accuracy: 0.8728
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2648 - accuracy: 0.9027 - val_loss: 0.3209 - val_accuracy: 0.8709
#
# Validation Accuracy: 0.8708997964859009
# Validation Loss: 0.32094454765319824
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8633    0.8509    0.8571      4535
#            1     0.8771    0.8876    0.8823      5434
#
#     accuracy                         0.8709      9969
#    macro avg     0.8702    0.8692    0.8697      9969
# weighted avg     0.8708    0.8709    0.8708      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8713210953957267
# Average Precision : 0.8770873788140048
# Average Recall : 0.8884431358115569
# Average F1 Score : 0.8712311443538164
