# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dropout_1 (Dropout)         (39872, 32)               0
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6887 - accuracy: 0.5599 - val_loss: 0.6777 - val_accuracy: 0.6353
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6423 - accuracy: 0.7506 - val_loss: 0.5945 - val_accuracy: 0.8223
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5314 - accuracy: 0.8381 - val_loss: 0.4715 - val_accuracy: 0.8584
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4234 - accuracy: 0.8619 - val_loss: 0.3869 - val_accuracy: 0.8626
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3595 - accuracy: 0.8728 - val_loss: 0.3465 - val_accuracy: 0.8686
# Epoch 6/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.3223 - accuracy: 0.8821 - val_loss: 0.3287 - val_accuracy: 0.8707
# Epoch 7/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.2999 - accuracy: 0.8885 - val_loss: 0.3202 - val_accuracy: 0.8711
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2832 - accuracy: 0.8941 - val_loss: 0.3181 - val_accuracy: 0.8715
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2714 - accuracy: 0.8995 - val_loss: 0.3177 - val_accuracy: 0.8700
# Epoch 10/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.2614 - accuracy: 0.9030 - val_loss: 0.3193 - val_accuracy: 0.8694
#
# Validation Accuracy: 0.8693951368331909
# Validation Loss: 0.3193202614784241
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8614    0.8496    0.8555      4535
#            1     0.8759    0.8859    0.8809      5434
#
#     accuracy                         0.8694      9969
#    macro avg     0.8687    0.8678    0.8682      9969
# weighted avg     0.8693    0.8694    0.8693      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dropout_2 (Dropout)         (39872, 32)               0
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6894 - accuracy: 0.5442 - val_loss: 0.6815 - val_accuracy: 0.5453
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6560 - accuracy: 0.6648 - val_loss: 0.6206 - val_accuracy: 0.7723
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5692 - accuracy: 0.8129 - val_loss: 0.5173 - val_accuracy: 0.8383
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4664 - accuracy: 0.8566 - val_loss: 0.4252 - val_accuracy: 0.8630
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3888 - accuracy: 0.8746 - val_loss: 0.3686 - val_accuracy: 0.8684
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3424 - accuracy: 0.8800 - val_loss: 0.3401 - val_accuracy: 0.8705
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3128 - accuracy: 0.8877 - val_loss: 0.3269 - val_accuracy: 0.8724
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2948 - accuracy: 0.8949 - val_loss: 0.3220 - val_accuracy: 0.8721
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2800 - accuracy: 0.8982 - val_loss: 0.3201 - val_accuracy: 0.8723
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2694 - accuracy: 0.9033 - val_loss: 0.3208 - val_accuracy: 0.8714
#
# Validation Accuracy: 0.8714013695716858
# Validation Loss: 0.32078662514686584
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8641    0.8512    0.8576      4535
#            1     0.8773    0.8883    0.8828      5434
#
#     accuracy                         0.8714      9969
#    macro avg     0.8707    0.8697    0.8702      9969
# weighted avg     0.8713    0.8714    0.8713      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dropout_3 (Dropout)         (39872, 32)               0
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 15ms/step - loss: 0.6905 - accuracy: 0.5429 - val_loss: 0.6843 - val_accuracy: 0.5453
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6630 - accuracy: 0.6450 - val_loss: 0.6314 - val_accuracy: 0.7539
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5796 - accuracy: 0.8033 - val_loss: 0.5244 - val_accuracy: 0.8435
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4704 - accuracy: 0.8538 - val_loss: 0.4259 - val_accuracy: 0.8607
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3892 - accuracy: 0.8702 - val_loss: 0.3673 - val_accuracy: 0.8667
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3419 - accuracy: 0.8820 - val_loss: 0.3387 - val_accuracy: 0.8699
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3147 - accuracy: 0.8880 - val_loss: 0.3259 - val_accuracy: 0.8702
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2969 - accuracy: 0.8919 - val_loss: 0.3204 - val_accuracy: 0.8701
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2826 - accuracy: 0.8959 - val_loss: 0.3195 - val_accuracy: 0.8715
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2697 - accuracy: 0.9031 - val_loss: 0.3196 - val_accuracy: 0.8701
#
# Validation Accuracy: 0.870097279548645
# Validation Loss: 0.31959840655326843
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8645    0.8472    0.8558      4535
#            1     0.8746    0.8892    0.8818      5434
#
#     accuracy                         0.8701      9969
#    macro avg     0.8696    0.8682    0.8688      9969
# weighted avg     0.8700    0.8701    0.8700      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dropout_4 (Dropout)         (39872, 32)               0
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6910 - accuracy: 0.5433 - val_loss: 0.6861 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6667 - accuracy: 0.6673 - val_loss: 0.6337 - val_accuracy: 0.7821
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5759 - accuracy: 0.8240 - val_loss: 0.5129 - val_accuracy: 0.8564
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4553 - accuracy: 0.8572 - val_loss: 0.4069 - val_accuracy: 0.8633
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3753 - accuracy: 0.8714 - val_loss: 0.3534 - val_accuracy: 0.8679
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3318 - accuracy: 0.8798 - val_loss: 0.3300 - val_accuracy: 0.8687
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3042 - accuracy: 0.8880 - val_loss: 0.3202 - val_accuracy: 0.8706
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2876 - accuracy: 0.8944 - val_loss: 0.3171 - val_accuracy: 0.8715
# Epoch 9/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.2743 - accuracy: 0.8979 - val_loss: 0.3159 - val_accuracy: 0.8714
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2644 - accuracy: 0.9023 - val_loss: 0.3174 - val_accuracy: 0.8705
#
# Validation Accuracy: 0.870498538017273
# Validation Loss: 0.3173585534095764
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8638    0.8492    0.8564      4535
#            1     0.8759    0.8883    0.8820      5434
#
#     accuracy                         0.8705      9969
#    macro avg     0.8699    0.8687    0.8692      9969
# weighted avg     0.8704    0.8705    0.8704      9969
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_5 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_5 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_5 (Flatten)         (39872, 32)               0
#
#  dense_10 (Dense)            (39872, 32)               1056
#
#  dropout_5 (Dropout)         (39872, 32)               0
#
#  dense_11 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6885 - accuracy: 0.5927 - val_loss: 0.6773 - val_accuracy: 0.7319
# Epoch 2/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.6422 - accuracy: 0.8032 - val_loss: 0.5949 - val_accuracy: 0.8531
# Epoch 3/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.5297 - accuracy: 0.8485 - val_loss: 0.4682 - val_accuracy: 0.8598
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4186 - accuracy: 0.8633 - val_loss: 0.3826 - val_accuracy: 0.8655
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3538 - accuracy: 0.8752 - val_loss: 0.3428 - val_accuracy: 0.8694
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3164 - accuracy: 0.8834 - val_loss: 0.3248 - val_accuracy: 0.8704
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2935 - accuracy: 0.8904 - val_loss: 0.3173 - val_accuracy: 0.8718
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2805 - accuracy: 0.8957 - val_loss: 0.3151 - val_accuracy: 0.8712
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2656 - accuracy: 0.9013 - val_loss: 0.3155 - val_accuracy: 0.8708
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2562 - accuracy: 0.9052 - val_loss: 0.3170 - val_accuracy: 0.8693
#
# Validation Accuracy: 0.8692948222160339
# Validation Loss: 0.31703853607177734
#
# 312/312 [==============================] - 2s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8620    0.8485    0.8552      4535
#            1     0.8752    0.8866    0.8809      5434
#
#     accuracy                         0.8693      9969
#    macro avg     0.8686    0.8676    0.8680      9969
# weighted avg     0.8692    0.8693    0.8692      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8701374260206641
# Average Precision : 0.8757772363127614
# Average Recall : 0.8876702245123298
# Average F1 Score : 0.8700425892847757
