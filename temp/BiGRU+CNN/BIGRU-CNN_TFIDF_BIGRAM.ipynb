# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_BIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(2,2), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 9s 15ms/step - loss: 0.6898 - accuracy: 0.5448 - val_loss: 0.6852 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6718 - accuracy: 0.5653 - val_loss: 0.6556 - val_accuracy: 0.6091
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6246 - accuracy: 0.6614 - val_loss: 0.6047 - val_accuracy: 0.6947
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5589 - accuracy: 0.7429 - val_loss: 0.5483 - val_accuracy: 0.7399
# Epoch 5/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.4928 - accuracy: 0.7880 - val_loss: 0.5051 - val_accuracy: 0.7536
# Epoch 6/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.4410 - accuracy: 0.8012 - val_loss: 0.4785 - val_accuracy: 0.7567
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4049 - accuracy: 0.8162 - val_loss: 0.4663 - val_accuracy: 0.7647
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3811 - accuracy: 0.8227 - val_loss: 0.4651 - val_accuracy: 0.7641
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3653 - accuracy: 0.8265 - val_loss: 0.4677 - val_accuracy: 0.7638
# Epoch 10/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.3540 - accuracy: 0.8297 - val_loss: 0.4721 - val_accuracy: 0.7618
#
# Validation Accuracy: 0.761761486530304
# Validation Loss: 0.4721353352069855
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7095    0.8064    0.7549      4535
#            1     0.8177    0.7245    0.7683      5434
#
#     accuracy                         0.7618      9969
#    macro avg     0.7636    0.7655    0.7616      9969
# weighted avg     0.7685    0.7618    0.7622      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6914 - accuracy: 0.5446 - val_loss: 0.6886 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6795 - accuracy: 0.5839 - val_loss: 0.6667 - val_accuracy: 0.6489
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6367 - accuracy: 0.7039 - val_loss: 0.6102 - val_accuracy: 0.7263
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5576 - accuracy: 0.7695 - val_loss: 0.5376 - val_accuracy: 0.7495
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4792 - accuracy: 0.7916 - val_loss: 0.4902 - val_accuracy: 0.7633
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4284 - accuracy: 0.8017 - val_loss: 0.4690 - val_accuracy: 0.7556
# Epoch 7/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.3981 - accuracy: 0.8142 - val_loss: 0.4621 - val_accuracy: 0.7629
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3789 - accuracy: 0.8207 - val_loss: 0.4616 - val_accuracy: 0.7635
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3653 - accuracy: 0.8233 - val_loss: 0.4646 - val_accuracy: 0.7629
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3552 - accuracy: 0.8268 - val_loss: 0.4695 - val_accuracy: 0.7602
#
# Validation Accuracy: 0.760156512260437
# Validation Loss: 0.46945634484291077
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7085    0.8033    0.7529      4535
#            1     0.8152    0.7241    0.7670      5434
#
#     accuracy                         0.7602      9969
#    macro avg     0.7618    0.7637    0.7600      9969
# weighted avg     0.7667    0.7602    0.7606      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6916 - accuracy: 0.5424 - val_loss: 0.6886 - val_accuracy: 0.5573
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6779 - accuracy: 0.6221 - val_loss: 0.6622 - val_accuracy: 0.6743
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6266 - accuracy: 0.7329 - val_loss: 0.5971 - val_accuracy: 0.7369
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5430 - accuracy: 0.7764 - val_loss: 0.5275 - val_accuracy: 0.7481
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4693 - accuracy: 0.7920 - val_loss: 0.4849 - val_accuracy: 0.7562
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4228 - accuracy: 0.8047 - val_loss: 0.4671 - val_accuracy: 0.7564
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3946 - accuracy: 0.8141 - val_loss: 0.4612 - val_accuracy: 0.7653
# Epoch 8/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.3761 - accuracy: 0.8214 - val_loss: 0.4617 - val_accuracy: 0.7638
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3628 - accuracy: 0.8254 - val_loss: 0.4650 - val_accuracy: 0.7631
# Epoch 10/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.3528 - accuracy: 0.8279 - val_loss: 0.4700 - val_accuracy: 0.7613
#
# Validation Accuracy: 0.761259913444519
# Validation Loss: 0.46999219059944153
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7106    0.8018    0.7534      4535
#            1     0.8147    0.7275    0.7686      5434
#
#     accuracy                         0.7613      9969
#    macro avg     0.7626    0.7646    0.7610      9969
# weighted avg     0.7673    0.7613    0.7617      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 16ms/step - loss: 0.6914 - accuracy: 0.5455 - val_loss: 0.6882 - val_accuracy: 0.5549
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6777 - accuracy: 0.5957 - val_loss: 0.6633 - val_accuracy: 0.6478
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6298 - accuracy: 0.7003 - val_loss: 0.6020 - val_accuracy: 0.7251
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5494 - accuracy: 0.7659 - val_loss: 0.5318 - val_accuracy: 0.7496
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.4728 - accuracy: 0.7915 - val_loss: 0.4863 - val_accuracy: 0.7557
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.4234 - accuracy: 0.8045 - val_loss: 0.4667 - val_accuracy: 0.7646
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3941 - accuracy: 0.8162 - val_loss: 0.4609 - val_accuracy: 0.7643
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3756 - accuracy: 0.8213 - val_loss: 0.4614 - val_accuracy: 0.7623
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3626 - accuracy: 0.8253 - val_loss: 0.4651 - val_accuracy: 0.7618
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3526 - accuracy: 0.8281 - val_loss: 0.4701 - val_accuracy: 0.7612
#
# Validation Accuracy: 0.7611595988273621
# Validation Loss: 0.4701221287250519
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7101    0.8026    0.7535      4535
#            1     0.8152    0.7265    0.7683      5434
#
#     accuracy                         0.7612      9969
#    macro avg     0.7627    0.7646    0.7609      9969
# weighted avg     0.7674    0.7612    0.7616      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6909 - accuracy: 0.5432 - val_loss: 0.6873 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6759 - accuracy: 0.5867 - val_loss: 0.6608 - val_accuracy: 0.6404
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6283 - accuracy: 0.6983 - val_loss: 0.6025 - val_accuracy: 0.7194
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5475 - accuracy: 0.7699 - val_loss: 0.5303 - val_accuracy: 0.7537
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4698 - accuracy: 0.7935 - val_loss: 0.4853 - val_accuracy: 0.7549
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4200 - accuracy: 0.8068 - val_loss: 0.4668 - val_accuracy: 0.7631
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3910 - accuracy: 0.8179 - val_loss: 0.4628 - val_accuracy: 0.7628
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3730 - accuracy: 0.8227 - val_loss: 0.4640 - val_accuracy: 0.7618
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3606 - accuracy: 0.8260 - val_loss: 0.4683 - val_accuracy: 0.7605
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3510 - accuracy: 0.8293 - val_loss: 0.4737 - val_accuracy: 0.7594
#
# Validation Accuracy: 0.7593539953231812
# Validation Loss: 0.4736974537372589
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.7063    0.8062    0.7530      4535
#            1     0.8166    0.7203    0.7654      5434
#
#     accuracy                         0.7594      9969
#    macro avg     0.7615    0.7632    0.7592      9969
# weighted avg     0.7664    0.7594    0.7598      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN BIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_BIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_BIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.7607382886949543
# Average Precision : 0.8158759250133881
# Average Recall : 0.7245859403754141
# Average F1 Score : 0.7611635281675169
