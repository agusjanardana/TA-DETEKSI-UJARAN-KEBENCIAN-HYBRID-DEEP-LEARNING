# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## BIGU-CNN_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=10000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.2)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           1926528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dropout (Dropout)           (39872, 32)               0
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 10s 16ms/step - loss: 0.6888 - accuracy: 0.5456 - val_loss: 0.6784 - val_accuracy: 0.5572
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6465 - accuracy: 0.6876 - val_loss: 0.6043 - val_accuracy: 0.7673
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5463 - accuracy: 0.8190 - val_loss: 0.4919 - val_accuracy: 0.8474
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4369 - accuracy: 0.8619 - val_loss: 0.4012 - val_accuracy: 0.8602
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3615 - accuracy: 0.8760 - val_loss: 0.3526 - val_accuracy: 0.8691
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3184 - accuracy: 0.8832 - val_loss: 0.3305 - val_accuracy: 0.8713
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2928 - accuracy: 0.8893 - val_loss: 0.3211 - val_accuracy: 0.8720
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2774 - accuracy: 0.8940 - val_loss: 0.3177 - val_accuracy: 0.8724
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2636 - accuracy: 0.8989 - val_loss: 0.3178 - val_accuracy: 0.8723
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2551 - accuracy: 0.9024 - val_loss: 0.3189 - val_accuracy: 0.8711
#
# Validation Accuracy: 0.8711004257202148
# Validation Loss: 0.31888002157211304
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8594    0.8569    0.8581      4535
#            1     0.8809    0.8830    0.8819      5434
#
#     accuracy                         0.8711      9969
#    macro avg     0.8701    0.8699    0.8700      9969
# weighted avg     0.8711    0.8711    0.8711      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dropout_1 (Dropout)         (39872, 32)               0
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 17ms/step - loss: 0.6887 - accuracy: 0.5439 - val_loss: 0.6778 - val_accuracy: 0.5575
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6413 - accuracy: 0.6896 - val_loss: 0.5932 - val_accuracy: 0.7797
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5295 - accuracy: 0.8265 - val_loss: 0.4738 - val_accuracy: 0.8430
# Epoch 4/10
# 312/312 [==============================] - 5s 15ms/step - loss: 0.4198 - accuracy: 0.8652 - val_loss: 0.3890 - val_accuracy: 0.8640
# Epoch 5/10
# 312/312 [==============================] - 5s 15ms/step - loss: 0.3490 - accuracy: 0.8787 - val_loss: 0.3461 - val_accuracy: 0.8698
# Epoch 6/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.3102 - accuracy: 0.8861 - val_loss: 0.3276 - val_accuracy: 0.8717
# Epoch 7/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.2876 - accuracy: 0.8916 - val_loss: 0.3219 - val_accuracy: 0.8727
# Epoch 8/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.2728 - accuracy: 0.8964 - val_loss: 0.3181 - val_accuracy: 0.8722
# Epoch 9/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.2599 - accuracy: 0.9019 - val_loss: 0.3186 - val_accuracy: 0.8709
# Epoch 10/10
# 312/312 [==============================] - 4s 14ms/step - loss: 0.2513 - accuracy: 0.9037 - val_loss: 0.3212 - val_accuracy: 0.8711
#
# Validation Accuracy: 0.8711004257202148
# Validation Loss: 0.3211715519428253
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8619    0.8534    0.8576      4535
#            1     0.8786    0.8859    0.8823      5434
#
#     accuracy                         0.8711      9969
#    macro avg     0.8703    0.8696    0.8699      9969
# weighted avg     0.8710    0.8711    0.8710      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dropout_2 (Dropout)         (39872, 32)               0
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 9s 17ms/step - loss: 0.6885 - accuracy: 0.5437 - val_loss: 0.6784 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 5s 15ms/step - loss: 0.6494 - accuracy: 0.6304 - val_loss: 0.6113 - val_accuracy: 0.7059
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5581 - accuracy: 0.7812 - val_loss: 0.5080 - val_accuracy: 0.8235
# Epoch 4/10
# 312/312 [==============================] - 5s 15ms/step - loss: 0.4538 - accuracy: 0.8549 - val_loss: 0.4176 - val_accuracy: 0.8590
# Epoch 5/10
# 312/312 [==============================] - 5s 16ms/step - loss: 0.3741 - accuracy: 0.8764 - val_loss: 0.3623 - val_accuracy: 0.8681
# Epoch 6/10
# 312/312 [==============================] - 6s 21ms/step - loss: 0.3250 - accuracy: 0.8845 - val_loss: 0.3358 - val_accuracy: 0.8715
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2981 - accuracy: 0.8896 - val_loss: 0.3242 - val_accuracy: 0.8722
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2802 - accuracy: 0.8945 - val_loss: 0.3210 - val_accuracy: 0.8730
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2672 - accuracy: 0.8977 - val_loss: 0.3202 - val_accuracy: 0.8716
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2571 - accuracy: 0.9018 - val_loss: 0.3217 - val_accuracy: 0.8722
#
# Validation Accuracy: 0.8722038269042969
# Validation Loss: 0.3216809332370758
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8678    0.8483    0.8579      4535
#            1     0.8757    0.8922    0.8839      5434
#
#     accuracy                         0.8722      9969
#    macro avg     0.8718    0.8702    0.8709      9969
# weighted avg     0.8721    0.8722    0.8721      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dropout_3 (Dropout)         (39872, 32)               0
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 15ms/step - loss: 0.6873 - accuracy: 0.5467 - val_loss: 0.6752 - val_accuracy: 0.5659
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6405 - accuracy: 0.6799 - val_loss: 0.5942 - val_accuracy: 0.7723
# Epoch 3/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.5326 - accuracy: 0.8210 - val_loss: 0.4799 - val_accuracy: 0.8463
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.4241 - accuracy: 0.8647 - val_loss: 0.3943 - val_accuracy: 0.8636
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3511 - accuracy: 0.8811 - val_loss: 0.3483 - val_accuracy: 0.8680
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3092 - accuracy: 0.8873 - val_loss: 0.3285 - val_accuracy: 0.8705
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2857 - accuracy: 0.8928 - val_loss: 0.3203 - val_accuracy: 0.8719
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2694 - accuracy: 0.8983 - val_loss: 0.3194 - val_accuracy: 0.8710
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2568 - accuracy: 0.9030 - val_loss: 0.3190 - val_accuracy: 0.8709
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2481 - accuracy: 0.9058 - val_loss: 0.3214 - val_accuracy: 0.8699
#
# Validation Accuracy: 0.869896650314331
# Validation Loss: 0.3214152455329895
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8580    0.8556    0.8568      4535
#            1     0.8798    0.8819    0.8808      5434
#
#     accuracy                         0.8699      9969
#    macro avg     0.8689    0.8687    0.8688      9969
# weighted avg     0.8699    0.8699    0.8699      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dropout_4 (Dropout)         (39872, 32)               0
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6882 - accuracy: 0.5578 - val_loss: 0.6754 - val_accuracy: 0.6281
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6363 - accuracy: 0.7506 - val_loss: 0.5826 - val_accuracy: 0.8137
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5106 - accuracy: 0.8479 - val_loss: 0.4495 - val_accuracy: 0.8588
# Epoch 4/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3948 - accuracy: 0.8704 - val_loss: 0.3691 - val_accuracy: 0.8654
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3313 - accuracy: 0.8800 - val_loss: 0.3350 - val_accuracy: 0.8709
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2980 - accuracy: 0.8877 - val_loss: 0.3220 - val_accuracy: 0.8734
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2767 - accuracy: 0.8948 - val_loss: 0.3167 - val_accuracy: 0.8737
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2643 - accuracy: 0.8983 - val_loss: 0.3156 - val_accuracy: 0.8709
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2535 - accuracy: 0.9032 - val_loss: 0.3171 - val_accuracy: 0.8706
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2449 - accuracy: 0.9074 - val_loss: 0.3199 - val_accuracy: 0.8698
#
# Validation Accuracy: 0.8697963953018188
# Validation Loss: 0.31986913084983826
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8574    0.8562    0.8568      4535
#            1     0.8801    0.8811    0.8806      5434
#
#     accuracy                         0.8698      9969
#    macro avg     0.8688    0.8687    0.8687      9969
# weighted avg     0.8698    0.8698    0.8698      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function BiGRU+CNN UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_BIGRU_CNN_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8708195405757848
# Average Precision : 0.8790198510547758
# Average Recall : 0.8847994111152007
# Average F1 Score : 0.8707742283224569
