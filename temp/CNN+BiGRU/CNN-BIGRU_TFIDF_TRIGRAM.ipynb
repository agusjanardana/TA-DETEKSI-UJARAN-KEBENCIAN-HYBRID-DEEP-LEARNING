# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_TRIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(3,3), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 12s 11ms/step - loss: 0.6927 - accuracy: 0.5452 - val_loss: 0.6923 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6919 - accuracy: 0.5450 - val_loss: 0.6915 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6910 - accuracy: 0.5450 - val_loss: 0.6906 - val_accuracy: 0.5448
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6900 - accuracy: 0.5450 - val_loss: 0.6898 - val_accuracy: 0.5448
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6889 - accuracy: 0.5450 - val_loss: 0.6888 - val_accuracy: 0.5448
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6876 - accuracy: 0.5450 - val_loss: 0.6877 - val_accuracy: 0.5448
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6860 - accuracy: 0.5451 - val_loss: 0.6863 - val_accuracy: 0.5454
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6839 - accuracy: 0.5487 - val_loss: 0.6845 - val_accuracy: 0.5505
# Epoch 9/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6811 - accuracy: 0.5633 - val_loss: 0.6822 - val_accuracy: 0.5677
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6773 - accuracy: 0.5861 - val_loss: 0.6791 - val_accuracy: 0.5864
#
# Validation Accuracy: 0.5863590836524963
# Validation Loss: 0.6790838241577148
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9331    0.0983    0.1778      2269
#            1     0.5689    0.9941    0.7237      2716
#
#     accuracy                         0.5864      4985
#    macro avg     0.7510    0.5462    0.4507      4985
# weighted avg     0.7347    0.5864    0.4752      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6927 - accuracy: 0.5440 - val_loss: 0.6923 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6918 - accuracy: 0.5450 - val_loss: 0.6914 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6908 - accuracy: 0.5450 - val_loss: 0.6904 - val_accuracy: 0.5448
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6897 - accuracy: 0.5450 - val_loss: 0.6894 - val_accuracy: 0.5448
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6883 - accuracy: 0.5450 - val_loss: 0.6882 - val_accuracy: 0.5448
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6866 - accuracy: 0.5457 - val_loss: 0.6866 - val_accuracy: 0.5464
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6842 - accuracy: 0.5520 - val_loss: 0.6846 - val_accuracy: 0.5569
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6810 - accuracy: 0.5707 - val_loss: 0.6819 - val_accuracy: 0.5721
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6769 - accuracy: 0.5931 - val_loss: 0.6787 - val_accuracy: 0.5890
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6718 - accuracy: 0.6165 - val_loss: 0.6747 - val_accuracy: 0.6036
#
# Validation Accuracy: 0.6036108136177063
# Validation Loss: 0.6746968030929565
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9104    0.1432    0.2475      2269
#            1     0.5799    0.9882    0.7309      2716
#
#     accuracy                         0.6036      4985
#    macro avg     0.7452    0.5657    0.4892      4985
# weighted avg     0.7303    0.6036    0.5109      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6925 - accuracy: 0.5450 - val_loss: 0.6919 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6912 - accuracy: 0.5450 - val_loss: 0.6907 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6900 - accuracy: 0.5450 - val_loss: 0.6896 - val_accuracy: 0.5448
# Epoch 4/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6888 - accuracy: 0.5450 - val_loss: 0.6886 - val_accuracy: 0.5448
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6876 - accuracy: 0.5450 - val_loss: 0.6876 - val_accuracy: 0.5448
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6861 - accuracy: 0.5450 - val_loss: 0.6863 - val_accuracy: 0.5448
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6841 - accuracy: 0.5455 - val_loss: 0.6847 - val_accuracy: 0.5456
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6814 - accuracy: 0.5514 - val_loss: 0.6824 - val_accuracy: 0.5553
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6779 - accuracy: 0.5674 - val_loss: 0.6795 - val_accuracy: 0.5701
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6734 - accuracy: 0.5887 - val_loss: 0.6759 - val_accuracy: 0.5872
#
# Validation Accuracy: 0.5871614813804626
# Validation Loss: 0.6759365200996399
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9170    0.1022    0.1840      2269
#            1     0.5695    0.9923    0.7237      2716
#
#     accuracy                         0.5872      4985
#    macro avg     0.7433    0.5473    0.4538      4985
# weighted avg     0.7277    0.5872    0.4780      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6924 - accuracy: 0.5447 - val_loss: 0.6917 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6910 - accuracy: 0.5450 - val_loss: 0.6904 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6896 - accuracy: 0.5450 - val_loss: 0.6892 - val_accuracy: 0.5448
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6881 - accuracy: 0.5450 - val_loss: 0.6879 - val_accuracy: 0.5448
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6863 - accuracy: 0.5450 - val_loss: 0.6864 - val_accuracy: 0.5448
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6839 - accuracy: 0.5468 - val_loss: 0.6843 - val_accuracy: 0.5478
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6806 - accuracy: 0.5588 - val_loss: 0.6816 - val_accuracy: 0.5609
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6763 - accuracy: 0.5792 - val_loss: 0.6783 - val_accuracy: 0.5799
# Epoch 9/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6712 - accuracy: 0.6020 - val_loss: 0.6743 - val_accuracy: 0.5974
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6650 - accuracy: 0.6231 - val_loss: 0.6697 - val_accuracy: 0.6096
#
# Validation Accuracy: 0.6096289157867432
# Validation Loss: 0.6696966886520386
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9152    0.1569    0.2679      2269
#            1     0.5838    0.9878    0.7339      2716
#
#     accuracy                         0.6096      4985
#    macro avg     0.7495    0.5724    0.5009      4985
# weighted avg     0.7346    0.6096    0.5218      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6928 - accuracy: 0.5446 - val_loss: 0.6924 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6919 - accuracy: 0.5450 - val_loss: 0.6915 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6909 - accuracy: 0.5450 - val_loss: 0.6906 - val_accuracy: 0.5448
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6897 - accuracy: 0.5450 - val_loss: 0.6895 - val_accuracy: 0.5452
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6882 - accuracy: 0.5463 - val_loss: 0.6881 - val_accuracy: 0.5458
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6862 - accuracy: 0.5533 - val_loss: 0.6864 - val_accuracy: 0.5575
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6834 - accuracy: 0.5712 - val_loss: 0.6841 - val_accuracy: 0.5727
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6798 - accuracy: 0.5941 - val_loss: 0.6812 - val_accuracy: 0.5942
# Epoch 9/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6752 - accuracy: 0.6214 - val_loss: 0.6775 - val_accuracy: 0.6088
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6696 - accuracy: 0.6470 - val_loss: 0.6730 - val_accuracy: 0.6269
#
# Validation Accuracy: 0.6268806457519531
# Validation Loss: 0.673044741153717
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8956    0.2041    0.3324      2269
#            1     0.5958    0.9801    0.7411      2716
#
#     accuracy                         0.6269      4985
#    macro avg     0.7457    0.5921    0.5367      4985
# weighted avg     0.7322    0.6269    0.5551      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF TRIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.602728184553661
# Average Precision : 0.5795871381071434
# Average Recall : 0.9885125184094257
# Average F1 Score : 0.5081944828100673
