# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_BIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(2,2), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 10ms/step - loss: 0.6923 - accuracy: 0.5451 - val_loss: 0.6913 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6899 - accuracy: 0.5450 - val_loss: 0.6883 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6856 - accuracy: 0.5450 - val_loss: 0.6830 - val_accuracy: 0.5448
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6779 - accuracy: 0.5523 - val_loss: 0.6744 - val_accuracy: 0.5633
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6662 - accuracy: 0.6017 - val_loss: 0.6620 - val_accuracy: 0.6207
# Epoch 6/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6506 - accuracy: 0.6466 - val_loss: 0.6470 - val_accuracy: 0.6510
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6320 - accuracy: 0.6733 - val_loss: 0.6297 - val_accuracy: 0.6764
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6109 - accuracy: 0.7003 - val_loss: 0.6108 - val_accuracy: 0.6945
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5880 - accuracy: 0.7247 - val_loss: 0.5909 - val_accuracy: 0.7143
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5640 - accuracy: 0.7484 - val_loss: 0.5706 - val_accuracy: 0.7332
#
# Validation Accuracy: 0.7331995964050293
# Validation Loss: 0.5706444382667542
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9108    0.4588    0.6102      2269
#            1     0.6804    0.9624    0.7972      2716
#
#     accuracy                         0.7332      4985
#    macro avg     0.7956    0.7106    0.7037      4985
# weighted avg     0.7852    0.7332    0.7121      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6926 - accuracy: 0.5424 - val_loss: 0.6919 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6908 - accuracy: 0.5450 - val_loss: 0.6895 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6872 - accuracy: 0.5480 - val_loss: 0.6851 - val_accuracy: 0.5543
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6807 - accuracy: 0.5784 - val_loss: 0.6774 - val_accuracy: 0.6136
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6700 - accuracy: 0.6496 - val_loss: 0.6660 - val_accuracy: 0.6648
# Epoch 6/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6549 - accuracy: 0.6898 - val_loss: 0.6507 - val_accuracy: 0.6909
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6356 - accuracy: 0.7211 - val_loss: 0.6323 - val_accuracy: 0.7182
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6128 - accuracy: 0.7483 - val_loss: 0.6113 - val_accuracy: 0.7344
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5873 - accuracy: 0.7675 - val_loss: 0.5888 - val_accuracy: 0.7517
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5603 - accuracy: 0.7862 - val_loss: 0.5660 - val_accuracy: 0.7557
#
# Validation Accuracy: 0.755666971206665
# Validation Loss: 0.5659670829772949
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8833    0.5337    0.6654      2269
#            1     0.7072    0.9411    0.8076      2716
#
#     accuracy                         0.7557      4985
#    macro avg     0.7953    0.7374    0.7365      4985
# weighted avg     0.7874    0.7557    0.7429      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6924 - accuracy: 0.5435 - val_loss: 0.6916 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6903 - accuracy: 0.5450 - val_loss: 0.6889 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6860 - accuracy: 0.5457 - val_loss: 0.6832 - val_accuracy: 0.5525
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6778 - accuracy: 0.5608 - val_loss: 0.6739 - val_accuracy: 0.5892
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6653 - accuracy: 0.6239 - val_loss: 0.6610 - val_accuracy: 0.6345
# Epoch 6/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6490 - accuracy: 0.6596 - val_loss: 0.6451 - val_accuracy: 0.6624
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6290 - accuracy: 0.6846 - val_loss: 0.6263 - val_accuracy: 0.6897
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6061 - accuracy: 0.7140 - val_loss: 0.6059 - val_accuracy: 0.7043
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5814 - accuracy: 0.7374 - val_loss: 0.5842 - val_accuracy: 0.7292
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5553 - accuracy: 0.7651 - val_loss: 0.5624 - val_accuracy: 0.7448
#
# Validation Accuracy: 0.7448344826698303
# Validation Loss: 0.5624001622200012
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9063    0.4901    0.6362      2269
#            1     0.6921    0.9577    0.8035      2716
#
#     accuracy                         0.7448      4985
#    macro avg     0.7992    0.7239    0.7198      4985
# weighted avg     0.7896    0.7448    0.7273      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6927 - accuracy: 0.5407 - val_loss: 0.6922 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6912 - accuracy: 0.5450 - val_loss: 0.6900 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6878 - accuracy: 0.5504 - val_loss: 0.6858 - val_accuracy: 0.5573
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6815 - accuracy: 0.5883 - val_loss: 0.6783 - val_accuracy: 0.6213
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6706 - accuracy: 0.6568 - val_loss: 0.6664 - val_accuracy: 0.6672
# Epoch 6/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6554 - accuracy: 0.6941 - val_loss: 0.6513 - val_accuracy: 0.7019
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6363 - accuracy: 0.7273 - val_loss: 0.6329 - val_accuracy: 0.7234
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6136 - accuracy: 0.7544 - val_loss: 0.6120 - val_accuracy: 0.7376
# Epoch 9/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5885 - accuracy: 0.7726 - val_loss: 0.5899 - val_accuracy: 0.7503
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5621 - accuracy: 0.7869 - val_loss: 0.5675 - val_accuracy: 0.7565
#
# Validation Accuracy: 0.7564694285392761
# Validation Loss: 0.5674720406532288
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8798    0.5386    0.6681      2269
#            1     0.7088    0.9385    0.8077      2716
#
#     accuracy                         0.7565      4985
#    macro avg     0.7943    0.7385    0.7379      4985
# weighted avg     0.7866    0.7565    0.7442      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6923 - accuracy: 0.5451 - val_loss: 0.6914 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6899 - accuracy: 0.5450 - val_loss: 0.6882 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6853 - accuracy: 0.5450 - val_loss: 0.6824 - val_accuracy: 0.5448
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6771 - accuracy: 0.5535 - val_loss: 0.6733 - val_accuracy: 0.5657
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6651 - accuracy: 0.5993 - val_loss: 0.6609 - val_accuracy: 0.6241
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6492 - accuracy: 0.6490 - val_loss: 0.6455 - val_accuracy: 0.6606
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6301 - accuracy: 0.6806 - val_loss: 0.6276 - val_accuracy: 0.6794
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6081 - accuracy: 0.7028 - val_loss: 0.6076 - val_accuracy: 0.7011
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5841 - accuracy: 0.7295 - val_loss: 0.5866 - val_accuracy: 0.7240
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5589 - accuracy: 0.7562 - val_loss: 0.5653 - val_accuracy: 0.7414
#
# Validation Accuracy: 0.7414242625236511
# Validation Loss: 0.5652741193771362
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9043    0.4830    0.6297      2269
#            1     0.6891    0.9573    0.8014      2716
#
#     accuracy                         0.7414      4985
#    macro avg     0.7967    0.7202    0.7155      4985
# weighted avg     0.7871    0.7414    0.7232      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF BIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_BIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_BIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.7463189568706119
# Average Precision : 0.6955395660577666
# Average Recall : 0.9513991163475699
# Average F1 Score : 0.7299321912888748
