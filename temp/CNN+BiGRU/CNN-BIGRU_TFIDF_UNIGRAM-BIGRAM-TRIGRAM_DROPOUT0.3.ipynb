# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 13s 12ms/step - loss: 0.6921 - accuracy: 0.5441 - val_loss: 0.6905 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6867 - accuracy: 0.5484 - val_loss: 0.6820 - val_accuracy: 0.5513
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6739 - accuracy: 0.6249 - val_loss: 0.6652 - val_accuracy: 0.6664
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6518 - accuracy: 0.7118 - val_loss: 0.6398 - val_accuracy: 0.7368
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6211 - accuracy: 0.7733 - val_loss: 0.6073 - val_accuracy: 0.7789
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5849 - accuracy: 0.8096 - val_loss: 0.5711 - val_accuracy: 0.8082
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5454 - accuracy: 0.8377 - val_loss: 0.5335 - val_accuracy: 0.8311
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5063 - accuracy: 0.8522 - val_loss: 0.4966 - val_accuracy: 0.8469
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4680 - accuracy: 0.8638 - val_loss: 0.4619 - val_accuracy: 0.8588
# Epoch 10/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.4334 - accuracy: 0.8712 - val_loss: 0.4308 - val_accuracy: 0.8624
#
# Validation Accuracy: 0.8623871803283691
# Validation Loss: 0.4308156371116638
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9078    0.7766    0.8371      2269
#            1     0.8334    0.9341    0.8809      2716
#
#     accuracy                         0.8624      4985
#    macro avg     0.8706    0.8553    0.8590      4985
# weighted avg     0.8673    0.8624    0.8609      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6922 - accuracy: 0.5433 - val_loss: 0.6904 - val_accuracy: 0.5458
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6866 - accuracy: 0.6059 - val_loss: 0.6820 - val_accuracy: 0.6696
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6743 - accuracy: 0.7390 - val_loss: 0.6663 - val_accuracy: 0.7639
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6539 - accuracy: 0.8065 - val_loss: 0.6426 - val_accuracy: 0.8191
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6250 - accuracy: 0.8365 - val_loss: 0.6112 - val_accuracy: 0.8399
# Epoch 6/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5892 - accuracy: 0.8534 - val_loss: 0.5747 - val_accuracy: 0.8487
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5490 - accuracy: 0.8620 - val_loss: 0.5351 - val_accuracy: 0.8590
# Epoch 8/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5078 - accuracy: 0.8675 - val_loss: 0.4957 - val_accuracy: 0.8606
# Epoch 9/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.4668 - accuracy: 0.8707 - val_loss: 0.4588 - val_accuracy: 0.8602
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4296 - accuracy: 0.8742 - val_loss: 0.4259 - val_accuracy: 0.8632
#
# Validation Accuracy: 0.8631895780563354
# Validation Loss: 0.4258742928504944
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8828    0.8065    0.8429      2269
#            1     0.8492    0.9105    0.8788      2716
#
#     accuracy                         0.8632      4985
#    macro avg     0.8660    0.8585    0.8609      4985
# weighted avg     0.8645    0.8632    0.8625      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 12ms/step - loss: 0.6922 - accuracy: 0.5442 - val_loss: 0.6905 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6866 - accuracy: 0.5778 - val_loss: 0.6816 - val_accuracy: 0.6409
# Epoch 3/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6737 - accuracy: 0.6958 - val_loss: 0.6656 - val_accuracy: 0.7350
# Epoch 4/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6536 - accuracy: 0.7702 - val_loss: 0.6428 - val_accuracy: 0.7848
# Epoch 5/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6259 - accuracy: 0.8135 - val_loss: 0.6132 - val_accuracy: 0.8164
# Epoch 6/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5924 - accuracy: 0.8390 - val_loss: 0.5788 - val_accuracy: 0.8343
# Epoch 7/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5549 - accuracy: 0.8526 - val_loss: 0.5413 - val_accuracy: 0.8481
# Epoch 8/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5145 - accuracy: 0.8620 - val_loss: 0.5027 - val_accuracy: 0.8594
# Epoch 9/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.4749 - accuracy: 0.8692 - val_loss: 0.4657 - val_accuracy: 0.8628
# Epoch 10/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.4377 - accuracy: 0.8725 - val_loss: 0.4322 - val_accuracy: 0.8630
#
# Validation Accuracy: 0.8629889488220215
# Validation Loss: 0.43216612935066223
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8887    0.7990    0.8415      2269
#            1     0.8452    0.9164    0.8793      2716
#
#     accuracy                         0.8630      4985
#    macro avg     0.8669    0.8577    0.8604      4985
# weighted avg     0.8650    0.8630    0.8621      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 12ms/step - loss: 0.6922 - accuracy: 0.5454 - val_loss: 0.6908 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6878 - accuracy: 0.5457 - val_loss: 0.6840 - val_accuracy: 0.5452
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6774 - accuracy: 0.5904 - val_loss: 0.6706 - val_accuracy: 0.6283
# Epoch 4/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6599 - accuracy: 0.6680 - val_loss: 0.6508 - val_accuracy: 0.6925
# Epoch 5/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6365 - accuracy: 0.7213 - val_loss: 0.6256 - val_accuracy: 0.7356
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6079 - accuracy: 0.7649 - val_loss: 0.5963 - val_accuracy: 0.7687
# Epoch 7/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5758 - accuracy: 0.7988 - val_loss: 0.5647 - val_accuracy: 0.7942
# Epoch 8/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5426 - accuracy: 0.8251 - val_loss: 0.5327 - val_accuracy: 0.8160
# Epoch 9/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5090 - accuracy: 0.8442 - val_loss: 0.5012 - val_accuracy: 0.8381
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4761 - accuracy: 0.8581 - val_loss: 0.4714 - val_accuracy: 0.8481
#
# Validation Accuracy: 0.8481444120407104
# Validation Loss: 0.4714062213897705
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9257    0.7245    0.8129      2269
#            1     0.8052    0.9514    0.8722      2716
#
#     accuracy                         0.8481      4985
#    macro avg     0.8655    0.8380    0.8425      4985
# weighted avg     0.8601    0.8481    0.8452      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 12ms/step - loss: 0.6922 - accuracy: 0.5421 - val_loss: 0.6907 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6871 - accuracy: 0.5693 - val_loss: 0.6825 - val_accuracy: 0.6175
# Epoch 3/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6748 - accuracy: 0.6848 - val_loss: 0.6670 - val_accuracy: 0.7274
# Epoch 4/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6551 - accuracy: 0.7683 - val_loss: 0.6443 - val_accuracy: 0.7769
# Epoch 5/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6279 - accuracy: 0.8103 - val_loss: 0.6149 - val_accuracy: 0.8156
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5938 - accuracy: 0.8351 - val_loss: 0.5799 - val_accuracy: 0.8323
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5556 - accuracy: 0.8473 - val_loss: 0.5419 - val_accuracy: 0.8451
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5152 - accuracy: 0.8566 - val_loss: 0.5032 - val_accuracy: 0.8574
# Epoch 9/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.4753 - accuracy: 0.8659 - val_loss: 0.4663 - val_accuracy: 0.8608
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4386 - accuracy: 0.8692 - val_loss: 0.4333 - val_accuracy: 0.8616
#
# Validation Accuracy: 0.8615847826004028
# Validation Loss: 0.43334078788757324
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8946    0.7889    0.8384      2269
#            1     0.8395    0.9223    0.8789      2716
#
#     accuracy                         0.8616      4985
#    macro avg     0.8670    0.8556    0.8587      4985
# weighted avg     0.8645    0.8616    0.8605      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.3-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8596589769307925
# Average Precision : 0.8345122243541494
# Average Recall : 0.9269513991163476
# Average F1 Score : 0.8582502483307716
