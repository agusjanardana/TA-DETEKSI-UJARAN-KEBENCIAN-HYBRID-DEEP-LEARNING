# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 12s 11ms/step - loss: 0.6925 - accuracy: 0.5445 - val_loss: 0.6913 - val_accuracy: 0.5498
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6885 - accuracy: 0.6061 - val_loss: 0.6850 - val_accuracy: 0.6564
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6794 - accuracy: 0.7216 - val_loss: 0.6736 - val_accuracy: 0.7579
# Epoch 4/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6645 - accuracy: 0.7890 - val_loss: 0.6563 - val_accuracy: 0.8164
# Epoch 5/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6432 - accuracy: 0.8246 - val_loss: 0.6326 - val_accuracy: 0.8363
# Epoch 6/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6156 - accuracy: 0.8443 - val_loss: 0.6033 - val_accuracy: 0.8514
# Epoch 7/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5829 - accuracy: 0.8541 - val_loss: 0.5693 - val_accuracy: 0.8580
# Epoch 8/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5463 - accuracy: 0.8597 - val_loss: 0.5331 - val_accuracy: 0.8606
# Epoch 9/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5096 - accuracy: 0.8628 - val_loss: 0.4969 - val_accuracy: 0.8622
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4729 - accuracy: 0.8690 - val_loss: 0.4624 - val_accuracy: 0.8620
#
# Validation Accuracy: 0.861985981464386
# Validation Loss: 0.4624217450618744
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8839    0.8021    0.8410      2269
#            1     0.8465    0.9120    0.8781      2716
#
#     accuracy                         0.8620      4985
#    macro avg     0.8652    0.8571    0.8595      4985
# weighted avg     0.8636    0.8620    0.8612      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6926 - accuracy: 0.5387 - val_loss: 0.6918 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6895 - accuracy: 0.5572 - val_loss: 0.6864 - val_accuracy: 0.5631
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6809 - accuracy: 0.6434 - val_loss: 0.6749 - val_accuracy: 0.6818
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6655 - accuracy: 0.7320 - val_loss: 0.6565 - val_accuracy: 0.7517
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6438 - accuracy: 0.7806 - val_loss: 0.6326 - val_accuracy: 0.7918
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6158 - accuracy: 0.8110 - val_loss: 0.6036 - val_accuracy: 0.8169
# Epoch 7/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5848 - accuracy: 0.8286 - val_loss: 0.5710 - val_accuracy: 0.8363
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5503 - accuracy: 0.8398 - val_loss: 0.5362 - val_accuracy: 0.8469
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5152 - accuracy: 0.8513 - val_loss: 0.5013 - val_accuracy: 0.8562
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4810 - accuracy: 0.8574 - val_loss: 0.4680 - val_accuracy: 0.8600
#
# Validation Accuracy: 0.8599799275398254
# Validation Loss: 0.4679539203643799
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9039    0.7748    0.8344      2269
#            1     0.8319    0.9311    0.8787      2716
#
#     accuracy                         0.8600      4985
#    macro avg     0.8679    0.8530    0.8565      4985
# weighted avg     0.8647    0.8600    0.8585      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6926 - accuracy: 0.5392 - val_loss: 0.6919 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6899 - accuracy: 0.5638 - val_loss: 0.6874 - val_accuracy: 0.5801
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6830 - accuracy: 0.6705 - val_loss: 0.6783 - val_accuracy: 0.7262
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6710 - accuracy: 0.7748 - val_loss: 0.6643 - val_accuracy: 0.7928
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6538 - accuracy: 0.8157 - val_loss: 0.6451 - val_accuracy: 0.8363
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6314 - accuracy: 0.8363 - val_loss: 0.6209 - val_accuracy: 0.8556
# Epoch 7/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6039 - accuracy: 0.8456 - val_loss: 0.5921 - val_accuracy: 0.8590
# Epoch 8/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5728 - accuracy: 0.8532 - val_loss: 0.5597 - val_accuracy: 0.8594
# Epoch 9/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5386 - accuracy: 0.8573 - val_loss: 0.5254 - val_accuracy: 0.8636
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5046 - accuracy: 0.8597 - val_loss: 0.4913 - val_accuracy: 0.8626
#
# Validation Accuracy: 0.8625877499580383
# Validation Loss: 0.49125462770462036
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8768    0.8123    0.8433      2269
#            1     0.8522    0.9046    0.8777      2716
#
#     accuracy                         0.8626      4985
#    macro avg     0.8645    0.8584    0.8605      4985
# weighted avg     0.8634    0.8626    0.8620      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 12ms/step - loss: 0.6926 - accuracy: 0.5392 - val_loss: 0.6917 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6896 - accuracy: 0.5605 - val_loss: 0.6869 - val_accuracy: 0.5705
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6819 - accuracy: 0.6481 - val_loss: 0.6765 - val_accuracy: 0.6933
# Epoch 4/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6677 - accuracy: 0.7391 - val_loss: 0.6593 - val_accuracy: 0.7669
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6458 - accuracy: 0.7937 - val_loss: 0.6348 - val_accuracy: 0.8050
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6170 - accuracy: 0.8211 - val_loss: 0.6039 - val_accuracy: 0.8347
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5822 - accuracy: 0.8375 - val_loss: 0.5680 - val_accuracy: 0.8479
# Epoch 8/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5454 - accuracy: 0.8475 - val_loss: 0.5304 - val_accuracy: 0.8584
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5061 - accuracy: 0.8551 - val_loss: 0.4928 - val_accuracy: 0.8600
# Epoch 10/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.4691 - accuracy: 0.8600 - val_loss: 0.4578 - val_accuracy: 0.8620
#
# Validation Accuracy: 0.861985981464386
# Validation Loss: 0.4577842056751251
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8943    0.7902    0.8390      2269
#            1     0.8403    0.9219    0.8792      2716
#
#     accuracy                         0.8620      4985
#    macro avg     0.8673    0.8561    0.8591      4985
# weighted avg     0.8648    0.8620    0.8609      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 11ms/step - loss: 0.6922 - accuracy: 0.5441 - val_loss: 0.6908 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6877 - accuracy: 0.5521 - val_loss: 0.6837 - val_accuracy: 0.5561
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6767 - accuracy: 0.6232 - val_loss: 0.6690 - val_accuracy: 0.6770
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6572 - accuracy: 0.7221 - val_loss: 0.6463 - val_accuracy: 0.7386
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6304 - accuracy: 0.7757 - val_loss: 0.6171 - val_accuracy: 0.7838
# Epoch 6/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5969 - accuracy: 0.8105 - val_loss: 0.5827 - val_accuracy: 0.8136
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5607 - accuracy: 0.8317 - val_loss: 0.5458 - val_accuracy: 0.8379
# Epoch 8/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.5228 - accuracy: 0.8486 - val_loss: 0.5085 - val_accuracy: 0.8477
# Epoch 9/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.4853 - accuracy: 0.8577 - val_loss: 0.4728 - val_accuracy: 0.8582
# Epoch 10/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.4501 - accuracy: 0.8656 - val_loss: 0.4405 - val_accuracy: 0.8634
#
# Validation Accuracy: 0.8633901476860046
# Validation Loss: 0.4404802918434143
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9018    0.7854    0.8396      2269
#            1     0.8382    0.9286    0.8810      2716
#
#     accuracy                         0.8634      4985
#    macro avg     0.8700    0.8570    0.8603      4985
# weighted avg     0.8671    0.8634    0.8622      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8619859578736209
# Average Precision : 0.8418228005328585
# Average Recall : 0.9196612665684831
# Average F1 Score : 0.860969861851809
