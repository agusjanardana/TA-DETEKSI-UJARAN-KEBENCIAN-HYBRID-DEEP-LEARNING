# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_TRIGRAM
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 12s 11ms/step - loss: 0.6922 - accuracy: 0.5435 - val_loss: 0.6908 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6875 - accuracy: 0.5638 - val_loss: 0.6834 - val_accuracy: 0.6112
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6757 - accuracy: 0.6908 - val_loss: 0.6679 - val_accuracy: 0.7382
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6552 - accuracy: 0.7847 - val_loss: 0.6444 - val_accuracy: 0.7928
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6268 - accuracy: 0.8291 - val_loss: 0.6141 - val_accuracy: 0.8251
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5916 - accuracy: 0.8484 - val_loss: 0.5784 - val_accuracy: 0.8457
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5509 - accuracy: 0.8620 - val_loss: 0.5383 - val_accuracy: 0.8578
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5078 - accuracy: 0.8698 - val_loss: 0.4982 - val_accuracy: 0.8592
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4657 - accuracy: 0.8741 - val_loss: 0.4607 - val_accuracy: 0.8616
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4269 - accuracy: 0.8766 - val_loss: 0.4273 - val_accuracy: 0.8622
#
# Validation Accuracy: 0.8621865510940552
# Validation Loss: 0.4272986352443695
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8885    0.7973    0.8404      2269
#            1     0.8440    0.9164    0.8787      2716
#
#     accuracy                         0.8622      4985
#    macro avg     0.8663    0.8568    0.8596      4985
# weighted avg     0.8643    0.8622    0.8613      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6916 - accuracy: 0.5450 - val_loss: 0.6893 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6839 - accuracy: 0.5542 - val_loss: 0.6770 - val_accuracy: 0.6052
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6660 - accuracy: 0.6628 - val_loss: 0.6552 - val_accuracy: 0.6991
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6389 - accuracy: 0.7356 - val_loss: 0.6258 - val_accuracy: 0.7444
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6050 - accuracy: 0.7830 - val_loss: 0.5913 - val_accuracy: 0.7838
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5667 - accuracy: 0.8186 - val_loss: 0.5544 - val_accuracy: 0.8124
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5268 - accuracy: 0.8424 - val_loss: 0.5173 - val_accuracy: 0.8323
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4875 - accuracy: 0.8572 - val_loss: 0.4817 - val_accuracy: 0.8491
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4502 - accuracy: 0.8690 - val_loss: 0.4491 - val_accuracy: 0.8580
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4161 - accuracy: 0.8768 - val_loss: 0.4202 - val_accuracy: 0.8622
#
# Validation Accuracy: 0.8621865510940552
# Validation Loss: 0.4201577305793762
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9111    0.7726    0.8362      2269
#            1     0.8314    0.9370    0.8811      2716
#
#     accuracy                         0.8622      4985
#    macro avg     0.8713    0.8548    0.8586      4985
# weighted avg     0.8677    0.8622    0.8606      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6922 - accuracy: 0.5401 - val_loss: 0.6906 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6868 - accuracy: 0.5720 - val_loss: 0.6816 - val_accuracy: 0.6405
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6723 - accuracy: 0.7193 - val_loss: 0.6629 - val_accuracy: 0.7717
# Epoch 4/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6481 - accuracy: 0.8119 - val_loss: 0.6355 - val_accuracy: 0.8211
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6147 - accuracy: 0.8467 - val_loss: 0.6000 - val_accuracy: 0.8407
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5744 - accuracy: 0.8608 - val_loss: 0.5599 - val_accuracy: 0.8542
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5301 - accuracy: 0.8687 - val_loss: 0.5175 - val_accuracy: 0.8598
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4850 - accuracy: 0.8732 - val_loss: 0.4765 - val_accuracy: 0.8608
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4426 - accuracy: 0.8759 - val_loss: 0.4397 - val_accuracy: 0.8616
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4050 - accuracy: 0.8783 - val_loss: 0.4086 - val_accuracy: 0.8634
#
# Validation Accuracy: 0.8633901476860046
# Validation Loss: 0.4086141586303711
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8828    0.8070    0.8432      2269
#            1     0.8495    0.9105    0.8790      2716
#
#     accuracy                         0.8634      4985
#    macro avg     0.8662    0.8587    0.8611      4985
# weighted avg     0.8647    0.8634    0.8627      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6923 - accuracy: 0.5433 - val_loss: 0.6909 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6872 - accuracy: 0.5702 - val_loss: 0.6822 - val_accuracy: 0.6255
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6739 - accuracy: 0.6969 - val_loss: 0.6653 - val_accuracy: 0.7386
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6518 - accuracy: 0.7832 - val_loss: 0.6399 - val_accuracy: 0.7940
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6209 - accuracy: 0.8286 - val_loss: 0.6069 - val_accuracy: 0.8301
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5830 - accuracy: 0.8517 - val_loss: 0.5686 - val_accuracy: 0.8437
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5406 - accuracy: 0.8609 - val_loss: 0.5277 - val_accuracy: 0.8576
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4967 - accuracy: 0.8705 - val_loss: 0.4872 - val_accuracy: 0.8592
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4545 - accuracy: 0.8744 - val_loss: 0.4500 - val_accuracy: 0.8642
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4163 - accuracy: 0.8775 - val_loss: 0.4177 - val_accuracy: 0.8638
#
# Validation Accuracy: 0.8637913465499878
# Validation Loss: 0.41770732402801514
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8924    0.7968    0.8419      2269
#            1     0.8442    0.9197    0.8804      2716
#
#     accuracy                         0.8638      4985
#    macro avg     0.8683    0.8583    0.8611      4985
# weighted avg     0.8661    0.8638    0.8629      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6918 - accuracy: 0.5447 - val_loss: 0.6896 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6848 - accuracy: 0.5556 - val_loss: 0.6789 - val_accuracy: 0.5930
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6698 - accuracy: 0.6460 - val_loss: 0.6609 - val_accuracy: 0.6784
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6476 - accuracy: 0.7104 - val_loss: 0.6368 - val_accuracy: 0.7266
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6192 - accuracy: 0.7571 - val_loss: 0.6075 - val_accuracy: 0.7689
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5862 - accuracy: 0.7992 - val_loss: 0.5751 - val_accuracy: 0.7924
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5506 - accuracy: 0.8270 - val_loss: 0.5415 - val_accuracy: 0.8195
# Epoch 8/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5144 - accuracy: 0.8460 - val_loss: 0.5083 - val_accuracy: 0.8375
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4790 - accuracy: 0.8610 - val_loss: 0.4767 - val_accuracy: 0.8471
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4453 - accuracy: 0.8699 - val_loss: 0.4471 - val_accuracy: 0.8584
#
# Validation Accuracy: 0.8583751320838928
# Validation Loss: 0.44712358713150024
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9164    0.7580    0.8297      2269
#            1     0.8234    0.9422    0.8788      2716
#
#     accuracy                         0.8584      4985
#    macro avg     0.8699    0.8501    0.8542      4985
# weighted avg     0.8657    0.8584    0.8564      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM TRIGRAM-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_TRIGRAM.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8619859578736209
# Average Precision : 0.838508399310731
# Average Recall : 0.9251840942562591
# Average F1 Score : 0.8607828150446222
