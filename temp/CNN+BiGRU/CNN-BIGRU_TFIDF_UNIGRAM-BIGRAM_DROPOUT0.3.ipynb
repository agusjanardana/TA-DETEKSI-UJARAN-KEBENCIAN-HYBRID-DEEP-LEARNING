# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT0.3
# Copyright @I Gde Bagus Janardana Abasan

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 12s 11ms/step - loss: 0.6920 - accuracy: 0.5445 - val_loss: 0.6903 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6867 - accuracy: 0.5462 - val_loss: 0.6821 - val_accuracy: 0.5464
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6747 - accuracy: 0.5904 - val_loss: 0.6672 - val_accuracy: 0.6325
# Epoch 4/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6556 - accuracy: 0.6718 - val_loss: 0.6456 - val_accuracy: 0.6987
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6298 - accuracy: 0.7330 - val_loss: 0.6182 - val_accuracy: 0.7416
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5991 - accuracy: 0.7766 - val_loss: 0.5869 - val_accuracy: 0.7763
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5650 - accuracy: 0.8103 - val_loss: 0.5538 - val_accuracy: 0.8064
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5294 - accuracy: 0.8327 - val_loss: 0.5205 - val_accuracy: 0.8249
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4963 - accuracy: 0.8491 - val_loss: 0.4887 - val_accuracy: 0.8425
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4634 - accuracy: 0.8606 - val_loss: 0.4590 - val_accuracy: 0.8526
#
# Validation Accuracy: 0.8525576591491699
# Validation Loss: 0.4590187668800354
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9187    0.7417    0.8208      2269
#            1     0.8141    0.9451    0.8748      2716
#
#     accuracy                         0.8526      4985
#    macro avg     0.8664    0.8434    0.8478      4985
# weighted avg     0.8617    0.8526    0.8502      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6924 - accuracy: 0.5376 - val_loss: 0.6909 - val_accuracy: 0.5452
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6873 - accuracy: 0.5952 - val_loss: 0.6826 - val_accuracy: 0.6806
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6751 - accuracy: 0.7380 - val_loss: 0.6676 - val_accuracy: 0.7669
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6562 - accuracy: 0.8052 - val_loss: 0.6462 - val_accuracy: 0.8086
# Epoch 5/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6305 - accuracy: 0.8346 - val_loss: 0.6187 - val_accuracy: 0.8363
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5989 - accuracy: 0.8508 - val_loss: 0.5860 - val_accuracy: 0.8473
# Epoch 7/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5626 - accuracy: 0.8596 - val_loss: 0.5497 - val_accuracy: 0.8612
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5243 - accuracy: 0.8665 - val_loss: 0.5127 - val_accuracy: 0.8630
# Epoch 9/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4852 - accuracy: 0.8715 - val_loss: 0.4766 - val_accuracy: 0.8614
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4488 - accuracy: 0.8739 - val_loss: 0.4438 - val_accuracy: 0.8624
#
# Validation Accuracy: 0.8623871803283691
# Validation Loss: 0.44378167390823364
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8897    0.7964    0.8405      2269
#            1     0.8436    0.9175    0.8790      2716
#
#     accuracy                         0.8624      4985
#    macro avg     0.8667    0.8570    0.8597      4985
# weighted avg     0.8646    0.8624    0.8615      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6920 - accuracy: 0.5444 - val_loss: 0.6903 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6864 - accuracy: 0.5503 - val_loss: 0.6813 - val_accuracy: 0.5545
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6730 - accuracy: 0.6288 - val_loss: 0.6638 - val_accuracy: 0.6828
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6495 - accuracy: 0.7404 - val_loss: 0.6368 - val_accuracy: 0.7597
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6183 - accuracy: 0.7989 - val_loss: 0.6035 - val_accuracy: 0.8002
# Epoch 6/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5804 - accuracy: 0.8276 - val_loss: 0.5652 - val_accuracy: 0.8279
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5388 - accuracy: 0.8474 - val_loss: 0.5249 - val_accuracy: 0.8477
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4975 - accuracy: 0.8595 - val_loss: 0.4857 - val_accuracy: 0.8576
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4574 - accuracy: 0.8670 - val_loss: 0.4496 - val_accuracy: 0.8624
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4216 - accuracy: 0.8726 - val_loss: 0.4181 - val_accuracy: 0.8628
#
# Validation Accuracy: 0.8627883791923523
# Validation Loss: 0.4181106686592102
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8961    0.7902    0.8398      2269
#            1     0.8405    0.9234    0.8800      2716
#
#     accuracy                         0.8628      4985
#    macro avg     0.8683    0.8568    0.8599      4985
# weighted avg     0.8658    0.8628    0.8617      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 10ms/step - loss: 0.6920 - accuracy: 0.5449 - val_loss: 0.6903 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6866 - accuracy: 0.5538 - val_loss: 0.6818 - val_accuracy: 0.5709
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6739 - accuracy: 0.6292 - val_loss: 0.6657 - val_accuracy: 0.6714
# Epoch 4/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6532 - accuracy: 0.7076 - val_loss: 0.6419 - val_accuracy: 0.7224
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6251 - accuracy: 0.7608 - val_loss: 0.6123 - val_accuracy: 0.7657
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5925 - accuracy: 0.7974 - val_loss: 0.5792 - val_accuracy: 0.7986
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5563 - accuracy: 0.8238 - val_loss: 0.5443 - val_accuracy: 0.8229
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5196 - accuracy: 0.8439 - val_loss: 0.5096 - val_accuracy: 0.8397
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4842 - accuracy: 0.8570 - val_loss: 0.4765 - val_accuracy: 0.8483
# Epoch 10/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.4502 - accuracy: 0.8667 - val_loss: 0.4461 - val_accuracy: 0.8592
#
# Validation Accuracy: 0.8591775298118591
# Validation Loss: 0.44607773423194885
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9174    0.7589    0.8307      2269
#            1     0.8240    0.9429    0.8795      2716
#
#     accuracy                         0.8592      4985
#    macro avg     0.8707    0.8509    0.8551      4985
# weighted avg     0.8665    0.8592    0.8573      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6921 - accuracy: 0.5451 - val_loss: 0.6904 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6867 - accuracy: 0.5556 - val_loss: 0.6820 - val_accuracy: 0.5914
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6739 - accuracy: 0.6450 - val_loss: 0.6656 - val_accuracy: 0.6883
# Epoch 4/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6529 - accuracy: 0.7246 - val_loss: 0.6418 - val_accuracy: 0.7318
# Epoch 5/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6249 - accuracy: 0.7702 - val_loss: 0.6121 - val_accuracy: 0.7809
# Epoch 6/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5913 - accuracy: 0.8067 - val_loss: 0.5782 - val_accuracy: 0.8000
# Epoch 7/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5541 - accuracy: 0.8303 - val_loss: 0.5419 - val_accuracy: 0.8287
# Epoch 8/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.5161 - accuracy: 0.8476 - val_loss: 0.5057 - val_accuracy: 0.8459
# Epoch 9/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4782 - accuracy: 0.8611 - val_loss: 0.4712 - val_accuracy: 0.8522
# Epoch 10/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.4432 - accuracy: 0.8681 - val_loss: 0.4395 - val_accuracy: 0.8626
#
# Validation Accuracy: 0.8625877499580383
# Validation Loss: 0.439490407705307
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9116    0.7730    0.8366      2269
#            1     0.8318    0.9374    0.8814      2716
#
#     accuracy                         0.8626      4985
#    macro avg     0.8717    0.8552    0.8590      4985
# weighted avg     0.8681    0.8626    0.8610      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM DROPOUT0.3-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.3-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.3.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8598996990972919
# Average Precision : 0.8307973261196928
# Average Recall : 0.9332842415316642
# Average F1 Score : 0.8583326887440395
