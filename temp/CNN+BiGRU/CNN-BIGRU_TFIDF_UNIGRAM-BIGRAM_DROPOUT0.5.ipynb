# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## CNN_BIGRU_TFIDF_UNIGRAM_BIGRAM_DROPOUT.5
# Copyright @I Gde Bagus Janardana Abasan

# %%
def process_data(test_size):
  dataset = pd.read_csv('../../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=15000)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00001)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call():
  X_train, X_test, y_train, y_test = process_data(test_size=0.1)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
result = []
for i in range (5):
  result.append([i+1] + call())
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (44856, 1, 32)            1440032
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (44856, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (44856, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (44856, 64)               0
#
#  dense (Dense)               (44856, 32)               2080
#
#  dropout (Dropout)           (44856, 32)               0
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 12s 11ms/step - loss: 0.6919 - accuracy: 0.5445 - val_loss: 0.6903 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6870 - accuracy: 0.5451 - val_loss: 0.6827 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6760 - accuracy: 0.5502 - val_loss: 0.6689 - val_accuracy: 0.5501
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6581 - accuracy: 0.6092 - val_loss: 0.6475 - val_accuracy: 0.6550
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6327 - accuracy: 0.6878 - val_loss: 0.6213 - val_accuracy: 0.6995
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6046 - accuracy: 0.7342 - val_loss: 0.5929 - val_accuracy: 0.7478
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5742 - accuracy: 0.7773 - val_loss: 0.5634 - val_accuracy: 0.7765
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5441 - accuracy: 0.8077 - val_loss: 0.5345 - val_accuracy: 0.8006
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5153 - accuracy: 0.8306 - val_loss: 0.5070 - val_accuracy: 0.8275
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4872 - accuracy: 0.8500 - val_loss: 0.4812 - val_accuracy: 0.8421
#
# Validation Accuracy: 0.8421263694763184
# Validation Loss: 0.4811636507511139
#
# 156/156 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9395    0.6981    0.8010      2269
#            1     0.7924    0.9624    0.8692      2716
#
#     accuracy                         0.8421      4985
#    macro avg     0.8659    0.8303    0.8351      4985
# weighted avg     0.8593    0.8421    0.8381      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (44856, 64)               0
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dropout_1 (Dropout)         (44856, 32)               0
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 10s 11ms/step - loss: 0.6925 - accuracy: 0.5417 - val_loss: 0.6916 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6893 - accuracy: 0.5633 - val_loss: 0.6861 - val_accuracy: 0.5797
# Epoch 3/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6809 - accuracy: 0.6585 - val_loss: 0.6754 - val_accuracy: 0.6943
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6673 - accuracy: 0.7378 - val_loss: 0.6593 - val_accuracy: 0.7597
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6475 - accuracy: 0.7913 - val_loss: 0.6369 - val_accuracy: 0.8058
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6210 - accuracy: 0.8204 - val_loss: 0.6089 - val_accuracy: 0.8311
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5898 - accuracy: 0.8372 - val_loss: 0.5768 - val_accuracy: 0.8475
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5562 - accuracy: 0.8473 - val_loss: 0.5421 - val_accuracy: 0.8560
# Epoch 9/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.5202 - accuracy: 0.8549 - val_loss: 0.5066 - val_accuracy: 0.8616
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4853 - accuracy: 0.8616 - val_loss: 0.4722 - val_accuracy: 0.8630
#
# Validation Accuracy: 0.8629889488220215
# Validation Loss: 0.47223106026649475
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9013    0.7849    0.8391      2269
#            1     0.8378    0.9282    0.8807      2716
#
#     accuracy                         0.8630      4985
#    macro avg     0.8696    0.8566    0.8599      4985
# weighted avg     0.8667    0.8630    0.8618      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (44856, 64)               0
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dropout_2 (Dropout)         (44856, 32)               0
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 11ms/step - loss: 0.6922 - accuracy: 0.5442 - val_loss: 0.6909 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6880 - accuracy: 0.5452 - val_loss: 0.6843 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6781 - accuracy: 0.5708 - val_loss: 0.6716 - val_accuracy: 0.6006
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6616 - accuracy: 0.6390 - val_loss: 0.6525 - val_accuracy: 0.6740
# Epoch 5/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6385 - accuracy: 0.6981 - val_loss: 0.6276 - val_accuracy: 0.7151
# Epoch 6/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6105 - accuracy: 0.7447 - val_loss: 0.5987 - val_accuracy: 0.7442
# Epoch 7/10
# 701/701 [==============================] - 8s 12ms/step - loss: 0.5791 - accuracy: 0.7834 - val_loss: 0.5675 - val_accuracy: 0.7821
# Epoch 8/10
# 701/701 [==============================] - 8s 12ms/step - loss: 0.5465 - accuracy: 0.8148 - val_loss: 0.5358 - val_accuracy: 0.8068
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5144 - accuracy: 0.8367 - val_loss: 0.5048 - val_accuracy: 0.8301
# Epoch 10/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.4837 - accuracy: 0.8516 - val_loss: 0.4755 - val_accuracy: 0.8463
#
# Validation Accuracy: 0.8463389873504639
# Validation Loss: 0.4755115807056427
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9297    0.7166    0.8094      2269
#            1     0.8013    0.9547    0.8713      2716
#
#     accuracy                         0.8463      4985
#    macro avg     0.8655    0.8357    0.8403      4985
# weighted avg     0.8597    0.8463    0.8431      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (44856, 64)               0
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dropout_3 (Dropout)         (44856, 32)               0
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 12ms/step - loss: 0.6920 - accuracy: 0.5452 - val_loss: 0.6904 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6869 - accuracy: 0.5454 - val_loss: 0.6826 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6756 - accuracy: 0.5655 - val_loss: 0.6684 - val_accuracy: 0.5908
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6572 - accuracy: 0.6383 - val_loss: 0.6471 - val_accuracy: 0.6788
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6321 - accuracy: 0.7155 - val_loss: 0.6195 - val_accuracy: 0.7386
# Epoch 6/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.6003 - accuracy: 0.7743 - val_loss: 0.5866 - val_accuracy: 0.7785
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5648 - accuracy: 0.8125 - val_loss: 0.5517 - val_accuracy: 0.8078
# Epoch 8/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5293 - accuracy: 0.8374 - val_loss: 0.5170 - val_accuracy: 0.8341
# Epoch 9/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4942 - accuracy: 0.8530 - val_loss: 0.4839 - val_accuracy: 0.8477
# Epoch 10/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.4611 - accuracy: 0.8639 - val_loss: 0.4531 - val_accuracy: 0.8574
#
# Validation Accuracy: 0.8573721051216125
# Validation Loss: 0.4531157910823822
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9170    0.7550    0.8281      2269
#            1     0.8216    0.9429    0.8781      2716
#
#     accuracy                         0.8574      4985
#    macro avg     0.8693    0.8489    0.8531      4985
# weighted avg     0.8650    0.8574    0.8554      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (44856, 1, 32)            1440032
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (44856, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (44856, 64)               0
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dropout_4 (Dropout)         (44856, 32)               0
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 701/701 [==============================] - 11s 11ms/step - loss: 0.6923 - accuracy: 0.5449 - val_loss: 0.6913 - val_accuracy: 0.5448
# Epoch 2/10
# 701/701 [==============================] - 7s 11ms/step - loss: 0.6890 - accuracy: 0.5454 - val_loss: 0.6860 - val_accuracy: 0.5448
# Epoch 3/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6810 - accuracy: 0.5607 - val_loss: 0.6758 - val_accuracy: 0.5496
# Epoch 4/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6675 - accuracy: 0.6152 - val_loss: 0.6596 - val_accuracy: 0.6570
# Epoch 5/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6469 - accuracy: 0.6879 - val_loss: 0.6364 - val_accuracy: 0.7085
# Epoch 6/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.6195 - accuracy: 0.7421 - val_loss: 0.6072 - val_accuracy: 0.7501
# Epoch 7/10
# 701/701 [==============================] - 7s 10ms/step - loss: 0.5878 - accuracy: 0.7836 - val_loss: 0.5743 - val_accuracy: 0.7864
# Epoch 8/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5526 - accuracy: 0.8161 - val_loss: 0.5395 - val_accuracy: 0.8150
# Epoch 9/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.5168 - accuracy: 0.8377 - val_loss: 0.5050 - val_accuracy: 0.8383
# Epoch 10/10
# 701/701 [==============================] - 8s 11ms/step - loss: 0.4814 - accuracy: 0.8548 - val_loss: 0.4724 - val_accuracy: 0.8499
#
# Validation Accuracy: 0.849949836730957
# Validation Loss: 0.4724283814430237
#
# 156/156 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.9265    0.7281    0.8154      2269
#            1     0.8073    0.9518    0.8736      2716
#
#     accuracy                         0.8499      4985
#    macro avg     0.8669    0.8399    0.8445      4985
# weighted avg     0.8616    0.8499    0.8471      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx])
    plt.plot(df['Val Loss'].iloc[idx])
    plt.title(f'loss function CNN+Bi-GRU TF-IDF UNIGRAM BIGRAM DROPOUT0.5-{idx+1}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/lossfunctionGraphics_CNN_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5-{idx+1}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/hasil_CNN_BIGRU_UNIGRAM_BIGRAM_DROPOUT0.5.csv', index=False)

#average
print('Average Accuracy :', df['Accuracy'].mean())
print('Average Precision :', df['Precision'].mean())
print('Average Recall :', df['Recall'].mean())
print('Average F1 Score :', df['F1 Score'].mean())
loss_func(df)
# Out:
# Average Accuracy : 0.8517552657973921
# Average Precision : 0.8120820764596178
# Average Recall : 0.9480117820324006
# Average F1 Score : 0.8490981683485819
