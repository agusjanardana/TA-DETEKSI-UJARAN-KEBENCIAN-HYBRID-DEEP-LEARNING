# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode BiGRU+ CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# check tensorflow version
# 2.9.1 untuk version paperspace
# 2.11 untuk collab
print(tf.__version__)
# Out:
# 2.9.3

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.1]
max_features = [5000, 10000, 15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           966528
#  l)
#
#  conv1d (Conv1D)             (44856, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (44856, 1, 32)           0
#  )
#
#  flatten (Flatten)           (44856, 32)               0
#
#  dense (Dense)               (44856, 32)               1056
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 9s 13ms/step - loss: 0.6871 - accuracy: 0.5675 - val_loss: 0.6708 - val_accuracy: 0.7025
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6193 - accuracy: 0.8086 - val_loss: 0.5547 - val_accuracy: 0.8459
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4770 - accuracy: 0.8577 - val_loss: 0.4232 - val_accuracy: 0.8562
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3730 - accuracy: 0.8695 - val_loss: 0.3613 - val_accuracy: 0.8618
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3259 - accuracy: 0.8764 - val_loss: 0.3375 - val_accuracy: 0.8640
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3028 - accuracy: 0.8826 - val_loss: 0.3281 - val_accuracy: 0.8670
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2896 - accuracy: 0.8868 - val_loss: 0.3242 - val_accuracy: 0.8666
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2805 - accuracy: 0.8909 - val_loss: 0.3238 - val_accuracy: 0.8666
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2740 - accuracy: 0.8940 - val_loss: 0.3234 - val_accuracy: 0.8682
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2688 - accuracy: 0.8966 - val_loss: 0.3263 - val_accuracy: 0.8660
#
# Validation Accuracy: 0.8659979701042175
# Validation Loss: 0.32628291845321655
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8718    0.8272    0.8489      2269
#            1     0.8616    0.8984    0.8796      2716
#
#     accuracy                         0.8660      4985
#    macro avg     0.8667    0.8628    0.8643      4985
# weighted avg     0.8662    0.8660    0.8656      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  conv1d_1 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (44856, 32)               0
#
#  dense_2 (Dense)             (44856, 32)               1056
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 12ms/step - loss: 0.6876 - accuracy: 0.5570 - val_loss: 0.6743 - val_accuracy: 0.6459
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6295 - accuracy: 0.7786 - val_loss: 0.5700 - val_accuracy: 0.8387
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4925 - accuracy: 0.8552 - val_loss: 0.4336 - val_accuracy: 0.8570
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3807 - accuracy: 0.8674 - val_loss: 0.3639 - val_accuracy: 0.8610
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3294 - accuracy: 0.8752 - val_loss: 0.3377 - val_accuracy: 0.8630
# Epoch 6/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3055 - accuracy: 0.8809 - val_loss: 0.3276 - val_accuracy: 0.8644
# Epoch 7/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2918 - accuracy: 0.8850 - val_loss: 0.3231 - val_accuracy: 0.8672
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2825 - accuracy: 0.8894 - val_loss: 0.3224 - val_accuracy: 0.8676
# Epoch 9/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2759 - accuracy: 0.8923 - val_loss: 0.3224 - val_accuracy: 0.8666
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2703 - accuracy: 0.8942 - val_loss: 0.3223 - val_accuracy: 0.8680
#
# Validation Accuracy: 0.8680040240287781
# Validation Loss: 0.3223287761211395
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8604    0.8475    0.8539      2269
#            1     0.8742    0.8851    0.8796      2716
#
#     accuracy                         0.8680      4985
#    macro avg     0.8673    0.8663    0.8668      4985
# weighted avg     0.8679    0.8680    0.8679      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  conv1d_2 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (44856, 32)               0
#
#  dense_4 (Dense)             (44856, 32)               1056
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 12ms/step - loss: 0.6874 - accuracy: 0.5451 - val_loss: 0.6752 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6358 - accuracy: 0.6528 - val_loss: 0.5868 - val_accuracy: 0.7521
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5264 - accuracy: 0.8189 - val_loss: 0.4788 - val_accuracy: 0.8407
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4241 - accuracy: 0.8641 - val_loss: 0.3980 - val_accuracy: 0.8604
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3563 - accuracy: 0.8740 - val_loss: 0.3556 - val_accuracy: 0.8616
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3201 - accuracy: 0.8798 - val_loss: 0.3362 - val_accuracy: 0.8620
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3009 - accuracy: 0.8844 - val_loss: 0.3283 - val_accuracy: 0.8638
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2894 - accuracy: 0.8885 - val_loss: 0.3256 - val_accuracy: 0.8658
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2817 - accuracy: 0.8907 - val_loss: 0.3241 - val_accuracy: 0.8668
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2759 - accuracy: 0.8935 - val_loss: 0.3249 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.3248501121997833
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8618    0.8409    0.8512      2269
#            1     0.8697    0.8873    0.8784      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8658    0.8641    0.8648      4985
# weighted avg     0.8661    0.8662    0.8660      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  conv1d_3 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (44856, 32)               0
#
#  dense_6 (Dense)             (44856, 32)               1056
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 12ms/step - loss: 0.6854 - accuracy: 0.5488 - val_loss: 0.6685 - val_accuracy: 0.5834
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6214 - accuracy: 0.7087 - val_loss: 0.5656 - val_accuracy: 0.7952
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4987 - accuracy: 0.8378 - val_loss: 0.4491 - val_accuracy: 0.8514
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3948 - accuracy: 0.8678 - val_loss: 0.3745 - val_accuracy: 0.8612
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3361 - accuracy: 0.8768 - val_loss: 0.3426 - val_accuracy: 0.8632
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3078 - accuracy: 0.8832 - val_loss: 0.3296 - val_accuracy: 0.8654
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2926 - accuracy: 0.8872 - val_loss: 0.3254 - val_accuracy: 0.8668
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2830 - accuracy: 0.8909 - val_loss: 0.3243 - val_accuracy: 0.8670
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2761 - accuracy: 0.8935 - val_loss: 0.3235 - val_accuracy: 0.8678
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.2708 - accuracy: 0.8961 - val_loss: 0.3250 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.32498571276664734
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8618    0.8409    0.8512      2269
#            1     0.8697    0.8873    0.8784      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8658    0.8641    0.8648      4985
# weighted avg     0.8661    0.8662    0.8660      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  conv1d_4 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (44856, 32)               0
#
#  dense_8 (Dense)             (44856, 32)               1056
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 12ms/step - loss: 0.6883 - accuracy: 0.5441 - val_loss: 0.6776 - val_accuracy: 0.5448
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6335 - accuracy: 0.6978 - val_loss: 0.5721 - val_accuracy: 0.8104
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4937 - accuracy: 0.8469 - val_loss: 0.4355 - val_accuracy: 0.8495
# Epoch 4/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3813 - accuracy: 0.8663 - val_loss: 0.3655 - val_accuracy: 0.8608
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3296 - accuracy: 0.8746 - val_loss: 0.3391 - val_accuracy: 0.8642
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3054 - accuracy: 0.8800 - val_loss: 0.3286 - val_accuracy: 0.8648
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2915 - accuracy: 0.8851 - val_loss: 0.3247 - val_accuracy: 0.8662
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2824 - accuracy: 0.8895 - val_loss: 0.3228 - val_accuracy: 0.8656
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2756 - accuracy: 0.8934 - val_loss: 0.3228 - val_accuracy: 0.8654
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2702 - accuracy: 0.8954 - val_loss: 0.3234 - val_accuracy: 0.8670
#
# Validation Accuracy: 0.8670009970664978
# Validation Loss: 0.323433518409729
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8578    0.8484    0.8531      2269
#            1     0.8745    0.8825    0.8785      2716
#
#     accuracy                         0.8670      4985
#    macro avg     0.8662    0.8655    0.8658      4985
# weighted avg     0.8669    0.8670    0.8669      4985
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_5 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_5 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_5 (Flatten)         (44856, 32)               0
#
#  dense_10 (Dense)            (44856, 32)               1056
#
#  dense_11 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 14ms/step - loss: 0.6886 - accuracy: 0.5452 - val_loss: 0.6781 - val_accuracy: 0.5567
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6465 - accuracy: 0.6969 - val_loss: 0.6036 - val_accuracy: 0.8042
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5353 - accuracy: 0.8441 - val_loss: 0.4769 - val_accuracy: 0.8518
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4131 - accuracy: 0.8709 - val_loss: 0.3865 - val_accuracy: 0.8630
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3395 - accuracy: 0.8787 - val_loss: 0.3453 - val_accuracy: 0.8660
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3021 - accuracy: 0.8865 - val_loss: 0.3282 - val_accuracy: 0.8674
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2807 - accuracy: 0.8929 - val_loss: 0.3220 - val_accuracy: 0.8668
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2665 - accuracy: 0.8985 - val_loss: 0.3191 - val_accuracy: 0.8704
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2562 - accuracy: 0.9033 - val_loss: 0.3193 - val_accuracy: 0.8708
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2479 - accuracy: 0.9071 - val_loss: 0.3211 - val_accuracy: 0.8694
#
# Validation Accuracy: 0.8694082498550415
# Validation Loss: 0.32113417983055115
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8694    0.8391    0.8540      2269
#            1     0.8694    0.8947    0.8819      2716
#
#     accuracy                         0.8694      4985
#    macro avg     0.8694    0.8669    0.8679      4985
# weighted avg     0.8694    0.8694    0.8692      4985
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_6 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_6 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_6 (Flatten)         (44856, 32)               0
#
#  dense_12 (Dense)            (44856, 32)               1056
#
#  dense_13 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6870 - accuracy: 0.5451 - val_loss: 0.6736 - val_accuracy: 0.5482
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6370 - accuracy: 0.6594 - val_loss: 0.5900 - val_accuracy: 0.7539
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5226 - accuracy: 0.8280 - val_loss: 0.4721 - val_accuracy: 0.8479
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4123 - accuracy: 0.8720 - val_loss: 0.3919 - val_accuracy: 0.8606
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3421 - accuracy: 0.8834 - val_loss: 0.3486 - val_accuracy: 0.8660
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3030 - accuracy: 0.8898 - val_loss: 0.3306 - val_accuracy: 0.8666
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2802 - accuracy: 0.8952 - val_loss: 0.3247 - val_accuracy: 0.8686
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2654 - accuracy: 0.9011 - val_loss: 0.3224 - val_accuracy: 0.8694
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2548 - accuracy: 0.9051 - val_loss: 0.3220 - val_accuracy: 0.8704
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2463 - accuracy: 0.9091 - val_loss: 0.3242 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.3242482542991638
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8592    0.8444    0.8517      2269
#            1     0.8719    0.8844    0.8781      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8655    0.8644    0.8649      4985
# weighted avg     0.8661    0.8662    0.8661      4985
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_7 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_7 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_7 (Flatten)         (44856, 32)               0
#
#  dense_14 (Dense)            (44856, 32)               1056
#
#  dense_15 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6864 - accuracy: 0.6046 - val_loss: 0.6692 - val_accuracy: 0.7827
# Epoch 2/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.6198 - accuracy: 0.8403 - val_loss: 0.5589 - val_accuracy: 0.8556
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4802 - accuracy: 0.8658 - val_loss: 0.4258 - val_accuracy: 0.8606
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3683 - accuracy: 0.8755 - val_loss: 0.3578 - val_accuracy: 0.8624
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3133 - accuracy: 0.8843 - val_loss: 0.3313 - val_accuracy: 0.8664
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2850 - accuracy: 0.8921 - val_loss: 0.3214 - val_accuracy: 0.8684
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2676 - accuracy: 0.8977 - val_loss: 0.3197 - val_accuracy: 0.8670
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2554 - accuracy: 0.9038 - val_loss: 0.3192 - val_accuracy: 0.8694
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2459 - accuracy: 0.9079 - val_loss: 0.3210 - val_accuracy: 0.8696
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2381 - accuracy: 0.9121 - val_loss: 0.3244 - val_accuracy: 0.8674
#
# Validation Accuracy: 0.867402195930481
# Validation Loss: 0.32444706559181213
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8631    0.8422    0.8526      2269
#            1     0.8708    0.8884    0.8795      2716
#
#     accuracy                         0.8674      4985
#    macro avg     0.8670    0.8653    0.8660      4985
# weighted avg     0.8673    0.8674    0.8673      4985
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_8 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_8 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_8 (Flatten)         (44856, 32)               0
#
#  dense_16 (Dense)            (44856, 32)               1056
#
#  dense_17 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 13ms/step - loss: 0.6873 - accuracy: 0.5527 - val_loss: 0.6730 - val_accuracy: 0.6138
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6312 - accuracy: 0.7281 - val_loss: 0.5786 - val_accuracy: 0.8050
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5073 - accuracy: 0.8461 - val_loss: 0.4551 - val_accuracy: 0.8578
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3954 - accuracy: 0.8723 - val_loss: 0.3778 - val_accuracy: 0.8634
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3308 - accuracy: 0.8820 - val_loss: 0.3435 - val_accuracy: 0.8656
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2970 - accuracy: 0.8894 - val_loss: 0.3280 - val_accuracy: 0.8668
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2771 - accuracy: 0.8958 - val_loss: 0.3224 - val_accuracy: 0.8666
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2636 - accuracy: 0.9008 - val_loss: 0.3216 - val_accuracy: 0.8700
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2534 - accuracy: 0.9048 - val_loss: 0.3221 - val_accuracy: 0.8688
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2452 - accuracy: 0.9085 - val_loss: 0.3248 - val_accuracy: 0.8666
#
# Validation Accuracy: 0.8665997982025146
# Validation Loss: 0.3248419463634491
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8574    0.8480    0.8526      2269
#            1     0.8741    0.8822    0.8781      2716
#
#     accuracy                         0.8666      4985
#    macro avg     0.8658    0.8651    0.8654      4985
# weighted avg     0.8665    0.8666    0.8665      4985
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_9 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  conv1d_9 (Conv1D)           (44856, 1, 32)            6176
#
#  max_pooling1d_9 (MaxPooling  (44856, 1, 32)           0
#  1D)
#
#  flatten_9 (Flatten)         (44856, 32)               0
#
#  dense_18 (Dense)            (44856, 32)               1056
#
#  dense_19 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6870 - accuracy: 0.5621 - val_loss: 0.6715 - val_accuracy: 0.6700
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6248 - accuracy: 0.7776 - val_loss: 0.5677 - val_accuracy: 0.8327
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4894 - accuracy: 0.8578 - val_loss: 0.4333 - val_accuracy: 0.8560
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3736 - accuracy: 0.8731 - val_loss: 0.3614 - val_accuracy: 0.8630
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3169 - accuracy: 0.8820 - val_loss: 0.3348 - val_accuracy: 0.8638
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2885 - accuracy: 0.8893 - val_loss: 0.3248 - val_accuracy: 0.8654
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2711 - accuracy: 0.8964 - val_loss: 0.3208 - val_accuracy: 0.8666
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2588 - accuracy: 0.9016 - val_loss: 0.3202 - val_accuracy: 0.8694
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2495 - accuracy: 0.9063 - val_loss: 0.3220 - val_accuracy: 0.8682
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2417 - accuracy: 0.9103 - val_loss: 0.3250 - val_accuracy: 0.8678
#
# Validation Accuracy: 0.8678033947944641
# Validation Loss: 0.3249867558479309
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8633    0.8431    0.8531      2269
#            1     0.8714    0.8884    0.8799      2716
#
#     accuracy                         0.8678      4985
#    macro avg     0.8674    0.8658    0.8665      4985
# weighted avg     0.8677    0.8678    0.8677      4985
#
#
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_10 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  conv1d_10 (Conv1D)          (44856, 1, 32)            6176
#
#  max_pooling1d_10 (MaxPoolin  (44856, 1, 32)           0
#  g1D)
#
#  flatten_10 (Flatten)        (44856, 32)               0
#
#  dense_20 (Dense)            (44856, 32)               1056
#
#  dense_21 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6844 - accuracy: 0.5565 - val_loss: 0.6651 - val_accuracy: 0.6221
# Epoch 2/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.6182 - accuracy: 0.7369 - val_loss: 0.5654 - val_accuracy: 0.7954
# Epoch 3/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.4976 - accuracy: 0.8470 - val_loss: 0.4519 - val_accuracy: 0.8562
# Epoch 4/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.3900 - accuracy: 0.8769 - val_loss: 0.3771 - val_accuracy: 0.8626
# Epoch 5/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.3241 - accuracy: 0.8871 - val_loss: 0.3431 - val_accuracy: 0.8638
# Epoch 6/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2880 - accuracy: 0.8955 - val_loss: 0.3285 - val_accuracy: 0.8658
# Epoch 7/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2659 - accuracy: 0.9018 - val_loss: 0.3231 - val_accuracy: 0.8682
# Epoch 8/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2507 - accuracy: 0.9068 - val_loss: 0.3229 - val_accuracy: 0.8682
# Epoch 9/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2390 - accuracy: 0.9117 - val_loss: 0.3269 - val_accuracy: 0.8674
# Epoch 10/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2295 - accuracy: 0.9166 - val_loss: 0.3296 - val_accuracy: 0.8664
#
# Validation Accuracy: 0.8663991689682007
# Validation Loss: 0.3295685052871704
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8561    0.8493    0.8527      2269
#            1     0.8749    0.8807    0.8778      2716
#
#     accuracy                         0.8664      4985
#    macro avg     0.8655    0.8650    0.8652      4985
# weighted avg     0.8663    0.8664    0.8664      4985
#
#
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_11 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  conv1d_11 (Conv1D)          (44856, 1, 32)            6176
#
#  max_pooling1d_11 (MaxPoolin  (44856, 1, 32)           0
#  g1D)
#
#  flatten_11 (Flatten)        (44856, 32)               0
#
#  dense_22 (Dense)            (44856, 32)               1056
#
#  dense_23 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 16ms/step - loss: 0.6869 - accuracy: 0.5505 - val_loss: 0.6716 - val_accuracy: 0.6134
# Epoch 2/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.6280 - accuracy: 0.7317 - val_loss: 0.5732 - val_accuracy: 0.7958
# Epoch 3/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.4978 - accuracy: 0.8495 - val_loss: 0.4465 - val_accuracy: 0.8568
# Epoch 4/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.3819 - accuracy: 0.8783 - val_loss: 0.3704 - val_accuracy: 0.8630
# Epoch 5/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.3161 - accuracy: 0.8898 - val_loss: 0.3387 - val_accuracy: 0.8628
# Epoch 6/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2816 - accuracy: 0.8977 - val_loss: 0.3271 - val_accuracy: 0.8642
# Epoch 7/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.2607 - accuracy: 0.9046 - val_loss: 0.3237 - val_accuracy: 0.8660
# Epoch 8/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2461 - accuracy: 0.9098 - val_loss: 0.3254 - val_accuracy: 0.8664
# Epoch 9/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2348 - accuracy: 0.9144 - val_loss: 0.3281 - val_accuracy: 0.8660
# Epoch 10/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2255 - accuracy: 0.9190 - val_loss: 0.3332 - val_accuracy: 0.8648
#
# Validation Accuracy: 0.8647943735122681
# Validation Loss: 0.33321160078048706
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8578    0.8427    0.8502      2269
#            1     0.8705    0.8833    0.8768      2716
#
#     accuracy                         0.8648      4985
#    macro avg     0.8641    0.8630    0.8635      4985
# weighted avg     0.8647    0.8648    0.8647      4985
#
#
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_12 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  conv1d_12 (Conv1D)          (44856, 1, 32)            6176
#
#  max_pooling1d_12 (MaxPoolin  (44856, 1, 32)           0
#  g1D)
#
#  flatten_12 (Flatten)        (44856, 32)               0
#
#  dense_24 (Dense)            (44856, 32)               1056
#
#  dense_25 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 17ms/step - loss: 0.6853 - accuracy: 0.5482 - val_loss: 0.6668 - val_accuracy: 0.5982
# Epoch 2/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.6155 - accuracy: 0.7338 - val_loss: 0.5581 - val_accuracy: 0.8030
# Epoch 3/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.4881 - accuracy: 0.8499 - val_loss: 0.4427 - val_accuracy: 0.8544
# Epoch 4/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.3818 - accuracy: 0.8773 - val_loss: 0.3712 - val_accuracy: 0.8634
# Epoch 5/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.3183 - accuracy: 0.8881 - val_loss: 0.3380 - val_accuracy: 0.8656
# Epoch 6/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2835 - accuracy: 0.8957 - val_loss: 0.3265 - val_accuracy: 0.8646
# Epoch 7/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2623 - accuracy: 0.9027 - val_loss: 0.3220 - val_accuracy: 0.8670
# Epoch 8/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2472 - accuracy: 0.9092 - val_loss: 0.3224 - val_accuracy: 0.8674
# Epoch 9/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2357 - accuracy: 0.9140 - val_loss: 0.3268 - val_accuracy: 0.8654
# Epoch 10/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2263 - accuracy: 0.9180 - val_loss: 0.3304 - val_accuracy: 0.8636
#
# Validation Accuracy: 0.8635907769203186
# Validation Loss: 0.33037057518959045
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8574    0.8400    0.8486      2269
#            1     0.8686    0.8833    0.8759      2716
#
#     accuracy                         0.8636      4985
#    macro avg     0.8630    0.8617    0.8622      4985
# weighted avg     0.8635    0.8636    0.8635      4985
#
#
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_13 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  conv1d_13 (Conv1D)          (44856, 1, 32)            6176
#
#  max_pooling1d_13 (MaxPoolin  (44856, 1, 32)           0
#  g1D)
#
#  flatten_13 (Flatten)        (44856, 32)               0
#
#  dense_26 (Dense)            (44856, 32)               1056
#
#  dense_27 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 16ms/step - loss: 0.6879 - accuracy: 0.5474 - val_loss: 0.6750 - val_accuracy: 0.5878
# Epoch 2/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.6364 - accuracy: 0.7128 - val_loss: 0.5885 - val_accuracy: 0.7787
# Epoch 3/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.5180 - accuracy: 0.8404 - val_loss: 0.4644 - val_accuracy: 0.8538
# Epoch 4/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.3989 - accuracy: 0.8732 - val_loss: 0.3801 - val_accuracy: 0.8634
# Epoch 5/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.3271 - accuracy: 0.8846 - val_loss: 0.3428 - val_accuracy: 0.8638
# Epoch 6/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2892 - accuracy: 0.8934 - val_loss: 0.3285 - val_accuracy: 0.8632
# Epoch 7/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2667 - accuracy: 0.9010 - val_loss: 0.3235 - val_accuracy: 0.8634
# Epoch 8/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2512 - accuracy: 0.9074 - val_loss: 0.3228 - val_accuracy: 0.8672
# Epoch 9/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.2394 - accuracy: 0.9118 - val_loss: 0.3272 - val_accuracy: 0.8656
# Epoch 10/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2298 - accuracy: 0.9165 - val_loss: 0.3291 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.3290547728538513
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8592    0.8444    0.8517      2269
#            1     0.8719    0.8844    0.8781      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8655    0.8644    0.8649      4985
# weighted avg     0.8661    0.8662    0.8661      4985
#
#
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_14 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  conv1d_14 (Conv1D)          (44856, 1, 32)            6176
#
#  max_pooling1d_14 (MaxPoolin  (44856, 1, 32)           0
#  g1D)
#
#  flatten_14 (Flatten)        (44856, 32)               0
#
#  dense_28 (Dense)            (44856, 32)               1056
#
#  dense_29 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 16ms/step - loss: 0.6844 - accuracy: 0.5550 - val_loss: 0.6648 - val_accuracy: 0.6233
# Epoch 2/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.6143 - accuracy: 0.7464 - val_loss: 0.5570 - val_accuracy: 0.8080
# Epoch 3/10
# 351/351 [==============================] - 5s 14ms/step - loss: 0.4860 - accuracy: 0.8542 - val_loss: 0.4402 - val_accuracy: 0.8612
# Epoch 4/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.3777 - accuracy: 0.8809 - val_loss: 0.3681 - val_accuracy: 0.8654
# Epoch 5/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.3139 - accuracy: 0.8902 - val_loss: 0.3371 - val_accuracy: 0.8660
# Epoch 6/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2795 - accuracy: 0.8995 - val_loss: 0.3253 - val_accuracy: 0.8668
# Epoch 7/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2583 - accuracy: 0.9067 - val_loss: 0.3222 - val_accuracy: 0.8682
# Epoch 8/10
# 351/351 [==============================] - 5s 13ms/step - loss: 0.2434 - accuracy: 0.9123 - val_loss: 0.3240 - val_accuracy: 0.8688
# Epoch 9/10
# 351/351 [==============================] - 4s 13ms/step - loss: 0.2319 - accuracy: 0.9162 - val_loss: 0.3279 - val_accuracy: 0.8660
# Epoch 10/10
# 351/351 [==============================] - 4s 13ms/step - loss: 0.2226 - accuracy: 0.9204 - val_loss: 0.3329 - val_accuracy: 0.8644
#
# Validation Accuracy: 0.8643931746482849
# Validation Loss: 0.33289635181427
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8583    0.8409    0.8495      2269
#            1     0.8693    0.8840    0.8766      2716
#
#     accuracy                         0.8644      4985
#    macro avg     0.8638    0.8625    0.8631      4985
# weighted avg     0.8643    0.8644    0.8643      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_BiGRUCNN-1.csv', index=False)
loss_func(df)

# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.1 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.1 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.1 & max features 15000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
# Out:
# Average Score by Test Size
# Test Size 0.1 & max features 5000
# Average Accuracy Score : 0.8666800401203612
# Average Precision Score : 0.8699412682608862
# Average Recall Score : 0.8881443298969071
# Average F1 Score : 0.8665183416865139
#
# Test_Size 0.1 & max features 10000
# Average Accuracy Score : 0.8674824473420261
# Average Precision Score : 0.871530202144481
# Average Recall Score : 0.8876288659793815
# Average F1 Score : 0.8673466431627925
#
# Test_Size 0.1 & max features 15000
# Average Accuracy Score : 0.8650752256770311
# Average Precision Score : 0.8710226872987427
# Average Recall Score : 0.8831369661266567
# Average F1 Score : 0.8649740003845651
