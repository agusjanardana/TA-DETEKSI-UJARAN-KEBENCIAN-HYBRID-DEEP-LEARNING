# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode BiGRU+ CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# check tensorflow version
# 2.9.1 untuk version paperspace
# 2.11 untuk collab
print(tf.__version__)
# Out:
# 2.9.3

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.3]
max_features = [5000, 10000, 15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (34888, 1, 64)           966528
#  l)
#
#  conv1d (Conv1D)             (34888, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (34888, 1, 32)           0
#  )
#
#  flatten (Flatten)           (34888, 32)               0
#
#  dense (Dense)               (34888, 32)               1056
#
#  dense_1 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 14ms/step - loss: 0.6888 - accuracy: 0.5456 - val_loss: 0.6804 - val_accuracy: 0.5465
# Epoch 2/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.6536 - accuracy: 0.6278 - val_loss: 0.6175 - val_accuracy: 0.7251
# Epoch 3/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.5633 - accuracy: 0.7915 - val_loss: 0.5202 - val_accuracy: 0.8240
# Epoch 4/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.4648 - accuracy: 0.8526 - val_loss: 0.4404 - val_accuracy: 0.8506
# Epoch 5/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3903 - accuracy: 0.8709 - val_loss: 0.3883 - val_accuracy: 0.8551
# Epoch 6/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3418 - accuracy: 0.8783 - val_loss: 0.3599 - val_accuracy: 0.8584
# Epoch 7/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3124 - accuracy: 0.8835 - val_loss: 0.3451 - val_accuracy: 0.8598
# Epoch 8/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2942 - accuracy: 0.8881 - val_loss: 0.3391 - val_accuracy: 0.8614
# Epoch 9/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2819 - accuracy: 0.8921 - val_loss: 0.3368 - val_accuracy: 0.8624
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2730 - accuracy: 0.8954 - val_loss: 0.3363 - val_accuracy: 0.8620
#
# Validation Accuracy: 0.8619675040245056
# Validation Loss: 0.3363156020641327
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8539    0.8404    0.8471      6803
#            1     0.8685    0.8800    0.8742      8150
#
#     accuracy                         0.8620     14953
#    macro avg     0.8612    0.8602    0.8606     14953
# weighted avg     0.8619    0.8620    0.8619     14953
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  conv1d_1 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (34888, 32)               0
#
#  dense_2 (Dense)             (34888, 32)               1056
#
#  dense_3 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 13ms/step - loss: 0.6894 - accuracy: 0.5431 - val_loss: 0.6824 - val_accuracy: 0.5450
# Epoch 2/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.6597 - accuracy: 0.6214 - val_loss: 0.6270 - val_accuracy: 0.7459
# Epoch 3/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.5732 - accuracy: 0.8040 - val_loss: 0.5264 - val_accuracy: 0.8266
# Epoch 4/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.4655 - accuracy: 0.8559 - val_loss: 0.4357 - val_accuracy: 0.8509
# Epoch 5/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3839 - accuracy: 0.8698 - val_loss: 0.3816 - val_accuracy: 0.8547
# Epoch 6/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3361 - accuracy: 0.8771 - val_loss: 0.3553 - val_accuracy: 0.8580
# Epoch 7/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3092 - accuracy: 0.8822 - val_loss: 0.3431 - val_accuracy: 0.8600
# Epoch 8/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2924 - accuracy: 0.8866 - val_loss: 0.3371 - val_accuracy: 0.8609
# Epoch 9/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2809 - accuracy: 0.8906 - val_loss: 0.3355 - val_accuracy: 0.8609
# Epoch 10/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2724 - accuracy: 0.8945 - val_loss: 0.3356 - val_accuracy: 0.8616
#
# Validation Accuracy: 0.8615662455558777
# Validation Loss: 0.3355967700481415
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8605    0.8304    0.8452      6803
#            1     0.8624    0.8876    0.8748      8150
#
#     accuracy                         0.8616     14953
#    macro avg     0.8614    0.8590    0.8600     14953
# weighted avg     0.8615    0.8616    0.8613     14953
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  conv1d_2 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (34888, 32)               0
#
#  dense_4 (Dense)             (34888, 32)               1056
#
#  dense_5 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 13ms/step - loss: 0.6900 - accuracy: 0.5444 - val_loss: 0.6836 - val_accuracy: 0.5450
# Epoch 2/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.6606 - accuracy: 0.6365 - val_loss: 0.6276 - val_accuracy: 0.7408
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5720 - accuracy: 0.8127 - val_loss: 0.5242 - val_accuracy: 0.8318
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4640 - accuracy: 0.8577 - val_loss: 0.4355 - val_accuracy: 0.8517
# Epoch 5/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3840 - accuracy: 0.8718 - val_loss: 0.3824 - val_accuracy: 0.8547
# Epoch 6/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3366 - accuracy: 0.8786 - val_loss: 0.3560 - val_accuracy: 0.8579
# Epoch 7/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3094 - accuracy: 0.8830 - val_loss: 0.3433 - val_accuracy: 0.8603
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2927 - accuracy: 0.8876 - val_loss: 0.3381 - val_accuracy: 0.8617
# Epoch 9/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2815 - accuracy: 0.8921 - val_loss: 0.3368 - val_accuracy: 0.8616
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2730 - accuracy: 0.8947 - val_loss: 0.3367 - val_accuracy: 0.8618
#
# Validation Accuracy: 0.8618337512016296
# Validation Loss: 0.33669352531433105
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8633    0.8273    0.8449      6803
#            1     0.8607    0.8907    0.8754      8150
#
#     accuracy                         0.8618     14953
#    macro avg     0.8620    0.8590    0.8602     14953
# weighted avg     0.8619    0.8618    0.8615     14953
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  conv1d_3 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (34888, 32)               0
#
#  dense_6 (Dense)             (34888, 32)               1056
#
#  dense_7 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 13ms/step - loss: 0.6900 - accuracy: 0.5404 - val_loss: 0.6834 - val_accuracy: 0.5481
# Epoch 2/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.6591 - accuracy: 0.6606 - val_loss: 0.6248 - val_accuracy: 0.7757
# Epoch 3/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.5665 - accuracy: 0.8243 - val_loss: 0.5154 - val_accuracy: 0.8418
# Epoch 4/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.4523 - accuracy: 0.8614 - val_loss: 0.4241 - val_accuracy: 0.8502
# Epoch 5/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3744 - accuracy: 0.8694 - val_loss: 0.3759 - val_accuracy: 0.8546
# Epoch 6/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3317 - accuracy: 0.8755 - val_loss: 0.3530 - val_accuracy: 0.8573
# Epoch 7/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3072 - accuracy: 0.8804 - val_loss: 0.3420 - val_accuracy: 0.8601
# Epoch 8/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2916 - accuracy: 0.8860 - val_loss: 0.3370 - val_accuracy: 0.8608
# Epoch 9/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2808 - accuracy: 0.8902 - val_loss: 0.3352 - val_accuracy: 0.8622
# Epoch 10/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2729 - accuracy: 0.8931 - val_loss: 0.3352 - val_accuracy: 0.8615
#
# Validation Accuracy: 0.8614993691444397
# Validation Loss: 0.3351582884788513
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8594    0.8317    0.8453      6803
#            1     0.8632    0.8864    0.8746      8150
#
#     accuracy                         0.8615     14953
#    macro avg     0.8613    0.8590    0.8600     14953
# weighted avg     0.8614    0.8615    0.8613     14953
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  conv1d_4 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (34888, 32)               0
#
#  dense_8 (Dense)             (34888, 32)               1056
#
#  dense_9 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 13ms/step - loss: 0.6892 - accuracy: 0.5432 - val_loss: 0.6813 - val_accuracy: 0.5531
# Epoch 2/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.6554 - accuracy: 0.6791 - val_loss: 0.6197 - val_accuracy: 0.7699
# Epoch 3/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.5603 - accuracy: 0.8260 - val_loss: 0.5106 - val_accuracy: 0.8406
# Epoch 4/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.4482 - accuracy: 0.8604 - val_loss: 0.4213 - val_accuracy: 0.8505
# Epoch 5/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3708 - accuracy: 0.8721 - val_loss: 0.3735 - val_accuracy: 0.8550
# Epoch 6/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3281 - accuracy: 0.8784 - val_loss: 0.3512 - val_accuracy: 0.8582
# Epoch 7/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3038 - accuracy: 0.8826 - val_loss: 0.3411 - val_accuracy: 0.8607
# Epoch 8/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2884 - accuracy: 0.8873 - val_loss: 0.3364 - val_accuracy: 0.8606
# Epoch 9/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2776 - accuracy: 0.8919 - val_loss: 0.3354 - val_accuracy: 0.8612
# Epoch 10/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.2695 - accuracy: 0.8952 - val_loss: 0.3358 - val_accuracy: 0.8615
#
# Validation Accuracy: 0.8614993691444397
# Validation Loss: 0.3357728123664856
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8600    0.8308    0.8452      6803
#            1     0.8627    0.8871    0.8747      8150
#
#     accuracy                         0.8615     14953
#    macro avg     0.8613    0.8590    0.8599     14953
# weighted avg     0.8615    0.8615    0.8613     14953
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  conv1d_5 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_5 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_5 (Flatten)         (34888, 32)               0
#
#  dense_10 (Dense)            (34888, 32)               1056
#
#  dense_11 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 16ms/step - loss: 0.6886 - accuracy: 0.5449 - val_loss: 0.6793 - val_accuracy: 0.5450
# Epoch 2/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6493 - accuracy: 0.6438 - val_loss: 0.6125 - val_accuracy: 0.7423
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5551 - accuracy: 0.8100 - val_loss: 0.5139 - val_accuracy: 0.8299
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4518 - accuracy: 0.8642 - val_loss: 0.4316 - val_accuracy: 0.8532
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3725 - accuracy: 0.8801 - val_loss: 0.3799 - val_accuracy: 0.8578
# Epoch 6/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3217 - accuracy: 0.8876 - val_loss: 0.3528 - val_accuracy: 0.8591
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2903 - accuracy: 0.8954 - val_loss: 0.3403 - val_accuracy: 0.8614
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2696 - accuracy: 0.9005 - val_loss: 0.3355 - val_accuracy: 0.8620
# Epoch 9/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2549 - accuracy: 0.9045 - val_loss: 0.3353 - val_accuracy: 0.8616
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2438 - accuracy: 0.9088 - val_loss: 0.3373 - val_accuracy: 0.8616
#
# Validation Accuracy: 0.8615662455558777
# Validation Loss: 0.33731865882873535
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8571    0.8349    0.8459      6803
#            1     0.8651    0.8838    0.8744      8150
#
#     accuracy                         0.8616     14953
#    macro avg     0.8611    0.8594    0.8601     14953
# weighted avg     0.8615    0.8616    0.8614     14953
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  conv1d_6 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_6 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_6 (Flatten)         (34888, 32)               0
#
#  dense_12 (Dense)            (34888, 32)               1056
#
#  dense_13 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 15ms/step - loss: 0.6904 - accuracy: 0.5463 - val_loss: 0.6841 - val_accuracy: 0.6106
# Epoch 2/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6607 - accuracy: 0.7725 - val_loss: 0.6267 - val_accuracy: 0.8397
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5659 - accuracy: 0.8594 - val_loss: 0.5147 - val_accuracy: 0.8488
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4459 - accuracy: 0.8703 - val_loss: 0.4193 - val_accuracy: 0.8537
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3612 - accuracy: 0.8778 - val_loss: 0.3686 - val_accuracy: 0.8561
# Epoch 6/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3137 - accuracy: 0.8860 - val_loss: 0.3455 - val_accuracy: 0.8584
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2856 - accuracy: 0.8925 - val_loss: 0.3353 - val_accuracy: 0.8604
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2669 - accuracy: 0.8988 - val_loss: 0.3314 - val_accuracy: 0.8634
# Epoch 9/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2529 - accuracy: 0.9038 - val_loss: 0.3311 - val_accuracy: 0.8641
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2420 - accuracy: 0.9091 - val_loss: 0.3336 - val_accuracy: 0.8633
#
# Validation Accuracy: 0.8633050322532654
# Validation Loss: 0.3336164355278015
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8511    0.8479    0.8495      6803
#            1     0.8734    0.8762    0.8748      8150
#
#     accuracy                         0.8633     14953
#    macro avg     0.8623    0.8620    0.8621     14953
# weighted avg     0.8633    0.8633    0.8633     14953
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  conv1d_7 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_7 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_7 (Flatten)         (34888, 32)               0
#
#  dense_14 (Dense)            (34888, 32)               1056
#
#  dense_15 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 16ms/step - loss: 0.6903 - accuracy: 0.5453 - val_loss: 0.6840 - val_accuracy: 0.6024
# Epoch 2/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6632 - accuracy: 0.7492 - val_loss: 0.6359 - val_accuracy: 0.8190
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5861 - accuracy: 0.8532 - val_loss: 0.5419 - val_accuracy: 0.8480
# Epoch 4/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4767 - accuracy: 0.8684 - val_loss: 0.4457 - val_accuracy: 0.8527
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3865 - accuracy: 0.8762 - val_loss: 0.3857 - val_accuracy: 0.8557
# Epoch 6/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3309 - accuracy: 0.8835 - val_loss: 0.3550 - val_accuracy: 0.8578
# Epoch 7/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2979 - accuracy: 0.8902 - val_loss: 0.3405 - val_accuracy: 0.8606
# Epoch 8/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2762 - accuracy: 0.8960 - val_loss: 0.3338 - val_accuracy: 0.8625
# Epoch 9/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2607 - accuracy: 0.9020 - val_loss: 0.3317 - val_accuracy: 0.8638
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2487 - accuracy: 0.9059 - val_loss: 0.3319 - val_accuracy: 0.8636
#
# Validation Accuracy: 0.8635725378990173
# Validation Loss: 0.3318710923194885
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8571    0.8402    0.8486      6803
#            1     0.8688    0.8831    0.8759      8150
#
#     accuracy                         0.8636     14953
#    macro avg     0.8629    0.8616    0.8622     14953
# weighted avg     0.8635    0.8636    0.8635     14953
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  conv1d_8 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_8 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_8 (Flatten)         (34888, 32)               0
#
#  dense_16 (Dense)            (34888, 32)               1056
#
#  dense_17 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 16ms/step - loss: 0.6902 - accuracy: 0.5435 - val_loss: 0.6844 - val_accuracy: 0.5450
# Epoch 2/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6644 - accuracy: 0.6039 - val_loss: 0.6358 - val_accuracy: 0.7137
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5824 - accuracy: 0.7948 - val_loss: 0.5349 - val_accuracy: 0.8274
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4676 - accuracy: 0.8601 - val_loss: 0.4383 - val_accuracy: 0.8515
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3777 - accuracy: 0.8756 - val_loss: 0.3804 - val_accuracy: 0.8544
# Epoch 6/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3245 - accuracy: 0.8836 - val_loss: 0.3528 - val_accuracy: 0.8568
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2937 - accuracy: 0.8904 - val_loss: 0.3406 - val_accuracy: 0.8605
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2736 - accuracy: 0.8969 - val_loss: 0.3352 - val_accuracy: 0.8622
# Epoch 9/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2591 - accuracy: 0.9022 - val_loss: 0.3339 - val_accuracy: 0.8627
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.2476 - accuracy: 0.9058 - val_loss: 0.3350 - val_accuracy: 0.8633
#
# Validation Accuracy: 0.8633050322532654
# Validation Loss: 0.33503270149230957
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8552    0.8421    0.8486      6803
#            1     0.8699    0.8810    0.8754      8150
#
#     accuracy                         0.8633     14953
#    macro avg     0.8625    0.8616    0.8620     14953
# weighted avg     0.8632    0.8633    0.8632     14953
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_9 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  conv1d_9 (Conv1D)           (34888, 1, 32)            6176
#
#  max_pooling1d_9 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  flatten_9 (Flatten)         (34888, 32)               0
#
#  dense_18 (Dense)            (34888, 32)               1056
#
#  dense_19 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 15ms/step - loss: 0.6888 - accuracy: 0.5449 - val_loss: 0.6799 - val_accuracy: 0.5450
# Epoch 2/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6527 - accuracy: 0.6154 - val_loss: 0.6181 - val_accuracy: 0.7210
# Epoch 3/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.5620 - accuracy: 0.7943 - val_loss: 0.5207 - val_accuracy: 0.8156
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4588 - accuracy: 0.8592 - val_loss: 0.4373 - val_accuracy: 0.8511
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3777 - accuracy: 0.8797 - val_loss: 0.3831 - val_accuracy: 0.8567
# Epoch 6/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3245 - accuracy: 0.8875 - val_loss: 0.3546 - val_accuracy: 0.8603
# Epoch 7/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2917 - accuracy: 0.8947 - val_loss: 0.3414 - val_accuracy: 0.8634
# Epoch 8/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2705 - accuracy: 0.9013 - val_loss: 0.3367 - val_accuracy: 0.8634
# Epoch 9/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2555 - accuracy: 0.9057 - val_loss: 0.3371 - val_accuracy: 0.8628
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.2441 - accuracy: 0.9098 - val_loss: 0.3381 - val_accuracy: 0.8605
#
# Validation Accuracy: 0.8604962229728699
# Validation Loss: 0.338149756193161
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8471    0.8461    0.8466      6803
#            1     0.8717    0.8725    0.8721      8150
#
#     accuracy                         0.8605     14953
#    macro avg     0.8594    0.8593    0.8593     14953
# weighted avg     0.8605    0.8605    0.8605     14953
#
#
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_10 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  conv1d_10 (Conv1D)          (34888, 1, 32)            6176
#
#  max_pooling1d_10 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  flatten_10 (Flatten)        (34888, 32)               0
#
#  dense_20 (Dense)            (34888, 32)               1056
#
#  dense_21 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 19ms/step - loss: 0.6894 - accuracy: 0.5445 - val_loss: 0.6811 - val_accuracy: 0.5458
# Epoch 2/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.6541 - accuracy: 0.6682 - val_loss: 0.6204 - val_accuracy: 0.7529
# Epoch 3/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.5639 - accuracy: 0.8248 - val_loss: 0.5201 - val_accuracy: 0.8370
# Epoch 4/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.4516 - accuracy: 0.8710 - val_loss: 0.4288 - val_accuracy: 0.8546
# Epoch 5/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3637 - accuracy: 0.8845 - val_loss: 0.3748 - val_accuracy: 0.8588
# Epoch 6/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3096 - accuracy: 0.8933 - val_loss: 0.3483 - val_accuracy: 0.8604
# Epoch 7/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2771 - accuracy: 0.8997 - val_loss: 0.3376 - val_accuracy: 0.8627
# Epoch 8/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.2554 - accuracy: 0.9067 - val_loss: 0.3337 - val_accuracy: 0.8631
# Epoch 9/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2393 - accuracy: 0.9118 - val_loss: 0.3343 - val_accuracy: 0.8618
# Epoch 10/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2266 - accuracy: 0.9169 - val_loss: 0.3375 - val_accuracy: 0.8609
#
# Validation Accuracy: 0.8608974814414978
# Validation Loss: 0.33753401041030884
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8524    0.8396    0.8460      6803
#            1     0.8678    0.8787    0.8732      8150
#
#     accuracy                         0.8609     14953
#    macro avg     0.8601    0.8591    0.8596     14953
# weighted avg     0.8608    0.8609    0.8608     14953
#
#
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_11 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  conv1d_11 (Conv1D)          (34888, 1, 32)            6176
#
#  max_pooling1d_11 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  flatten_11 (Flatten)        (34888, 32)               0
#
#  dense_22 (Dense)            (34888, 32)               1056
#
#  dense_23 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 19ms/step - loss: 0.6899 - accuracy: 0.5444 - val_loss: 0.6827 - val_accuracy: 0.5487
# Epoch 2/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.6604 - accuracy: 0.6473 - val_loss: 0.6319 - val_accuracy: 0.7372
# Epoch 3/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.5828 - accuracy: 0.8002 - val_loss: 0.5442 - val_accuracy: 0.8103
# Epoch 4/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.4813 - accuracy: 0.8579 - val_loss: 0.4559 - val_accuracy: 0.8504
# Epoch 5/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3930 - accuracy: 0.8803 - val_loss: 0.3958 - val_accuracy: 0.8572
# Epoch 6/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3325 - accuracy: 0.8887 - val_loss: 0.3611 - val_accuracy: 0.8582
# Epoch 7/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2941 - accuracy: 0.8969 - val_loss: 0.3446 - val_accuracy: 0.8605
# Epoch 8/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2689 - accuracy: 0.9026 - val_loss: 0.3368 - val_accuracy: 0.8625
# Epoch 9/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2506 - accuracy: 0.9084 - val_loss: 0.3356 - val_accuracy: 0.8622
# Epoch 10/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.2367 - accuracy: 0.9132 - val_loss: 0.3361 - val_accuracy: 0.8610
#
# Validation Accuracy: 0.8610312342643738
# Validation Loss: 0.33613109588623047
#
# 468/468 [==============================] - 1s 3ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8548    0.8367    0.8456      6803
#            1     0.8660    0.8813    0.8736      8150
#
#     accuracy                         0.8610     14953
#    macro avg     0.8604    0.8590    0.8596     14953
# weighted avg     0.8609    0.8610    0.8609     14953
#
#
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_12 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  conv1d_12 (Conv1D)          (34888, 1, 32)            6176
#
#  max_pooling1d_12 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  flatten_12 (Flatten)        (34888, 32)               0
#
#  dense_24 (Dense)            (34888, 32)               1056
#
#  dense_25 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 20ms/step - loss: 0.6894 - accuracy: 0.5461 - val_loss: 0.6809 - val_accuracy: 0.5787
# Epoch 2/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.6549 - accuracy: 0.7087 - val_loss: 0.6234 - val_accuracy: 0.7754
# Epoch 3/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.5689 - accuracy: 0.8291 - val_loss: 0.5270 - val_accuracy: 0.8348
# Epoch 4/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.4576 - accuracy: 0.8732 - val_loss: 0.4335 - val_accuracy: 0.8568
# Epoch 5/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3673 - accuracy: 0.8854 - val_loss: 0.3771 - val_accuracy: 0.8584
# Epoch 6/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3115 - accuracy: 0.8933 - val_loss: 0.3497 - val_accuracy: 0.8600
# Epoch 7/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.2780 - accuracy: 0.9002 - val_loss: 0.3380 - val_accuracy: 0.8620
# Epoch 8/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2556 - accuracy: 0.9071 - val_loss: 0.3342 - val_accuracy: 0.8622
# Epoch 9/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.2394 - accuracy: 0.9125 - val_loss: 0.3353 - val_accuracy: 0.8612
# Epoch 10/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2264 - accuracy: 0.9182 - val_loss: 0.3378 - val_accuracy: 0.8598
#
# Validation Accuracy: 0.859760582447052
# Validation Loss: 0.33782222867012024
#
# 468/468 [==============================] - 2s 3ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8498    0.8402    0.8450      6803
#            1     0.8679    0.8761    0.8720      8150
#
#     accuracy                         0.8598     14953
#    macro avg     0.8589    0.8581    0.8585     14953
# weighted avg     0.8597    0.8598    0.8597     14953
#
#
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_13 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  conv1d_13 (Conv1D)          (34888, 1, 32)            6176
#
#  max_pooling1d_13 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  flatten_13 (Flatten)        (34888, 32)               0
#
#  dense_26 (Dense)            (34888, 32)               1056
#
#  dense_27 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 19ms/step - loss: 0.6887 - accuracy: 0.5449 - val_loss: 0.6792 - val_accuracy: 0.5549
# Epoch 2/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.6511 - accuracy: 0.6717 - val_loss: 0.6174 - val_accuracy: 0.7367
# Epoch 3/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.5616 - accuracy: 0.8099 - val_loss: 0.5210 - val_accuracy: 0.8275
# Epoch 4/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.4560 - accuracy: 0.8657 - val_loss: 0.4364 - val_accuracy: 0.8525
# Epoch 5/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3728 - accuracy: 0.8821 - val_loss: 0.3827 - val_accuracy: 0.8578
# Epoch 6/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3183 - accuracy: 0.8909 - val_loss: 0.3547 - val_accuracy: 0.8589
# Epoch 7/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.2839 - accuracy: 0.8980 - val_loss: 0.3414 - val_accuracy: 0.8616
# Epoch 8/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2607 - accuracy: 0.9051 - val_loss: 0.3358 - val_accuracy: 0.8624
# Epoch 9/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.2438 - accuracy: 0.9110 - val_loss: 0.3357 - val_accuracy: 0.8618
# Epoch 10/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2306 - accuracy: 0.9156 - val_loss: 0.3383 - val_accuracy: 0.8603
#
# Validation Accuracy: 0.8602955937385559
# Validation Loss: 0.3383273184299469
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8559    0.8332    0.8444      6803
#            1     0.8638    0.8829    0.8732      8150
#
#     accuracy                         0.8603     14953
#    macro avg     0.8598    0.8581    0.8588     14953
# weighted avg     0.8602    0.8603    0.8601     14953
#
#
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_14 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  conv1d_14 (Conv1D)          (34888, 1, 32)            6176
#
#  max_pooling1d_14 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  flatten_14 (Flatten)        (34888, 32)               0
#
#  dense_28 (Dense)            (34888, 32)               1056
#
#  dense_29 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 18ms/step - loss: 0.6886 - accuracy: 0.5565 - val_loss: 0.6784 - val_accuracy: 0.6568
# Epoch 2/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.6478 - accuracy: 0.7687 - val_loss: 0.6095 - val_accuracy: 0.8291
# Epoch 3/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.5426 - accuracy: 0.8615 - val_loss: 0.4944 - val_accuracy: 0.8489
# Epoch 4/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.4227 - accuracy: 0.8739 - val_loss: 0.4065 - val_accuracy: 0.8533
# Epoch 5/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.3435 - accuracy: 0.8835 - val_loss: 0.3634 - val_accuracy: 0.8577
# Epoch 6/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2987 - accuracy: 0.8922 - val_loss: 0.3435 - val_accuracy: 0.8584
# Epoch 7/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2706 - accuracy: 0.8999 - val_loss: 0.3352 - val_accuracy: 0.8610
# Epoch 8/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.2508 - accuracy: 0.9066 - val_loss: 0.3331 - val_accuracy: 0.8614
# Epoch 9/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2356 - accuracy: 0.9125 - val_loss: 0.3339 - val_accuracy: 0.8626
# Epoch 10/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2232 - accuracy: 0.9177 - val_loss: 0.3375 - val_accuracy: 0.8608
#
# Validation Accuracy: 0.8607637286186218
# Validation Loss: 0.33745768666267395
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8536    0.8376    0.8455      6803
#            1     0.8665    0.8801    0.8733      8150
#
#     accuracy                         0.8608     14953
#    macro avg     0.8601    0.8588    0.8594     14953
# weighted avg     0.8607    0.8608    0.8606     14953

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_BiGRUCNN-3.csv', index=False)
loss_func(df)

# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.3 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.3 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.3 & max features 15000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
# Out:
# Average Score by Test Size
# Test Size 0.3 & max features 5000
# Average Accuracy Score : 0.8616732428275263
# Average Precision Score : 0.8634895474423944
# Average Recall Score : 0.8863558282208588
# Average F1 Score : 0.8614598517212914
#
# Test_Size 0.3 & max features 10000
# Average Accuracy Score : 0.8624490068882498
# Average Precision Score : 0.8697710947822094
# Average Recall Score : 0.8793128834355828
# Average F1 Score : 0.8623666171260005
#
# Test_Size 0.3 & max features 15000
# Average Accuracy Score : 0.8605497224637197
# Average Precision Score : 0.8663973898496234
# Average Recall Score : 0.8798282208588958
# Average F1 Score : 0.860431650327004
