# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN MODEL BASELINE
# 1. Tanpa TF-IDF ( CountVectorize )
# 2. Testing Test Size ( splitting )
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 5), 'device_name': 'Tesla T4'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)

  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)

  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=5, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
   # predict
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.3]
max_features = [10000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         192
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 546/546 [==============================] - 16s 20ms/step - loss: 0.6751 - accuracy: 0.5623 - val_loss: 0.6588 - val_accuracy: 0.5625
# Epoch 2/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6411 - accuracy: 0.6667 - val_loss: 0.6261 - val_accuracy: 0.7382
# Epoch 3/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6067 - accuracy: 0.7722 - val_loss: 0.5931 - val_accuracy: 0.8003
# Epoch 4/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5727 - accuracy: 0.8171 - val_loss: 0.5618 - val_accuracy: 0.8067
# Epoch 5/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5408 - accuracy: 0.8350 - val_loss: 0.5328 - val_accuracy: 0.8391
# Epoch 6/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5121 - accuracy: 0.8437 - val_loss: 0.5075 - val_accuracy: 0.8291
# Epoch 7/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4867 - accuracy: 0.8504 - val_loss: 0.4843 - val_accuracy: 0.8420
# Epoch 8/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4640 - accuracy: 0.8523 - val_loss: 0.4645 - val_accuracy: 0.8440
# Epoch 9/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4445 - accuracy: 0.8554 - val_loss: 0.4474 - val_accuracy: 0.8456
# Epoch 10/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4276 - accuracy: 0.8580 - val_loss: 0.4334 - val_accuracy: 0.8463
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8463184833526611
# Validation Loss: 0.43335381150245667
#
# 468/468 [==============================] - 2s 4ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8760    0.7714    0.8204      6803
#            1     0.8265    0.9088    0.8657      8150
#
#     accuracy                         0.8463     14953
#    macro avg     0.8512    0.8401    0.8430     14953
# weighted avg     0.8490    0.8463    0.8451     14953
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 546/546 [==============================] - 11s 20ms/step - loss: 0.6756 - accuracy: 0.5655 - val_loss: 0.6589 - val_accuracy: 0.5662
# Epoch 2/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6415 - accuracy: 0.6715 - val_loss: 0.6263 - val_accuracy: 0.7392
# Epoch 3/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6069 - accuracy: 0.7739 - val_loss: 0.5932 - val_accuracy: 0.8127
# Epoch 4/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5732 - accuracy: 0.8186 - val_loss: 0.5621 - val_accuracy: 0.8136
# Epoch 5/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5418 - accuracy: 0.8360 - val_loss: 0.5338 - val_accuracy: 0.8410
# Epoch 6/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5136 - accuracy: 0.8474 - val_loss: 0.5083 - val_accuracy: 0.8409
# Epoch 7/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4888 - accuracy: 0.8507 - val_loss: 0.4864 - val_accuracy: 0.8437
# Epoch 8/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4667 - accuracy: 0.8548 - val_loss: 0.4669 - val_accuracy: 0.8456
# Epoch 9/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4476 - accuracy: 0.8575 - val_loss: 0.4511 - val_accuracy: 0.8454
# Epoch 10/10
# 546/546 [==============================] - 10s 19ms/step - loss: 0.4307 - accuracy: 0.8596 - val_loss: 0.4359 - val_accuracy: 0.8476
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8475891351699829
# Validation Loss: 0.4358869194984436
#
# 468/468 [==============================] - 2s 4ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8448    0.8146    0.8295      6803
#            1     0.8498    0.8751    0.8622      8150
#
#     accuracy                         0.8476     14953
#    macro avg     0.8473    0.8449    0.8458     14953
# weighted avg     0.8475    0.8476    0.8473     14953
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 546/546 [==============================] - 11s 20ms/step - loss: 0.6739 - accuracy: 0.5723 - val_loss: 0.6551 - val_accuracy: 0.6023
# Epoch 2/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6361 - accuracy: 0.6935 - val_loss: 0.6201 - val_accuracy: 0.7435
# Epoch 3/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5999 - accuracy: 0.7816 - val_loss: 0.5861 - val_accuracy: 0.8207
# Epoch 4/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5652 - accuracy: 0.8249 - val_loss: 0.5544 - val_accuracy: 0.8127
# Epoch 5/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5332 - accuracy: 0.8396 - val_loss: 0.5254 - val_accuracy: 0.8389
# Epoch 6/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5047 - accuracy: 0.8491 - val_loss: 0.5011 - val_accuracy: 0.8331
# Epoch 7/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4798 - accuracy: 0.8527 - val_loss: 0.4778 - val_accuracy: 0.8459
# Epoch 8/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4580 - accuracy: 0.8566 - val_loss: 0.4603 - val_accuracy: 0.8422
# Epoch 9/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4386 - accuracy: 0.8579 - val_loss: 0.4430 - val_accuracy: 0.8459
# Epoch 10/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4222 - accuracy: 0.8610 - val_loss: 0.4287 - val_accuracy: 0.8505
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8505316376686096
# Validation Loss: 0.4286758601665497
#
# 468/468 [==============================] - 2s 4ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8836    0.7733    0.8248      6803
#            1     0.8286    0.9150    0.8697      8150
#
#     accuracy                         0.8505     14953
#    macro avg     0.8561    0.8442    0.8472     14953
# weighted avg     0.8537    0.8505    0.8493     14953
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 546/546 [==============================] - 11s 20ms/step - loss: 0.6759 - accuracy: 0.5619 - val_loss: 0.6602 - val_accuracy: 0.5921
# Epoch 2/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6436 - accuracy: 0.6631 - val_loss: 0.6294 - val_accuracy: 0.7290
# Epoch 3/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6112 - accuracy: 0.7628 - val_loss: 0.5982 - val_accuracy: 0.7703
# Epoch 4/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5789 - accuracy: 0.8075 - val_loss: 0.5683 - val_accuracy: 0.7972
# Epoch 5/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5481 - accuracy: 0.8312 - val_loss: 0.5409 - val_accuracy: 0.8029
# Epoch 6/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5197 - accuracy: 0.8420 - val_loss: 0.5139 - val_accuracy: 0.8400
# Epoch 7/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4943 - accuracy: 0.8497 - val_loss: 0.4920 - val_accuracy: 0.8408
# Epoch 8/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4719 - accuracy: 0.8520 - val_loss: 0.4728 - val_accuracy: 0.8380
# Epoch 9/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4519 - accuracy: 0.8551 - val_loss: 0.4542 - val_accuracy: 0.8445
# Epoch 10/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4346 - accuracy: 0.8559 - val_loss: 0.4389 - val_accuracy: 0.8454
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8453822135925293
# Validation Loss: 0.43891265988349915
#
# 468/468 [==============================] - 2s 4ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8546    0.7955    0.8240      6803
#            1     0.8386    0.8870    0.8621      8150
#
#     accuracy                         0.8454     14953
#    macro avg     0.8466    0.8413    0.8431     14953
# weighted avg     0.8459    0.8454    0.8448     14953
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 546/546 [==============================] - 11s 20ms/step - loss: 0.6739 - accuracy: 0.5695 - val_loss: 0.6562 - val_accuracy: 0.6756
# Epoch 2/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6372 - accuracy: 0.6882 - val_loss: 0.6217 - val_accuracy: 0.6837
# Epoch 3/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.6013 - accuracy: 0.7804 - val_loss: 0.5871 - val_accuracy: 0.7983
# Epoch 4/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5666 - accuracy: 0.8223 - val_loss: 0.5551 - val_accuracy: 0.8232
# Epoch 5/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5342 - accuracy: 0.8386 - val_loss: 0.5258 - val_accuracy: 0.8382
# Epoch 6/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.5055 - accuracy: 0.8479 - val_loss: 0.5000 - val_accuracy: 0.8423
# Epoch 7/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4797 - accuracy: 0.8515 - val_loss: 0.4779 - val_accuracy: 0.8435
# Epoch 8/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4577 - accuracy: 0.8540 - val_loss: 0.4583 - val_accuracy: 0.8456
# Epoch 9/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4384 - accuracy: 0.8559 - val_loss: 0.4414 - val_accuracy: 0.8462
# Epoch 10/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4215 - accuracy: 0.8587 - val_loss: 0.4269 - val_accuracy: 0.8472
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.847187876701355
# Validation Loss: 0.4268677532672882
#
# 468/468 [==============================] - 2s 4ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8562    0.7982    0.8262      6803
#            1     0.8406    0.8881    0.8637      8150
#
#     accuracy                         0.8472     14953
#    macro avg     0.8484    0.8431    0.8449     14953
# weighted avg     0.8477    0.8472    0.8466     14953

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baselineCNN-3-10000.csv', index=False)

print('Test_Size 0.3 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
# Out:
# Test_Size 0.3 & max features 10000
# Average Accuracy Score : 0.8474018591586973
# Average Precision Score : 0.8368153742035955
# Average Recall Score : 0.8947975460122699
# Average F1 Score : 0.8466122011118202
