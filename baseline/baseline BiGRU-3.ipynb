# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode BiGru
#
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# check tensorflow version
# 2.9.1 untuk version paperspace
# 2.11 untuk collab
print(tf.__version__)
# Out:
# 2.9.3

# %% [markdown]
# ## BIGRU MODEL BASELINE
# 1. TF-IDF max features
# 2. Test Size
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 5), 'device_name': 'Tesla T4'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %% [markdown]
# ###  Test Size

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.3]
max_features = [5000, 10000, 15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (34888, 1, 64)           966528
#  l)
#
#  global_max_pooling1d (Globa  (34888, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (34888, 32)               2080
#
#  dense_1 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 15ms/step - loss: 0.6894 - accuracy: 0.5692 - val_loss: 0.6833 - val_accuracy: 0.5845
# Epoch 2/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6681 - accuracy: 0.6678 - val_loss: 0.6490 - val_accuracy: 0.7370
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6183 - accuracy: 0.7942 - val_loss: 0.5907 - val_accuracy: 0.8099
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5515 - accuracy: 0.8358 - val_loss: 0.5253 - val_accuracy: 0.8391
# Epoch 5/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4835 - accuracy: 0.8539 - val_loss: 0.4677 - val_accuracy: 0.8430
# Epoch 6/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4280 - accuracy: 0.8618 - val_loss: 0.4246 - val_accuracy: 0.8477
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3868 - accuracy: 0.8672 - val_loss: 0.3950 - val_accuracy: 0.8511
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3573 - accuracy: 0.8715 - val_loss: 0.3753 - val_accuracy: 0.8531
# Epoch 9/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3362 - accuracy: 0.8752 - val_loss: 0.3615 - val_accuracy: 0.8549
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3202 - accuracy: 0.8792 - val_loss: 0.3522 - val_accuracy: 0.8556
#
# Validation Accuracy: 0.8556142449378967
# Validation Loss: 0.3522118926048279
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8528    0.8251    0.8387      6803
#            1     0.8578    0.8811    0.8693      8150
#
#     accuracy                         0.8556     14953
#    macro avg     0.8553    0.8531    0.8540     14953
# weighted avg     0.8555    0.8556    0.8554     14953
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (34888, 32)               2080
#
#  dense_3 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 13ms/step - loss: 0.6899 - accuracy: 0.5637 - val_loss: 0.6841 - val_accuracy: 0.5812
# Epoch 2/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6702 - accuracy: 0.6810 - val_loss: 0.6533 - val_accuracy: 0.7376
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6250 - accuracy: 0.8071 - val_loss: 0.5984 - val_accuracy: 0.8234
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5587 - accuracy: 0.8473 - val_loss: 0.5318 - val_accuracy: 0.8428
# Epoch 5/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4897 - accuracy: 0.8576 - val_loss: 0.4727 - val_accuracy: 0.8455
# Epoch 6/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4326 - accuracy: 0.8634 - val_loss: 0.4284 - val_accuracy: 0.8496
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3903 - accuracy: 0.8684 - val_loss: 0.3979 - val_accuracy: 0.8525
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3601 - accuracy: 0.8720 - val_loss: 0.3770 - val_accuracy: 0.8533
# Epoch 9/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3383 - accuracy: 0.8749 - val_loss: 0.3629 - val_accuracy: 0.8557
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3220 - accuracy: 0.8780 - val_loss: 0.3534 - val_accuracy: 0.8563
#
# Validation Accuracy: 0.8563498854637146
# Validation Loss: 0.35335731506347656
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8616    0.8152    0.8378      6803
#            1     0.8524    0.8907    0.8711      8150
#
#     accuracy                         0.8563     14953
#    macro avg     0.8570    0.8530    0.8544     14953
# weighted avg     0.8566    0.8563    0.8559     14953
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (34888, 32)               2080
#
#  dense_5 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 13ms/step - loss: 0.6884 - accuracy: 0.5594 - val_loss: 0.6811 - val_accuracy: 0.5547
# Epoch 2/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6645 - accuracy: 0.6251 - val_loss: 0.6444 - val_accuracy: 0.7073
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6128 - accuracy: 0.7696 - val_loss: 0.5854 - val_accuracy: 0.7963
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5464 - accuracy: 0.8302 - val_loss: 0.5226 - val_accuracy: 0.8304
# Epoch 5/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4824 - accuracy: 0.8539 - val_loss: 0.4686 - val_accuracy: 0.8444
# Epoch 6/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4294 - accuracy: 0.8632 - val_loss: 0.4271 - val_accuracy: 0.8511
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3890 - accuracy: 0.8688 - val_loss: 0.3975 - val_accuracy: 0.8528
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3594 - accuracy: 0.8727 - val_loss: 0.3769 - val_accuracy: 0.8537
# Epoch 9/10
# 273/273 [==============================] - 3s 10ms/step - loss: 0.3374 - accuracy: 0.8761 - val_loss: 0.3628 - val_accuracy: 0.8563
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3211 - accuracy: 0.8803 - val_loss: 0.3531 - val_accuracy: 0.8578
#
# Validation Accuracy: 0.8577542901039124
# Validation Loss: 0.3530708849430084
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8620    0.8183    0.8396      6803
#            1     0.8545    0.8907    0.8722      8150
#
#     accuracy                         0.8578     14953
#    macro avg     0.8583    0.8545    0.8559     14953
# weighted avg     0.8579    0.8578    0.8574     14953
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (34888, 32)               2080
#
#  dense_7 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 14ms/step - loss: 0.6898 - accuracy: 0.5579 - val_loss: 0.6839 - val_accuracy: 0.5718
# Epoch 2/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6683 - accuracy: 0.7069 - val_loss: 0.6489 - val_accuracy: 0.7849
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6170 - accuracy: 0.8310 - val_loss: 0.5883 - val_accuracy: 0.8353
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5475 - accuracy: 0.8534 - val_loss: 0.5212 - val_accuracy: 0.8430
# Epoch 5/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4793 - accuracy: 0.8600 - val_loss: 0.4636 - val_accuracy: 0.8450
# Epoch 6/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4240 - accuracy: 0.8639 - val_loss: 0.4215 - val_accuracy: 0.8487
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3837 - accuracy: 0.8684 - val_loss: 0.3926 - val_accuracy: 0.8509
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3548 - accuracy: 0.8722 - val_loss: 0.3730 - val_accuracy: 0.8538
# Epoch 9/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3339 - accuracy: 0.8758 - val_loss: 0.3598 - val_accuracy: 0.8540
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3181 - accuracy: 0.8797 - val_loss: 0.3512 - val_accuracy: 0.8573
#
# Validation Accuracy: 0.8572861552238464
# Validation Loss: 0.35116976499557495
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8682    0.8092    0.8376      6803
#            1     0.8493    0.8974    0.8727      8150
#
#     accuracy                         0.8573     14953
#    macro avg     0.8587    0.8533    0.8552     14953
# weighted avg     0.8579    0.8573    0.8567     14953
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (34888, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (34888, 32)               2080
#
#  dense_9 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 6s 14ms/step - loss: 0.6894 - accuracy: 0.5549 - val_loss: 0.6826 - val_accuracy: 0.5701
# Epoch 2/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6641 - accuracy: 0.6741 - val_loss: 0.6414 - val_accuracy: 0.7602
# Epoch 3/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.6060 - accuracy: 0.8143 - val_loss: 0.5752 - val_accuracy: 0.8235
# Epoch 4/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.5329 - accuracy: 0.8484 - val_loss: 0.5075 - val_accuracy: 0.8422
# Epoch 5/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4656 - accuracy: 0.8596 - val_loss: 0.4523 - val_accuracy: 0.8455
# Epoch 6/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.4131 - accuracy: 0.8648 - val_loss: 0.4130 - val_accuracy: 0.8493
# Epoch 7/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3755 - accuracy: 0.8701 - val_loss: 0.3865 - val_accuracy: 0.8515
# Epoch 8/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3486 - accuracy: 0.8739 - val_loss: 0.3686 - val_accuracy: 0.8540
# Epoch 9/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3288 - accuracy: 0.8774 - val_loss: 0.3563 - val_accuracy: 0.8564
# Epoch 10/10
# 273/273 [==============================] - 3s 11ms/step - loss: 0.3138 - accuracy: 0.8800 - val_loss: 0.3479 - val_accuracy: 0.8580
#
# Validation Accuracy: 0.8579549193382263
# Validation Loss: 0.34791186451911926
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8571    0.8254    0.8409      6803
#            1     0.8586    0.8852    0.8717      8150
#
#     accuracy                         0.8580     14953
#    macro avg     0.8579    0.8553    0.8563     14953
# weighted avg     0.8579    0.8580    0.8577     14953
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_5 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_10 (Dense)            (34888, 32)               2080
#
#  dense_11 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 17ms/step - loss: 0.6899 - accuracy: 0.5459 - val_loss: 0.6839 - val_accuracy: 0.5569
# Epoch 2/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.6674 - accuracy: 0.6521 - val_loss: 0.6476 - val_accuracy: 0.7427
# Epoch 3/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6158 - accuracy: 0.7910 - val_loss: 0.5895 - val_accuracy: 0.8081
# Epoch 4/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.5485 - accuracy: 0.8397 - val_loss: 0.5262 - val_accuracy: 0.8329
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4818 - accuracy: 0.8600 - val_loss: 0.4705 - val_accuracy: 0.8454
# Epoch 6/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4256 - accuracy: 0.8698 - val_loss: 0.4276 - val_accuracy: 0.8509
# Epoch 7/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3823 - accuracy: 0.8758 - val_loss: 0.3969 - val_accuracy: 0.8529
# Epoch 8/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3498 - accuracy: 0.8811 - val_loss: 0.3753 - val_accuracy: 0.8539
# Epoch 9/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3253 - accuracy: 0.8842 - val_loss: 0.3602 - val_accuracy: 0.8553
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3062 - accuracy: 0.8892 - val_loss: 0.3500 - val_accuracy: 0.8564
#
# Validation Accuracy: 0.8564167618751526
# Validation Loss: 0.3499773144721985
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8610    0.8161    0.8380      6803
#            1     0.8529    0.8901    0.8711      8150
#
#     accuracy                         0.8564     14953
#    macro avg     0.8570    0.8531    0.8545     14953
# weighted avg     0.8566    0.8564    0.8560     14953
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_6 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_12 (Dense)            (34888, 32)               2080
#
#  dense_13 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 16ms/step - loss: 0.6884 - accuracy: 0.5450 - val_loss: 0.6806 - val_accuracy: 0.5458
# Epoch 2/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6644 - accuracy: 0.5933 - val_loss: 0.6459 - val_accuracy: 0.6677
# Epoch 3/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6173 - accuracy: 0.7251 - val_loss: 0.5945 - val_accuracy: 0.7632
# Epoch 4/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.5582 - accuracy: 0.8061 - val_loss: 0.5388 - val_accuracy: 0.8169
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4980 - accuracy: 0.8483 - val_loss: 0.4866 - val_accuracy: 0.8391
# Epoch 6/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.4435 - accuracy: 0.8656 - val_loss: 0.4428 - val_accuracy: 0.8484
# Epoch 7/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3985 - accuracy: 0.8742 - val_loss: 0.4094 - val_accuracy: 0.8529
# Epoch 8/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3632 - accuracy: 0.8808 - val_loss: 0.3848 - val_accuracy: 0.8553
# Epoch 9/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3361 - accuracy: 0.8841 - val_loss: 0.3674 - val_accuracy: 0.8561
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3151 - accuracy: 0.8881 - val_loss: 0.3550 - val_accuracy: 0.8568
#
# Validation Accuracy: 0.8567511439323425
# Validation Loss: 0.35500288009643555
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8603    0.8180    0.8386      6803
#            1     0.8541    0.8891    0.8712      8150
#
#     accuracy                         0.8568     14953
#    macro avg     0.8572    0.8536    0.8549     14953
# weighted avg     0.8569    0.8568    0.8564     14953
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_7 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_14 (Dense)            (34888, 32)               2080
#
#  dense_15 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 16ms/step - loss: 0.6894 - accuracy: 0.5442 - val_loss: 0.6824 - val_accuracy: 0.5458
# Epoch 2/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6662 - accuracy: 0.6282 - val_loss: 0.6476 - val_accuracy: 0.7166
# Epoch 3/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6186 - accuracy: 0.7759 - val_loss: 0.5948 - val_accuracy: 0.7974
# Epoch 4/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.5569 - accuracy: 0.8365 - val_loss: 0.5356 - val_accuracy: 0.8257
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4932 - accuracy: 0.8575 - val_loss: 0.4807 - val_accuracy: 0.8456
# Epoch 6/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4370 - accuracy: 0.8693 - val_loss: 0.4366 - val_accuracy: 0.8513
# Epoch 7/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3922 - accuracy: 0.8745 - val_loss: 0.4039 - val_accuracy: 0.8545
# Epoch 8/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3580 - accuracy: 0.8796 - val_loss: 0.3805 - val_accuracy: 0.8547
# Epoch 9/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.3322 - accuracy: 0.8829 - val_loss: 0.3645 - val_accuracy: 0.8556
# Epoch 10/10
# 273/273 [==============================] - 3s 13ms/step - loss: 0.3125 - accuracy: 0.8871 - val_loss: 0.3530 - val_accuracy: 0.8579
#
# Validation Accuracy: 0.8578880429267883
# Validation Loss: 0.3530179262161255
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8655    0.8142    0.8391      6803
#            1     0.8522    0.8944    0.8728      8150
#
#     accuracy                         0.8579     14953
#    macro avg     0.8588    0.8543    0.8559     14953
# weighted avg     0.8582    0.8579    0.8574     14953
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_8 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_16 (Dense)            (34888, 32)               2080
#
#  dense_17 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 17ms/step - loss: 0.6891 - accuracy: 0.5429 - val_loss: 0.6822 - val_accuracy: 0.5481
# Epoch 2/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6651 - accuracy: 0.6408 - val_loss: 0.6453 - val_accuracy: 0.7386
# Epoch 3/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6138 - accuracy: 0.7926 - val_loss: 0.5876 - val_accuracy: 0.8126
# Epoch 4/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.5462 - accuracy: 0.8440 - val_loss: 0.5234 - val_accuracy: 0.8347
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4787 - accuracy: 0.8615 - val_loss: 0.4673 - val_accuracy: 0.8462
# Epoch 6/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4224 - accuracy: 0.8693 - val_loss: 0.4245 - val_accuracy: 0.8507
# Epoch 7/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3794 - accuracy: 0.8751 - val_loss: 0.3946 - val_accuracy: 0.8542
# Epoch 8/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3475 - accuracy: 0.8801 - val_loss: 0.3733 - val_accuracy: 0.8541
# Epoch 9/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3233 - accuracy: 0.8835 - val_loss: 0.3593 - val_accuracy: 0.8564
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3047 - accuracy: 0.8880 - val_loss: 0.3487 - val_accuracy: 0.8571
#
# Validation Accuracy: 0.8570855259895325
# Validation Loss: 0.3487418591976166
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8589    0.8207    0.8394      6803
#            1     0.8557    0.8875    0.8713      8150
#
#     accuracy                         0.8571     14953
#    macro avg     0.8573    0.8541    0.8553     14953
# weighted avg     0.8572    0.8571    0.8568     14953
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_9 (Bidirectio  (34888, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_9 (Glo  (34888, 64)              0
#  balMaxPooling1D)
#
#  dense_18 (Dense)            (34888, 32)               2080
#
#  dense_19 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 7s 17ms/step - loss: 0.6878 - accuracy: 0.5458 - val_loss: 0.6790 - val_accuracy: 0.5473
# Epoch 2/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6593 - accuracy: 0.6091 - val_loss: 0.6365 - val_accuracy: 0.6939
# Epoch 3/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.6023 - accuracy: 0.7557 - val_loss: 0.5759 - val_accuracy: 0.7829
# Epoch 4/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.5347 - accuracy: 0.8263 - val_loss: 0.5146 - val_accuracy: 0.8301
# Epoch 5/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4707 - accuracy: 0.8571 - val_loss: 0.4621 - val_accuracy: 0.8452
# Epoch 6/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.4171 - accuracy: 0.8710 - val_loss: 0.4216 - val_accuracy: 0.8512
# Epoch 7/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3756 - accuracy: 0.8767 - val_loss: 0.3920 - val_accuracy: 0.8537
# Epoch 8/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3441 - accuracy: 0.8829 - val_loss: 0.3718 - val_accuracy: 0.8539
# Epoch 9/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3202 - accuracy: 0.8870 - val_loss: 0.3579 - val_accuracy: 0.8563
# Epoch 10/10
# 273/273 [==============================] - 3s 12ms/step - loss: 0.3019 - accuracy: 0.8912 - val_loss: 0.3480 - val_accuracy: 0.8582
#
# Validation Accuracy: 0.8581555485725403
# Validation Loss: 0.34802746772766113
#
# 468/468 [==============================] - 1s 2ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8614    0.8202    0.8403      6803
#            1     0.8557    0.8898    0.8724      8150
#
#     accuracy                         0.8582     14953
#    macro avg     0.8585    0.8550    0.8564     14953
# weighted avg     0.8583    0.8582    0.8578     14953
#
#
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_10 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_10 (Gl  (34888, 64)              0
#  obalMaxPooling1D)
#
#  dense_20 (Dense)            (34888, 32)               2080
#
#  dense_21 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 21ms/step - loss: 0.6870 - accuracy: 0.5474 - val_loss: 0.6763 - val_accuracy: 0.5662
# Epoch 2/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.6540 - accuracy: 0.6486 - val_loss: 0.6313 - val_accuracy: 0.6991
# Epoch 3/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5966 - accuracy: 0.7656 - val_loss: 0.5730 - val_accuracy: 0.7890
# Epoch 4/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5307 - accuracy: 0.8324 - val_loss: 0.5149 - val_accuracy: 0.8217
# Epoch 5/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4682 - accuracy: 0.8607 - val_loss: 0.4642 - val_accuracy: 0.8455
# Epoch 6/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4153 - accuracy: 0.8758 - val_loss: 0.4247 - val_accuracy: 0.8520
# Epoch 7/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3731 - accuracy: 0.8829 - val_loss: 0.3958 - val_accuracy: 0.8543
# Epoch 8/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3403 - accuracy: 0.8884 - val_loss: 0.3746 - val_accuracy: 0.8553
# Epoch 9/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3148 - accuracy: 0.8929 - val_loss: 0.3603 - val_accuracy: 0.8566
# Epoch 10/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.2947 - accuracy: 0.8979 - val_loss: 0.3504 - val_accuracy: 0.8574
#
# Validation Accuracy: 0.8574199080467224
# Validation Loss: 0.35044264793395996
#
# 468/468 [==============================] - 2s 3ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8652    0.8133    0.8385      6803
#            1     0.8516    0.8942    0.8724      8150
#
#     accuracy                         0.8574     14953
#    macro avg     0.8584    0.8538    0.8554     14953
# weighted avg     0.8578    0.8574    0.8570     14953
#
#
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_11 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_11 (Gl  (34888, 64)              0
#  obalMaxPooling1D)
#
#  dense_22 (Dense)            (34888, 32)               2080
#
#  dense_23 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 20ms/step - loss: 0.6881 - accuracy: 0.5508 - val_loss: 0.6785 - val_accuracy: 0.5765
# Epoch 2/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.6572 - accuracy: 0.6877 - val_loss: 0.6341 - val_accuracy: 0.7505
# Epoch 3/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5988 - accuracy: 0.8054 - val_loss: 0.5731 - val_accuracy: 0.8151
# Epoch 4/10
# 273/273 [==============================] - 4s 15ms/step - loss: 0.5295 - accuracy: 0.8487 - val_loss: 0.5107 - val_accuracy: 0.8413
# Epoch 5/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4633 - accuracy: 0.8669 - val_loss: 0.4578 - val_accuracy: 0.8469
# Epoch 6/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4087 - accuracy: 0.8744 - val_loss: 0.4175 - val_accuracy: 0.8515
# Epoch 7/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3665 - accuracy: 0.8811 - val_loss: 0.3891 - val_accuracy: 0.8549
# Epoch 8/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3346 - accuracy: 0.8864 - val_loss: 0.3693 - val_accuracy: 0.8548
# Epoch 9/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3102 - accuracy: 0.8913 - val_loss: 0.3559 - val_accuracy: 0.8552
# Epoch 10/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.2909 - accuracy: 0.8963 - val_loss: 0.3470 - val_accuracy: 0.8577
#
# Validation Accuracy: 0.8576874136924744
# Validation Loss: 0.3470263183116913
#
# 468/468 [==============================] - 1s 3ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8636    0.8161    0.8392      6803
#            1     0.8532    0.8924    0.8724      8150
#
#     accuracy                         0.8577     14953
#    macro avg     0.8584    0.8543    0.8558     14953
# weighted avg     0.8579    0.8577    0.8573     14953
#
#
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_12 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_12 (Gl  (34888, 64)              0
#  obalMaxPooling1D)
#
#  dense_24 (Dense)            (34888, 32)               2080
#
#  dense_25 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 20ms/step - loss: 0.6873 - accuracy: 0.5550 - val_loss: 0.6773 - val_accuracy: 0.5973
# Epoch 2/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.6561 - accuracy: 0.7022 - val_loss: 0.6337 - val_accuracy: 0.7624
# Epoch 3/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5977 - accuracy: 0.8178 - val_loss: 0.5715 - val_accuracy: 0.8219
# Epoch 4/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5260 - accuracy: 0.8547 - val_loss: 0.5070 - val_accuracy: 0.8419
# Epoch 5/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4581 - accuracy: 0.8689 - val_loss: 0.4532 - val_accuracy: 0.8500
# Epoch 6/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4030 - accuracy: 0.8761 - val_loss: 0.4136 - val_accuracy: 0.8523
# Epoch 7/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3616 - accuracy: 0.8819 - val_loss: 0.3863 - val_accuracy: 0.8537
# Epoch 8/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3308 - accuracy: 0.8864 - val_loss: 0.3676 - val_accuracy: 0.8547
# Epoch 9/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3072 - accuracy: 0.8914 - val_loss: 0.3549 - val_accuracy: 0.8554
# Epoch 10/10
# 273/273 [==============================] - 4s 13ms/step - loss: 0.2887 - accuracy: 0.8967 - val_loss: 0.3464 - val_accuracy: 0.8565
#
# Validation Accuracy: 0.8564836382865906
# Validation Loss: 0.3463911712169647
#
# 468/468 [==============================] - 1s 3ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8588    0.8192    0.8385      6803
#            1     0.8547    0.8876    0.8708      8150
#
#     accuracy                         0.8565     14953
#    macro avg     0.8568    0.8534    0.8547     14953
# weighted avg     0.8566    0.8565    0.8561     14953
#
#
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_13 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_13 (Gl  (34888, 64)              0
#  obalMaxPooling1D)
#
#  dense_26 (Dense)            (34888, 32)               2080
#
#  dense_27 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 20ms/step - loss: 0.6890 - accuracy: 0.5457 - val_loss: 0.6816 - val_accuracy: 0.5469
# Epoch 2/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.6661 - accuracy: 0.5875 - val_loss: 0.6490 - val_accuracy: 0.6540
# Epoch 3/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.6215 - accuracy: 0.7101 - val_loss: 0.6004 - val_accuracy: 0.7411
# Epoch 4/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5638 - accuracy: 0.7939 - val_loss: 0.5460 - val_accuracy: 0.7999
# Epoch 5/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5039 - accuracy: 0.8413 - val_loss: 0.4952 - val_accuracy: 0.8289
# Epoch 6/10
# 273/273 [==============================] - 4s 15ms/step - loss: 0.4496 - accuracy: 0.8652 - val_loss: 0.4526 - val_accuracy: 0.8438
# Epoch 7/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4037 - accuracy: 0.8776 - val_loss: 0.4184 - val_accuracy: 0.8514
# Epoch 8/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3661 - accuracy: 0.8839 - val_loss: 0.3919 - val_accuracy: 0.8553
# Epoch 9/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3362 - accuracy: 0.8896 - val_loss: 0.3730 - val_accuracy: 0.8556
# Epoch 10/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3125 - accuracy: 0.8934 - val_loss: 0.3592 - val_accuracy: 0.8575
#
# Validation Accuracy: 0.8574867844581604
# Validation Loss: 0.35915565490722656
#
# 468/468 [==============================] - 2s 3ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8599    0.8204    0.8397      6803
#            1     0.8556    0.8885    0.8717      8150
#
#     accuracy                         0.8575     14953
#    macro avg     0.8578    0.8544    0.8557     14953
# weighted avg     0.8576    0.8575    0.8572     14953
#
#
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_14 (Bidirecti  (34888, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_14 (Gl  (34888, 64)              0
#  obalMaxPooling1D)
#
#  dense_28 (Dense)            (34888, 32)               2080
#
#  dense_29 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 273/273 [==============================] - 8s 20ms/step - loss: 0.6889 - accuracy: 0.5547 - val_loss: 0.6812 - val_accuracy: 0.5921
# Epoch 2/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.6638 - accuracy: 0.7057 - val_loss: 0.6438 - val_accuracy: 0.7901
# Epoch 3/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.6104 - accuracy: 0.8275 - val_loss: 0.5839 - val_accuracy: 0.8339
# Epoch 4/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.5394 - accuracy: 0.8600 - val_loss: 0.5175 - val_accuracy: 0.8459
# Epoch 5/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4689 - accuracy: 0.8688 - val_loss: 0.4606 - val_accuracy: 0.8497
# Epoch 6/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.4111 - accuracy: 0.8746 - val_loss: 0.4185 - val_accuracy: 0.8520
# Epoch 7/10
# 273/273 [==============================] - 4s 15ms/step - loss: 0.3676 - accuracy: 0.8806 - val_loss: 0.3894 - val_accuracy: 0.8543
# Epoch 8/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3353 - accuracy: 0.8849 - val_loss: 0.3695 - val_accuracy: 0.8553
# Epoch 9/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.3110 - accuracy: 0.8901 - val_loss: 0.3559 - val_accuracy: 0.8551
# Epoch 10/10
# 273/273 [==============================] - 4s 14ms/step - loss: 0.2919 - accuracy: 0.8949 - val_loss: 0.3469 - val_accuracy: 0.8568
#
# Validation Accuracy: 0.8567511439323425
# Validation Loss: 0.34693244099617004
#
# 468/468 [==============================] - 2s 3ms/step
# using test size : 0.3
#
#
#               precision    recall  f1-score   support
#
#            0     0.8588    0.8199    0.8389      6803
#            1     0.8552    0.8875    0.8710      8150
#
#     accuracy                         0.8568     14953
#    macro avg     0.8570    0.8537    0.8550     14953
# weighted avg     0.8568    0.8568    0.8564     14953

# %%
def loss_func(df):
  # plot loss function rata-rata
  # plot loss function
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function test size {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru/lfg_baselineBiGRU_testSize{df["Test_Size"].iloc[idx]}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_BiGRU-3.csv', index=False)
loss_func(df)

# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.3 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.3 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.3 & max features 15000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
# Out:
# Average Score by Test Size
# Test Size 0.3 & max features 5000
# Average Accuracy Score : 0.8569919079783321
# Average Precision Score : 0.8545251718928426
# Average Recall Score : 0.8890061349693251
# Average F1 Score : 0.8566297250330797
#
# Test_Size 0.3 & max features 10000
# Average Accuracy Score : 0.8572594128268575
# Average Precision Score : 0.8541139344755827
# Average Recall Score : 0.8901595092024539
# Average F1 Score : 0.8568825200023389
#
# Test_Size 0.3 & max features 15000
# Average Accuracy Score : 0.8571657861298736
# Average Precision Score : 0.8540581723280513
# Average Recall Score : 0.8900368098159509
# Average F1 Score : 0.8567891793821898
