# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN MODEL BASELINE
# 1. Tanpa TF-IDF ( CountVectorize )
# 2. Testing Test Size ( splitting )
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 5), 'device_name': 'Tesla T4'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)

  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)

  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
   # predict
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.1]
max_features = [15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 15000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 7500, 32)         0
#  )
#
#  flatten (Flatten)           (None, 240000)            0
#
#  dense (Dense)               (None, 32)                7680032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 24s 24ms/step - loss: 0.6751 - accuracy: 0.5650 - val_loss: 0.6588 - val_accuracy: 0.6169
# Epoch 2/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6417 - accuracy: 0.6687 - val_loss: 0.6265 - val_accuracy: 0.6654
# Epoch 3/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6073 - accuracy: 0.7688 - val_loss: 0.5922 - val_accuracy: 0.7739
# Epoch 4/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5731 - accuracy: 0.8179 - val_loss: 0.5598 - val_accuracy: 0.8140
# Epoch 5/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5404 - accuracy: 0.8385 - val_loss: 0.5298 - val_accuracy: 0.8279
# Epoch 6/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5106 - accuracy: 0.8489 - val_loss: 0.5026 - val_accuracy: 0.8393
# Epoch 7/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4840 - accuracy: 0.8529 - val_loss: 0.4780 - val_accuracy: 0.8491
# Epoch 8/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4605 - accuracy: 0.8573 - val_loss: 0.4565 - val_accuracy: 0.8528
# Epoch 9/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4398 - accuracy: 0.8608 - val_loss: 0.4379 - val_accuracy: 0.8554
# Epoch 10/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4216 - accuracy: 0.8619 - val_loss: 0.4220 - val_accuracy: 0.8568
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8567703366279602
# Validation Loss: 0.4219529330730438
#
# 156/156 [==============================] - 1s 6ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8859    0.7867    0.8333      2269
#            1     0.8370    0.9153    0.8744      2716
#
#     accuracy                         0.8568      4985
#    macro avg     0.8614    0.8510    0.8539      4985
# weighted avg     0.8593    0.8568    0.8557      4985
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 240000)            0
#
#  dense_2 (Dense)             (None, 32)                7680032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.6735 - accuracy: 0.5728 - val_loss: 0.6557 - val_accuracy: 0.6251
# Epoch 2/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6370 - accuracy: 0.6827 - val_loss: 0.6199 - val_accuracy: 0.7501
# Epoch 3/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5998 - accuracy: 0.7824 - val_loss: 0.5839 - val_accuracy: 0.7848
# Epoch 4/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5635 - accuracy: 0.8211 - val_loss: 0.5506 - val_accuracy: 0.8459
# Epoch 5/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5298 - accuracy: 0.8429 - val_loss: 0.5194 - val_accuracy: 0.8317
# Epoch 6/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4994 - accuracy: 0.8516 - val_loss: 0.4918 - val_accuracy: 0.8421
# Epoch 7/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4727 - accuracy: 0.8564 - val_loss: 0.4676 - val_accuracy: 0.8504
# Epoch 8/10
# 701/701 [==============================] - 16s 22ms/step - loss: 0.4493 - accuracy: 0.8596 - val_loss: 0.4462 - val_accuracy: 0.8550
# Epoch 9/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4290 - accuracy: 0.8627 - val_loss: 0.4288 - val_accuracy: 0.8562
# Epoch 10/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4114 - accuracy: 0.8638 - val_loss: 0.4135 - val_accuracy: 0.8582
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8581745028495789
# Validation Loss: 0.41349056363105774
#
# 156/156 [==============================] - 1s 6ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8944    0.7805    0.8336      2269
#            1     0.8343    0.9230    0.8764      2716
#
#     accuracy                         0.8582      4985
#    macro avg     0.8644    0.8518    0.8550      4985
# weighted avg     0.8617    0.8582    0.8569      4985
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 240000)            0
#
#  dense_4 (Dense)             (None, 32)                7680032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 23ms/step - loss: 0.6741 - accuracy: 0.5666 - val_loss: 0.6576 - val_accuracy: 0.5563
# Epoch 2/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6397 - accuracy: 0.6768 - val_loss: 0.6247 - val_accuracy: 0.8391
# Epoch 3/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6046 - accuracy: 0.7771 - val_loss: 0.5895 - val_accuracy: 0.7637
# Epoch 4/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5700 - accuracy: 0.8201 - val_loss: 0.5564 - val_accuracy: 0.8195
# Epoch 5/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5375 - accuracy: 0.8399 - val_loss: 0.5262 - val_accuracy: 0.8393
# Epoch 6/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5082 - accuracy: 0.8486 - val_loss: 0.5027 - val_accuracy: 0.8181
# Epoch 7/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4819 - accuracy: 0.8542 - val_loss: 0.4751 - val_accuracy: 0.8526
# Epoch 8/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4587 - accuracy: 0.8572 - val_loss: 0.4543 - val_accuracy: 0.8550
# Epoch 9/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4385 - accuracy: 0.8602 - val_loss: 0.4360 - val_accuracy: 0.8570
# Epoch 10/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4208 - accuracy: 0.8619 - val_loss: 0.4210 - val_accuracy: 0.8576
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8575727343559265
# Validation Loss: 0.4209570586681366
#
# 156/156 [==============================] - 1s 6ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8939    0.7796    0.8329      2269
#            1     0.8337    0.9227    0.8759      2716
#
#     accuracy                         0.8576      4985
#    macro avg     0.8638    0.8512    0.8544      4985
# weighted avg     0.8611    0.8576    0.8563      4985
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 240000)            0
#
#  dense_6 (Dense)             (None, 32)                7680032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 24ms/step - loss: 0.6779 - accuracy: 0.5504 - val_loss: 0.6646 - val_accuracy: 0.5488
# Epoch 2/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6501 - accuracy: 0.6356 - val_loss: 0.6366 - val_accuracy: 0.6520
# Epoch 3/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6201 - accuracy: 0.7429 - val_loss: 0.6062 - val_accuracy: 0.7785
# Epoch 4/10
# 701/701 [==============================] - 16s 22ms/step - loss: 0.5887 - accuracy: 0.8020 - val_loss: 0.5775 - val_accuracy: 0.7484
# Epoch 5/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5580 - accuracy: 0.8276 - val_loss: 0.5470 - val_accuracy: 0.8201
# Epoch 6/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5290 - accuracy: 0.8436 - val_loss: 0.5201 - val_accuracy: 0.8325
# Epoch 7/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5022 - accuracy: 0.8514 - val_loss: 0.4953 - val_accuracy: 0.8439
# Epoch 8/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4780 - accuracy: 0.8547 - val_loss: 0.4725 - val_accuracy: 0.8526
# Epoch 9/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4565 - accuracy: 0.8587 - val_loss: 0.4538 - val_accuracy: 0.8536
# Epoch 10/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4374 - accuracy: 0.8605 - val_loss: 0.4373 - val_accuracy: 0.8532
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.853159487247467
# Validation Loss: 0.43726256489753723
#
# 156/156 [==============================] - 1s 6ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.9055    0.7563    0.8242      2269
#            1     0.8210    0.9341    0.8739      2716
#
#     accuracy                         0.8532      4985
#    macro avg     0.8633    0.8452    0.8491      4985
# weighted avg     0.8595    0.8532    0.8513      4985
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 240000)            0
#
#  dense_8 (Dense)             (None, 32)                7680032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 17s 23ms/step - loss: 0.6764 - accuracy: 0.5500 - val_loss: 0.6616 - val_accuracy: 0.5605
# Epoch 2/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6458 - accuracy: 0.6459 - val_loss: 0.6311 - val_accuracy: 0.6822
# Epoch 3/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.6133 - accuracy: 0.7550 - val_loss: 0.5991 - val_accuracy: 0.7731
# Epoch 4/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5806 - accuracy: 0.8105 - val_loss: 0.5678 - val_accuracy: 0.8347
# Epoch 5/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.5490 - accuracy: 0.8366 - val_loss: 0.5382 - val_accuracy: 0.8335
# Epoch 6/10
# 701/701 [==============================] - 16s 22ms/step - loss: 0.5195 - accuracy: 0.8466 - val_loss: 0.5110 - val_accuracy: 0.8499
# Epoch 7/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4930 - accuracy: 0.8540 - val_loss: 0.4867 - val_accuracy: 0.8506
# Epoch 8/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4691 - accuracy: 0.8577 - val_loss: 0.4655 - val_accuracy: 0.8522
# Epoch 9/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4480 - accuracy: 0.8608 - val_loss: 0.4464 - val_accuracy: 0.8550
# Epoch 10/10
# 701/701 [==============================] - 16s 23ms/step - loss: 0.4293 - accuracy: 0.8623 - val_loss: 0.4302 - val_accuracy: 0.8558
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8557673096656799
# Validation Loss: 0.43016695976257324
#
# 156/156 [==============================] - 1s 6ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8950    0.7739    0.8301      2269
#            1     0.8303    0.9242    0.8747      2716
#
#     accuracy                         0.8558      4985
#    macro avg     0.8627    0.8490    0.8524      4985
# weighted avg     0.8598    0.8558    0.8544      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baselineCNN-1-15000.csv', index=False)
loss_func(df)
# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.1 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
print()
# Out:
# Average Score by Test Size
# Test Size 0.1 & max features 10000
# Average Accuracy Score : 0.8562888665997994
# Average Precision Score : 0.8312631737734785
# Average Recall Score : 0.923858615611193
# Average F1 Score : 0.8549328158157792
