# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN MODEL BASELINE
# 1. Tanpa TF-IDF ( CountVectorize )
# 2. Testing Test Size ( splitting )
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)

  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)

  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=5, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
   # predict
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.2]
max_features = [10000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10000, 32)         192
#
#  max_pooling1d (MaxPooling1D  (None, 5000, 32)         0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 32)                5120032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 8s 9ms/step - loss: 0.6712 - accuracy: 0.5703 - val_loss: 0.6505 - val_accuracy: 0.6551
# Epoch 2/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6296 - accuracy: 0.7111 - val_loss: 0.6105 - val_accuracy: 0.8119
# Epoch 3/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5888 - accuracy: 0.7990 - val_loss: 0.5713 - val_accuracy: 0.8194
# Epoch 4/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5504 - accuracy: 0.8305 - val_loss: 0.5357 - val_accuracy: 0.8425
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5161 - accuracy: 0.8442 - val_loss: 0.5046 - val_accuracy: 0.8432
# Epoch 6/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4864 - accuracy: 0.8482 - val_loss: 0.4780 - val_accuracy: 0.8465
# Epoch 7/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4606 - accuracy: 0.8529 - val_loss: 0.4545 - val_accuracy: 0.8505
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4387 - accuracy: 0.8554 - val_loss: 0.4358 - val_accuracy: 0.8518
# Epoch 9/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4201 - accuracy: 0.8575 - val_loss: 0.4187 - val_accuracy: 0.8529
# Epoch 10/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4044 - accuracy: 0.8602 - val_loss: 0.4050 - val_accuracy: 0.8531
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8531447649002075
# Validation Loss: 0.40504077076911926
#
# 312/312 [==============================] - 1s 3ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8523    0.8192    0.8354      4535
#            1     0.8538    0.8815    0.8674      5434
#
#     accuracy                         0.8531      9969
#    macro avg     0.8530    0.8503    0.8514      9969
# weighted avg     0.8531    0.8531    0.8529      9969
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_1 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 32)                5120032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 6s 9ms/step - loss: 0.6730 - accuracy: 0.5620 - val_loss: 0.6547 - val_accuracy: 0.5611
# Epoch 2/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6347 - accuracy: 0.6896 - val_loss: 0.6167 - val_accuracy: 0.7909
# Epoch 3/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5959 - accuracy: 0.7885 - val_loss: 0.5789 - val_accuracy: 0.8098
# Epoch 4/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5585 - accuracy: 0.8265 - val_loss: 0.5444 - val_accuracy: 0.8102
# Epoch 5/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.5241 - accuracy: 0.8413 - val_loss: 0.5121 - val_accuracy: 0.8446
# Epoch 6/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4941 - accuracy: 0.8479 - val_loss: 0.4854 - val_accuracy: 0.8465
# Epoch 7/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4678 - accuracy: 0.8524 - val_loss: 0.4611 - val_accuracy: 0.8484
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4455 - accuracy: 0.8550 - val_loss: 0.4410 - val_accuracy: 0.8507
# Epoch 9/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4263 - accuracy: 0.8570 - val_loss: 0.4241 - val_accuracy: 0.8511
# Epoch 10/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4097 - accuracy: 0.8587 - val_loss: 0.4097 - val_accuracy: 0.8526
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8526431918144226
# Validation Loss: 0.4096691906452179
#
# 312/312 [==============================] - 1s 3ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8634    0.8031    0.8322      4535
#            1     0.8447    0.8940    0.8687      5434
#
#     accuracy                         0.8526      9969
#    macro avg     0.8541    0.8485    0.8504      9969
# weighted avg     0.8532    0.8526    0.8521      9969
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_2 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 32)                5120032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 6s 9ms/step - loss: 0.6735 - accuracy: 0.5672 - val_loss: 0.6552 - val_accuracy: 0.6224
# Epoch 2/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.6362 - accuracy: 0.6885 - val_loss: 0.6193 - val_accuracy: 0.8228
# Epoch 3/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.5983 - accuracy: 0.7857 - val_loss: 0.5815 - val_accuracy: 0.8297
# Epoch 4/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5613 - accuracy: 0.8238 - val_loss: 0.5466 - val_accuracy: 0.8210
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5273 - accuracy: 0.8411 - val_loss: 0.5150 - val_accuracy: 0.8442
# Epoch 6/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4971 - accuracy: 0.8467 - val_loss: 0.4883 - val_accuracy: 0.8439
# Epoch 7/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4711 - accuracy: 0.8520 - val_loss: 0.4645 - val_accuracy: 0.8484
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4490 - accuracy: 0.8537 - val_loss: 0.4442 - val_accuracy: 0.8508
# Epoch 9/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4295 - accuracy: 0.8568 - val_loss: 0.4271 - val_accuracy: 0.8517
# Epoch 10/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4132 - accuracy: 0.8581 - val_loss: 0.4131 - val_accuracy: 0.8541
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8541478514671326
# Validation Loss: 0.4131161570549011
#
# 312/312 [==============================] - 1s 3ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8788    0.7881    0.8310      4535
#            1     0.8372    0.9093    0.8717      5434
#
#     accuracy                         0.8541      9969
#    macro avg     0.8580    0.8487    0.8514      9969
# weighted avg     0.8561    0.8541    0.8532      9969
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_3 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 160000)            0
#
#  dense_6 (Dense)             (None, 32)                5120032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 6s 9ms/step - loss: 0.6732 - accuracy: 0.5686 - val_loss: 0.6545 - val_accuracy: 0.5750
# Epoch 2/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6353 - accuracy: 0.6939 - val_loss: 0.6177 - val_accuracy: 0.7869
# Epoch 3/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.5975 - accuracy: 0.7871 - val_loss: 0.5819 - val_accuracy: 0.8436
# Epoch 4/10
# 623/623 [==============================] - 5s 9ms/step - loss: 0.5610 - accuracy: 0.8228 - val_loss: 0.5468 - val_accuracy: 0.8427
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5280 - accuracy: 0.8408 - val_loss: 0.5167 - val_accuracy: 0.8317
# Epoch 6/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4985 - accuracy: 0.8470 - val_loss: 0.4891 - val_accuracy: 0.8486
# Epoch 7/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4726 - accuracy: 0.8511 - val_loss: 0.4665 - val_accuracy: 0.8492
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4509 - accuracy: 0.8541 - val_loss: 0.4460 - val_accuracy: 0.8497
# Epoch 9/10
# 623/623 [==============================] - 5s 9ms/step - loss: 0.4316 - accuracy: 0.8561 - val_loss: 0.4295 - val_accuracy: 0.8537
# Epoch 10/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4151 - accuracy: 0.8589 - val_loss: 0.4145 - val_accuracy: 0.8533
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8533453941345215
# Validation Loss: 0.41451144218444824
#
# 312/312 [==============================] - 1s 3ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8558    0.8150    0.8349      4535
#            1     0.8515    0.8854    0.8681      5434
#
#     accuracy                         0.8533      9969
#    macro avg     0.8536    0.8502    0.8515      9969
# weighted avg     0.8534    0.8533    0.8530      9969
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 10000, 32)         192
#
#  max_pooling1d_4 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 32)                5120032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,120,257
# Trainable params: 5,120,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 6s 9ms/step - loss: 0.6757 - accuracy: 0.5626 - val_loss: 0.6594 - val_accuracy: 0.5567
# Epoch 2/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.6425 - accuracy: 0.6713 - val_loss: 0.6271 - val_accuracy: 0.6494
# Epoch 3/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.6080 - accuracy: 0.7676 - val_loss: 0.5921 - val_accuracy: 0.7895
# Epoch 4/10
# 623/623 [==============================] - 5s 9ms/step - loss: 0.5738 - accuracy: 0.8140 - val_loss: 0.5596 - val_accuracy: 0.8450
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5414 - accuracy: 0.8380 - val_loss: 0.5291 - val_accuracy: 0.8458
# Epoch 6/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.5121 - accuracy: 0.8463 - val_loss: 0.5030 - val_accuracy: 0.8481
# Epoch 7/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4861 - accuracy: 0.8504 - val_loss: 0.4782 - val_accuracy: 0.8513
# Epoch 8/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4633 - accuracy: 0.8542 - val_loss: 0.4577 - val_accuracy: 0.8509
# Epoch 9/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4437 - accuracy: 0.8560 - val_loss: 0.4397 - val_accuracy: 0.8529
# Epoch 10/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.4266 - accuracy: 0.8584 - val_loss: 0.4243 - val_accuracy: 0.8544
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8544487953186035
# Validation Loss: 0.4243066608905792
#
# 312/312 [==============================] - 1s 3ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8714    0.7978    0.8330      4535
#            1     0.8424    0.9017    0.8710      5434
#
#     accuracy                         0.8544      9969
#    macro avg     0.8569    0.8498    0.8520      9969
# weighted avg     0.8556    0.8544    0.8537      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baselineCNN-2-10000.csv', index=False)

print('Test_Size 0.2 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
# Out:
# Test_Size 0.2 & max features 10000
# Average Accuracy Score : 0.8535459925769887
# Average Precision Score : 0.8459183934487331
# Average Recall Score : 0.8943687891056312
# Average F1 Score : 0.8529637770616416
