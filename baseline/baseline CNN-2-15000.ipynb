# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN MODEL BASELINE
# 1. Tanpa TF-IDF ( CountVectorize )
# 2. Testing Test Size ( splitting )
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 5), 'device_name': 'Tesla T4'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)

  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)

  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
   # predict
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.2]
max_features = [15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 15000, 32)         128
#
#  max_pooling1d (MaxPooling1D  (None, 7500, 32)         0
#  )
#
#  flatten (Flatten)           (None, 240000)            0
#
#  dense (Dense)               (None, 32)                7680032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 18s 25ms/step - loss: 0.6737 - accuracy: 0.5576 - val_loss: 0.6562 - val_accuracy: 0.6338
# Epoch 2/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6376 - accuracy: 0.6839 - val_loss: 0.6210 - val_accuracy: 0.7721
# Epoch 3/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6008 - accuracy: 0.7837 - val_loss: 0.5857 - val_accuracy: 0.7787
# Epoch 4/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5651 - accuracy: 0.8233 - val_loss: 0.5520 - val_accuracy: 0.8405
# Epoch 5/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5319 - accuracy: 0.8414 - val_loss: 0.5217 - val_accuracy: 0.8496
# Epoch 6/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5018 - accuracy: 0.8514 - val_loss: 0.4949 - val_accuracy: 0.8487
# Epoch 7/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4753 - accuracy: 0.8570 - val_loss: 0.4704 - val_accuracy: 0.8530
# Epoch 8/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4521 - accuracy: 0.8588 - val_loss: 0.4499 - val_accuracy: 0.8518
# Epoch 9/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.4320 - accuracy: 0.8611 - val_loss: 0.4330 - val_accuracy: 0.8517
# Epoch 10/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4144 - accuracy: 0.8637 - val_loss: 0.4173 - val_accuracy: 0.8543
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8543484807014465
# Validation Loss: 0.41728851199150085
#
# 312/312 [==============================] - 2s 6ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8540    0.8201    0.8367      4535
#            1     0.8546    0.8830    0.8686      5434
#
#     accuracy                         0.8543      9969
#    macro avg     0.8543    0.8515    0.8526      9969
# weighted avg     0.8543    0.8543    0.8541      9969
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_1 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 240000)            0
#
#  dense_2 (Dense)             (None, 32)                7680032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 16s 25ms/step - loss: 0.6772 - accuracy: 0.5548 - val_loss: 0.6638 - val_accuracy: 0.5984
# Epoch 2/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6491 - accuracy: 0.6383 - val_loss: 0.6355 - val_accuracy: 0.7092
# Epoch 3/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6188 - accuracy: 0.7411 - val_loss: 0.6054 - val_accuracy: 0.7793
# Epoch 4/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5876 - accuracy: 0.7968 - val_loss: 0.5766 - val_accuracy: 0.8447
# Epoch 5/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5573 - accuracy: 0.8293 - val_loss: 0.5469 - val_accuracy: 0.8437
# Epoch 6/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5287 - accuracy: 0.8406 - val_loss: 0.5205 - val_accuracy: 0.8476
# Epoch 7/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5027 - accuracy: 0.8497 - val_loss: 0.4965 - val_accuracy: 0.8498
# Epoch 8/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4791 - accuracy: 0.8545 - val_loss: 0.4756 - val_accuracy: 0.8498
# Epoch 9/10
# 623/623 [==============================] - 15s 24ms/step - loss: 0.4581 - accuracy: 0.8580 - val_loss: 0.4588 - val_accuracy: 0.8411
# Epoch 10/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4394 - accuracy: 0.8598 - val_loss: 0.4401 - val_accuracy: 0.8523
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8523422479629517
# Validation Loss: 0.44011929631233215
#
# 312/312 [==============================] - 2s 6ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8956    0.7645    0.8249      4535
#            1     0.8249    0.9257    0.8724      5434
#
#     accuracy                         0.8523      9969
#    macro avg     0.8602    0.8451    0.8486      9969
# weighted avg     0.8571    0.8523    0.8508      9969
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_2 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 240000)            0
#
#  dense_4 (Dense)             (None, 32)                7680032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 16s 25ms/step - loss: 0.6741 - accuracy: 0.5572 - val_loss: 0.6571 - val_accuracy: 0.5747
# Epoch 2/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6393 - accuracy: 0.6768 - val_loss: 0.6231 - val_accuracy: 0.7419
# Epoch 3/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6040 - accuracy: 0.7764 - val_loss: 0.5900 - val_accuracy: 0.7422
# Epoch 4/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5695 - accuracy: 0.8158 - val_loss: 0.5569 - val_accuracy: 0.8457
# Epoch 5/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5372 - accuracy: 0.8396 - val_loss: 0.5276 - val_accuracy: 0.8213
# Epoch 6/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5080 - accuracy: 0.8476 - val_loss: 0.4998 - val_accuracy: 0.8484
# Epoch 7/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4817 - accuracy: 0.8546 - val_loss: 0.4762 - val_accuracy: 0.8509
# Epoch 8/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.4586 - accuracy: 0.8578 - val_loss: 0.4554 - val_accuracy: 0.8522
# Epoch 9/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4383 - accuracy: 0.8615 - val_loss: 0.4374 - val_accuracy: 0.8537
# Epoch 10/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4208 - accuracy: 0.8618 - val_loss: 0.4220 - val_accuracy: 0.8539
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8539472222328186
# Validation Loss: 0.4220429062843323
#
# 312/312 [==============================] - 2s 6ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8581    0.8135    0.8352      4535
#            1     0.8508    0.8877    0.8689      5434
#
#     accuracy                         0.8539      9969
#    macro avg     0.8545    0.8506    0.8520      9969
# weighted avg     0.8541    0.8539    0.8535      9969
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_3 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 240000)            0
#
#  dense_6 (Dense)             (None, 32)                7680032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 16s 25ms/step - loss: 0.6775 - accuracy: 0.5563 - val_loss: 0.6632 - val_accuracy: 0.5595
# Epoch 2/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6484 - accuracy: 0.6397 - val_loss: 0.6346 - val_accuracy: 0.6908
# Epoch 3/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.6182 - accuracy: 0.7427 - val_loss: 0.6049 - val_accuracy: 0.8080
# Epoch 4/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5873 - accuracy: 0.8017 - val_loss: 0.5754 - val_accuracy: 0.7874
# Epoch 5/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.5573 - accuracy: 0.8290 - val_loss: 0.5468 - val_accuracy: 0.8413
# Epoch 6/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.5291 - accuracy: 0.8417 - val_loss: 0.5209 - val_accuracy: 0.8341
# Epoch 7/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.5031 - accuracy: 0.8511 - val_loss: 0.4966 - val_accuracy: 0.8498
# Epoch 8/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4795 - accuracy: 0.8559 - val_loss: 0.4754 - val_accuracy: 0.8512
# Epoch 9/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.4585 - accuracy: 0.8582 - val_loss: 0.4567 - val_accuracy: 0.8523
# Epoch 10/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4399 - accuracy: 0.8609 - val_loss: 0.4416 - val_accuracy: 0.8497
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8497341871261597
# Validation Loss: 0.4415625035762787
#
# 312/312 [==============================] - 2s 6ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8334    0.8370    0.8352      4535
#            1     0.8635    0.8603    0.8619      5434
#
#     accuracy                         0.8497      9969
#    macro avg     0.8484    0.8487    0.8486      9969
# weighted avg     0.8498    0.8497    0.8498      9969
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 15000, 32)         128
#
#  max_pooling1d_4 (MaxPooling  (None, 7500, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 240000)            0
#
#  dense_8 (Dense)             (None, 32)                7680032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,680,193
# Trainable params: 7,680,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 16s 25ms/step - loss: 0.6787 - accuracy: 0.5551 - val_loss: 0.6648 - val_accuracy: 0.5742
# Epoch 2/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6512 - accuracy: 0.6339 - val_loss: 0.6384 - val_accuracy: 0.6927
# Epoch 3/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.6235 - accuracy: 0.7394 - val_loss: 0.6114 - val_accuracy: 0.7763
# Epoch 4/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5958 - accuracy: 0.7876 - val_loss: 0.5844 - val_accuracy: 0.7850
# Epoch 5/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5682 - accuracy: 0.8194 - val_loss: 0.5583 - val_accuracy: 0.8471
# Epoch 6/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5419 - accuracy: 0.8368 - val_loss: 0.5343 - val_accuracy: 0.8175
# Epoch 7/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.5174 - accuracy: 0.8468 - val_loss: 0.5117 - val_accuracy: 0.8507
# Epoch 8/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.4953 - accuracy: 0.8529 - val_loss: 0.4900 - val_accuracy: 0.8525
# Epoch 9/10
# 623/623 [==============================] - 14s 23ms/step - loss: 0.4749 - accuracy: 0.8569 - val_loss: 0.4713 - val_accuracy: 0.8541
# Epoch 10/10
# 623/623 [==============================] - 15s 23ms/step - loss: 0.4563 - accuracy: 0.8595 - val_loss: 0.4544 - val_accuracy: 0.8555
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8554518818855286
# Validation Loss: 0.4544265866279602
#
# 312/312 [==============================] - 2s 6ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8762    0.7945    0.8334      4535
#            1     0.8409    0.9063    0.8724      5434
#
#     accuracy                         0.8555      9969
#    macro avg     0.8585    0.8504    0.8529      9969
# weighted avg     0.8570    0.8555    0.8546      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baselineCNN-2-15000.csv', index=False)
loss_func(df)
# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.2 & max features 15000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
print()
# Out:
# Average Score by Test Size
# Test Size 0.2 & max features 15000
# Average Accuracy Score : 0.8531648109138329
# Average Precision Score : 0.8469359103637327
# Average Recall Score : 0.8926021347073979
# Average F1 Score : 0.8525510477987795
