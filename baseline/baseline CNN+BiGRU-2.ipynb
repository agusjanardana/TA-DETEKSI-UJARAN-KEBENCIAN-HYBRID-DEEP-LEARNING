# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## CNN+BIGRU MODEL BASELINE
# 1. TF-IDF, Max Features , Test Size
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.
# 2. max Features terbaik

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.2]
max_features = [5000, 10000, 15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (39872, 1, 32)            480032
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (39872, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (39872, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (39872, 64)               0
#
#  dense (Dense)               (39872, 32)               2080
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 12s 7ms/step - loss: 0.6775 - accuracy: 0.6302 - val_loss: 0.6338 - val_accuracy: 0.8171
# Epoch 2/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.5257 - accuracy: 0.8510 - val_loss: 0.4238 - val_accuracy: 0.8595
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3617 - accuracy: 0.8705 - val_loss: 0.3421 - val_accuracy: 0.8649
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3090 - accuracy: 0.8803 - val_loss: 0.3248 - val_accuracy: 0.8686
# Epoch 5/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2888 - accuracy: 0.8866 - val_loss: 0.3207 - val_accuracy: 0.8692
# Epoch 6/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2772 - accuracy: 0.8917 - val_loss: 0.3209 - val_accuracy: 0.8690
# Epoch 7/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2692 - accuracy: 0.8954 - val_loss: 0.3228 - val_accuracy: 0.8682
# Epoch 8/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2630 - accuracy: 0.8981 - val_loss: 0.3259 - val_accuracy: 0.8665
# Epoch 9/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2580 - accuracy: 0.8998 - val_loss: 0.3285 - val_accuracy: 0.8651
# Epoch 10/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2536 - accuracy: 0.9022 - val_loss: 0.3317 - val_accuracy: 0.8645
#
# Validation Accuracy: 0.8644798994064331
# Validation Loss: 0.3317347466945648
#
# 312/312 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8599    0.8388    0.8492      4535
#            1     0.8682    0.8859    0.8769      5434
#
#     accuracy                         0.8645      9969
#    macro avg     0.8640    0.8624    0.8631      9969
# weighted avg     0.8644    0.8645    0.8643      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (39872, 1, 32)            480032
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (39872, 64)               0
#
#  dense_2 (Dense)             (39872, 32)               2080
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 6s 7ms/step - loss: 0.6794 - accuracy: 0.6379 - val_loss: 0.6399 - val_accuracy: 0.7965
# Epoch 2/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.5333 - accuracy: 0.8485 - val_loss: 0.4285 - val_accuracy: 0.8616
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3633 - accuracy: 0.8710 - val_loss: 0.3419 - val_accuracy: 0.8658
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3090 - accuracy: 0.8798 - val_loss: 0.3246 - val_accuracy: 0.8683
# Epoch 5/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2890 - accuracy: 0.8871 - val_loss: 0.3211 - val_accuracy: 0.8695
# Epoch 6/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2777 - accuracy: 0.8913 - val_loss: 0.3214 - val_accuracy: 0.8700
# Epoch 7/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2698 - accuracy: 0.8950 - val_loss: 0.3229 - val_accuracy: 0.8685
# Epoch 8/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2636 - accuracy: 0.8978 - val_loss: 0.3257 - val_accuracy: 0.8679
# Epoch 9/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2587 - accuracy: 0.9002 - val_loss: 0.3283 - val_accuracy: 0.8660
# Epoch 10/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2546 - accuracy: 0.9021 - val_loss: 0.3314 - val_accuracy: 0.8652
#
# Validation Accuracy: 0.8651820421218872
# Validation Loss: 0.33135268092155457
#
# 312/312 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8589    0.8419    0.8503      4535
#            1     0.8702    0.8846    0.8773      5434
#
#     accuracy                         0.8652      9969
#    macro avg     0.8646    0.8633    0.8638      9969
# weighted avg     0.8651    0.8652    0.8651      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (39872, 1, 32)            480032
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (39872, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (39872, 64)               0
#
#  dense_4 (Dense)             (39872, 32)               2080
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 6s 7ms/step - loss: 0.6715 - accuracy: 0.6232 - val_loss: 0.6119 - val_accuracy: 0.8231
# Epoch 2/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.4935 - accuracy: 0.8536 - val_loss: 0.3991 - val_accuracy: 0.8597
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3468 - accuracy: 0.8715 - val_loss: 0.3367 - val_accuracy: 0.8668
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3038 - accuracy: 0.8800 - val_loss: 0.3235 - val_accuracy: 0.8690
# Epoch 5/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2862 - accuracy: 0.8868 - val_loss: 0.3213 - val_accuracy: 0.8680
# Epoch 6/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2756 - accuracy: 0.8915 - val_loss: 0.3220 - val_accuracy: 0.8693
# Epoch 7/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2682 - accuracy: 0.8951 - val_loss: 0.3244 - val_accuracy: 0.8679
# Epoch 8/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2628 - accuracy: 0.8973 - val_loss: 0.3274 - val_accuracy: 0.8675
# Epoch 9/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2585 - accuracy: 0.9004 - val_loss: 0.3306 - val_accuracy: 0.8652
# Epoch 10/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2549 - accuracy: 0.9012 - val_loss: 0.3340 - val_accuracy: 0.8629
#
# Validation Accuracy: 0.8628749251365662
# Validation Loss: 0.3340105414390564
#
# 312/312 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8561    0.8397    0.8478      4535
#            1     0.8683    0.8822    0.8752      5434
#
#     accuracy                         0.8629      9969
#    macro avg     0.8622    0.8610    0.8615      9969
# weighted avg     0.8628    0.8629    0.8628      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (39872, 1, 32)            480032
#
#  max_pooling1d_6 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (39872, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (39872, 64)               0
#
#  dense_6 (Dense)             (39872, 32)               2080
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 7s 7ms/step - loss: 0.6710 - accuracy: 0.6308 - val_loss: 0.6107 - val_accuracy: 0.8079
# Epoch 2/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.4957 - accuracy: 0.8506 - val_loss: 0.4025 - val_accuracy: 0.8645
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3475 - accuracy: 0.8745 - val_loss: 0.3368 - val_accuracy: 0.8653
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3030 - accuracy: 0.8831 - val_loss: 0.3243 - val_accuracy: 0.8680
# Epoch 5/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2853 - accuracy: 0.8891 - val_loss: 0.3228 - val_accuracy: 0.8703
# Epoch 6/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2747 - accuracy: 0.8933 - val_loss: 0.3232 - val_accuracy: 0.8696
# Epoch 7/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2676 - accuracy: 0.8967 - val_loss: 0.3256 - val_accuracy: 0.8686
# Epoch 8/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2622 - accuracy: 0.8988 - val_loss: 0.3285 - val_accuracy: 0.8671
# Epoch 9/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2578 - accuracy: 0.9003 - val_loss: 0.3323 - val_accuracy: 0.8646
# Epoch 10/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2543 - accuracy: 0.9020 - val_loss: 0.3351 - val_accuracy: 0.8646
#
# Validation Accuracy: 0.8645802140235901
# Validation Loss: 0.3351198136806488
#
# 312/312 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8537    0.8476    0.8506      4535
#            1     0.8736    0.8787    0.8761      5434
#
#     accuracy                         0.8646      9969
#    macro avg     0.8636    0.8632    0.8634      9969
# weighted avg     0.8645    0.8646    0.8645      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (39872, 1, 32)            480032
#
#  max_pooling1d_8 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (39872, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (39872, 64)               0
#
#  dense_8 (Dense)             (39872, 32)               2080
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 6s 7ms/step - loss: 0.6772 - accuracy: 0.5834 - val_loss: 0.6359 - val_accuracy: 0.7097
# Epoch 2/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.5444 - accuracy: 0.8076 - val_loss: 0.4581 - val_accuracy: 0.8555
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3870 - accuracy: 0.8708 - val_loss: 0.3560 - val_accuracy: 0.8659
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3183 - accuracy: 0.8808 - val_loss: 0.3308 - val_accuracy: 0.8688
# Epoch 5/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2938 - accuracy: 0.8867 - val_loss: 0.3244 - val_accuracy: 0.8688
# Epoch 6/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2811 - accuracy: 0.8910 - val_loss: 0.3238 - val_accuracy: 0.8677
# Epoch 7/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2729 - accuracy: 0.8937 - val_loss: 0.3253 - val_accuracy: 0.8683
# Epoch 8/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2669 - accuracy: 0.8961 - val_loss: 0.3279 - val_accuracy: 0.8664
# Epoch 9/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2622 - accuracy: 0.8983 - val_loss: 0.3306 - val_accuracy: 0.8656
# Epoch 10/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2583 - accuracy: 0.9001 - val_loss: 0.3337 - val_accuracy: 0.8639
#
# Validation Accuracy: 0.8638780117034912
# Validation Loss: 0.33367305994033813
#
# 312/312 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8544    0.8448    0.8495      4535
#            1     0.8716    0.8798    0.8757      5434
#
#     accuracy                         0.8639      9969
#    macro avg     0.8630    0.8623    0.8626      9969
# weighted avg     0.8638    0.8639    0.8638      9969
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (39872, 1, 32)            960032
#
#  max_pooling1d_10 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_5 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_11 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_5 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_5 (Flatten)         (39872, 64)               0
#
#  dense_10 (Dense)            (39872, 32)               2080
#
#  dense_11 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 7s 8ms/step - loss: 0.6731 - accuracy: 0.5977 - val_loss: 0.6242 - val_accuracy: 0.7406
# Epoch 2/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.5231 - accuracy: 0.8333 - val_loss: 0.4339 - val_accuracy: 0.8607
# Epoch 3/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.3632 - accuracy: 0.8764 - val_loss: 0.3447 - val_accuracy: 0.8655
# Epoch 4/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2983 - accuracy: 0.8882 - val_loss: 0.3236 - val_accuracy: 0.8677
# Epoch 5/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2713 - accuracy: 0.8974 - val_loss: 0.3206 - val_accuracy: 0.8695
# Epoch 6/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2552 - accuracy: 0.9036 - val_loss: 0.3227 - val_accuracy: 0.8683
# Epoch 7/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2438 - accuracy: 0.9087 - val_loss: 0.3271 - val_accuracy: 0.8671
# Epoch 8/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2347 - accuracy: 0.9124 - val_loss: 0.3327 - val_accuracy: 0.8655
# Epoch 9/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2271 - accuracy: 0.9156 - val_loss: 0.3402 - val_accuracy: 0.8626
# Epoch 10/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2209 - accuracy: 0.9184 - val_loss: 0.3471 - val_accuracy: 0.8618
#
# Validation Accuracy: 0.8617714643478394
# Validation Loss: 0.3470754027366638
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8524    0.8419    0.8471      4535
#            1     0.8694    0.8784    0.8739      5434
#
#     accuracy                         0.8618      9969
#    macro avg     0.8609    0.8601    0.8605      9969
# weighted avg     0.8617    0.8618    0.8617      9969
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (39872, 1, 32)            960032
#
#  max_pooling1d_12 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_6 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_13 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_6 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_6 (Flatten)         (39872, 64)               0
#
#  dense_12 (Dense)            (39872, 32)               2080
#
#  dense_13 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 8s 10ms/step - loss: 0.6769 - accuracy: 0.6942 - val_loss: 0.6298 - val_accuracy: 0.8524
# Epoch 2/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.5195 - accuracy: 0.8593 - val_loss: 0.4207 - val_accuracy: 0.8630
# Epoch 3/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.3526 - accuracy: 0.8759 - val_loss: 0.3376 - val_accuracy: 0.8669
# Epoch 4/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2937 - accuracy: 0.8876 - val_loss: 0.3195 - val_accuracy: 0.8683
# Epoch 5/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2683 - accuracy: 0.8966 - val_loss: 0.3168 - val_accuracy: 0.8699
# Epoch 6/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2527 - accuracy: 0.9038 - val_loss: 0.3188 - val_accuracy: 0.8686
# Epoch 7/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2410 - accuracy: 0.9094 - val_loss: 0.3237 - val_accuracy: 0.8682
# Epoch 8/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2316 - accuracy: 0.9138 - val_loss: 0.3293 - val_accuracy: 0.8652
# Epoch 9/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2239 - accuracy: 0.9173 - val_loss: 0.3350 - val_accuracy: 0.8642
# Epoch 10/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2171 - accuracy: 0.9205 - val_loss: 0.3421 - val_accuracy: 0.8622
#
# Validation Accuracy: 0.8621727228164673
# Validation Loss: 0.34214815497398376
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8577    0.8357    0.8465      4535
#            1     0.8658    0.8842    0.8749      5434
#
#     accuracy                         0.8622      9969
#    macro avg     0.8617    0.8600    0.8607      9969
# weighted avg     0.8621    0.8622    0.8620      9969
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_7 (Conv1D)           (39872, 1, 32)            960032
#
#  max_pooling1d_14 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_7 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_15 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_7 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_7 (Flatten)         (39872, 64)               0
#
#  dense_14 (Dense)            (39872, 32)               2080
#
#  dense_15 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 7s 9ms/step - loss: 0.6749 - accuracy: 0.6212 - val_loss: 0.6267 - val_accuracy: 0.7765
# Epoch 2/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5176 - accuracy: 0.8453 - val_loss: 0.4211 - val_accuracy: 0.8627
# Epoch 3/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.3533 - accuracy: 0.8764 - val_loss: 0.3387 - val_accuracy: 0.8661
# Epoch 4/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2944 - accuracy: 0.8865 - val_loss: 0.3210 - val_accuracy: 0.8700
# Epoch 5/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2693 - accuracy: 0.8963 - val_loss: 0.3183 - val_accuracy: 0.8692
# Epoch 6/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2537 - accuracy: 0.9033 - val_loss: 0.3208 - val_accuracy: 0.8682
# Epoch 7/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2423 - accuracy: 0.9080 - val_loss: 0.3253 - val_accuracy: 0.8653
# Epoch 8/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2332 - accuracy: 0.9125 - val_loss: 0.3311 - val_accuracy: 0.8643
# Epoch 9/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2257 - accuracy: 0.9163 - val_loss: 0.3375 - val_accuracy: 0.8631
# Epoch 10/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2191 - accuracy: 0.9197 - val_loss: 0.3447 - val_accuracy: 0.8618
#
# Validation Accuracy: 0.8617714643478394
# Validation Loss: 0.34467360377311707
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8498    0.8456    0.8477      4535
#            1     0.8717    0.8752    0.8735      5434
#
#     accuracy                         0.8618      9969
#    macro avg     0.8607    0.8604    0.8606      9969
# weighted avg     0.8617    0.8618    0.8617      9969
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (39872, 1, 32)            960032
#
#  max_pooling1d_16 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_8 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_17 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_8 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_8 (Flatten)         (39872, 64)               0
#
#  dense_16 (Dense)            (39872, 32)               2080
#
#  dense_17 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 7s 8ms/step - loss: 0.6725 - accuracy: 0.5917 - val_loss: 0.6199 - val_accuracy: 0.7373
# Epoch 2/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.5203 - accuracy: 0.8222 - val_loss: 0.4345 - val_accuracy: 0.8595
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3653 - accuracy: 0.8778 - val_loss: 0.3464 - val_accuracy: 0.8656
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2988 - accuracy: 0.8893 - val_loss: 0.3244 - val_accuracy: 0.8697
# Epoch 5/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2709 - accuracy: 0.8976 - val_loss: 0.3210 - val_accuracy: 0.8705
# Epoch 6/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2548 - accuracy: 0.9038 - val_loss: 0.3238 - val_accuracy: 0.8679
# Epoch 7/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2432 - accuracy: 0.9084 - val_loss: 0.3291 - val_accuracy: 0.8658
# Epoch 8/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2342 - accuracy: 0.9130 - val_loss: 0.3356 - val_accuracy: 0.8650
# Epoch 9/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2267 - accuracy: 0.9157 - val_loss: 0.3429 - val_accuracy: 0.8602
# Epoch 10/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2204 - accuracy: 0.9195 - val_loss: 0.3502 - val_accuracy: 0.8592
#
# Validation Accuracy: 0.8591634035110474
# Validation Loss: 0.3502236008644104
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8472    0.8423    0.8448      4535
#            1     0.8690    0.8732    0.8711      5434
#
#     accuracy                         0.8592      9969
#    macro avg     0.8581    0.8578    0.8579      9969
# weighted avg     0.8591    0.8592    0.8591      9969
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_9 (Conv1D)           (39872, 1, 32)            960032
#
#  max_pooling1d_18 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_9 (Bidirectio  (39872, 1, 64)           12672
#  nal)
#
#  max_pooling1d_19 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_9 (Averag  (39872, 1, 64)           0
#  ePooling1D)
#
#  flatten_9 (Flatten)         (39872, 64)               0
#
#  dense_18 (Dense)            (39872, 32)               2080
#
#  dense_19 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 7s 9ms/step - loss: 0.6690 - accuracy: 0.6300 - val_loss: 0.6079 - val_accuracy: 0.7960
# Epoch 2/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.4936 - accuracy: 0.8512 - val_loss: 0.4022 - val_accuracy: 0.8651
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.3406 - accuracy: 0.8780 - val_loss: 0.3339 - val_accuracy: 0.8684
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2891 - accuracy: 0.8900 - val_loss: 0.3203 - val_accuracy: 0.8698
# Epoch 5/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2658 - accuracy: 0.8978 - val_loss: 0.3194 - val_accuracy: 0.8706
# Epoch 6/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2510 - accuracy: 0.9051 - val_loss: 0.3228 - val_accuracy: 0.8687
# Epoch 7/10
# 623/623 [==============================] - 4s 7ms/step - loss: 0.2398 - accuracy: 0.9103 - val_loss: 0.3286 - val_accuracy: 0.8663
# Epoch 8/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2311 - accuracy: 0.9130 - val_loss: 0.3345 - val_accuracy: 0.8646
# Epoch 9/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.2239 - accuracy: 0.9173 - val_loss: 0.3417 - val_accuracy: 0.8625
# Epoch 10/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.2176 - accuracy: 0.9194 - val_loss: 0.3500 - val_accuracy: 0.8607
#
# Validation Accuracy: 0.8606680631637573
# Validation Loss: 0.34998711943626404
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8572    0.8324    0.8446      4535
#            1     0.8634    0.8842    0.8737      5434
#
#     accuracy                         0.8607      9969
#    macro avg     0.8603    0.8583    0.8592      9969
# weighted avg     0.8606    0.8607    0.8605      9969
#
#
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (39872, 1, 32)            1440032
#
#  max_pooling1d_20 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_10 (Bidirecti  (39872, 1, 64)           12672
#  onal)
#
#  max_pooling1d_21 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_10 (Avera  (39872, 1, 64)           0
#  gePooling1D)
#
#  flatten_10 (Flatten)        (39872, 64)               0
#
#  dense_20 (Dense)            (39872, 32)               2080
#
#  dense_21 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 8s 10ms/step - loss: 0.6684 - accuracy: 0.6021 - val_loss: 0.6041 - val_accuracy: 0.7554
# Epoch 2/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4955 - accuracy: 0.8376 - val_loss: 0.4126 - val_accuracy: 0.8656
# Epoch 3/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3436 - accuracy: 0.8838 - val_loss: 0.3386 - val_accuracy: 0.8696
# Epoch 4/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2835 - accuracy: 0.8943 - val_loss: 0.3241 - val_accuracy: 0.8699
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2556 - accuracy: 0.9054 - val_loss: 0.3239 - val_accuracy: 0.8700
# Epoch 6/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2378 - accuracy: 0.9124 - val_loss: 0.3287 - val_accuracy: 0.8680
# Epoch 7/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.2241 - accuracy: 0.9179 - val_loss: 0.3372 - val_accuracy: 0.8653
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2134 - accuracy: 0.9225 - val_loss: 0.3475 - val_accuracy: 0.8614
# Epoch 9/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2042 - accuracy: 0.9263 - val_loss: 0.3566 - val_accuracy: 0.8575
# Epoch 10/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1962 - accuracy: 0.9305 - val_loss: 0.3683 - val_accuracy: 0.8537
#
# Validation Accuracy: 0.8537465929985046
# Validation Loss: 0.3682733476161957
#
# 312/312 [==============================] - 1s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8385    0.8404    0.8394      4535
#            1     0.8665    0.8649    0.8657      5434
#
#     accuracy                         0.8537      9969
#    macro avg     0.8525    0.8526    0.8526      9969
# weighted avg     0.8538    0.8537    0.8538      9969
#
#
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (39872, 1, 32)            1440032
#
#  max_pooling1d_22 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_11 (Bidirecti  (39872, 1, 64)           12672
#  onal)
#
#  max_pooling1d_23 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_11 (Avera  (39872, 1, 64)           0
#  gePooling1D)
#
#  flatten_11 (Flatten)        (39872, 64)               0
#
#  dense_22 (Dense)            (39872, 32)               2080
#
#  dense_23 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 8s 10ms/step - loss: 0.6720 - accuracy: 0.6283 - val_loss: 0.6184 - val_accuracy: 0.7942
# Epoch 2/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.5037 - accuracy: 0.8501 - val_loss: 0.4088 - val_accuracy: 0.8639
# Epoch 3/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.3403 - accuracy: 0.8806 - val_loss: 0.3347 - val_accuracy: 0.8687
# Epoch 4/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.2831 - accuracy: 0.8931 - val_loss: 0.3201 - val_accuracy: 0.8694
# Epoch 5/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.2565 - accuracy: 0.9032 - val_loss: 0.3193 - val_accuracy: 0.8681
# Epoch 6/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.2391 - accuracy: 0.9111 - val_loss: 0.3233 - val_accuracy: 0.8683
# Epoch 7/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2257 - accuracy: 0.9164 - val_loss: 0.3301 - val_accuracy: 0.8666
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2147 - accuracy: 0.9214 - val_loss: 0.3384 - val_accuracy: 0.8619
# Epoch 9/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.2053 - accuracy: 0.9254 - val_loss: 0.3473 - val_accuracy: 0.8591
# Epoch 10/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.1971 - accuracy: 0.9295 - val_loss: 0.3575 - val_accuracy: 0.8569
#
# Validation Accuracy: 0.8568562269210815
# Validation Loss: 0.3574523627758026
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8446    0.8399    0.8422      4535
#            1     0.8670    0.8710    0.8690      5434
#
#     accuracy                         0.8569      9969
#    macro avg     0.8558    0.8555    0.8556      9969
# weighted avg     0.8568    0.8569    0.8568      9969
#
#
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (39872, 1, 32)            1440032
#
#  max_pooling1d_24 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_12 (Bidirecti  (39872, 1, 64)           12672
#  onal)
#
#  max_pooling1d_25 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_12 (Avera  (39872, 1, 64)           0
#  gePooling1D)
#
#  flatten_12 (Flatten)        (39872, 64)               0
#
#  dense_24 (Dense)            (39872, 32)               2080
#
#  dense_25 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 30s 38ms/step - loss: 0.6673 - accuracy: 0.6039 - val_loss: 0.6060 - val_accuracy: 0.7649
# Epoch 2/10
# 623/623 [==============================] - 6s 9ms/step - loss: 0.4974 - accuracy: 0.8442 - val_loss: 0.4120 - val_accuracy: 0.8635
# Epoch 3/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3431 - accuracy: 0.8815 - val_loss: 0.3364 - val_accuracy: 0.8681
# Epoch 4/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2839 - accuracy: 0.8930 - val_loss: 0.3212 - val_accuracy: 0.8696
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2567 - accuracy: 0.9030 - val_loss: 0.3206 - val_accuracy: 0.8710
# Epoch 6/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2389 - accuracy: 0.9115 - val_loss: 0.3252 - val_accuracy: 0.8689
# Epoch 7/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2254 - accuracy: 0.9178 - val_loss: 0.3312 - val_accuracy: 0.8655
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2144 - accuracy: 0.9213 - val_loss: 0.3394 - val_accuracy: 0.8622
# Epoch 9/10
# 623/623 [==============================] - 5s 9ms/step - loss: 0.2049 - accuracy: 0.9255 - val_loss: 0.3495 - val_accuracy: 0.8599
# Epoch 10/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1968 - accuracy: 0.9294 - val_loss: 0.3598 - val_accuracy: 0.8570
#
# Validation Accuracy: 0.8569565415382385
# Validation Loss: 0.35979506373405457
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8429    0.8426    0.8427      4535
#            1     0.8687    0.8690    0.8688      5434
#
#     accuracy                         0.8570      9969
#    macro avg     0.8558    0.8558    0.8558      9969
# weighted avg     0.8570    0.8570    0.8570      9969
#
#
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_13 (Conv1D)          (39872, 1, 32)            1440032
#
#  max_pooling1d_26 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_13 (Bidirecti  (39872, 1, 64)           12672
#  onal)
#
#  max_pooling1d_27 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_13 (Avera  (39872, 1, 64)           0
#  gePooling1D)
#
#  flatten_13 (Flatten)        (39872, 64)               0
#
#  dense_26 (Dense)            (39872, 32)               2080
#
#  dense_27 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 8s 10ms/step - loss: 0.6731 - accuracy: 0.6365 - val_loss: 0.6215 - val_accuracy: 0.7901
# Epoch 2/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5105 - accuracy: 0.8520 - val_loss: 0.4165 - val_accuracy: 0.8637
# Epoch 3/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3476 - accuracy: 0.8790 - val_loss: 0.3378 - val_accuracy: 0.8668
# Epoch 4/10
# 623/623 [==============================] - 5s 7ms/step - loss: 0.2881 - accuracy: 0.8905 - val_loss: 0.3208 - val_accuracy: 0.8690
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2606 - accuracy: 0.9010 - val_loss: 0.3180 - val_accuracy: 0.8703
# Epoch 6/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2429 - accuracy: 0.9088 - val_loss: 0.3208 - val_accuracy: 0.8687
# Epoch 7/10
# 623/623 [==============================] - 5s 9ms/step - loss: 0.2291 - accuracy: 0.9142 - val_loss: 0.3269 - val_accuracy: 0.8668
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2180 - accuracy: 0.9195 - val_loss: 0.3332 - val_accuracy: 0.8641
# Epoch 9/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2085 - accuracy: 0.9241 - val_loss: 0.3418 - val_accuracy: 0.8603
# Epoch 10/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2001 - accuracy: 0.9277 - val_loss: 0.3511 - val_accuracy: 0.8583
#
# Validation Accuracy: 0.8582606315612793
# Validation Loss: 0.3511055111885071
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8481    0.8386    0.8433      4535
#            1     0.8665    0.8747    0.8706      5434
#
#     accuracy                         0.8583      9969
#    macro avg     0.8573    0.8566    0.8570      9969
# weighted avg     0.8582    0.8583    0.8582      9969
#
#
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (39872, 1, 32)            1440032
#
#  max_pooling1d_28 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  bidirectional_14 (Bidirecti  (39872, 1, 64)           12672
#  onal)
#
#  max_pooling1d_29 (MaxPoolin  (39872, 1, 64)           0
#  g1D)
#
#  average_pooling1d_14 (Avera  (39872, 1, 64)           0
#  gePooling1D)
#
#  flatten_14 (Flatten)        (39872, 64)               0
#
#  dense_28 (Dense)            (39872, 32)               2080
#
#  dense_29 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 623/623 [==============================] - 8s 10ms/step - loss: 0.6735 - accuracy: 0.7116 - val_loss: 0.6220 - val_accuracy: 0.8546
# Epoch 2/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5075 - accuracy: 0.8647 - val_loss: 0.4106 - val_accuracy: 0.8630
# Epoch 3/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3418 - accuracy: 0.8799 - val_loss: 0.3344 - val_accuracy: 0.8690
# Epoch 4/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2835 - accuracy: 0.8925 - val_loss: 0.3183 - val_accuracy: 0.8708
# Epoch 5/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2559 - accuracy: 0.9033 - val_loss: 0.3173 - val_accuracy: 0.8701
# Epoch 6/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2375 - accuracy: 0.9117 - val_loss: 0.3211 - val_accuracy: 0.8700
# Epoch 7/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2233 - accuracy: 0.9178 - val_loss: 0.3271 - val_accuracy: 0.8673
# Epoch 8/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2114 - accuracy: 0.9235 - val_loss: 0.3355 - val_accuracy: 0.8644
# Epoch 9/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2011 - accuracy: 0.9279 - val_loss: 0.3453 - val_accuracy: 0.8619
# Epoch 10/10
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1920 - accuracy: 0.9316 - val_loss: 0.3563 - val_accuracy: 0.8581
#
# Validation Accuracy: 0.8580600023269653
# Validation Loss: 0.35632213950157166
#
# 312/312 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8453    0.8421    0.8437      4535
#            1     0.8686    0.8714    0.8700      5434
#
#     accuracy                         0.8581      9969
#    macro avg     0.8570    0.8567    0.8569      9969
# weighted avg     0.8580    0.8581    0.8580      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline CNN-BiGRU lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/cnn+bigru/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_CNNbiGRU-2.csv', index=False)
loss_func(df)

print('Test_Size 0.2 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.2 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.2 & max features 15000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
# Out:
# Test_Size 0.2 & max features 5000
# Average Accuracy Score : 0.864199016952553
# Average Precision Score : 0.8703850657309575
# Average Recall Score : 0.8822598454177403
# Average F1 Score : 0.8640982437304645
#
# Test_Size 0.2 & max features 10000
# Average Accuracy Score : 0.8611094392617114
# Average Precision Score : 0.8678690674003127
# Average Recall Score : 0.8790577843209423
# Average F1 Score : 0.8610106214502602
#
# Test_Size 0.2 & max features 20000
# Average Accuracy Score : 0.8567760056174141
# Average Precision Score : 0.8674748565753951
# Average Recall Score : 0.8701877070298123
# Average F1 Score : 0.8567529753232966

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_CNNbiGRU-2.csv', index=False)
loss_func(df)

print('Test_Size 0.2 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.2 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.2 & max features 20000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
