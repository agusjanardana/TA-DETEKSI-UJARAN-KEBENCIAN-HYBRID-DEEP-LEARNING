# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN MODEL BASELINE
# 1. Tanpa TF-IDF ( CountVectorize )
# 2. Testing Test Size ( splitting )
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)

  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)

  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
   # predict
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.1]
max_features = [10000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_5 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_5 (Flatten)         (None, 160000)            0
#
#  dense_10 (Dense)            (None, 32)                5120032
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 9ms/step - loss: 0.6755 - accuracy: 0.5614 - val_loss: 0.6596 - val_accuracy: 0.5737
# Epoch 2/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.6428 - accuracy: 0.6646 - val_loss: 0.6270 - val_accuracy: 0.7454
# Epoch 3/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.6087 - accuracy: 0.7665 - val_loss: 0.5934 - val_accuracy: 0.8201
# Epoch 4/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.5744 - accuracy: 0.8192 - val_loss: 0.5610 - val_accuracy: 0.7988
# Epoch 5/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.5418 - accuracy: 0.8357 - val_loss: 0.5299 - val_accuracy: 0.8445
# Epoch 6/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5120 - accuracy: 0.8466 - val_loss: 0.5025 - val_accuracy: 0.8449
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4853 - accuracy: 0.8511 - val_loss: 0.4789 - val_accuracy: 0.8489
# Epoch 8/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.4619 - accuracy: 0.8538 - val_loss: 0.4568 - val_accuracy: 0.8524
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4413 - accuracy: 0.8569 - val_loss: 0.4384 - val_accuracy: 0.8546
# Epoch 10/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4235 - accuracy: 0.8585 - val_loss: 0.4225 - val_accuracy: 0.8564
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8563690781593323
# Validation Loss: 0.4224775433540344
#
# 156/156 [==============================] - 0s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8790    0.7937    0.8342      2269
#            1     0.8406    0.9087    0.8733      2716
#
#     accuracy                         0.8564      4985
#    macro avg     0.8598    0.8512    0.8538      4985
# weighted avg     0.8581    0.8564    0.8555      4985
#
#
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_6 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_6 (Flatten)         (None, 160000)            0
#
#  dense_12 (Dense)            (None, 32)                5120032
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.6744 - accuracy: 0.5659 - val_loss: 0.6568 - val_accuracy: 0.5858
# Epoch 2/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.6392 - accuracy: 0.6783 - val_loss: 0.6226 - val_accuracy: 0.6969
# Epoch 3/10
# 701/701 [==============================] - 6s 9ms/step - loss: 0.6034 - accuracy: 0.7778 - val_loss: 0.5875 - val_accuracy: 0.7964
# Epoch 4/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5684 - accuracy: 0.8226 - val_loss: 0.5547 - val_accuracy: 0.8205
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5357 - accuracy: 0.8379 - val_loss: 0.5242 - val_accuracy: 0.8439
# Epoch 6/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5061 - accuracy: 0.8483 - val_loss: 0.4973 - val_accuracy: 0.8520
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4798 - accuracy: 0.8523 - val_loss: 0.4732 - val_accuracy: 0.8530
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4568 - accuracy: 0.8559 - val_loss: 0.4524 - val_accuracy: 0.8558
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4368 - accuracy: 0.8583 - val_loss: 0.4345 - val_accuracy: 0.8570
# Epoch 10/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.4195 - accuracy: 0.8607 - val_loss: 0.4192 - val_accuracy: 0.8584
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8583751320838928
# Validation Loss: 0.41922056674957275
#
# 156/156 [==============================] - 0s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8807    0.7968    0.8366      2269
#            1     0.8428    0.9098    0.8750      2716
#
#     accuracy                         0.8584      4985
#    macro avg     0.8617    0.8533    0.8558      4985
# weighted avg     0.8600    0.8584    0.8575      4985
#
#
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_7 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_7 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_7 (Flatten)         (None, 160000)            0
#
#  dense_14 (Dense)            (None, 32)                5120032
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.6744 - accuracy: 0.5653 - val_loss: 0.6567 - val_accuracy: 0.6618
# Epoch 2/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.6384 - accuracy: 0.6851 - val_loss: 0.6216 - val_accuracy: 0.7667
# Epoch 3/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.6026 - accuracy: 0.7779 - val_loss: 0.5878 - val_accuracy: 0.8445
# Epoch 4/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5676 - accuracy: 0.8225 - val_loss: 0.5536 - val_accuracy: 0.8337
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5353 - accuracy: 0.8386 - val_loss: 0.5235 - val_accuracy: 0.8395
# Epoch 6/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5058 - accuracy: 0.8474 - val_loss: 0.4967 - val_accuracy: 0.8467
# Epoch 7/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.4801 - accuracy: 0.8506 - val_loss: 0.4734 - val_accuracy: 0.8493
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4576 - accuracy: 0.8534 - val_loss: 0.4537 - val_accuracy: 0.8518
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4382 - accuracy: 0.8563 - val_loss: 0.4353 - val_accuracy: 0.8540
# Epoch 10/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4212 - accuracy: 0.8576 - val_loss: 0.4202 - val_accuracy: 0.8562
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8561685085296631
# Validation Loss: 0.4202464818954468
#
# 156/156 [==============================] - 0s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8804    0.7915    0.8336      2269
#            1     0.8394    0.9102    0.8733      2716
#
#     accuracy                         0.8562      4985
#    macro avg     0.8599    0.8509    0.8535      4985
# weighted avg     0.8581    0.8562    0.8553      4985
#
#
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_8 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_8 (Flatten)         (None, 160000)            0
#
#  dense_16 (Dense)            (None, 32)                5120032
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 7s 8ms/step - loss: 0.6743 - accuracy: 0.5557 - val_loss: 0.6572 - val_accuracy: 0.5729
# Epoch 2/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.6394 - accuracy: 0.6742 - val_loss: 0.6226 - val_accuracy: 0.7412
# Epoch 3/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.6034 - accuracy: 0.7792 - val_loss: 0.5880 - val_accuracy: 0.7575
# Epoch 4/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5681 - accuracy: 0.8195 - val_loss: 0.5544 - val_accuracy: 0.8453
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5350 - accuracy: 0.8370 - val_loss: 0.5243 - val_accuracy: 0.8205
# Epoch 6/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.5049 - accuracy: 0.8482 - val_loss: 0.4958 - val_accuracy: 0.8445
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4784 - accuracy: 0.8521 - val_loss: 0.4715 - val_accuracy: 0.8516
# Epoch 8/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4552 - accuracy: 0.8543 - val_loss: 0.4506 - val_accuracy: 0.8526
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4352 - accuracy: 0.8570 - val_loss: 0.4329 - val_accuracy: 0.8514
# Epoch 10/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4177 - accuracy: 0.8591 - val_loss: 0.4172 - val_accuracy: 0.8554
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8553661108016968
# Validation Loss: 0.4172270596027374
#
# 156/156 [==============================] - 0s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8696    0.8026    0.8347      2269
#            1     0.8450    0.8995    0.8714      2716
#
#     accuracy                         0.8554      4985
#    macro avg     0.8573    0.8510    0.8531      4985
# weighted avg     0.8562    0.8554    0.8547      4985
#
#
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_9 (Conv1D)           (None, 10000, 32)         128
#
#  max_pooling1d_9 (MaxPooling  (None, 5000, 32)         0
#  1D)
#
#  flatten_9 (Flatten)         (None, 160000)            0
#
#  dense_18 (Dense)            (None, 32)                5120032
#
#  dense_19 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 5,120,193
# Trainable params: 5,120,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 701/701 [==============================] - 8s 9ms/step - loss: 0.6773 - accuracy: 0.5531 - val_loss: 0.6631 - val_accuracy: 0.5952
# Epoch 2/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.6481 - accuracy: 0.6396 - val_loss: 0.6339 - val_accuracy: 0.6973
# Epoch 3/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.6173 - accuracy: 0.7465 - val_loss: 0.6032 - val_accuracy: 0.7848
# Epoch 4/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5859 - accuracy: 0.8050 - val_loss: 0.5731 - val_accuracy: 0.7962
# Epoch 5/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5554 - accuracy: 0.8293 - val_loss: 0.5443 - val_accuracy: 0.8199
# Epoch 6/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5267 - accuracy: 0.8440 - val_loss: 0.5179 - val_accuracy: 0.8317
# Epoch 7/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.5005 - accuracy: 0.8495 - val_loss: 0.4930 - val_accuracy: 0.8504
# Epoch 8/10
# 701/701 [==============================] - 6s 8ms/step - loss: 0.4769 - accuracy: 0.8534 - val_loss: 0.4712 - val_accuracy: 0.8528
# Epoch 9/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4557 - accuracy: 0.8559 - val_loss: 0.4527 - val_accuracy: 0.8528
# Epoch 10/10
# 701/701 [==============================] - 5s 8ms/step - loss: 0.4371 - accuracy: 0.8565 - val_loss: 0.4353 - val_accuracy: 0.8558
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8557673096656799
# Validation Loss: 0.43528544902801514
#
# 156/156 [==============================] - 1s 4ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8777    0.7937    0.8336      2269
#            1     0.8404    0.9076    0.8727      2716
#
#     accuracy                         0.8558      4985
#    macro avg     0.8591    0.8507    0.8532      4985
# weighted avg     0.8574    0.8558    0.8549      4985

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baselineCNN-1-10000.csv', index=False)

# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.1 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
# Out:
# Average Score by Test Size
# Test Size 0.1 & max features 10000
# Average Accuracy Score : 0.8564092276830492
# Average Precision Score : 0.841646084620829
# Average Recall Score : 0.9071428571428571
# Average F1 Score : 0.855588789169851
