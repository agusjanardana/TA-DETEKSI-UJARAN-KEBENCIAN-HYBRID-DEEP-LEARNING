# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## CNN MODEL BASELINE
# 1. Tanpa TF-IDF ( CountVectorize )
# 2. Testing Test Size ( splitting )
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)

  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)

  return X_train, X_test, y_train, y_test

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def create_cnn_model(X_train, X_test, y_train, y_test):
  # reshape
  X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  # CNN model
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units=32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  optimizer = Adam(learning_rate=0.00001)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.build(input_shape=(None, X_train.shape[1], 1))
  model.summary()
  
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)
    
  model.fit(x, y, validation_data=(X_test, y_test), epochs=10, batch_size=64)
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  print("=== MODEL EVALUATE TEST DATA ===")
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_model(X_train, X_test, y_train, y_test)
   # predict
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.2]
max_features = [5000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 5000, 32)          128
#
#  max_pooling1d (MaxPooling1D  (None, 2500, 32)         0
#  )
#
#  flatten (Flatten)           (None, 80000)             0
#
#  dense (Dense)               (None, 32)                2560032
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,560,193
# Trainable params: 2,560,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 9s 6ms/step - loss: 0.6740 - accuracy: 0.5816 - val_loss: 0.6553 - val_accuracy: 0.6615
# Epoch 2/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6374 - accuracy: 0.6921 - val_loss: 0.6209 - val_accuracy: 0.7875
# Epoch 3/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.6027 - accuracy: 0.7808 - val_loss: 0.5875 - val_accuracy: 0.8282
# Epoch 4/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5697 - accuracy: 0.8194 - val_loss: 0.5563 - val_accuracy: 0.8423
# Epoch 5/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5394 - accuracy: 0.8347 - val_loss: 0.5282 - val_accuracy: 0.8297
# Epoch 6/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5124 - accuracy: 0.8431 - val_loss: 0.5030 - val_accuracy: 0.8481
# Epoch 7/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4884 - accuracy: 0.8470 - val_loss: 0.4820 - val_accuracy: 0.8421
# Epoch 8/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4674 - accuracy: 0.8502 - val_loss: 0.4620 - val_accuracy: 0.8497
# Epoch 9/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4494 - accuracy: 0.8529 - val_loss: 0.4452 - val_accuracy: 0.8517
# Epoch 10/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4335 - accuracy: 0.8527 - val_loss: 0.4319 - val_accuracy: 0.8521
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8521416187286377
# Validation Loss: 0.4319433271884918
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8884    0.7720    0.8261      4535
#            1     0.8285    0.9190    0.8714      5434
#
#     accuracy                         0.8521      9969
#    macro avg     0.8584    0.8455    0.8487      9969
# weighted avg     0.8557    0.8521    0.8508      9969
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 5000, 32)          128
#
#  max_pooling1d_1 (MaxPooling  (None, 2500, 32)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 80000)             0
#
#  dense_2 (Dense)             (None, 32)                2560032
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,560,193
# Trainable params: 2,560,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.6786 - accuracy: 0.5542 - val_loss: 0.6658 - val_accuracy: 0.5470
# Epoch 2/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6526 - accuracy: 0.6195 - val_loss: 0.6401 - val_accuracy: 0.7050
# Epoch 3/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6257 - accuracy: 0.7253 - val_loss: 0.6131 - val_accuracy: 0.7526
# Epoch 4/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5980 - accuracy: 0.7877 - val_loss: 0.5859 - val_accuracy: 0.8100
# Epoch 5/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5707 - accuracy: 0.8201 - val_loss: 0.5596 - val_accuracy: 0.8204
# Epoch 6/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5446 - accuracy: 0.8332 - val_loss: 0.5360 - val_accuracy: 0.8125
# Epoch 7/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5203 - accuracy: 0.8421 - val_loss: 0.5118 - val_accuracy: 0.8436
# Epoch 8/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4980 - accuracy: 0.8449 - val_loss: 0.4910 - val_accuracy: 0.8478
# Epoch 9/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4781 - accuracy: 0.8479 - val_loss: 0.4726 - val_accuracy: 0.8494
# Epoch 10/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4601 - accuracy: 0.8511 - val_loss: 0.4560 - val_accuracy: 0.8500
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8500351309776306
# Validation Loss: 0.45603421330451965
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8742    0.7830    0.8261      4535
#            1     0.8334    0.9060    0.8682      5434
#
#     accuracy                         0.8500      9969
#    macro avg     0.8538    0.8445    0.8471      9969
# weighted avg     0.8520    0.8500    0.8490      9969
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 5000, 32)          128
#
#  max_pooling1d_2 (MaxPooling  (None, 2500, 32)         0
#  1D)
#
#  flatten_2 (Flatten)         (None, 80000)             0
#
#  dense_4 (Dense)             (None, 32)                2560032
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,560,193
# Trainable params: 2,560,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.6763 - accuracy: 0.5686 - val_loss: 0.6595 - val_accuracy: 0.5720
# Epoch 2/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6436 - accuracy: 0.6615 - val_loss: 0.6288 - val_accuracy: 0.6790
# Epoch 3/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6120 - accuracy: 0.7632 - val_loss: 0.5979 - val_accuracy: 0.7575
# Epoch 4/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5809 - accuracy: 0.8078 - val_loss: 0.5680 - val_accuracy: 0.8336
# Epoch 5/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5519 - accuracy: 0.8277 - val_loss: 0.5411 - val_accuracy: 0.8154
# Epoch 6/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5250 - accuracy: 0.8383 - val_loss: 0.5160 - val_accuracy: 0.8280
# Epoch 7/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5009 - accuracy: 0.8437 - val_loss: 0.4928 - val_accuracy: 0.8462
# Epoch 8/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4794 - accuracy: 0.8457 - val_loss: 0.4732 - val_accuracy: 0.8472
# Epoch 9/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4607 - accuracy: 0.8480 - val_loss: 0.4565 - val_accuracy: 0.8477
# Epoch 10/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4440 - accuracy: 0.8510 - val_loss: 0.4408 - val_accuracy: 0.8488
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8488313555717468
# Validation Loss: 0.44082677364349365
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8523    0.8077    0.8294      4535
#            1     0.8462    0.8831    0.8643      5434
#
#     accuracy                         0.8488      9969
#    macro avg     0.8492    0.8454    0.8468      9969
# weighted avg     0.8490    0.8488    0.8484      9969
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 5000, 32)          128
#
#  max_pooling1d_3 (MaxPooling  (None, 2500, 32)         0
#  1D)
#
#  flatten_3 (Flatten)         (None, 80000)             0
#
#  dense_6 (Dense)             (None, 32)                2560032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,560,193
# Trainable params: 2,560,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.6768 - accuracy: 0.5633 - val_loss: 0.6605 - val_accuracy: 0.5530
# Epoch 2/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6447 - accuracy: 0.6559 - val_loss: 0.6302 - val_accuracy: 0.7388
# Epoch 3/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6141 - accuracy: 0.7575 - val_loss: 0.6002 - val_accuracy: 0.7812
# Epoch 4/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.5841 - accuracy: 0.8088 - val_loss: 0.5715 - val_accuracy: 0.8241
# Epoch 5/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5558 - accuracy: 0.8312 - val_loss: 0.5447 - val_accuracy: 0.8382
# Epoch 6/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5297 - accuracy: 0.8384 - val_loss: 0.5203 - val_accuracy: 0.8456
# Epoch 7/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5060 - accuracy: 0.8445 - val_loss: 0.4995 - val_accuracy: 0.8335
# Epoch 8/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4848 - accuracy: 0.8483 - val_loss: 0.4790 - val_accuracy: 0.8507
# Epoch 9/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4659 - accuracy: 0.8515 - val_loss: 0.4615 - val_accuracy: 0.8496
# Epoch 10/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4491 - accuracy: 0.8523 - val_loss: 0.4457 - val_accuracy: 0.8518
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8518407344818115
# Validation Loss: 0.4456784725189209
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8753    0.7863    0.8284      4535
#            1     0.8356    0.9065    0.8696      5434
#
#     accuracy                         0.8518      9969
#    macro avg     0.8555    0.8464    0.8490      9969
# weighted avg     0.8537    0.8518    0.8509      9969
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 5000, 32)          128
#
#  max_pooling1d_4 (MaxPooling  (None, 2500, 32)         0
#  1D)
#
#  flatten_4 (Flatten)         (None, 80000)             0
#
#  dense_8 (Dense)             (None, 32)                2560032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,560,193
# Trainable params: 2,560,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.6792 - accuracy: 0.5469 - val_loss: 0.6667 - val_accuracy: 0.5534
# Epoch 2/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6539 - accuracy: 0.6086 - val_loss: 0.6416 - val_accuracy: 0.7035
# Epoch 3/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.6271 - accuracy: 0.7156 - val_loss: 0.6148 - val_accuracy: 0.7928
# Epoch 4/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5995 - accuracy: 0.7807 - val_loss: 0.5876 - val_accuracy: 0.8268
# Epoch 5/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5720 - accuracy: 0.8174 - val_loss: 0.5613 - val_accuracy: 0.8034
# Epoch 6/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5459 - accuracy: 0.8292 - val_loss: 0.5371 - val_accuracy: 0.8451
# Epoch 7/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.5216 - accuracy: 0.8413 - val_loss: 0.5135 - val_accuracy: 0.8474
# Epoch 8/10
# 623/623 [==============================] - 4s 6ms/step - loss: 0.4996 - accuracy: 0.8461 - val_loss: 0.4942 - val_accuracy: 0.8319
# Epoch 9/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4799 - accuracy: 0.8476 - val_loss: 0.4744 - val_accuracy: 0.8492
# Epoch 10/10
# 623/623 [==============================] - 3s 5ms/step - loss: 0.4621 - accuracy: 0.8507 - val_loss: 0.4580 - val_accuracy: 0.8515
# === MODEL EVALUATE TEST DATA ===
#
# Validation Accuracy: 0.8515397906303406
# Validation Loss: 0.4580084979534149
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8671    0.7956    0.8298      4535
#            1     0.8404    0.8982    0.8684      5434
#
#     accuracy                         0.8515      9969
#    macro avg     0.8537    0.8469    0.8491      9969
# weighted avg     0.8525    0.8515    0.8508      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baselineCNN-2-5000.csv', index=False)

# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.2 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
# Out:
# Average Score by Test Size
# Test Size 0.2 & max features 5000
# Average Accuracy Score : 0.8508777209348983
# Average Precision Score : 0.8368272670976463
# Average Recall Score : 0.9025763709974237
# Average F1 Score : 0.8499900752066025
