# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode BiGRU+ CNN
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# check tensorflow version
# 2.9.1 untuk version paperspace
# 2.11 untuk collab
print(tf.__version__)
# Out:
# 2.9.3

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_cnn_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(Conv1D(filters=units, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])
  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  model.fit(X_train, y_train, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_bigru_cnn_model(X_train, y_train, X_test, y_test, 32)
   # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.2]
max_features = [5000, 10000, 15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (39872, 1, 64)           966528
#  l)
#
#  conv1d (Conv1D)             (39872, 1, 32)            6176
#
#  max_pooling1d (MaxPooling1D  (39872, 1, 32)           0
#  )
#
#  flatten (Flatten)           (39872, 32)               0
#
#  dense (Dense)               (39872, 32)               1056
#
#  dense_1 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 14s 13ms/step - loss: 0.6910 - accuracy: 0.5476 - val_loss: 0.6848 - val_accuracy: 0.6563
# Epoch 2/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.6572 - accuracy: 0.7980 - val_loss: 0.6148 - val_accuracy: 0.8444
# Epoch 3/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.5470 - accuracy: 0.8559 - val_loss: 0.4826 - val_accuracy: 0.8564
# Epoch 4/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.4211 - accuracy: 0.8658 - val_loss: 0.3885 - val_accuracy: 0.8615
# Epoch 5/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3492 - accuracy: 0.8739 - val_loss: 0.3483 - val_accuracy: 0.8635
# Epoch 6/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3152 - accuracy: 0.8802 - val_loss: 0.3322 - val_accuracy: 0.8661
# Epoch 7/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2969 - accuracy: 0.8848 - val_loss: 0.3255 - val_accuracy: 0.8675
# Epoch 8/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2849 - accuracy: 0.8888 - val_loss: 0.3234 - val_accuracy: 0.8664
# Epoch 9/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.2767 - accuracy: 0.8924 - val_loss: 0.3229 - val_accuracy: 0.8672
# Epoch 10/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2704 - accuracy: 0.8948 - val_loss: 0.3236 - val_accuracy: 0.8678
#
# Validation Accuracy: 0.867790162563324
# Validation Loss: 0.3236083984375
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8655    0.8399    0.8525      4535
#            1     0.8696    0.8911    0.8802      5434
#
#     accuracy                         0.8678      9969
#    macro avg     0.8675    0.8655    0.8664      9969
# weighted avg     0.8677    0.8678    0.8676      9969
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (39872, 1, 64)           966528
#  nal)
#
#  conv1d_1 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (39872, 32)               0
#
#  dense_2 (Dense)             (39872, 32)               1056
#
#  dense_3 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 6s 11ms/step - loss: 0.6893 - accuracy: 0.5823 - val_loss: 0.6798 - val_accuracy: 0.7149
# Epoch 2/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.6503 - accuracy: 0.8065 - val_loss: 0.6093 - val_accuracy: 0.8423
# Epoch 3/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.5466 - accuracy: 0.8561 - val_loss: 0.4885 - val_accuracy: 0.8553
# Epoch 4/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.4293 - accuracy: 0.8653 - val_loss: 0.3977 - val_accuracy: 0.8607
# Epoch 5/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3570 - accuracy: 0.8731 - val_loss: 0.3549 - val_accuracy: 0.8632
# Epoch 6/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3208 - accuracy: 0.8788 - val_loss: 0.3364 - val_accuracy: 0.8645
# Epoch 7/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.3009 - accuracy: 0.8835 - val_loss: 0.3289 - val_accuracy: 0.8668
# Epoch 8/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2883 - accuracy: 0.8867 - val_loss: 0.3252 - val_accuracy: 0.8677
# Epoch 9/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.2795 - accuracy: 0.8908 - val_loss: 0.3242 - val_accuracy: 0.8684
# Epoch 10/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.2729 - accuracy: 0.8934 - val_loss: 0.3249 - val_accuracy: 0.8692
#
# Validation Accuracy: 0.869194507598877
# Validation Loss: 0.32485806941986084
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8693    0.8386    0.8536      4535
#            1     0.8691    0.8947    0.8818      5434
#
#     accuracy                         0.8692      9969
#    macro avg     0.8692    0.8667    0.8677      9969
# weighted avg     0.8692    0.8692    0.8690      9969
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (39872, 1, 64)           966528
#  nal)
#
#  conv1d_2 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_2 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (39872, 32)               0
#
#  dense_4 (Dense)             (39872, 32)               1056
#
#  dense_5 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 6s 11ms/step - loss: 0.6900 - accuracy: 0.5453 - val_loss: 0.6827 - val_accuracy: 0.5476
# Epoch 2/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.6534 - accuracy: 0.7009 - val_loss: 0.6109 - val_accuracy: 0.8191
# Epoch 3/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.5482 - accuracy: 0.8402 - val_loss: 0.4910 - val_accuracy: 0.8520
# Epoch 4/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.4329 - accuracy: 0.8629 - val_loss: 0.4010 - val_accuracy: 0.8599
# Epoch 5/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3601 - accuracy: 0.8719 - val_loss: 0.3566 - val_accuracy: 0.8640
# Epoch 6/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3225 - accuracy: 0.8781 - val_loss: 0.3375 - val_accuracy: 0.8654
# Epoch 7/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.3019 - accuracy: 0.8829 - val_loss: 0.3292 - val_accuracy: 0.8667
# Epoch 8/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2890 - accuracy: 0.8872 - val_loss: 0.3255 - val_accuracy: 0.8680
# Epoch 9/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2801 - accuracy: 0.8910 - val_loss: 0.3245 - val_accuracy: 0.8690
# Epoch 10/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2734 - accuracy: 0.8934 - val_loss: 0.3250 - val_accuracy: 0.8686
#
# Validation Accuracy: 0.8685926198959351
# Validation Loss: 0.32504257559776306
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8672    0.8397    0.8532      4535
#            1     0.8697    0.8927    0.8810      5434
#
#     accuracy                         0.8686      9969
#    macro avg     0.8684    0.8662    0.8671      9969
# weighted avg     0.8686    0.8686    0.8684      9969
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (39872, 1, 64)           966528
#  nal)
#
#  conv1d_3 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_3 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (39872, 32)               0
#
#  dense_6 (Dense)             (39872, 32)               1056
#
#  dense_7 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 6s 11ms/step - loss: 0.6887 - accuracy: 0.5454 - val_loss: 0.6797 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.6494 - accuracy: 0.6537 - val_loss: 0.6062 - val_accuracy: 0.7682
# Epoch 3/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.5437 - accuracy: 0.8216 - val_loss: 0.4881 - val_accuracy: 0.8412
# Epoch 4/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.4320 - accuracy: 0.8618 - val_loss: 0.4016 - val_accuracy: 0.8594
# Epoch 5/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3610 - accuracy: 0.8728 - val_loss: 0.3579 - val_accuracy: 0.8616
# Epoch 6/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3231 - accuracy: 0.8791 - val_loss: 0.3381 - val_accuracy: 0.8624
# Epoch 7/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3024 - accuracy: 0.8837 - val_loss: 0.3297 - val_accuracy: 0.8644
# Epoch 8/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2897 - accuracy: 0.8869 - val_loss: 0.3264 - val_accuracy: 0.8651
# Epoch 9/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2807 - accuracy: 0.8910 - val_loss: 0.3257 - val_accuracy: 0.8674
# Epoch 10/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.2740 - accuracy: 0.8938 - val_loss: 0.3259 - val_accuracy: 0.8682
#
# Validation Accuracy: 0.8681914210319519
# Validation Loss: 0.32588857412338257
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8581    0.8509    0.8545      4535
#            1     0.8765    0.8826    0.8795      5434
#
#     accuracy                         0.8682      9969
#    macro avg     0.8673    0.8668    0.8670      9969
# weighted avg     0.8681    0.8682    0.8681      9969
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (39872, 1, 64)           966528
#  nal)
#
#  conv1d_4 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_4 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (39872, 32)               0
#
#  dense_8 (Dense)             (39872, 32)               1056
#
#  dense_9 (Dense)             (39872, 1)                33
#
# =================================================================
# Total params: 973,793
# Trainable params: 973,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 6s 11ms/step - loss: 0.6893 - accuracy: 0.5493 - val_loss: 0.6799 - val_accuracy: 0.6157
# Epoch 2/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.6447 - accuracy: 0.7758 - val_loss: 0.5952 - val_accuracy: 0.8422
# Epoch 3/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.5252 - accuracy: 0.8538 - val_loss: 0.4647 - val_accuracy: 0.8549
# Epoch 4/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.4087 - accuracy: 0.8646 - val_loss: 0.3834 - val_accuracy: 0.8600
# Epoch 5/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3455 - accuracy: 0.8728 - val_loss: 0.3483 - val_accuracy: 0.8641
# Epoch 6/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.3144 - accuracy: 0.8785 - val_loss: 0.3335 - val_accuracy: 0.8648
# Epoch 7/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2970 - accuracy: 0.8841 - val_loss: 0.3274 - val_accuracy: 0.8673
# Epoch 8/10
# 312/312 [==============================] - 3s 10ms/step - loss: 0.2857 - accuracy: 0.8874 - val_loss: 0.3250 - val_accuracy: 0.8672
# Epoch 9/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.2777 - accuracy: 0.8904 - val_loss: 0.3248 - val_accuracy: 0.8673
# Epoch 10/10
# 312/312 [==============================] - 3s 9ms/step - loss: 0.2717 - accuracy: 0.8938 - val_loss: 0.3253 - val_accuracy: 0.8673
#
# Validation Accuracy: 0.8672885894775391
# Validation Loss: 0.32534322142601013
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8611    0.8445    0.8527      4535
#            1     0.8723    0.8863    0.8792      5434
#
#     accuracy                         0.8673      9969
#    macro avg     0.8667    0.8654    0.8660      9969
# weighted avg     0.8672    0.8673    0.8672      9969
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_5 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_5 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_5 (Flatten)         (39872, 32)               0
#
#  dense_10 (Dense)            (39872, 32)               1056
#
#  dense_11 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 14ms/step - loss: 0.6888 - accuracy: 0.5888 - val_loss: 0.6783 - val_accuracy: 0.7496
# Epoch 2/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.6460 - accuracy: 0.8246 - val_loss: 0.6020 - val_accuracy: 0.8476
# Epoch 3/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.5356 - accuracy: 0.8617 - val_loss: 0.4779 - val_accuracy: 0.8567
# Epoch 4/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.4156 - accuracy: 0.8717 - val_loss: 0.3890 - val_accuracy: 0.8625
# Epoch 5/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.3424 - accuracy: 0.8801 - val_loss: 0.3473 - val_accuracy: 0.8643
# Epoch 6/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3036 - accuracy: 0.8864 - val_loss: 0.3293 - val_accuracy: 0.8658
# Epoch 7/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2805 - accuracy: 0.8936 - val_loss: 0.3217 - val_accuracy: 0.8680
# Epoch 8/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2647 - accuracy: 0.8990 - val_loss: 0.3199 - val_accuracy: 0.8685
# Epoch 9/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2531 - accuracy: 0.9041 - val_loss: 0.3202 - val_accuracy: 0.8686
# Epoch 10/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2439 - accuracy: 0.9081 - val_loss: 0.3223 - val_accuracy: 0.8676
#
# Validation Accuracy: 0.86758953332901
# Validation Loss: 0.3222775161266327
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8644    0.8408    0.8524      4535
#            1     0.8701    0.8900    0.8799      5434
#
#     accuracy                         0.8676      9969
#    macro avg     0.8673    0.8654    0.8662      9969
# weighted avg     0.8675    0.8676    0.8674      9969
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_6 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_6 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_6 (Flatten)         (39872, 32)               0
#
#  dense_12 (Dense)            (39872, 32)               1056
#
#  dense_13 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 6s 14ms/step - loss: 0.6896 - accuracy: 0.5915 - val_loss: 0.6807 - val_accuracy: 0.7256
# Epoch 2/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.6499 - accuracy: 0.8222 - val_loss: 0.6069 - val_accuracy: 0.8457
# Epoch 3/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.5386 - accuracy: 0.8618 - val_loss: 0.4790 - val_accuracy: 0.8569
# Epoch 4/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.4142 - accuracy: 0.8716 - val_loss: 0.3876 - val_accuracy: 0.8623
# Epoch 5/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3393 - accuracy: 0.8792 - val_loss: 0.3465 - val_accuracy: 0.8628
# Epoch 6/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3008 - accuracy: 0.8877 - val_loss: 0.3295 - val_accuracy: 0.8651
# Epoch 7/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2782 - accuracy: 0.8954 - val_loss: 0.3229 - val_accuracy: 0.8654
# Epoch 8/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2629 - accuracy: 0.9003 - val_loss: 0.3211 - val_accuracy: 0.8672
# Epoch 9/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.2516 - accuracy: 0.9053 - val_loss: 0.3220 - val_accuracy: 0.8671
# Epoch 10/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2426 - accuracy: 0.9095 - val_loss: 0.3245 - val_accuracy: 0.8665
#
# Validation Accuracy: 0.866486132144928
# Validation Loss: 0.3245188891887665
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8661    0.8357    0.8506      4535
#            1     0.8668    0.8922    0.8793      5434
#
#     accuracy                         0.8665      9969
#    macro avg     0.8664    0.8639    0.8650      9969
# weighted avg     0.8665    0.8665    0.8663      9969
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_7 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_7 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_7 (Flatten)         (39872, 32)               0
#
#  dense_14 (Dense)            (39872, 32)               1056
#
#  dense_15 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 15ms/step - loss: 0.6895 - accuracy: 0.5606 - val_loss: 0.6800 - val_accuracy: 0.6687
# Epoch 2/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.6447 - accuracy: 0.8012 - val_loss: 0.5957 - val_accuracy: 0.8474
# Epoch 3/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.5241 - accuracy: 0.8595 - val_loss: 0.4658 - val_accuracy: 0.8568
# Epoch 4/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.4047 - accuracy: 0.8704 - val_loss: 0.3823 - val_accuracy: 0.8598
# Epoch 5/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3367 - accuracy: 0.8785 - val_loss: 0.3450 - val_accuracy: 0.8630
# Epoch 6/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3006 - accuracy: 0.8854 - val_loss: 0.3289 - val_accuracy: 0.8656
# Epoch 7/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2785 - accuracy: 0.8937 - val_loss: 0.3222 - val_accuracy: 0.8669
# Epoch 8/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2632 - accuracy: 0.8989 - val_loss: 0.3202 - val_accuracy: 0.8678
# Epoch 9/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2515 - accuracy: 0.9045 - val_loss: 0.3210 - val_accuracy: 0.8688
# Epoch 10/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2421 - accuracy: 0.9086 - val_loss: 0.3231 - val_accuracy: 0.8668
#
# Validation Accuracy: 0.8667870163917542
# Validation Loss: 0.323140412569046
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8599    0.8448    0.8523      4535
#            1     0.8723    0.8852    0.8787      5434
#
#     accuracy                         0.8668      9969
#    macro avg     0.8661    0.8650    0.8655      9969
# weighted avg     0.8667    0.8668    0.8667      9969
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_8 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_8 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_8 (Flatten)         (39872, 32)               0
#
#  dense_16 (Dense)            (39872, 32)               1056
#
#  dense_17 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 6s 14ms/step - loss: 0.6897 - accuracy: 0.5442 - val_loss: 0.6821 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.6505 - accuracy: 0.6934 - val_loss: 0.6071 - val_accuracy: 0.7975
# Epoch 3/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.5428 - accuracy: 0.8428 - val_loss: 0.4877 - val_accuracy: 0.8518
# Epoch 4/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.4255 - accuracy: 0.8702 - val_loss: 0.3977 - val_accuracy: 0.8613
# Epoch 5/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3486 - accuracy: 0.8808 - val_loss: 0.3522 - val_accuracy: 0.8625
# Epoch 6/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3064 - accuracy: 0.8880 - val_loss: 0.3334 - val_accuracy: 0.8644
# Epoch 7/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2822 - accuracy: 0.8944 - val_loss: 0.3245 - val_accuracy: 0.8675
# Epoch 8/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2662 - accuracy: 0.8992 - val_loss: 0.3223 - val_accuracy: 0.8673
# Epoch 9/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2546 - accuracy: 0.9043 - val_loss: 0.3228 - val_accuracy: 0.8675
# Epoch 10/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2452 - accuracy: 0.9081 - val_loss: 0.3249 - val_accuracy: 0.8675
#
# Validation Accuracy: 0.867489218711853
# Validation Loss: 0.3249332308769226
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8623    0.8434    0.8527      4535
#            1     0.8717    0.8876    0.8795      5434
#
#     accuracy                         0.8675      9969
#    macro avg     0.8670    0.8655    0.8661      9969
# weighted avg     0.8674    0.8675    0.8674      9969
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_9 (Bidirectio  (39872, 1, 64)           1926528
#  nal)
#
#  conv1d_9 (Conv1D)           (39872, 1, 32)            6176
#
#  max_pooling1d_9 (MaxPooling  (39872, 1, 32)           0
#  1D)
#
#  flatten_9 (Flatten)         (39872, 32)               0
#
#  dense_18 (Dense)            (39872, 32)               1056
#
#  dense_19 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 1,933,793
# Trainable params: 1,933,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 6s 13ms/step - loss: 0.6881 - accuracy: 0.5490 - val_loss: 0.6773 - val_accuracy: 0.5793
# Epoch 2/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.6466 - accuracy: 0.7257 - val_loss: 0.6054 - val_accuracy: 0.8115
# Epoch 3/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.5446 - accuracy: 0.8462 - val_loss: 0.4919 - val_accuracy: 0.8541
# Epoch 4/10
# 312/312 [==============================] - 4s 11ms/step - loss: 0.4316 - accuracy: 0.8681 - val_loss: 0.4035 - val_accuracy: 0.8603
# Epoch 5/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3559 - accuracy: 0.8773 - val_loss: 0.3571 - val_accuracy: 0.8610
# Epoch 6/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.3132 - accuracy: 0.8846 - val_loss: 0.3356 - val_accuracy: 0.8632
# Epoch 7/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2876 - accuracy: 0.8910 - val_loss: 0.3262 - val_accuracy: 0.8666
# Epoch 8/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2707 - accuracy: 0.8975 - val_loss: 0.3223 - val_accuracy: 0.8670
# Epoch 9/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2581 - accuracy: 0.9014 - val_loss: 0.3217 - val_accuracy: 0.8679
# Epoch 10/10
# 312/312 [==============================] - 3s 11ms/step - loss: 0.2483 - accuracy: 0.9065 - val_loss: 0.3232 - val_accuracy: 0.8679
#
# Validation Accuracy: 0.867890477180481
# Validation Loss: 0.32319533824920654
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8677    0.8373    0.8522      4535
#            1     0.8680    0.8934    0.8806      5434
#
#     accuracy                         0.8679      9969
#    macro avg     0.8679    0.8654    0.8664      9969
# weighted avg     0.8679    0.8679    0.8677      9969
#
#
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_10 (Bidirecti  (39872, 1, 64)           2886528
#  onal)
#
#  conv1d_10 (Conv1D)          (39872, 1, 32)            6176
#
#  max_pooling1d_10 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  flatten_10 (Flatten)        (39872, 32)               0
#
#  dense_20 (Dense)            (39872, 32)               1056
#
#  dense_21 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 8s 16ms/step - loss: 0.6874 - accuracy: 0.5477 - val_loss: 0.6745 - val_accuracy: 0.5748
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6384 - accuracy: 0.6925 - val_loss: 0.5950 - val_accuracy: 0.7568
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5345 - accuracy: 0.8224 - val_loss: 0.4890 - val_accuracy: 0.8430
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4270 - accuracy: 0.8733 - val_loss: 0.4058 - val_accuracy: 0.8644
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3486 - accuracy: 0.8880 - val_loss: 0.3586 - val_accuracy: 0.8653
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3006 - accuracy: 0.8959 - val_loss: 0.3356 - val_accuracy: 0.8658
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2717 - accuracy: 0.9032 - val_loss: 0.3274 - val_accuracy: 0.8680
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2526 - accuracy: 0.9095 - val_loss: 0.3259 - val_accuracy: 0.8672
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2386 - accuracy: 0.9136 - val_loss: 0.3278 - val_accuracy: 0.8652
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2275 - accuracy: 0.9173 - val_loss: 0.3322 - val_accuracy: 0.8640
#
# Validation Accuracy: 0.8639783263206482
# Validation Loss: 0.3322110176086426
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8574    0.8408    0.8490      4535
#            1     0.8693    0.8833    0.8762      5434
#
#     accuracy                         0.8640      9969
#    macro avg     0.8633    0.8621    0.8626      9969
# weighted avg     0.8639    0.8640    0.8639      9969
#
#
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_11 (Bidirecti  (39872, 1, 64)           2886528
#  onal)
#
#  conv1d_11 (Conv1D)          (39872, 1, 32)            6176
#
#  max_pooling1d_11 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  flatten_11 (Flatten)        (39872, 32)               0
#
#  dense_22 (Dense)            (39872, 32)               1056
#
#  dense_23 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6882 - accuracy: 0.5931 - val_loss: 0.6773 - val_accuracy: 0.7378
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6473 - accuracy: 0.8293 - val_loss: 0.6092 - val_accuracy: 0.8508
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5484 - accuracy: 0.8659 - val_loss: 0.4972 - val_accuracy: 0.8572
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4309 - accuracy: 0.8746 - val_loss: 0.4032 - val_accuracy: 0.8620
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3485 - accuracy: 0.8831 - val_loss: 0.3547 - val_accuracy: 0.8649
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3026 - accuracy: 0.8907 - val_loss: 0.3332 - val_accuracy: 0.8677
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2751 - accuracy: 0.8983 - val_loss: 0.3242 - val_accuracy: 0.8689
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2564 - accuracy: 0.9058 - val_loss: 0.3215 - val_accuracy: 0.8673
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2422 - accuracy: 0.9111 - val_loss: 0.3216 - val_accuracy: 0.8687
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2307 - accuracy: 0.9157 - val_loss: 0.3241 - val_accuracy: 0.8686
#
# Validation Accuracy: 0.8685926198959351
# Validation Loss: 0.32407331466674805
#
# 312/312 [==============================] - 1s 3ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8664    0.8408    0.8534      4535
#            1     0.8703    0.8918    0.8809      5434
#
#     accuracy                         0.8686      9969
#    macro avg     0.8684    0.8663    0.8672      9969
# weighted avg     0.8685    0.8686    0.8684      9969
#
#
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_12 (Bidirecti  (39872, 1, 64)           2886528
#  onal)
#
#  conv1d_12 (Conv1D)          (39872, 1, 32)            6176
#
#  max_pooling1d_12 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  flatten_12 (Flatten)        (39872, 32)               0
#
#  dense_24 (Dense)            (39872, 32)               1056
#
#  dense_25 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6894 - accuracy: 0.5621 - val_loss: 0.6799 - val_accuracy: 0.6801
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6470 - accuracy: 0.8000 - val_loss: 0.6013 - val_accuracy: 0.8471
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5309 - accuracy: 0.8638 - val_loss: 0.4737 - val_accuracy: 0.8560
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4074 - accuracy: 0.8741 - val_loss: 0.3860 - val_accuracy: 0.8603
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3336 - accuracy: 0.8821 - val_loss: 0.3468 - val_accuracy: 0.8637
# Epoch 6/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2939 - accuracy: 0.8923 - val_loss: 0.3296 - val_accuracy: 0.8657
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2694 - accuracy: 0.8993 - val_loss: 0.3230 - val_accuracy: 0.8658
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2524 - accuracy: 0.9053 - val_loss: 0.3216 - val_accuracy: 0.8669
# Epoch 9/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2393 - accuracy: 0.9112 - val_loss: 0.3229 - val_accuracy: 0.8658
# Epoch 10/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2286 - accuracy: 0.9160 - val_loss: 0.3260 - val_accuracy: 0.8656
#
# Validation Accuracy: 0.8655833005905151
# Validation Loss: 0.32601481676101685
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8560    0.8470    0.8515      4535
#            1     0.8734    0.8811    0.8772      5434
#
#     accuracy                         0.8656      9969
#    macro avg     0.8647    0.8640    0.8644      9969
# weighted avg     0.8655    0.8656    0.8655      9969
#
#
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_13 (Bidirecti  (39872, 1, 64)           2886528
#  onal)
#
#  conv1d_13 (Conv1D)          (39872, 1, 32)            6176
#
#  max_pooling1d_13 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  flatten_13 (Flatten)        (39872, 32)               0
#
#  dense_26 (Dense)            (39872, 32)               1056
#
#  dense_27 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6885 - accuracy: 0.5449 - val_loss: 0.6788 - val_accuracy: 0.5451
# Epoch 2/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.6502 - accuracy: 0.5850 - val_loss: 0.6124 - val_accuracy: 0.6924
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5573 - accuracy: 0.7715 - val_loss: 0.5157 - val_accuracy: 0.8141
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4604 - accuracy: 0.8576 - val_loss: 0.4381 - val_accuracy: 0.8540
# Epoch 5/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.3819 - accuracy: 0.8831 - val_loss: 0.3824 - val_accuracy: 0.8647
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3247 - accuracy: 0.8933 - val_loss: 0.3497 - val_accuracy: 0.8640
# Epoch 7/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2878 - accuracy: 0.8998 - val_loss: 0.3346 - val_accuracy: 0.8664
# Epoch 8/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2641 - accuracy: 0.9067 - val_loss: 0.3289 - val_accuracy: 0.8659
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2477 - accuracy: 0.9112 - val_loss: 0.3285 - val_accuracy: 0.8649
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2351 - accuracy: 0.9160 - val_loss: 0.3312 - val_accuracy: 0.8636
#
# Validation Accuracy: 0.8635770678520203
# Validation Loss: 0.33115434646606445
#
# 312/312 [==============================] - 1s 2ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8538    0.8448    0.8493      4535
#            1     0.8716    0.8793    0.8754      5434
#
#     accuracy                         0.8636      9969
#    macro avg     0.8627    0.8620    0.8623      9969
# weighted avg     0.8635    0.8636    0.8635      9969
#
#
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_14 (Bidirecti  (39872, 1, 64)           2886528
#  onal)
#
#  conv1d_14 (Conv1D)          (39872, 1, 32)            6176
#
#  max_pooling1d_14 (MaxPoolin  (39872, 1, 32)           0
#  g1D)
#
#  flatten_14 (Flatten)        (39872, 32)               0
#
#  dense_28 (Dense)            (39872, 32)               1056
#
#  dense_29 (Dense)            (39872, 1)                33
#
# =================================================================
# Total params: 2,893,793
# Trainable params: 2,893,793
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 312/312 [==============================] - 7s 16ms/step - loss: 0.6866 - accuracy: 0.5451 - val_loss: 0.6736 - val_accuracy: 0.5460
# Epoch 2/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.6380 - accuracy: 0.6538 - val_loss: 0.5943 - val_accuracy: 0.7367
# Epoch 3/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.5367 - accuracy: 0.8098 - val_loss: 0.4964 - val_accuracy: 0.8344
# Epoch 4/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.4398 - accuracy: 0.8680 - val_loss: 0.4220 - val_accuracy: 0.8580
# Epoch 5/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3658 - accuracy: 0.8859 - val_loss: 0.3720 - val_accuracy: 0.8642
# Epoch 6/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.3146 - accuracy: 0.8941 - val_loss: 0.3452 - val_accuracy: 0.8638
# Epoch 7/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2814 - accuracy: 0.9015 - val_loss: 0.3337 - val_accuracy: 0.8650
# Epoch 8/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2598 - accuracy: 0.9074 - val_loss: 0.3292 - val_accuracy: 0.8666
# Epoch 9/10
# 312/312 [==============================] - 4s 12ms/step - loss: 0.2441 - accuracy: 0.9131 - val_loss: 0.3306 - val_accuracy: 0.8663
# Epoch 10/10
# 312/312 [==============================] - 4s 13ms/step - loss: 0.2323 - accuracy: 0.9166 - val_loss: 0.3339 - val_accuracy: 0.8641
#
# Validation Accuracy: 0.8640786409378052
# Validation Loss: 0.3339264690876007
#
# 312/312 [==============================] - 1s 3ms/step
# using test size : 0.2
#
#
#               precision    recall  f1-score   support
#
#            0     0.8620    0.8348    0.8482      4535
#            1     0.8657    0.8885    0.8769      5434
#
#     accuracy                         0.8641      9969
#    macro avg     0.8639    0.8617    0.8626      9969
# weighted avg     0.8640    0.8641    0.8639      9969

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline BiGRU + CNN lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru+cnn/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_BiGRUCNN-2.csv', index=False)
loss_func(df)

# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.2 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.2 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.2 & max features 15000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.2) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
# Out:
# Average Score by Test Size
# Test Size 0.2 & max features 5000
# Average Accuracy Score : 0.8682114555120876
# Average Precision Score : 0.8714383718364562
# Average Recall Score : 0.8894736842105264
# Average F1 Score : 0.8680562899296056
#
# Test_Size 0.2 & max features 10000
# Average Accuracy Score : 0.8672484702577993
# Average Precision Score : 0.8697896590665444
# Average Recall Score : 0.8896577107103422
# Average F1 Score : 0.8670755443232896
#
# Test_Size 0.2 & max features 15000
# Average Accuracy Score : 0.8651620022068413
# Average Precision Score : 0.8700525436409686
# Average Recall Score : 0.8847994111152004
# Average F1 Score : 0.8650347775229239
