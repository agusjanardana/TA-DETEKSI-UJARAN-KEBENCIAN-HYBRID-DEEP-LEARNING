# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 0), 'device_name': 'Tesla V100-SXM2-16GB'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %% [markdown]
# ## CNN+BIGRU MODEL BASELINE
# 1. TF-IDF, Max Features , Test Size
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.
# 2. max Features terbaik

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  
  return X_train, X_test, y_train, y_test

# %%
def create_cnn_bigru_model(X_train, y_train, X_test, y_test):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Bidirectional(GRU(32, activation='relu', return_sequences=True)))
  model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
  model.add(AveragePooling1D(pool_size=3, strides=2, padding='same'))
  model.add(Flatten())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt,loss='binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()
  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size=64, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=64, verbose=0)

  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_cnn_bigru_model(X_train, y_train, X_test, y_test)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  y_pred = model.predict(X_test)

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.3]
max_features = [5000, 10000, 15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (34888, 1, 32)            480032
#
#  max_pooling1d (MaxPooling1D  (34888, 1, 32)           0
#  )
#
#  bidirectional (Bidirectiona  (34888, 1, 64)           12672
#  l)
#
#  max_pooling1d_1 (MaxPooling  (34888, 1, 64)           0
#  1D)
#
#  average_pooling1d (AverageP  (34888, 1, 64)           0
#  ooling1D)
#
#  flatten (Flatten)           (34888, 64)               0
#
#  dense (Dense)               (34888, 32)               2080
#
#  dense_1 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 15s 13ms/step - loss: 0.6810 - accuracy: 0.5570 - val_loss: 0.6486 - val_accuracy: 0.6438
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5648 - accuracy: 0.7812 - val_loss: 0.4874 - val_accuracy: 0.8392
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.4097 - accuracy: 0.8680 - val_loss: 0.3797 - val_accuracy: 0.8613
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3282 - accuracy: 0.8802 - val_loss: 0.3433 - val_accuracy: 0.8628
# Epoch 5/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2960 - accuracy: 0.8866 - val_loss: 0.3349 - val_accuracy: 0.8638
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2805 - accuracy: 0.8923 - val_loss: 0.3339 - val_accuracy: 0.8628
# Epoch 7/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2706 - accuracy: 0.8957 - val_loss: 0.3353 - val_accuracy: 0.8613
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2634 - accuracy: 0.8991 - val_loss: 0.3382 - val_accuracy: 0.8592
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2578 - accuracy: 0.9015 - val_loss: 0.3425 - val_accuracy: 0.8581
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2535 - accuracy: 0.9033 - val_loss: 0.3459 - val_accuracy: 0.8574
#
# Validation Accuracy: 0.8574199080467224
# Validation Loss: 0.34591126441955566
#
# 468/468 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8453    0.8404    0.8428      6803
#            1     0.8674    0.8717    0.8695      8150
#
#     accuracy                         0.8574     14953
#    macro avg     0.8564    0.8560    0.8562     14953
# weighted avg     0.8574    0.8574    0.8574     14953
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (34888, 1, 32)            480032
#
#  max_pooling1d_2 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  bidirectional_1 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_3 (MaxPooling  (34888, 1, 64)           0
#  1D)
#
#  average_pooling1d_1 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (34888, 64)               0
#
#  dense_2 (Dense)             (34888, 32)               2080
#
#  dense_3 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 9s 12ms/step - loss: 0.6808 - accuracy: 0.5910 - val_loss: 0.6471 - val_accuracy: 0.7564
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5537 - accuracy: 0.8374 - val_loss: 0.4637 - val_accuracy: 0.8512
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3854 - accuracy: 0.8696 - val_loss: 0.3639 - val_accuracy: 0.8588
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3176 - accuracy: 0.8786 - val_loss: 0.3388 - val_accuracy: 0.8626
# Epoch 5/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2920 - accuracy: 0.8860 - val_loss: 0.3325 - val_accuracy: 0.8636
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2782 - accuracy: 0.8913 - val_loss: 0.3318 - val_accuracy: 0.8642
# Epoch 7/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2689 - accuracy: 0.8963 - val_loss: 0.3334 - val_accuracy: 0.8635
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2619 - accuracy: 0.8984 - val_loss: 0.3369 - val_accuracy: 0.8626
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2563 - accuracy: 0.9013 - val_loss: 0.3404 - val_accuracy: 0.8599
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2521 - accuracy: 0.9030 - val_loss: 0.3430 - val_accuracy: 0.8583
#
# Validation Accuracy: 0.8582893013954163
# Validation Loss: 0.3429867625236511
#
# 468/468 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8464    0.8411    0.8438      6803
#            1     0.8681    0.8726    0.8703      8150
#
#     accuracy                         0.8583     14953
#    macro avg     0.8573    0.8569    0.8571     14953
# weighted avg     0.8582    0.8583    0.8583     14953
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (34888, 1, 32)            480032
#
#  max_pooling1d_4 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  bidirectional_2 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_5 (MaxPooling  (34888, 1, 64)           0
#  1D)
#
#  average_pooling1d_2 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_2 (Flatten)         (34888, 64)               0
#
#  dense_4 (Dense)             (34888, 32)               2080
#
#  dense_5 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 9s 12ms/step - loss: 0.6818 - accuracy: 0.6153 - val_loss: 0.6513 - val_accuracy: 0.8039
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5635 - accuracy: 0.8413 - val_loss: 0.4735 - val_accuracy: 0.8515
# Epoch 3/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.3932 - accuracy: 0.8678 - val_loss: 0.3685 - val_accuracy: 0.8590
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3215 - accuracy: 0.8787 - val_loss: 0.3404 - val_accuracy: 0.8606
# Epoch 5/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2943 - accuracy: 0.8845 - val_loss: 0.3330 - val_accuracy: 0.8637
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2797 - accuracy: 0.8901 - val_loss: 0.3319 - val_accuracy: 0.8634
# Epoch 7/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2700 - accuracy: 0.8948 - val_loss: 0.3336 - val_accuracy: 0.8632
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2628 - accuracy: 0.8980 - val_loss: 0.3357 - val_accuracy: 0.8608
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2570 - accuracy: 0.9003 - val_loss: 0.3389 - val_accuracy: 0.8594
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2523 - accuracy: 0.9028 - val_loss: 0.3425 - val_accuracy: 0.8586
#
# Validation Accuracy: 0.8585568070411682
# Validation Loss: 0.34247642755508423
#
# 468/468 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8513    0.8349    0.8430      6803
#            1     0.8644    0.8783    0.8713      8150
#
#     accuracy                         0.8586     14953
#    macro avg     0.8579    0.8566    0.8572     14953
# weighted avg     0.8584    0.8586    0.8584     14953
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (34888, 1, 32)            480032
#
#  max_pooling1d_6 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  bidirectional_3 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_7 (MaxPooling  (34888, 1, 64)           0
#  1D)
#
#  average_pooling1d_3 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_3 (Flatten)         (34888, 64)               0
#
#  dense_6 (Dense)             (34888, 32)               2080
#
#  dense_7 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 9s 13ms/step - loss: 0.6777 - accuracy: 0.6203 - val_loss: 0.6388 - val_accuracy: 0.7833
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5410 - accuracy: 0.8410 - val_loss: 0.4511 - val_accuracy: 0.8530
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3765 - accuracy: 0.8723 - val_loss: 0.3593 - val_accuracy: 0.8600
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3131 - accuracy: 0.8805 - val_loss: 0.3388 - val_accuracy: 0.8631
# Epoch 5/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2889 - accuracy: 0.8886 - val_loss: 0.3326 - val_accuracy: 0.8641
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2752 - accuracy: 0.8937 - val_loss: 0.3325 - val_accuracy: 0.8619
# Epoch 7/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2661 - accuracy: 0.8969 - val_loss: 0.3344 - val_accuracy: 0.8619
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2591 - accuracy: 0.9002 - val_loss: 0.3380 - val_accuracy: 0.8617
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2535 - accuracy: 0.9024 - val_loss: 0.3418 - val_accuracy: 0.8597
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2490 - accuracy: 0.9038 - val_loss: 0.3456 - val_accuracy: 0.8590
#
# Validation Accuracy: 0.8590249419212341
# Validation Loss: 0.34563878178596497
#
# 468/468 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8512    0.8364    0.8437      6803
#            1     0.8654    0.8779    0.8716      8150
#
#     accuracy                         0.8590     14953
#    macro avg     0.8583    0.8572    0.8577     14953
# weighted avg     0.8589    0.8590    0.8589     14953
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (34888, 1, 32)            480032
#
#  max_pooling1d_8 (MaxPooling  (34888, 1, 32)           0
#  1D)
#
#  bidirectional_4 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_9 (MaxPooling  (34888, 1, 64)           0
#  1D)
#
#  average_pooling1d_4 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_4 (Flatten)         (34888, 64)               0
#
#  dense_8 (Dense)             (34888, 32)               2080
#
#  dense_9 (Dense)             (34888, 1)                33
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 9s 12ms/step - loss: 0.6774 - accuracy: 0.6028 - val_loss: 0.6369 - val_accuracy: 0.7602
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5396 - accuracy: 0.8336 - val_loss: 0.4503 - val_accuracy: 0.8555
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3756 - accuracy: 0.8720 - val_loss: 0.3583 - val_accuracy: 0.8610
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3123 - accuracy: 0.8800 - val_loss: 0.3362 - val_accuracy: 0.8638
# Epoch 5/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2882 - accuracy: 0.8875 - val_loss: 0.3317 - val_accuracy: 0.8650
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2749 - accuracy: 0.8926 - val_loss: 0.3322 - val_accuracy: 0.8630
# Epoch 7/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2657 - accuracy: 0.8968 - val_loss: 0.3348 - val_accuracy: 0.8622
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2590 - accuracy: 0.9007 - val_loss: 0.3386 - val_accuracy: 0.8613
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2536 - accuracy: 0.9031 - val_loss: 0.3420 - val_accuracy: 0.8594
# Epoch 10/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2491 - accuracy: 0.9046 - val_loss: 0.3464 - val_accuracy: 0.8570
#
# Validation Accuracy: 0.8569517731666565
# Validation Loss: 0.3463839590549469
#
# 468/468 [==============================] - 1s 2ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8385    0.8492    0.8438      6803
#            1     0.8728    0.8634    0.8681      8150
#
#     accuracy                         0.8570     14953
#    macro avg     0.8556    0.8563    0.8559     14953
# weighted avg     0.8572    0.8570    0.8570     14953
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (34888, 1, 32)            960032
#
#  max_pooling1d_10 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_5 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_11 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_5 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_5 (Flatten)         (34888, 64)               0
#
#  dense_10 (Dense)            (34888, 32)               2080
#
#  dense_11 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 11s 14ms/step - loss: 0.6793 - accuracy: 0.6077 - val_loss: 0.6424 - val_accuracy: 0.7516
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5468 - accuracy: 0.8425 - val_loss: 0.4563 - val_accuracy: 0.8556
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3726 - accuracy: 0.8760 - val_loss: 0.3547 - val_accuracy: 0.8622
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2985 - accuracy: 0.8882 - val_loss: 0.3307 - val_accuracy: 0.8665
# Epoch 5/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2677 - accuracy: 0.8972 - val_loss: 0.3269 - val_accuracy: 0.8682
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2492 - accuracy: 0.9045 - val_loss: 0.3301 - val_accuracy: 0.8655
# Epoch 7/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2360 - accuracy: 0.9109 - val_loss: 0.3355 - val_accuracy: 0.8634
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2252 - accuracy: 0.9154 - val_loss: 0.3433 - val_accuracy: 0.8602
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2162 - accuracy: 0.9191 - val_loss: 0.3518 - val_accuracy: 0.8571
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2085 - accuracy: 0.9231 - val_loss: 0.3605 - val_accuracy: 0.8555
#
# Validation Accuracy: 0.8554804921150208
# Validation Loss: 0.3605320453643799
#
# 468/468 [==============================] - 2s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8422    0.8396    0.8409      6803
#            1     0.8665    0.8687    0.8676      8150
#
#     accuracy                         0.8555     14953
#    macro avg     0.8544    0.8542    0.8543     14953
# weighted avg     0.8554    0.8555    0.8555     14953
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (34888, 1, 32)            960032
#
#  max_pooling1d_12 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_6 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_13 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_6 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_6 (Flatten)         (34888, 64)               0
#
#  dense_12 (Dense)            (34888, 32)               2080
#
#  dense_13 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 10s 14ms/step - loss: 0.6800 - accuracy: 0.5876 - val_loss: 0.6460 - val_accuracy: 0.7135
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5630 - accuracy: 0.8150 - val_loss: 0.4833 - val_accuracy: 0.8485
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3982 - accuracy: 0.8756 - val_loss: 0.3709 - val_accuracy: 0.8630
# Epoch 4/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.3113 - accuracy: 0.8874 - val_loss: 0.3367 - val_accuracy: 0.8650
# Epoch 5/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2752 - accuracy: 0.8967 - val_loss: 0.3294 - val_accuracy: 0.8655
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2550 - accuracy: 0.9041 - val_loss: 0.3309 - val_accuracy: 0.8657
# Epoch 7/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2409 - accuracy: 0.9095 - val_loss: 0.3349 - val_accuracy: 0.8626
# Epoch 8/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2299 - accuracy: 0.9140 - val_loss: 0.3411 - val_accuracy: 0.8608
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2209 - accuracy: 0.9181 - val_loss: 0.3492 - val_accuracy: 0.8580
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2133 - accuracy: 0.9208 - val_loss: 0.3584 - val_accuracy: 0.8546
#
# Validation Accuracy: 0.8546110987663269
# Validation Loss: 0.3583562672138214
#
# 468/468 [==============================] - 2s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8485    0.8283    0.8383      6803
#            1     0.8595    0.8766    0.8679      8150
#
#     accuracy                         0.8546     14953
#    macro avg     0.8540    0.8524    0.8531     14953
# weighted avg     0.8545    0.8546    0.8545     14953
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_7 (Conv1D)           (34888, 1, 32)            960032
#
#  max_pooling1d_14 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_7 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_15 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_7 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_7 (Flatten)         (34888, 64)               0
#
#  dense_14 (Dense)            (34888, 32)               2080
#
#  dense_15 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 11s 15ms/step - loss: 0.6757 - accuracy: 0.5770 - val_loss: 0.6322 - val_accuracy: 0.7019
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5389 - accuracy: 0.8046 - val_loss: 0.4587 - val_accuracy: 0.8474
# Epoch 3/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.3784 - accuracy: 0.8767 - val_loss: 0.3628 - val_accuracy: 0.8640
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3029 - accuracy: 0.8893 - val_loss: 0.3352 - val_accuracy: 0.8646
# Epoch 5/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2703 - accuracy: 0.8980 - val_loss: 0.3305 - val_accuracy: 0.8640
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2518 - accuracy: 0.9043 - val_loss: 0.3333 - val_accuracy: 0.8642
# Epoch 7/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2384 - accuracy: 0.9104 - val_loss: 0.3387 - val_accuracy: 0.8616
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2283 - accuracy: 0.9147 - val_loss: 0.3462 - val_accuracy: 0.8599
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2197 - accuracy: 0.9193 - val_loss: 0.3538 - val_accuracy: 0.8572
# Epoch 10/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2123 - accuracy: 0.9220 - val_loss: 0.3639 - val_accuracy: 0.8549
#
# Validation Accuracy: 0.8548786044120789
# Validation Loss: 0.36394214630126953
#
# 468/468 [==============================] - 2s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8455    0.8333    0.8394      6803
#            1     0.8625    0.8729    0.8677      8150
#
#     accuracy                         0.8549     14953
#    macro avg     0.8540    0.8531    0.8535     14953
# weighted avg     0.8548    0.8549    0.8548     14953
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (34888, 1, 32)            960032
#
#  max_pooling1d_16 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_8 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_17 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_8 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_8 (Flatten)         (34888, 64)               0
#
#  dense_16 (Dense)            (34888, 32)               2080
#
#  dense_17 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 10s 14ms/step - loss: 0.6759 - accuracy: 0.6658 - val_loss: 0.6312 - val_accuracy: 0.8273
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5260 - accuracy: 0.8579 - val_loss: 0.4355 - val_accuracy: 0.8552
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3581 - accuracy: 0.8773 - val_loss: 0.3497 - val_accuracy: 0.8618
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2941 - accuracy: 0.8885 - val_loss: 0.3301 - val_accuracy: 0.8642
# Epoch 5/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2660 - accuracy: 0.8980 - val_loss: 0.3272 - val_accuracy: 0.8656
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2484 - accuracy: 0.9050 - val_loss: 0.3298 - val_accuracy: 0.8652
# Epoch 7/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2350 - accuracy: 0.9109 - val_loss: 0.3354 - val_accuracy: 0.8642
# Epoch 8/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2243 - accuracy: 0.9150 - val_loss: 0.3428 - val_accuracy: 0.8608
# Epoch 9/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2152 - accuracy: 0.9189 - val_loss: 0.3508 - val_accuracy: 0.8595
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2073 - accuracy: 0.9233 - val_loss: 0.3599 - val_accuracy: 0.8563
#
# Validation Accuracy: 0.8563498854637146
# Validation Loss: 0.3599144220352173
#
# 468/468 [==============================] - 1s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8513    0.8290    0.8400      6803
#            1     0.8604    0.8791    0.8696      8150
#
#     accuracy                         0.8563     14953
#    macro avg     0.8558    0.8541    0.8548     14953
# weighted avg     0.8562    0.8563    0.8562     14953
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_9 (Conv1D)           (34888, 1, 32)            960032
#
#  max_pooling1d_18 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_9 (Bidirectio  (34888, 1, 64)           12672
#  nal)
#
#  max_pooling1d_19 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_9 (Averag  (34888, 1, 64)           0
#  ePooling1D)
#
#  flatten_9 (Flatten)         (34888, 64)               0
#
#  dense_18 (Dense)            (34888, 32)               2080
#
#  dense_19 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 974,817
# Trainable params: 974,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 10s 15ms/step - loss: 0.6802 - accuracy: 0.5814 - val_loss: 0.6472 - val_accuracy: 0.7273
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5549 - accuracy: 0.8192 - val_loss: 0.4654 - val_accuracy: 0.8543
# Epoch 3/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3812 - accuracy: 0.8735 - val_loss: 0.3611 - val_accuracy: 0.8603
# Epoch 4/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3052 - accuracy: 0.8857 - val_loss: 0.3345 - val_accuracy: 0.8636
# Epoch 5/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2736 - accuracy: 0.8945 - val_loss: 0.3295 - val_accuracy: 0.8655
# Epoch 6/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2551 - accuracy: 0.9026 - val_loss: 0.3306 - val_accuracy: 0.8643
# Epoch 7/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2415 - accuracy: 0.9085 - val_loss: 0.3359 - val_accuracy: 0.8624
# Epoch 8/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2309 - accuracy: 0.9141 - val_loss: 0.3405 - val_accuracy: 0.8614
# Epoch 9/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2220 - accuracy: 0.9168 - val_loss: 0.3480 - val_accuracy: 0.8592
# Epoch 10/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2146 - accuracy: 0.9199 - val_loss: 0.3574 - val_accuracy: 0.8537
#
# Validation Accuracy: 0.8537417054176331
# Validation Loss: 0.35739725828170776
#
# 468/468 [==============================] - 2s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8278    0.8567    0.8420      6803
#            1     0.8768    0.8513    0.8638      8150
#
#     accuracy                         0.8537     14953
#    macro avg     0.8523    0.8540    0.8529     14953
# weighted avg     0.8545    0.8537    0.8539     14953
#
#
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (34888, 1, 32)            1440032
#
#  max_pooling1d_20 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_10 (Bidirecti  (34888, 1, 64)           12672
#  onal)
#
#  max_pooling1d_21 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_10 (Avera  (34888, 1, 64)           0
#  gePooling1D)
#
#  flatten_10 (Flatten)        (34888, 64)               0
#
#  dense_20 (Dense)            (34888, 32)               2080
#
#  dense_21 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 11s 16ms/step - loss: 0.6830 - accuracy: 0.6418 - val_loss: 0.6539 - val_accuracy: 0.8238
# Epoch 2/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.5667 - accuracy: 0.8607 - val_loss: 0.4769 - val_accuracy: 0.8545
# Epoch 3/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.3867 - accuracy: 0.8761 - val_loss: 0.3649 - val_accuracy: 0.8599
# Epoch 4/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.3028 - accuracy: 0.8878 - val_loss: 0.3350 - val_accuracy: 0.8626
# Epoch 5/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2668 - accuracy: 0.8990 - val_loss: 0.3280 - val_accuracy: 0.8650
# Epoch 6/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2450 - accuracy: 0.9075 - val_loss: 0.3286 - val_accuracy: 0.8656
# Epoch 7/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2290 - accuracy: 0.9140 - val_loss: 0.3335 - val_accuracy: 0.8631
# Epoch 8/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2162 - accuracy: 0.9205 - val_loss: 0.3402 - val_accuracy: 0.8609
# Epoch 9/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2052 - accuracy: 0.9246 - val_loss: 0.3487 - val_accuracy: 0.8586
# Epoch 10/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.1957 - accuracy: 0.9288 - val_loss: 0.3588 - val_accuracy: 0.8548
#
# Validation Accuracy: 0.8548117280006409
# Validation Loss: 0.35880300402641296
#
# 468/468 [==============================] - 2s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8421    0.8380    0.8401      6803
#            1     0.8653    0.8688    0.8671      8150
#
#     accuracy                         0.8548     14953
#    macro avg     0.8537    0.8534    0.8536     14953
# weighted avg     0.8548    0.8548    0.8548     14953
#
#
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (34888, 1, 32)            1440032
#
#  max_pooling1d_22 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_11 (Bidirecti  (34888, 1, 64)           12672
#  onal)
#
#  max_pooling1d_23 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_11 (Avera  (34888, 1, 64)           0
#  gePooling1D)
#
#  flatten_11 (Flatten)        (34888, 64)               0
#
#  dense_22 (Dense)            (34888, 32)               2080
#
#  dense_23 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 11s 15ms/step - loss: 0.6814 - accuracy: 0.6173 - val_loss: 0.6480 - val_accuracy: 0.7867
# Epoch 2/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.5528 - accuracy: 0.8544 - val_loss: 0.4605 - val_accuracy: 0.8566
# Epoch 3/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.3709 - accuracy: 0.8781 - val_loss: 0.3564 - val_accuracy: 0.8603
# Epoch 4/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2933 - accuracy: 0.8913 - val_loss: 0.3318 - val_accuracy: 0.8646
# Epoch 5/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2595 - accuracy: 0.9026 - val_loss: 0.3282 - val_accuracy: 0.8660
# Epoch 6/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2386 - accuracy: 0.9108 - val_loss: 0.3308 - val_accuracy: 0.8651
# Epoch 7/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2230 - accuracy: 0.9175 - val_loss: 0.3371 - val_accuracy: 0.8622
# Epoch 8/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2105 - accuracy: 0.9226 - val_loss: 0.3456 - val_accuracy: 0.8597
# Epoch 9/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.1996 - accuracy: 0.9273 - val_loss: 0.3558 - val_accuracy: 0.8566
# Epoch 10/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.1903 - accuracy: 0.9320 - val_loss: 0.3679 - val_accuracy: 0.8532
#
# Validation Accuracy: 0.8532066941261292
# Validation Loss: 0.36794888973236084
#
# 468/468 [==============================] - 2s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8356    0.8433    0.8394      6803
#            1     0.8682    0.8615    0.8648      8150
#
#     accuracy                         0.8532     14953
#    macro avg     0.8519    0.8524    0.8521     14953
# weighted avg     0.8533    0.8532    0.8533     14953
#
#
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (34888, 1, 32)            1440032
#
#  max_pooling1d_24 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_12 (Bidirecti  (34888, 1, 64)           12672
#  onal)
#
#  max_pooling1d_25 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_12 (Avera  (34888, 1, 64)           0
#  gePooling1D)
#
#  flatten_12 (Flatten)        (34888, 64)               0
#
#  dense_24 (Dense)            (34888, 32)               2080
#
#  dense_25 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 44s 17ms/step - loss: 0.6794 - accuracy: 0.6666 - val_loss: 0.6445 - val_accuracy: 0.8460
# Epoch 2/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.5506 - accuracy: 0.8624 - val_loss: 0.4615 - val_accuracy: 0.8557
# Epoch 3/10
# 546/546 [==============================] - 8s 15ms/step - loss: 0.3754 - accuracy: 0.8767 - val_loss: 0.3607 - val_accuracy: 0.8596
# Epoch 4/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2986 - accuracy: 0.8890 - val_loss: 0.3345 - val_accuracy: 0.8628
# Epoch 5/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2644 - accuracy: 0.8998 - val_loss: 0.3303 - val_accuracy: 0.8640
# Epoch 6/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2429 - accuracy: 0.9081 - val_loss: 0.3301 - val_accuracy: 0.8649
# Epoch 7/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2267 - accuracy: 0.9154 - val_loss: 0.3353 - val_accuracy: 0.8631
# Epoch 8/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2133 - accuracy: 0.9212 - val_loss: 0.3432 - val_accuracy: 0.8600
# Epoch 9/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.2018 - accuracy: 0.9267 - val_loss: 0.3520 - val_accuracy: 0.8577
# Epoch 10/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.1917 - accuracy: 0.9314 - val_loss: 0.3625 - val_accuracy: 0.8535
#
# Validation Accuracy: 0.8535410761833191
# Validation Loss: 0.36246541142463684
#
# 468/468 [==============================] - 2s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8402    0.8373    0.8388      6803
#            1     0.8646    0.8671    0.8658      8150
#
#     accuracy                         0.8535     14953
#    macro avg     0.8524    0.8522    0.8523     14953
# weighted avg     0.8535    0.8535    0.8535     14953
#
#
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_13 (Conv1D)          (34888, 1, 32)            1440032
#
#  max_pooling1d_26 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_13 (Bidirecti  (34888, 1, 64)           12672
#  onal)
#
#  max_pooling1d_27 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_13 (Avera  (34888, 1, 64)           0
#  gePooling1D)
#
#  flatten_13 (Flatten)        (34888, 64)               0
#
#  dense_26 (Dense)            (34888, 32)               2080
#
#  dense_27 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 11s 16ms/step - loss: 0.6813 - accuracy: 0.5814 - val_loss: 0.6518 - val_accuracy: 0.7108
# Epoch 2/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.5651 - accuracy: 0.8206 - val_loss: 0.4780 - val_accuracy: 0.8497
# Epoch 3/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.3882 - accuracy: 0.8773 - val_loss: 0.3658 - val_accuracy: 0.8596
# Epoch 4/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.3027 - accuracy: 0.8889 - val_loss: 0.3357 - val_accuracy: 0.8642
# Epoch 5/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2662 - accuracy: 0.8994 - val_loss: 0.3289 - val_accuracy: 0.8646
# Epoch 6/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2444 - accuracy: 0.9083 - val_loss: 0.3303 - val_accuracy: 0.8648
# Epoch 7/10
# 546/546 [==============================] - 7s 14ms/step - loss: 0.2285 - accuracy: 0.9144 - val_loss: 0.3355 - val_accuracy: 0.8616
# Epoch 8/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2156 - accuracy: 0.9202 - val_loss: 0.3427 - val_accuracy: 0.8589
# Epoch 9/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2049 - accuracy: 0.9254 - val_loss: 0.3516 - val_accuracy: 0.8557
# Epoch 10/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.1956 - accuracy: 0.9299 - val_loss: 0.3619 - val_accuracy: 0.8524
#
# Validation Accuracy: 0.8524041771888733
# Validation Loss: 0.36190253496170044
#
# 468/468 [==============================] - 2s 3ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8453    0.8270    0.8360      6803
#            1     0.8581    0.8736    0.8658      8150
#
#     accuracy                         0.8524     14953
#    macro avg     0.8517    0.8503    0.8509     14953
# weighted avg     0.8523    0.8524    0.8523     14953
#
#
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (34888, 1, 32)            1440032
#
#  max_pooling1d_28 (MaxPoolin  (34888, 1, 32)           0
#  g1D)
#
#  bidirectional_14 (Bidirecti  (34888, 1, 64)           12672
#  onal)
#
#  max_pooling1d_29 (MaxPoolin  (34888, 1, 64)           0
#  g1D)
#
#  average_pooling1d_14 (Avera  (34888, 1, 64)           0
#  gePooling1D)
#
#  flatten_14 (Flatten)        (34888, 64)               0
#
#  dense_28 (Dense)            (34888, 32)               2080
#
#  dense_29 (Dense)            (34888, 1)                33
#
# =================================================================
# Total params: 1,454,817
# Trainable params: 1,454,817
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 546/546 [==============================] - 12s 16ms/step - loss: 0.6778 - accuracy: 0.6183 - val_loss: 0.6389 - val_accuracy: 0.7992
# Epoch 2/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.5452 - accuracy: 0.8481 - val_loss: 0.4614 - val_accuracy: 0.8562
# Epoch 3/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.3771 - accuracy: 0.8800 - val_loss: 0.3632 - val_accuracy: 0.8633
# Epoch 4/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2981 - accuracy: 0.8919 - val_loss: 0.3343 - val_accuracy: 0.8660
# Epoch 5/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2623 - accuracy: 0.9018 - val_loss: 0.3291 - val_accuracy: 0.8664
# Epoch 6/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2405 - accuracy: 0.9102 - val_loss: 0.3316 - val_accuracy: 0.8653
# Epoch 7/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2247 - accuracy: 0.9171 - val_loss: 0.3378 - val_accuracy: 0.8628
# Epoch 8/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2119 - accuracy: 0.9226 - val_loss: 0.3463 - val_accuracy: 0.8587
# Epoch 9/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.2012 - accuracy: 0.9273 - val_loss: 0.3565 - val_accuracy: 0.8545
# Epoch 10/10
# 546/546 [==============================] - 7s 12ms/step - loss: 0.1920 - accuracy: 0.9316 - val_loss: 0.3679 - val_accuracy: 0.8511
#
# Validation Accuracy: 0.8511335253715515
# Validation Loss: 0.3678637444972992
#
# 468/468 [==============================] - 2s 4ms/step
#
#               precision    recall  f1-score   support
#
#            0     0.8347    0.8389    0.8368      6803
#            1     0.8650    0.8613    0.8632      8150
#
#     accuracy                         0.8511     14953
#    macro avg     0.8498    0.8501    0.8500     14953
# weighted avg     0.8512    0.8511    0.8512     14953

# %%
def loss_func(df):
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val}')
    plt.title(f'baseline CNN-BiGRU lfg {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}-{idx}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/cnn+bigru/lfg_baselineCNNBiGRU_testSize{df["Test_Size"].iloc[idx]}-{idx}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_CNNbiGRU-3.csv', index=False)
loss_func(df)

# print average score by test size
print('Test_Size 0.3 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.3 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.3 & max features 20000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.3) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
# Out:
# Test_Size 0.3 & max features 5000
# Average Accuracy Score : 0.8580485521300073
# Average Precision Score : 0.8675964834889898
# Average Recall Score : 0.8727852760736197
# Average F1 Score : 0.8580011511168764
#
# Test_Size 0.3 & max features 10000
# Average Accuracy Score : 0.8550123720992444
# Average Precision Score : 0.8651214132916383
# Average Recall Score : 0.869717791411043
# Average F1 Score : 0.854957314169168
#
# Test_Size 0.3 & max features 20000
# Average Accuracy Score : 0.8530194609777302
# Average Precision Score : 0.8642368523592199
# Average Recall Score : 0.8664785276073619
# Average F1 Score : 0.8529965530159714
