# %% [markdown]
# Baseline Deteksi Ujaran Kebencian Metode BiGru
#
# Copyright@ I Gde Bagus Janardana Abasan

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional, AveragePooling1D, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, GlobalMaxPooling1D, CuDNNGRU , GlobalAveragePooling1D, Concatenate, TimeDistributed
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# check tensorflow version
# 2.9.1 untuk version paperspace
# 2.11 untuk collab
print(tf.__version__)
# Out:
# 2.9.3

# %% [markdown]
# ## BIGRU MODEL BASELINE
# 1. Tanpa TF-IDF ( CountVectorize )
# 2. Testing Test Size ( splitting )
#
# Expected Result :
# 1. test-size yang bagus untuk model ini.

# %%
# Menampilkan informasi perangkat GPU yang digunakan
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    device_details = tf.config.experimental.get_device_details(device)
    print(device_details)

try:
    print(f'Found {physical_devices[0]} GPU(s)')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    assert tf.config.experimental.get_memory_growth(physical_devices[0])
    print('Memory growth set to True, using Nvidia Tesla T4')
except:
    print('Failed to set memory growth to True')
    pass
# Out:
# {'compute_capability': (7, 5), 'device_name': 'Tesla T4'}
# Found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') GPU(s)
# Memory growth set to True, using Nvidia Tesla T4

# %%
def process_data(test_size, max_features):
  dataset = pd.read_csv('../../data/data_preprocessed/dataset/DatasetHateSpeech_Final_TA2023.csv', usecols=['preprocess_final', 'preprocess_token', 'label_final'])
  # make data['label_fase_1'] to 0 and 1 binary classifier karena tensor hanya bisa input 0 =< label =< 1
  dataset['label_final'] = dataset['label_final'].apply(lambda x: 1 if x == 'HS' else 0)
  dataset.dropna(inplace=True)
  
  # feature extration
  # Create a CountVectorizer object and fit it to the training data
  vectorizer = TfidfVectorizer(ngram_range=(1,1), max_features=max_features)
  vectorizer_data = vectorizer.fit_transform(dataset['preprocess_final'])

  # to_pd
  x_final = pd.DataFrame(vectorizer_data.toarray(), columns=vectorizer.get_feature_names_out())
  y_final = dataset['label_final'].copy()

  # split
  X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size=test_size, random_state=0)
  return X_train, X_test, y_train, y_test

# %%
def create_bigru_model(X_train, y_train, X_test, y_test, units):
  # reshape# reshape train and test data
  X_train = np.array(X_train).reshape(X_train.shape[0], 1, X_train.shape[1])
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])

  # create sequential model
  model = Sequential()
  model.add(Bidirectional(GRU(units, input_shape=(X_train.shape), activation='relu', return_sequences=True)))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(units = 32, activation='relu'))
  model.add(Dense(units = 1, activation='sigmoid'))

  opt = Adam(learning_rate=0.00005)
  model.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['accuracy'])

  input_shape = X_train.shape
  model.build(input_shape)
  model.summary()
  print()

  with tf.device('/cpu:0'):
    x = tf.convert_to_tensor(X_train, np.float32)
    y = tf.convert_to_tensor(y_train, np.float32)

  model.fit(x, y, epochs=10, batch_size = 128, validation_data = (X_test, y_test))
  loss = model.history.history['loss']
  val_loss = model.history.history['val_loss']
  score = model.evaluate(X_test, y_test, batch_size=128, verbose=0)
  print()
  print('Validation Accuracy:', score[1])
  print('Validation Loss:', score[0])
  print()

  return model, loss, val_loss

# %% [markdown]
# ###  Test Size

# %%
def call(test_size, max_features):
  X_train, X_test, y_train, y_test = process_data(test_size, max_features)
  model, loss, val_loss = create_bigru_model(X_train, y_train, X_test, y_test, 32)
  # predict
  X_test = np.array(X_test).reshape(X_test.shape[0], 1, X_test.shape[1])
  
  y_pred = model.predict(X_test)
  print('using test size :', test_size)
  print()

  # confusion matrix
  classreport = classification_report(y_test, y_pred.round(), digits=4)
  print()
  print(classreport)
  print()
  accscore = accuracy_score(y_test, y_pred.round())
  precscore = precision_score(y_test, y_pred.round(), zero_division=0)
  recscore = recall_score(y_test, y_pred.round())
  f1score = f1_score(y_test, y_pred.round(), average='weighted', zero_division=0)

  return [accscore, precscore, recscore, f1score, loss, val_loss]

# %%
test_size = [0.1]
max_features = [5000, 10000, 15000]
result = []
count = 1
for idx, value_testsize in enumerate(test_size):
  for idx_max, value_features in enumerate(max_features):
    for i in range(5):
      result.append([count] + [value_testsize] + [value_features] + call(value_testsize, value_features))
      count += 1
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (44856, 1, 64)           966528
#  l)
#
#  global_max_pooling1d (Globa  (44856, 64)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (44856, 32)               2080
#
#  dense_1 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 12ms/step - loss: 0.6876 - accuracy: 0.5459 - val_loss: 0.6766 - val_accuracy: 0.5595
# Epoch 2/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.6497 - accuracy: 0.6743 - val_loss: 0.6160 - val_accuracy: 0.7735
# Epoch 3/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.5720 - accuracy: 0.8160 - val_loss: 0.5326 - val_accuracy: 0.8307
# Epoch 4/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4882 - accuracy: 0.8501 - val_loss: 0.4598 - val_accuracy: 0.8530
# Epoch 5/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4222 - accuracy: 0.8612 - val_loss: 0.4089 - val_accuracy: 0.8562
# Epoch 6/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3771 - accuracy: 0.8673 - val_loss: 0.3767 - val_accuracy: 0.8590
# Epoch 7/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3474 - accuracy: 0.8725 - val_loss: 0.3560 - val_accuracy: 0.8592
# Epoch 8/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3272 - accuracy: 0.8762 - val_loss: 0.3432 - val_accuracy: 0.8634
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3129 - accuracy: 0.8793 - val_loss: 0.3351 - val_accuracy: 0.8642
# Epoch 10/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3024 - accuracy: 0.8820 - val_loss: 0.3293 - val_accuracy: 0.8652
#
# Validation Accuracy: 0.8651955723762512
# Validation Loss: 0.32932910323143005
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8668    0.8316    0.8489      2269
#            1     0.8640    0.8932    0.8783      2716
#
#     accuracy                         0.8652      4985
#    macro avg     0.8654    0.8624    0.8636      4985
# weighted avg     0.8652    0.8652    0.8649      4985
#
#
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_1 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (44856, 32)               2080
#
#  dense_3 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 6s 11ms/step - loss: 0.6869 - accuracy: 0.5524 - val_loss: 0.6757 - val_accuracy: 0.5807
# Epoch 2/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.6477 - accuracy: 0.7007 - val_loss: 0.6149 - val_accuracy: 0.7671
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5702 - accuracy: 0.8204 - val_loss: 0.5318 - val_accuracy: 0.8337
# Epoch 4/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4864 - accuracy: 0.8520 - val_loss: 0.4592 - val_accuracy: 0.8506
# Epoch 5/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4205 - accuracy: 0.8626 - val_loss: 0.4086 - val_accuracy: 0.8544
# Epoch 6/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3757 - accuracy: 0.8681 - val_loss: 0.3764 - val_accuracy: 0.8566
# Epoch 7/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3462 - accuracy: 0.8731 - val_loss: 0.3565 - val_accuracy: 0.8596
# Epoch 8/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3262 - accuracy: 0.8769 - val_loss: 0.3435 - val_accuracy: 0.8620
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3121 - accuracy: 0.8796 - val_loss: 0.3357 - val_accuracy: 0.8638
# Epoch 10/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3016 - accuracy: 0.8828 - val_loss: 0.3300 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.3299638330936432
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8648    0.8369    0.8506      2269
#            1     0.8673    0.8906    0.8788      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8660    0.8638    0.8647      4985
# weighted avg     0.8662    0.8662    0.8660      4985
#
#
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_2 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (44856, 32)               2080
#
#  dense_5 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 6s 11ms/step - loss: 0.6870 - accuracy: 0.6266 - val_loss: 0.6750 - val_accuracy: 0.7593
# Epoch 2/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.6453 - accuracy: 0.8192 - val_loss: 0.6098 - val_accuracy: 0.8431
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5632 - accuracy: 0.8520 - val_loss: 0.5234 - val_accuracy: 0.8469
# Epoch 4/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4775 - accuracy: 0.8584 - val_loss: 0.4505 - val_accuracy: 0.8514
# Epoch 5/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.4125 - accuracy: 0.8638 - val_loss: 0.4015 - val_accuracy: 0.8552
# Epoch 6/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3694 - accuracy: 0.8695 - val_loss: 0.3710 - val_accuracy: 0.8592
# Epoch 7/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3411 - accuracy: 0.8738 - val_loss: 0.3521 - val_accuracy: 0.8612
# Epoch 8/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3218 - accuracy: 0.8778 - val_loss: 0.3404 - val_accuracy: 0.8628
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3082 - accuracy: 0.8810 - val_loss: 0.3328 - val_accuracy: 0.8650
# Epoch 10/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.2980 - accuracy: 0.8833 - val_loss: 0.3277 - val_accuracy: 0.8658
#
# Validation Accuracy: 0.8657974004745483
# Validation Loss: 0.3276640772819519
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8693    0.8299    0.8492      2269
#            1     0.8631    0.8958    0.8791      2716
#
#     accuracy                         0.8658      4985
#    macro avg     0.8662    0.8628    0.8641      4985
# weighted avg     0.8659    0.8658    0.8655      4985
#
#
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_3 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (44856, 32)               2080
#
#  dense_7 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 11ms/step - loss: 0.6845 - accuracy: 0.5448 - val_loss: 0.6703 - val_accuracy: 0.5452
# Epoch 2/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.6402 - accuracy: 0.6269 - val_loss: 0.6059 - val_accuracy: 0.7141
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5639 - accuracy: 0.7804 - val_loss: 0.5291 - val_accuracy: 0.8177
# Epoch 4/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4874 - accuracy: 0.8404 - val_loss: 0.4633 - val_accuracy: 0.8473
# Epoch 5/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4257 - accuracy: 0.8620 - val_loss: 0.4146 - val_accuracy: 0.8528
# Epoch 6/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3806 - accuracy: 0.8696 - val_loss: 0.3805 - val_accuracy: 0.8606
# Epoch 7/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3490 - accuracy: 0.8752 - val_loss: 0.3582 - val_accuracy: 0.8632
# Epoch 8/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3273 - accuracy: 0.8784 - val_loss: 0.3444 - val_accuracy: 0.8640
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3122 - accuracy: 0.8819 - val_loss: 0.3354 - val_accuracy: 0.8628
# Epoch 10/10
# 351/351 [==============================] - 4s 10ms/step - loss: 0.3012 - accuracy: 0.8845 - val_loss: 0.3300 - val_accuracy: 0.8624
#
# Validation Accuracy: 0.8623871803283691
# Validation Loss: 0.3300091624259949
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8593    0.8343    0.8466      2269
#            1     0.8648    0.8859    0.8752      2716
#
#     accuracy                         0.8624      4985
#    macro avg     0.8621    0.8601    0.8609      4985
# weighted avg     0.8623    0.8624    0.8622      4985
#
#
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (44856, 1, 64)           966528
#  nal)
#
#  global_max_pooling1d_4 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (44856, 32)               2080
#
#  dense_9 (Dense)             (44856, 1)                33
#
# =================================================================
# Total params: 968,641
# Trainable params: 968,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 6s 11ms/step - loss: 0.6884 - accuracy: 0.5874 - val_loss: 0.6786 - val_accuracy: 0.7079
# Epoch 2/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.6539 - accuracy: 0.8076 - val_loss: 0.6234 - val_accuracy: 0.8479
# Epoch 3/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.5805 - accuracy: 0.8523 - val_loss: 0.5421 - val_accuracy: 0.8487
# Epoch 4/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4965 - accuracy: 0.8579 - val_loss: 0.4669 - val_accuracy: 0.8520
# Epoch 5/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.4277 - accuracy: 0.8629 - val_loss: 0.4133 - val_accuracy: 0.8570
# Epoch 6/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3804 - accuracy: 0.8677 - val_loss: 0.3794 - val_accuracy: 0.8592
# Epoch 7/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3493 - accuracy: 0.8719 - val_loss: 0.3585 - val_accuracy: 0.8612
# Epoch 8/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3283 - accuracy: 0.8756 - val_loss: 0.3442 - val_accuracy: 0.8626
# Epoch 9/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3134 - accuracy: 0.8791 - val_loss: 0.3354 - val_accuracy: 0.8628
# Epoch 10/10
# 351/351 [==============================] - 3s 10ms/step - loss: 0.3025 - accuracy: 0.8820 - val_loss: 0.3297 - val_accuracy: 0.8662
#
# Validation Accuracy: 0.8661985993385315
# Validation Loss: 0.32972651720046997
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8681    0.8325    0.8499      2269
#            1     0.8647    0.8943    0.8793      2716
#
#     accuracy                         0.8662      4985
#    macro avg     0.8664    0.8634    0.8646      4985
# weighted avg     0.8663    0.8662    0.8659      4985
#
#
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_5 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_5 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_10 (Dense)            (44856, 32)               2080
#
#  dense_11 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6853 - accuracy: 0.5563 - val_loss: 0.6708 - val_accuracy: 0.6421
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6399 - accuracy: 0.7347 - val_loss: 0.6049 - val_accuracy: 0.7968
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5586 - accuracy: 0.8331 - val_loss: 0.5214 - val_accuracy: 0.8385
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4735 - accuracy: 0.8585 - val_loss: 0.4494 - val_accuracy: 0.8552
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4068 - accuracy: 0.8689 - val_loss: 0.4000 - val_accuracy: 0.8582
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3610 - accuracy: 0.8754 - val_loss: 0.3687 - val_accuracy: 0.8618
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3300 - accuracy: 0.8807 - val_loss: 0.3490 - val_accuracy: 0.8652
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3082 - accuracy: 0.8858 - val_loss: 0.3365 - val_accuracy: 0.8636
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2922 - accuracy: 0.8894 - val_loss: 0.3296 - val_accuracy: 0.8646
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2799 - accuracy: 0.8934 - val_loss: 0.3244 - val_accuracy: 0.8656
#
# Validation Accuracy: 0.8655967712402344
# Validation Loss: 0.32442882657051086
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8683    0.8308    0.8491      2269
#            1     0.8635    0.8947    0.8788      2716
#
#     accuracy                         0.8656      4985
#    macro avg     0.8659    0.8627    0.8640      4985
# weighted avg     0.8657    0.8656    0.8653      4985
#
#
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_6 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_12 (Dense)            (44856, 32)               2080
#
#  dense_13 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 13ms/step - loss: 0.6856 - accuracy: 0.5470 - val_loss: 0.6721 - val_accuracy: 0.5683
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6429 - accuracy: 0.6798 - val_loss: 0.6106 - val_accuracy: 0.7478
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5666 - accuracy: 0.8060 - val_loss: 0.5316 - val_accuracy: 0.8197
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4850 - accuracy: 0.8519 - val_loss: 0.4610 - val_accuracy: 0.8495
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4183 - accuracy: 0.8672 - val_loss: 0.4102 - val_accuracy: 0.8572
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3706 - accuracy: 0.8747 - val_loss: 0.3760 - val_accuracy: 0.8608
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3374 - accuracy: 0.8797 - val_loss: 0.3541 - val_accuracy: 0.8662
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3142 - accuracy: 0.8849 - val_loss: 0.3404 - val_accuracy: 0.8644
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2972 - accuracy: 0.8894 - val_loss: 0.3317 - val_accuracy: 0.8650
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2843 - accuracy: 0.8927 - val_loss: 0.3262 - val_accuracy: 0.8650
#
# Validation Accuracy: 0.864995002746582
# Validation Loss: 0.3261687457561493
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8624    0.8369    0.8495      2269
#            1     0.8670    0.8884    0.8776      2716
#
#     accuracy                         0.8650      4985
#    macro avg     0.8647    0.8627    0.8635      4985
# weighted avg     0.8649    0.8650    0.8648      4985
#
#
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_7 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_14 (Dense)            (44856, 32)               2080
#
#  dense_15 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 13ms/step - loss: 0.6850 - accuracy: 0.5454 - val_loss: 0.6712 - val_accuracy: 0.5507
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6414 - accuracy: 0.6457 - val_loss: 0.6085 - val_accuracy: 0.7198
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5664 - accuracy: 0.7827 - val_loss: 0.5348 - val_accuracy: 0.8058
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4907 - accuracy: 0.8437 - val_loss: 0.4694 - val_accuracy: 0.8403
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4267 - accuracy: 0.8670 - val_loss: 0.4184 - val_accuracy: 0.8566
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3776 - accuracy: 0.8758 - val_loss: 0.3822 - val_accuracy: 0.8614
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3421 - accuracy: 0.8822 - val_loss: 0.3584 - val_accuracy: 0.8660
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3169 - accuracy: 0.8873 - val_loss: 0.3429 - val_accuracy: 0.8652
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2986 - accuracy: 0.8909 - val_loss: 0.3332 - val_accuracy: 0.8660
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2848 - accuracy: 0.8945 - val_loss: 0.3274 - val_accuracy: 0.8660
#
# Validation Accuracy: 0.8659979701042175
# Validation Loss: 0.32743415236473083
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8691    0.8308    0.8495      2269
#            1     0.8636    0.8954    0.8792      2716
#
#     accuracy                         0.8660      4985
#    macro avg     0.8664    0.8631    0.8644      4985
# weighted avg     0.8661    0.8660    0.8657      4985
#
#
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_8 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_16 (Dense)            (44856, 32)               2080
#
#  dense_17 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 13ms/step - loss: 0.6867 - accuracy: 0.5738 - val_loss: 0.6742 - val_accuracy: 0.6520
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6483 - accuracy: 0.7468 - val_loss: 0.6183 - val_accuracy: 0.8038
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5753 - accuracy: 0.8353 - val_loss: 0.5388 - val_accuracy: 0.8413
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4927 - accuracy: 0.8583 - val_loss: 0.4665 - val_accuracy: 0.8520
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4243 - accuracy: 0.8664 - val_loss: 0.4137 - val_accuracy: 0.8568
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3757 - accuracy: 0.8730 - val_loss: 0.3792 - val_accuracy: 0.8590
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3424 - accuracy: 0.8776 - val_loss: 0.3572 - val_accuracy: 0.8608
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3189 - accuracy: 0.8819 - val_loss: 0.3428 - val_accuracy: 0.8626
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3014 - accuracy: 0.8874 - val_loss: 0.3332 - val_accuracy: 0.8618
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2881 - accuracy: 0.8906 - val_loss: 0.3272 - val_accuracy: 0.8640
#
# Validation Accuracy: 0.8639919757843018
# Validation Loss: 0.32718396186828613
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8674    0.8277    0.8471      2269
#            1     0.8613    0.8943    0.8775      2716
#
#     accuracy                         0.8640      4985
#    macro avg     0.8644    0.8610    0.8623      4985
# weighted avg     0.8641    0.8640    0.8637      4985
#
#
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_9 (Bidirectio  (44856, 1, 64)           1926528
#  nal)
#
#  global_max_pooling1d_9 (Glo  (44856, 64)              0
#  balMaxPooling1D)
#
#  dense_18 (Dense)            (44856, 32)               2080
#
#  dense_19 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 1,928,641
# Trainable params: 1,928,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 12ms/step - loss: 0.6865 - accuracy: 0.6036 - val_loss: 0.6728 - val_accuracy: 0.7398
# Epoch 2/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.6418 - accuracy: 0.8153 - val_loss: 0.6070 - val_accuracy: 0.8445
# Epoch 3/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.5600 - accuracy: 0.8557 - val_loss: 0.5227 - val_accuracy: 0.8520
# Epoch 4/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4754 - accuracy: 0.8635 - val_loss: 0.4515 - val_accuracy: 0.8536
# Epoch 5/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.4095 - accuracy: 0.8693 - val_loss: 0.4028 - val_accuracy: 0.8580
# Epoch 6/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3643 - accuracy: 0.8746 - val_loss: 0.3710 - val_accuracy: 0.8620
# Epoch 7/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3333 - accuracy: 0.8799 - val_loss: 0.3509 - val_accuracy: 0.8624
# Epoch 8/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.3112 - accuracy: 0.8848 - val_loss: 0.3379 - val_accuracy: 0.8656
# Epoch 9/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2948 - accuracy: 0.8891 - val_loss: 0.3295 - val_accuracy: 0.8662
# Epoch 10/10
# 351/351 [==============================] - 4s 11ms/step - loss: 0.2820 - accuracy: 0.8931 - val_loss: 0.3243 - val_accuracy: 0.8666
#
# Validation Accuracy: 0.8665997982025146
# Validation Loss: 0.3243200182914734
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8713    0.8294    0.8499      2269
#            1     0.8630    0.8976    0.8800      2716
#
#     accuracy                         0.8666      4985
#    macro avg     0.8672    0.8635    0.8649      4985
# weighted avg     0.8668    0.8666    0.8663      4985
#
#
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_10 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_10 (Gl  (44856, 64)              0
#  obalMaxPooling1D)
#
#  dense_20 (Dense)            (44856, 32)               2080
#
#  dense_21 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 15ms/step - loss: 0.6846 - accuracy: 0.5895 - val_loss: 0.6679 - val_accuracy: 0.6895
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6356 - accuracy: 0.7848 - val_loss: 0.6012 - val_accuracy: 0.8237
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5548 - accuracy: 0.8489 - val_loss: 0.5197 - val_accuracy: 0.8497
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4709 - accuracy: 0.8646 - val_loss: 0.4495 - val_accuracy: 0.8538
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4039 - accuracy: 0.8722 - val_loss: 0.3994 - val_accuracy: 0.8586
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3563 - accuracy: 0.8787 - val_loss: 0.3677 - val_accuracy: 0.8602
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3240 - accuracy: 0.8841 - val_loss: 0.3482 - val_accuracy: 0.8646
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3009 - accuracy: 0.8903 - val_loss: 0.3359 - val_accuracy: 0.8652
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2837 - accuracy: 0.8948 - val_loss: 0.3284 - val_accuracy: 0.8644
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2701 - accuracy: 0.8993 - val_loss: 0.3243 - val_accuracy: 0.8646
#
# Validation Accuracy: 0.8645938038825989
# Validation Loss: 0.324291855096817
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8690    0.8272    0.8476      2269
#            1     0.8612    0.8958    0.8782      2716
#
#     accuracy                         0.8646      4985
#    macro avg     0.8651    0.8615    0.8629      4985
# weighted avg     0.8648    0.8646    0.8643      4985
#
#
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_11 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_11 (Gl  (44856, 64)              0
#  obalMaxPooling1D)
#
#  dense_22 (Dense)            (44856, 32)               2080
#
#  dense_23 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 15ms/step - loss: 0.6859 - accuracy: 0.5779 - val_loss: 0.6715 - val_accuracy: 0.6712
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6424 - accuracy: 0.7585 - val_loss: 0.6104 - val_accuracy: 0.8084
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5646 - accuracy: 0.8380 - val_loss: 0.5286 - val_accuracy: 0.8421
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4793 - accuracy: 0.8612 - val_loss: 0.4561 - val_accuracy: 0.8534
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4102 - accuracy: 0.8715 - val_loss: 0.4049 - val_accuracy: 0.8568
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3618 - accuracy: 0.8774 - val_loss: 0.3719 - val_accuracy: 0.8598
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3286 - accuracy: 0.8836 - val_loss: 0.3515 - val_accuracy: 0.8630
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3050 - accuracy: 0.8893 - val_loss: 0.3384 - val_accuracy: 0.8626
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2873 - accuracy: 0.8941 - val_loss: 0.3304 - val_accuracy: 0.8640
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2735 - accuracy: 0.8981 - val_loss: 0.3256 - val_accuracy: 0.8664
#
# Validation Accuracy: 0.8663991689682007
# Validation Loss: 0.325614333152771
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8692    0.8316    0.8500      2269
#            1     0.8643    0.8954    0.8796      2716
#
#     accuracy                         0.8664      4985
#    macro avg     0.8667    0.8635    0.8648      4985
# weighted avg     0.8665    0.8664    0.8661      4985
#
#
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_12 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_12 (Gl  (44856, 64)              0
#  obalMaxPooling1D)
#
#  dense_24 (Dense)            (44856, 32)               2080
#
#  dense_25 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6850 - accuracy: 0.5521 - val_loss: 0.6692 - val_accuracy: 0.6032
# Epoch 2/10
# 351/351 [==============================] - 4s 13ms/step - loss: 0.6350 - accuracy: 0.7332 - val_loss: 0.5981 - val_accuracy: 0.7862
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5491 - accuracy: 0.8352 - val_loss: 0.5130 - val_accuracy: 0.8373
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4638 - accuracy: 0.8625 - val_loss: 0.4437 - val_accuracy: 0.8522
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3987 - accuracy: 0.8718 - val_loss: 0.3963 - val_accuracy: 0.8578
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3533 - accuracy: 0.8789 - val_loss: 0.3660 - val_accuracy: 0.8624
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3220 - accuracy: 0.8848 - val_loss: 0.3473 - val_accuracy: 0.8636
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2995 - accuracy: 0.8907 - val_loss: 0.3354 - val_accuracy: 0.8638
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2825 - accuracy: 0.8959 - val_loss: 0.3283 - val_accuracy: 0.8658
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2692 - accuracy: 0.9001 - val_loss: 0.3240 - val_accuracy: 0.8658
#
# Validation Accuracy: 0.8657974004745483
# Validation Loss: 0.32404643297195435
#
# 156/156 [==============================] - 1s 3ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8653    0.8352    0.8500      2269
#            1     0.8662    0.8914    0.8786      2716
#
#     accuracy                         0.8658      4985
#    macro avg     0.8657    0.8633    0.8643      4985
# weighted avg     0.8658    0.8658    0.8656      4985
#
#
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_13 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_13 (Gl  (44856, 64)              0
#  obalMaxPooling1D)
#
#  dense_26 (Dense)            (44856, 32)               2080
#
#  dense_27 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 8s 14ms/step - loss: 0.6838 - accuracy: 0.5456 - val_loss: 0.6679 - val_accuracy: 0.5519
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6394 - accuracy: 0.6275 - val_loss: 0.6107 - val_accuracy: 0.7093
# Epoch 3/10
# 351/351 [==============================] - 4s 13ms/step - loss: 0.5736 - accuracy: 0.7549 - val_loss: 0.5483 - val_accuracy: 0.7805
# Epoch 4/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5079 - accuracy: 0.8287 - val_loss: 0.4914 - val_accuracy: 0.8247
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4486 - accuracy: 0.8623 - val_loss: 0.4420 - val_accuracy: 0.8554
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3976 - accuracy: 0.8788 - val_loss: 0.4023 - val_accuracy: 0.8608
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3561 - accuracy: 0.8867 - val_loss: 0.3730 - val_accuracy: 0.8634
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3243 - accuracy: 0.8916 - val_loss: 0.3527 - val_accuracy: 0.8652
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3006 - accuracy: 0.8964 - val_loss: 0.3398 - val_accuracy: 0.8642
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2828 - accuracy: 0.9004 - val_loss: 0.3315 - val_accuracy: 0.8638
#
# Validation Accuracy: 0.8637913465499878
# Validation Loss: 0.33150437474250793
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8667    0.8281    0.8470      2269
#            1     0.8616    0.8936    0.8773      2716
#
#     accuracy                         0.8638      4985
#    macro avg     0.8641    0.8609    0.8621      4985
# weighted avg     0.8639    0.8638    0.8635      4985
#
#
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_14 (Bidirecti  (44856, 1, 64)           2886528
#  onal)
#
#  global_max_pooling1d_14 (Gl  (44856, 64)              0
#  obalMaxPooling1D)
#
#  dense_28 (Dense)            (44856, 32)               2080
#
#  dense_29 (Dense)            (44856, 1)                33
#
# =================================================================
# Total params: 2,888,641
# Trainable params: 2,888,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 351/351 [==============================] - 7s 14ms/step - loss: 0.6848 - accuracy: 0.5938 - val_loss: 0.6680 - val_accuracy: 0.7127
# Epoch 2/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.6353 - accuracy: 0.7951 - val_loss: 0.6001 - val_accuracy: 0.8223
# Epoch 3/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.5527 - accuracy: 0.8513 - val_loss: 0.5166 - val_accuracy: 0.8497
# Epoch 4/10
# 351/351 [==============================] - 4s 13ms/step - loss: 0.4677 - accuracy: 0.8652 - val_loss: 0.4458 - val_accuracy: 0.8542
# Epoch 5/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.4008 - accuracy: 0.8718 - val_loss: 0.3969 - val_accuracy: 0.8586
# Epoch 6/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3545 - accuracy: 0.8784 - val_loss: 0.3662 - val_accuracy: 0.8614
# Epoch 7/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3229 - accuracy: 0.8848 - val_loss: 0.3472 - val_accuracy: 0.8650
# Epoch 8/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.3002 - accuracy: 0.8900 - val_loss: 0.3353 - val_accuracy: 0.8664
# Epoch 9/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2831 - accuracy: 0.8951 - val_loss: 0.3278 - val_accuracy: 0.8654
# Epoch 10/10
# 351/351 [==============================] - 4s 12ms/step - loss: 0.2695 - accuracy: 0.8994 - val_loss: 0.3232 - val_accuracy: 0.8656
#
# Validation Accuracy: 0.8655967712402344
# Validation Loss: 0.32317033410072327
#
# 156/156 [==============================] - 1s 2ms/step
# using test size : 0.1
#
#
#               precision    recall  f1-score   support
#
#            0     0.8679    0.8312    0.8492      2269
#            1     0.8638    0.8943    0.8788      2716
#
#     accuracy                         0.8656      4985
#    macro avg     0.8659    0.8628    0.8640      4985
# weighted avg     0.8657    0.8656    0.8653      4985

# %%
def loss_func(df):
  # plot loss function rata-rata
  # plot loss function
  for idx, val in enumerate(df['No']):
    plt.plot(df['Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.plot(df['Val Loss'].iloc[idx], label=f'Test Size {val} ke {idx+1}')
    plt.title(f'loss function test size {df["Test_Size"].iloc[idx]} max_features {df["Max_Features"].iloc[idx]}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.savefig(f'hasil/grafik/bigru/lfg_baselineBiGRU_testSize{df["Test_Size"].iloc[idx]}-max_features{df["Max_Features"].iloc[idx]}.png')
    plt.show()
    plt.clf()

# %%
df = pd.DataFrame(result, columns=['No', 'Test_Size', 'Max_Features', 'Accuracy Score', 'Precision Score', 'Recall Score', 'F1 Score', 'Loss', 'Val Loss'])
df.to_csv('hasil/baseline_BiGRU-1.csv', index=False)
loss_func(df)

# print average score by test size
print('Average Score by Test Size')
print('Test Size 0.1 & max features 5000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 5000)]['F1 Score'].mean())
print()
print('Test_Size 0.1 & max features 10000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 10000)]['F1 Score'].mean())
print()
print('Test_Size 0.1 & max features 15000')
print('Average Accuracy Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Accuracy Score'].mean())
print('Average Precision Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Precision Score'].mean())
print('Average Recall Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['Recall Score'].mean())
print('Average F1 Score :', df[(df['Test_Size'] == 0.1) & (df['Max_Features'] == 15000)]['F1 Score'].mean())
# Out:
# Average Score by Test Size
# Test Size 0.1 & max features 5000
# Average Accuracy Score : 0.8651554663991977
# Average Precision Score : 0.8647868128158069
# Average Recall Score : 0.8919734904270987
# Average F1 Score : 0.8649051390623514
#
# Test_Size 0.1 & max features 10000
# Average Accuracy Score : 0.8654363089267804
# Average Precision Score : 0.8637164245309419
# Average Recall Score : 0.8941089837997055
# Average F1 Score : 0.8651509155842593
#
# Test_Size 0.1 & max features 15000
# Average Accuracy Score : 0.8652357071213641
# Average Precision Score : 0.8634063188361051
# Average Recall Score : 0.8941089837997055
# Average F1 Score : 0.8649468380869045
